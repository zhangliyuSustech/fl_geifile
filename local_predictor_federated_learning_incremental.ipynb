# %%
import torch
import torch.nn as nn
import pickle as pk
import numpy as np
from model import LocalPredictor
import random

# %%
data = dict({})
for d in range(1, 29):
    filename = '/data/fan/UsersInTokyoProcessed/201210{:02d}_interp.pk'.format(d)
    print(filename)
    with open(filename, 'rb') as f:
        data[d] = pk.load(f)
# Out:
# /data/fan/UsersInTokyoProcessed/20121001_interp.pk
# /data/fan/UsersInTokyoProcessed/20121002_interp.pk
# /data/fan/UsersInTokyoProcessed/20121003_interp.pk
# /data/fan/UsersInTokyoProcessed/20121004_interp.pk
# /data/fan/UsersInTokyoProcessed/20121005_interp.pk
# /data/fan/UsersInTokyoProcessed/20121006_interp.pk
# /data/fan/UsersInTokyoProcessed/20121007_interp.pk
# /data/fan/UsersInTokyoProcessed/20121008_interp.pk
# /data/fan/UsersInTokyoProcessed/20121009_interp.pk
# /data/fan/UsersInTokyoProcessed/20121010_interp.pk
# /data/fan/UsersInTokyoProcessed/20121011_interp.pk
# /data/fan/UsersInTokyoProcessed/20121012_interp.pk
# /data/fan/UsersInTokyoProcessed/20121013_interp.pk
# /data/fan/UsersInTokyoProcessed/20121014_interp.pk
# /data/fan/UsersInTokyoProcessed/20121015_interp.pk
# /data/fan/UsersInTokyoProcessed/20121016_interp.pk
# /data/fan/UsersInTokyoProcessed/20121017_interp.pk
# /data/fan/UsersInTokyoProcessed/20121018_interp.pk
# /data/fan/UsersInTokyoProcessed/20121019_interp.pk
# /data/fan/UsersInTokyoProcessed/20121020_interp.pk
# /data/fan/UsersInTokyoProcessed/20121021_interp.pk
# /data/fan/UsersInTokyoProcessed/20121022_interp.pk
# /data/fan/UsersInTokyoProcessed/20121023_interp.pk
# /data/fan/UsersInTokyoProcessed/20121024_interp.pk
# /data/fan/UsersInTokyoProcessed/20121025_interp.pk
# /data/fan/UsersInTokyoProcessed/20121026_interp.pk
# /data/fan/UsersInTokyoProcessed/20121027_interp.pk
# /data/fan/UsersInTokyoProcessed/20121028_interp.pk

# %%
uid_sets = dict({})
for d in data:
    uid_sets[d] = set(list(data[d].keys()))

# %%
uid_doc_set = set([])
for d in range(1, 15):
    uid_doc_set = uid_doc_set | uid_sets[d]

# %%
data_doc = dict({})
data_qry_train = dict({})
data_qry_test = dict({})

for d in range(1, 15):
    for uid in data[d]:
        if uid not in data_doc:
            data_doc[uid] = [data[d][uid]]
        else:
            data_doc[uid].append(data[d][uid])

for d in range(15, 22):
    for uid in data[d]:
        if uid not in data_qry_train:
            data_qry_train[uid] = [data[d][uid]]
        else:
            data_qry_train[uid].append(data[d][uid])
            
for d in range(22, 29):
    for uid in data[d]:
        if uid not in data_qry_test:
            data_qry_test[uid] = [data[d][uid]]
        else:
            data_qry_test[uid].append(data[d][uid])

# %%
for uid in data_doc:
    data_doc[uid] = torch.LongTensor(data_doc[uid]).cuda(0)

for uid in data_qry_train:
    data_qry_train[uid] = torch.LongTensor(data_qry_train[uid]).cuda(0)
    
for uid in data_qry_test:
    data_qry_test[uid] = torch.LongTensor(data_qry_test[uid]).cuda(0)

# %%
num_locs = 1600
loc_embedding_dim = 128
T = 96
num_time = T
time_embedding_dim = 32
hidden_dim = 256
latent_dim = 256

# %%
lr = 1e-3
momentum = 0.8

# %%
local_predictor = LocalPredictor(num_locs, loc_embedding_dim, num_time, time_embedding_dim, hidden_dim, latent_dim).cuda(0)
local_predictor_server = LocalPredictor(num_locs, loc_embedding_dim, num_time, time_embedding_dim, hidden_dim, latent_dim).cuda(0)
optimizer = torch.optim.SGD(local_predictor.parameters(), lr=lr)
optimizer.zero_grad()

# %%
local_predictor_server.load_state_dict(torch.load('./results_tokyo/local_predictor_open.pytorch').state_dict())

# %%
dT = 4

# %%
training_loss = dict({})
validation_loss = dict({})

# %%
user_list_train = list(data_qry_train.keys())
time_list = list(range(T - 2 * dT + 1))

# Initialize global SGD
local_predictor_update = dict({})
        
for epoch in range(2001, 3001):
    
    if epoch % 500 == 0:
        lr *= 0.5
    
    update_user_list = random.sample(user_list_train, 2048)
    random.shuffle(update_user_list)
    
    avg_loss = 0.0
    cnt = 0
    n = 0
    
    uidx = 0
    
    for uid in update_user_list:
        uidx += 1
        # loading server model to local
        local_predictor.load_state_dict(local_predictor_server.state_dict())

        nk = data_qry_train[uid].shape[0]
        n += data_qry_train[uid].shape[0]

        t = np.random.randint(T - 2 * dT + 1)
        x_loc_qry = data_qry_train[uid][:, t: t + dT]
        x_t_qry = torch.zeros_like(x_loc_qry) + t
        y = data_qry_train[uid][:, t + 2 * dT - 1]

        if uid not in data_doc:
            loss = local_predictor(x_loc_qry, x_t_qry, None, None, y)
        else:
            x_loc_doc = data_doc[uid][:, t: t + 2 * dT]
            x_t_doc = torch.zeros_like(x_loc_doc) + t
            loss = local_predictor(x_loc_qry, x_t_qry, x_loc_doc, x_t_doc, y)

        loss.backward()
        avg_loss += loss.item()
        cnt += nk
        
        with torch.no_grad():
            for name, para in local_predictor.named_parameters():
                if para.grad is None:
                    continue
                elif name not in local_predictor_update:
                    local_predictor_update[name] = (para.grad + torch.randn_like(para.grad) * 1e-2) * lr
                else:
                    local_predictor_update[name] += (para.grad + torch.randn_like(para.grad) * 1e-2) * lr
                
        optimizer.zero_grad()
        
        print('Epoch {:02d}, {:.1f}%, avg_loss = {:.4f}'.format(epoch, uidx * 100 / len(update_user_list), avg_loss / cnt), end='\r')

    # update
    with torch.no_grad():
        for name, para in local_predictor_server.named_parameters():
            para -= local_predictor_update[name]
            
        for name in local_predictor_update:
            local_predictor_update[name] *= momentum
    
    training_loss[epoch] = avg_loss / cnt
    print('')
    # testing
    
    if epoch % 5 == 0:
        with torch.no_grad():

            cnt = 0
            avg_loss = 0.0

            for uid in data_qry_test:

                if np.random.ranf() > 0.05:
                    continue

                nk = data_qry_test[uid].shape[0]

                t = np.random.randint(T - 2 * dT + 1)
                x_loc_qry = data_qry_test[uid][:, t: t + dT]
                x_t_qry = torch.zeros_like(x_loc_qry) + t
                y = data_qry_test[uid][:, t + 2 * dT - 1]

                if uid not in data_doc:
                    loss = local_predictor_server(x_loc_qry, x_t_qry, None, None, y)
                else:
                    x_loc_doc = data_doc[uid][:, t: t + 2 * dT]
                    x_t_doc = torch.zeros_like(x_loc_doc) + t
                    loss = local_predictor_server(x_loc_qry, x_t_qry, x_loc_doc, x_t_doc, y)

                avg_loss += loss.item()
                cnt += nk

            print('Validation Loss: {:.4f}'.format(avg_loss / cnt))
            validation_loss[epoch] = avg_loss / cnt
# Out:
# Epoch 2001, 100.0%, avg_loss = 1.5154
# Epoch 2002, 100.0%, avg_loss = 1.5615
# Epoch 2003, 100.0%, avg_loss = 1.5015
# Epoch 2004, 100.0%, avg_loss = 1.5619
# Epoch 2005, 100.0%, avg_loss = 1.4334
# Validation Loss: 1.5480
# Epoch 2006, 100.0%, avg_loss = 1.5662
# Epoch 2007, 100.0%, avg_loss = 1.5925
# Epoch 2008, 100.0%, avg_loss = 1.4826
# Epoch 2009, 100.0%, avg_loss = 1.4964
# Epoch 2010, 100.0%, avg_loss = 1.5007
# Validation Loss: 1.5312
# Epoch 2011, 100.0%, avg_loss = 1.5122
# Epoch 2012, 100.0%, avg_loss = 1.4908
# Epoch 2013, 100.0%, avg_loss = 1.5643
# Epoch 2014, 100.0%, avg_loss = 1.4965
# Epoch 2015, 100.0%, avg_loss = 1.5107
# Validation Loss: 1.5410
# Epoch 2016, 100.0%, avg_loss = 1.4971
# Epoch 2017, 100.0%, avg_loss = 1.5687
# Epoch 2018, 100.0%, avg_loss = 1.5178
# Epoch 2019, 100.0%, avg_loss = 1.5049
# Epoch 2020, 100.0%, avg_loss = 1.5196
# Validation Loss: 1.5411
# Epoch 2021, 100.0%, avg_loss = 1.5615
# Epoch 2022, 100.0%, avg_loss = 1.5617
# Epoch 2023, 100.0%, avg_loss = 1.5399
# Epoch 2024, 100.0%, avg_loss = 1.4795
# Epoch 2025, 100.0%, avg_loss = 1.5863
# Validation Loss: 1.5284
# Epoch 2026, 100.0%, avg_loss = 1.5300
# Epoch 2027, 100.0%, avg_loss = 1.5800
# Epoch 2028, 100.0%, avg_loss = 1.5025
# Epoch 2029, 100.0%, avg_loss = 1.5664
# Epoch 2030, 100.0%, avg_loss = 1.4765
# Validation Loss: 1.5637
# Epoch 2031, 100.0%, avg_loss = 1.5190
# Epoch 2032, 100.0%, avg_loss = 1.5427
# Epoch 2033, 100.0%, avg_loss = 1.4956
# Epoch 2034, 100.0%, avg_loss = 1.6069
# Epoch 2035, 100.0%, avg_loss = 1.4599
# Validation Loss: 1.5770
# Epoch 2036, 100.0%, avg_loss = 1.5307
# Epoch 2037, 100.0%, avg_loss = 1.4825
# Epoch 2038, 100.0%, avg_loss = 1.5214
# Epoch 2039, 100.0%, avg_loss = 1.5042
# Epoch 2040, 100.0%, avg_loss = 1.5414
# Validation Loss: 1.5222
# Epoch 2041, 100.0%, avg_loss = 1.5054
# Epoch 2042, 100.0%, avg_loss = 1.4807
# Epoch 2043, 100.0%, avg_loss = 1.6249
# Epoch 2044, 100.0%, avg_loss = 1.5142
# Epoch 2045, 100.0%, avg_loss = 1.5280
# Validation Loss: 1.5574
# Epoch 2046, 100.0%, avg_loss = 1.5122
# Epoch 2047, 100.0%, avg_loss = 1.5064
# Epoch 2048, 100.0%, avg_loss = 1.5692
# Epoch 2049, 100.0%, avg_loss = 1.5624
# Epoch 2050, 100.0%, avg_loss = 1.5812
# Validation Loss: 1.5398
# Epoch 2051, 100.0%, avg_loss = 1.6604
# Epoch 2052, 100.0%, avg_loss = 1.4719
# Epoch 2053, 100.0%, avg_loss = 1.5835
# Epoch 2054, 100.0%, avg_loss = 1.4932
# Epoch 2055, 100.0%, avg_loss = 1.4537
# Validation Loss: 1.5448
# Epoch 2056, 100.0%, avg_loss = 1.5293
# Epoch 2057, 100.0%, avg_loss = 1.5406
# Epoch 2058, 100.0%, avg_loss = 1.5446
# Epoch 2059, 100.0%, avg_loss = 1.5520
# Epoch 2060, 100.0%, avg_loss = 1.5347
# Validation Loss: 1.5636
# Epoch 2061, 100.0%, avg_loss = 1.4687
# Epoch 2062, 100.0%, avg_loss = 1.5005
# Epoch 2063, 100.0%, avg_loss = 1.5649
# Epoch 2064, 100.0%, avg_loss = 1.5497
# Epoch 2065, 100.0%, avg_loss = 1.5713
# Validation Loss: 1.5777
# Epoch 2066, 100.0%, avg_loss = 1.5712
# Epoch 2067, 100.0%, avg_loss = 1.4860
# Epoch 2068, 100.0%, avg_loss = 1.5368
# Epoch 2069, 100.0%, avg_loss = 1.5718
# Epoch 2070, 100.0%, avg_loss = 1.4865
# Validation Loss: 1.5452
# Epoch 2071, 100.0%, avg_loss = 1.5410
# Epoch 2072, 100.0%, avg_loss = 1.5240
# Epoch 2073, 100.0%, avg_loss = 1.5310
# Epoch 2074, 100.0%, avg_loss = 1.4670
# Epoch 2075, 100.0%, avg_loss = 1.5880
# Validation Loss: 1.5837
# Epoch 2076, 100.0%, avg_loss = 1.4999
# Epoch 2077, 100.0%, avg_loss = 1.4705
# Epoch 2078, 100.0%, avg_loss = 1.5935
# Epoch 2079, 100.0%, avg_loss = 1.5757
# Epoch 2080, 100.0%, avg_loss = 1.5552
# Validation Loss: 1.5512
# Epoch 2081, 100.0%, avg_loss = 1.5081
# Epoch 2082, 100.0%, avg_loss = 1.5563
# Epoch 2083, 100.0%, avg_loss = 1.4827
# Epoch 2084, 100.0%, avg_loss = 1.5198
# Epoch 2085, 100.0%, avg_loss = 1.4765
# Validation Loss: 1.5917
# Epoch 2086, 100.0%, avg_loss = 1.4774
# Epoch 2087, 100.0%, avg_loss = 1.5373
# Epoch 2088, 100.0%, avg_loss = 1.5978
# Epoch 2089, 100.0%, avg_loss = 1.5598
# Epoch 2090, 100.0%, avg_loss = 1.5673
# Validation Loss: 1.5644
# Epoch 2091, 100.0%, avg_loss = 1.5599
# Epoch 2092, 100.0%, avg_loss = 1.5118
# Epoch 2093, 100.0%, avg_loss = 1.5031
# Epoch 2094, 100.0%, avg_loss = 1.6141
# Epoch 2095, 100.0%, avg_loss = 1.5552
# Validation Loss: 1.5524
# Epoch 2096, 100.0%, avg_loss = 1.5490
# Epoch 2097, 100.0%, avg_loss = 1.6015
# Epoch 2098, 100.0%, avg_loss = 1.4555
# Epoch 2099, 100.0%, avg_loss = 1.4689
# Epoch 2100, 100.0%, avg_loss = 1.4853
# Validation Loss: 1.5136
# Epoch 2101, 100.0%, avg_loss = 1.4429
# Epoch 2102, 100.0%, avg_loss = 1.4833
# Epoch 2103, 100.0%, avg_loss = 1.5473
# Epoch 2104, 100.0%, avg_loss = 1.5687
# Epoch 2105, 100.0%, avg_loss = 1.5289
# Validation Loss: 1.5443
# Epoch 2106, 100.0%, avg_loss = 1.5061
# Epoch 2107, 100.0%, avg_loss = 1.4914
# Epoch 2108, 100.0%, avg_loss = 1.4881
# Epoch 2109, 100.0%, avg_loss = 1.5640
# Epoch 2110, 100.0%, avg_loss = 1.5312
# Validation Loss: 1.5637
# Epoch 2111, 100.0%, avg_loss = 1.4963
# Epoch 2112, 100.0%, avg_loss = 1.5442
# Epoch 2113, 100.0%, avg_loss = 1.5457
# Epoch 2114, 100.0%, avg_loss = 1.5296
# Epoch 2115, 100.0%, avg_loss = 1.4615
# Validation Loss: 1.5225
# Epoch 2116, 100.0%, avg_loss = 1.4773
# Epoch 2117, 100.0%, avg_loss = 1.5139
# Epoch 2118, 100.0%, avg_loss = 1.5083
# Epoch 2119, 100.0%, avg_loss = 1.5296
# Epoch 2120, 100.0%, avg_loss = 1.5257
# Validation Loss: 1.5449
# Epoch 2121, 100.0%, avg_loss = 1.5016
# Epoch 2122, 100.0%, avg_loss = 1.4907
# Epoch 2123, 100.0%, avg_loss = 1.4770
# Epoch 2124, 100.0%, avg_loss = 1.5534
# Epoch 2125, 100.0%, avg_loss = 1.6047
# Validation Loss: 1.5482
# Epoch 2126, 100.0%, avg_loss = 1.4802
# Epoch 2127, 100.0%, avg_loss = 1.4412
# Epoch 2128, 100.0%, avg_loss = 1.4895
# Epoch 2129, 100.0%, avg_loss = 1.4803
# Epoch 2130, 100.0%, avg_loss = 1.5722
# Validation Loss: 1.5410
# Epoch 2131, 100.0%, avg_loss = 1.5276
# Epoch 2132, 100.0%, avg_loss = 1.4961
# Epoch 2133, 100.0%, avg_loss = 1.5143
# Epoch 2134, 100.0%, avg_loss = 1.4855
# Epoch 2135, 100.0%, avg_loss = 1.4955
# Validation Loss: 1.5224
# Epoch 2136, 100.0%, avg_loss = 1.5233
# Epoch 2137, 100.0%, avg_loss = 1.4626
# Epoch 2138, 100.0%, avg_loss = 1.5156
# Epoch 2139, 100.0%, avg_loss = 1.5532
# Epoch 2140, 100.0%, avg_loss = 1.5536
# Validation Loss: 1.5174
# Epoch 2141, 100.0%, avg_loss = 1.4542
# Epoch 2142, 100.0%, avg_loss = 1.4977
# Epoch 2143, 100.0%, avg_loss = 1.4943
# Epoch 2144, 100.0%, avg_loss = 1.4853
# Epoch 2145, 100.0%, avg_loss = 1.4579
# Validation Loss: 1.5793
# Epoch 2146, 100.0%, avg_loss = 1.5339
# Epoch 2147, 100.0%, avg_loss = 1.5138
# Epoch 2148, 100.0%, avg_loss = 1.5584
# Epoch 2149, 100.0%, avg_loss = 1.5955
# Epoch 2150, 100.0%, avg_loss = 1.6004
# Validation Loss: 1.5271
# Epoch 2151, 100.0%, avg_loss = 1.4910
# Epoch 2152, 100.0%, avg_loss = 1.5054
# Epoch 2153, 100.0%, avg_loss = 1.5187
# Epoch 2154, 100.0%, avg_loss = 1.6093
# Epoch 2155, 100.0%, avg_loss = 1.5309
# Validation Loss: 1.5587
# Epoch 2156, 100.0%, avg_loss = 1.5122
# Epoch 2157, 100.0%, avg_loss = 1.5561
# Epoch 2158, 100.0%, avg_loss = 1.5059
# Epoch 2159, 100.0%, avg_loss = 1.5203
# Epoch 2160, 100.0%, avg_loss = 1.5724
# Validation Loss: 1.5098
# Epoch 2161, 100.0%, avg_loss = 1.5298
# Epoch 2162, 100.0%, avg_loss = 1.5411
# Epoch 2163, 100.0%, avg_loss = 1.4766
# Epoch 2164, 100.0%, avg_loss = 1.5000
# Epoch 2165, 100.0%, avg_loss = 1.5199
# Validation Loss: 1.5416
# Epoch 2166, 100.0%, avg_loss = 1.5604
# Epoch 2167, 100.0%, avg_loss = 1.6268
# Epoch 2168, 100.0%, avg_loss = 1.4396
# Epoch 2169, 100.0%, avg_loss = 1.5143
# Epoch 2170, 100.0%, avg_loss = 1.4550
# Validation Loss: 1.5362
# Epoch 2171, 100.0%, avg_loss = 1.4451
# Epoch 2172, 100.0%, avg_loss = 1.5282
# Epoch 2173, 100.0%, avg_loss = 1.5494
# Epoch 2174, 100.0%, avg_loss = 1.5175
# Epoch 2175, 100.0%, avg_loss = 1.6101
# Validation Loss: 1.5460
# Epoch 2176, 100.0%, avg_loss = 1.5718
# Epoch 2177, 100.0%, avg_loss = 1.5794
# Epoch 2178, 100.0%, avg_loss = 1.5345
# Epoch 2179, 100.0%, avg_loss = 1.4918
# Epoch 2180, 100.0%, avg_loss = 1.4931
# Validation Loss: 1.5263
# Epoch 2181, 100.0%, avg_loss = 1.4676
# Epoch 2182, 100.0%, avg_loss = 1.5649
# Epoch 2183, 100.0%, avg_loss = 1.4365
# Epoch 2184, 100.0%, avg_loss = 1.5098
# Epoch 2185, 100.0%, avg_loss = 1.6009
# Validation Loss: 1.5402
# Epoch 2186, 100.0%, avg_loss = 1.4337
# Epoch 2187, 100.0%, avg_loss = 1.5300
# Epoch 2188, 100.0%, avg_loss = 1.5148
# Epoch 2189, 100.0%, avg_loss = 1.5598
# Epoch 2190, 100.0%, avg_loss = 1.5328
# Validation Loss: 1.5925
# Epoch 2191, 100.0%, avg_loss = 1.5829
# Epoch 2192, 100.0%, avg_loss = 1.5641
# Epoch 2193, 100.0%, avg_loss = 1.4942
# Epoch 2194, 100.0%, avg_loss = 1.5011
# Epoch 2195, 100.0%, avg_loss = 1.5830
# Validation Loss: 1.5236
# Epoch 2196, 100.0%, avg_loss = 1.5278
# Epoch 2197, 100.0%, avg_loss = 1.4985
# Epoch 2198, 100.0%, avg_loss = 1.5144
# Epoch 2199, 100.0%, avg_loss = 1.5081
# Epoch 2200, 100.0%, avg_loss = 1.4687
# Validation Loss: 1.5702
# Epoch 2201, 100.0%, avg_loss = 1.5362
# Epoch 2202, 100.0%, avg_loss = 1.5384
# Epoch 2203, 100.0%, avg_loss = 1.5533
# Epoch 2204, 100.0%, avg_loss = 1.5360
# Epoch 2205, 100.0%, avg_loss = 1.4947
# Validation Loss: 1.4994
# Epoch 2206, 100.0%, avg_loss = 1.5116
# Epoch 2207, 100.0%, avg_loss = 1.5082
# Epoch 2208, 100.0%, avg_loss = 1.4616
# Epoch 2209, 100.0%, avg_loss = 1.5932
# Epoch 2210, 100.0%, avg_loss = 1.4159
# Validation Loss: 1.5957
# Epoch 2211, 100.0%, avg_loss = 1.4854
# Epoch 2212, 100.0%, avg_loss = 1.5196
# Epoch 2213, 100.0%, avg_loss = 1.4938
# Epoch 2214, 100.0%, avg_loss = 1.4494
# Epoch 2215, 100.0%, avg_loss = 1.5740
# Validation Loss: 1.5510
# Epoch 2216, 100.0%, avg_loss = 1.5908
# Epoch 2217, 100.0%, avg_loss = 1.5648
# Epoch 2218, 100.0%, avg_loss = 1.5290
# Epoch 2219, 100.0%, avg_loss = 1.5109
# Epoch 2220, 100.0%, avg_loss = 1.4849
# Validation Loss: 1.5496
# Epoch 2221, 100.0%, avg_loss = 1.5074
# Epoch 2222, 100.0%, avg_loss = 1.5575
# Epoch 2223, 100.0%, avg_loss = 1.4711
# Epoch 2224, 100.0%, avg_loss = 1.5162
# Epoch 2225, 100.0%, avg_loss = 1.5255
# Validation Loss: 1.5508
# Epoch 2226, 100.0%, avg_loss = 1.5085
# Epoch 2227, 100.0%, avg_loss = 1.5319
# Epoch 2228, 100.0%, avg_loss = 1.5736
# Epoch 2229, 100.0%, avg_loss = 1.4932
# Epoch 2230, 100.0%, avg_loss = 1.5780
# Validation Loss: 1.5382
# Epoch 2231, 100.0%, avg_loss = 1.5630
# Epoch 2232, 100.0%, avg_loss = 1.5352
# Epoch 2233, 100.0%, avg_loss = 1.4967
# Epoch 2234, 100.0%, avg_loss = 1.5794
# Epoch 2235, 100.0%, avg_loss = 1.5033
# Validation Loss: 1.5508
# Epoch 2236, 100.0%, avg_loss = 1.5930
# Epoch 2237, 100.0%, avg_loss = 1.4733
# Epoch 2238, 100.0%, avg_loss = 1.5422
# Epoch 2239, 100.0%, avg_loss = 1.4501
# Epoch 2240, 100.0%, avg_loss = 1.5214
# Validation Loss: 1.5181
# Epoch 2241, 100.0%, avg_loss = 1.4340
# Epoch 2242, 100.0%, avg_loss = 1.5369
# Epoch 2243, 100.0%, avg_loss = 1.4585
# Epoch 2244, 100.0%, avg_loss = 1.5311
# Epoch 2245, 100.0%, avg_loss = 1.4863
# Validation Loss: 1.5359
# Epoch 2246, 100.0%, avg_loss = 1.5006
# Epoch 2247, 100.0%, avg_loss = 1.5602
# Epoch 2248, 100.0%, avg_loss = 1.5458
# Epoch 2249, 100.0%, avg_loss = 1.5533
# Epoch 2250, 100.0%, avg_loss = 1.5050
# Validation Loss: 1.5316
# Epoch 2251, 100.0%, avg_loss = 1.4902
# Epoch 2252, 100.0%, avg_loss = 1.5093
# Epoch 2253, 100.0%, avg_loss = 1.4190
# Epoch 2254, 100.0%, avg_loss = 1.4548
# Epoch 2255, 100.0%, avg_loss = 1.5567
# Validation Loss: 1.5371
# Epoch 2256, 100.0%, avg_loss = 1.4875
# Epoch 2257, 100.0%, avg_loss = 1.4934
# Epoch 2258, 100.0%, avg_loss = 1.4375
# Epoch 2259, 100.0%, avg_loss = 1.5488
# Epoch 2260, 100.0%, avg_loss = 1.5165
# Validation Loss: 1.5414
# Epoch 2261, 100.0%, avg_loss = 1.4958
# Epoch 2262, 100.0%, avg_loss = 1.4655
# Epoch 2263, 100.0%, avg_loss = 1.5142
# Epoch 2264, 100.0%, avg_loss = 1.5396
# Epoch 2265, 100.0%, avg_loss = 1.5233
# Validation Loss: 1.5319
# Epoch 2266, 100.0%, avg_loss = 1.5353
# Epoch 2267, 100.0%, avg_loss = 1.4826
# Epoch 2268, 100.0%, avg_loss = 1.5339
# Epoch 2269, 100.0%, avg_loss = 1.5418
# Epoch 2270, 100.0%, avg_loss = 1.5198
# Validation Loss: 1.5283
# Epoch 2271, 100.0%, avg_loss = 1.4570
# Epoch 2272, 100.0%, avg_loss = 1.5348
# Epoch 2273, 100.0%, avg_loss = 1.5396
# Epoch 2274, 100.0%, avg_loss = 1.4944
# Epoch 2275, 100.0%, avg_loss = 1.5578
# Validation Loss: 1.5204
# Epoch 2276, 100.0%, avg_loss = 1.4999
# Epoch 2277, 100.0%, avg_loss = 1.5182
# Epoch 2278, 100.0%, avg_loss = 1.5617
# Epoch 2279, 100.0%, avg_loss = 1.5791
# Epoch 2280, 100.0%, avg_loss = 1.4937
# Validation Loss: 1.5901
# Epoch 2281, 100.0%, avg_loss = 1.5388
# Epoch 2282, 100.0%, avg_loss = 1.5421
# Epoch 2283, 100.0%, avg_loss = 1.4544
# Epoch 2284, 100.0%, avg_loss = 1.4952
# Epoch 2285, 100.0%, avg_loss = 1.5128
# Validation Loss: 1.5421
# Epoch 2286, 100.0%, avg_loss = 1.5172
# Epoch 2287, 100.0%, avg_loss = 1.4862
# Epoch 2288, 100.0%, avg_loss = 1.5354
# Epoch 2289, 100.0%, avg_loss = 1.4646
# Epoch 2290, 100.0%, avg_loss = 1.4580
# Validation Loss: 1.5039
# Epoch 2291, 100.0%, avg_loss = 1.4937
# Epoch 2292, 100.0%, avg_loss = 1.5800
# Epoch 2293, 100.0%, avg_loss = 1.4841
# Epoch 2294, 100.0%, avg_loss = 1.5853
# Epoch 2295, 100.0%, avg_loss = 1.5634
# Validation Loss: 1.5431
# Epoch 2296, 100.0%, avg_loss = 1.5288
# Epoch 2297, 100.0%, avg_loss = 1.5382
# Epoch 2298, 100.0%, avg_loss = 1.5588
# Epoch 2299, 100.0%, avg_loss = 1.5537
# Epoch 2300, 100.0%, avg_loss = 1.5700
# Validation Loss: 1.5638
# Epoch 2301, 100.0%, avg_loss = 1.4889
# Epoch 2302, 100.0%, avg_loss = 1.5323
# Epoch 2303, 100.0%, avg_loss = 1.5039
# Epoch 2304, 100.0%, avg_loss = 1.5083
# Epoch 2305, 100.0%, avg_loss = 1.5078
# Validation Loss: 1.4876
# Epoch 2306, 100.0%, avg_loss = 1.5314
# Epoch 2307, 100.0%, avg_loss = 1.5014
# Epoch 2308, 100.0%, avg_loss = 1.4958
# Epoch 2309, 100.0%, avg_loss = 1.5833
# Epoch 2310, 100.0%, avg_loss = 1.4241
# Validation Loss: 1.5106
# Epoch 2311, 100.0%, avg_loss = 1.4929
# Epoch 2312, 100.0%, avg_loss = 1.5365
# Epoch 2313, 100.0%, avg_loss = 1.5079
# Epoch 2314, 100.0%, avg_loss = 1.5045
# Epoch 2315, 100.0%, avg_loss = 1.6009
# Validation Loss: 1.5444
# Epoch 2316, 100.0%, avg_loss = 1.5641
# Epoch 2317, 100.0%, avg_loss = 1.5289
# Epoch 2318, 100.0%, avg_loss = 1.4800
# Epoch 2319, 100.0%, avg_loss = 1.4809
# Epoch 2320, 100.0%, avg_loss = 1.4827
# Validation Loss: 1.5203
# Epoch 2321, 100.0%, avg_loss = 1.5175
# Epoch 2322, 100.0%, avg_loss = 1.5688
# Epoch 2323, 100.0%, avg_loss = 1.5037
# Epoch 2324, 100.0%, avg_loss = 1.5497
# Epoch 2325, 100.0%, avg_loss = 1.5180
# Validation Loss: 1.5263
# Epoch 2326, 100.0%, avg_loss = 1.5604
# Epoch 2327, 100.0%, avg_loss = 1.4553
# Epoch 2328, 100.0%, avg_loss = 1.5041
# Epoch 2329, 100.0%, avg_loss = 1.4309
# Epoch 2330, 100.0%, avg_loss = 1.5041
# Validation Loss: 1.5775
# Epoch 2331, 100.0%, avg_loss = 1.5734
# Epoch 2332, 100.0%, avg_loss = 1.5328
# Epoch 2333, 100.0%, avg_loss = 1.5394
# Epoch 2334, 100.0%, avg_loss = 1.4978
# Epoch 2335, 100.0%, avg_loss = 1.5141
# Validation Loss: 1.5420
# Epoch 2336, 100.0%, avg_loss = 1.5090
# Epoch 2337, 100.0%, avg_loss = 1.4705
# Epoch 2338, 100.0%, avg_loss = 1.5460
# Epoch 2339, 100.0%, avg_loss = 1.5211
# Epoch 2340, 100.0%, avg_loss = 1.5013
# Validation Loss: 1.5530
# Epoch 2341, 100.0%, avg_loss = 1.5280
# Epoch 2342, 100.0%, avg_loss = 1.5034
# Epoch 2343, 100.0%, avg_loss = 1.4160
# Epoch 2344, 100.0%, avg_loss = 1.5236
# Epoch 2345, 100.0%, avg_loss = 1.4914
# Validation Loss: 1.5390
# Epoch 2346, 100.0%, avg_loss = 1.5102
# Epoch 2347, 100.0%, avg_loss = 1.5454
# Epoch 2348, 100.0%, avg_loss = 1.5291
# Epoch 2349, 100.0%, avg_loss = 1.5349
# Epoch 2350, 100.0%, avg_loss = 1.4031
# Validation Loss: 1.5429
# Epoch 2351, 100.0%, avg_loss = 1.5493
# Epoch 2352, 100.0%, avg_loss = 1.5264
# Epoch 2353, 100.0%, avg_loss = 1.5221
# Epoch 2354, 100.0%, avg_loss = 1.5568
# Epoch 2355, 100.0%, avg_loss = 1.5452
# Validation Loss: 1.5627
# Epoch 2356, 100.0%, avg_loss = 1.4796
# Epoch 2357, 100.0%, avg_loss = 1.5521
# Epoch 2358, 100.0%, avg_loss = 1.4881
# Epoch 2359, 100.0%, avg_loss = 1.4906
# Epoch 2360, 100.0%, avg_loss = 1.4743
# Validation Loss: 1.5429
# Epoch 2361, 100.0%, avg_loss = 1.5422
# Epoch 2362, 100.0%, avg_loss = 1.5466
# Epoch 2363, 100.0%, avg_loss = 1.4454
# Epoch 2364, 100.0%, avg_loss = 1.4699
# Epoch 2365, 100.0%, avg_loss = 1.4966
# Validation Loss: 1.5365
# Epoch 2366, 100.0%, avg_loss = 1.5358
# Epoch 2367, 100.0%, avg_loss = 1.6186
# Epoch 2368, 100.0%, avg_loss = 1.4918
# Epoch 2369, 100.0%, avg_loss = 1.5408
# Epoch 2370, 100.0%, avg_loss = 1.5364
# Validation Loss: 1.5540
# Epoch 2371, 100.0%, avg_loss = 1.4597
# Epoch 2372, 100.0%, avg_loss = 1.5635
# Epoch 2373, 100.0%, avg_loss = 1.5177
# Epoch 2374, 100.0%, avg_loss = 1.4356
# Epoch 2375, 100.0%, avg_loss = 1.5558
# Validation Loss: 1.5792
# Epoch 2376, 100.0%, avg_loss = 1.4934
# Epoch 2377, 100.0%, avg_loss = 1.5252
# Epoch 2378, 100.0%, avg_loss = 1.5242
# Epoch 2379, 100.0%, avg_loss = 1.4953
# Epoch 2380, 100.0%, avg_loss = 1.4978
# Validation Loss: 1.5541
# Epoch 2381, 100.0%, avg_loss = 1.5629
# Epoch 2382, 100.0%, avg_loss = 1.5005
# Epoch 2383, 100.0%, avg_loss = 1.5262
# Epoch 2384, 100.0%, avg_loss = 1.5318
# Epoch 2385, 100.0%, avg_loss = 1.5910
# Validation Loss: 1.5258
# Epoch 2386, 100.0%, avg_loss = 1.5420
# Epoch 2387, 100.0%, avg_loss = 1.4921
# Epoch 2388, 100.0%, avg_loss = 1.4910
# Epoch 2389, 100.0%, avg_loss = 1.4138
# Epoch 2390, 100.0%, avg_loss = 1.4860
# Validation Loss: 1.5234
# Epoch 2391, 100.0%, avg_loss = 1.5164
# Epoch 2392, 100.0%, avg_loss = 1.5547
# Epoch 2393, 100.0%, avg_loss = 1.5130
# Epoch 2394, 100.0%, avg_loss = 1.4624
# Epoch 2395, 100.0%, avg_loss = 1.4800
# Validation Loss: 1.5747
# Epoch 2396, 100.0%, avg_loss = 1.4758
# Epoch 2397, 100.0%, avg_loss = 1.5793
# Epoch 2398, 100.0%, avg_loss = 1.4697
# Epoch 2399, 100.0%, avg_loss = 1.5546
# Epoch 2400, 100.0%, avg_loss = 1.6150
# Validation Loss: 1.5197
# Epoch 2401, 100.0%, avg_loss = 1.5157
# Epoch 2402, 100.0%, avg_loss = 1.5006
# Epoch 2403, 100.0%, avg_loss = 1.5699
# Epoch 2404, 100.0%, avg_loss = 1.4578
# Epoch 2405, 100.0%, avg_loss = 1.5690
# Validation Loss: 1.5234
# Epoch 2406, 100.0%, avg_loss = 1.5257
# Epoch 2407, 100.0%, avg_loss = 1.5403
# Epoch 2408, 100.0%, avg_loss = 1.4960
# Epoch 2409, 100.0%, avg_loss = 1.5779
# Epoch 2410, 100.0%, avg_loss = 1.5658
# Validation Loss: 1.5689
# Epoch 2411, 100.0%, avg_loss = 1.5723
# Epoch 2412, 100.0%, avg_loss = 1.4855
# Epoch 2413, 100.0%, avg_loss = 1.5030
# Epoch 2414, 100.0%, avg_loss = 1.4920
# Epoch 2415, 100.0%, avg_loss = 1.6363
# Validation Loss: 1.4863
# Epoch 2416, 100.0%, avg_loss = 1.5184
# Epoch 2417, 100.0%, avg_loss = 1.5249
# Epoch 2418, 100.0%, avg_loss = 1.5440
# Epoch 2419, 100.0%, avg_loss = 1.4926
# Epoch 2420, 100.0%, avg_loss = 1.5098
# Validation Loss: 1.5843
# Epoch 2421, 100.0%, avg_loss = 1.4833
# Epoch 2422, 100.0%, avg_loss = 1.5094
# Epoch 2423, 100.0%, avg_loss = 1.6163
# Epoch 2424, 100.0%, avg_loss = 1.4526
# Epoch 2425, 100.0%, avg_loss = 1.4936
# Validation Loss: 1.5118
# Epoch 2426, 100.0%, avg_loss = 1.5098
# Epoch 2427, 100.0%, avg_loss = 1.4497
# Epoch 2428, 100.0%, avg_loss = 1.5811
# Epoch 2429, 100.0%, avg_loss = 1.4558
# Epoch 2430, 100.0%, avg_loss = 1.5238
# Validation Loss: 1.5571
# Epoch 2431, 100.0%, avg_loss = 1.5280
# Epoch 2432, 100.0%, avg_loss = 1.5222
# Epoch 2433, 100.0%, avg_loss = 1.5833
# Epoch 2434, 100.0%, avg_loss = 1.5025
# Epoch 2435, 100.0%, avg_loss = 1.5104
# Validation Loss: 1.5732
# Epoch 2436, 100.0%, avg_loss = 1.5244
# Epoch 2437, 100.0%, avg_loss = 1.5023
# Epoch 2438, 100.0%, avg_loss = 1.5389
# Epoch 2439, 100.0%, avg_loss = 1.4581
# Epoch 2440, 100.0%, avg_loss = 1.4400
# Validation Loss: 1.5283
# Epoch 2441, 100.0%, avg_loss = 1.4313
# Epoch 2442, 100.0%, avg_loss = 1.4843
# Epoch 2443, 100.0%, avg_loss = 1.4195
# Epoch 2444, 100.0%, avg_loss = 1.4645
# Epoch 2445, 100.0%, avg_loss = 1.5019
# Validation Loss: 1.4926
# Epoch 2446, 100.0%, avg_loss = 1.5147
# Epoch 2447, 100.0%, avg_loss = 1.5386
# Epoch 2448, 100.0%, avg_loss = 1.5614
# Epoch 2449, 100.0%, avg_loss = 1.5338
# Epoch 2450, 100.0%, avg_loss = 1.5388
# Validation Loss: 1.5399
# Epoch 2451, 100.0%, avg_loss = 1.5312
# Epoch 2452, 100.0%, avg_loss = 1.4650
# Epoch 2453, 100.0%, avg_loss = 1.6420
# Epoch 2454, 100.0%, avg_loss = 1.4917
# Epoch 2455, 100.0%, avg_loss = 1.5181
# Validation Loss: 1.4990
# Epoch 2456, 100.0%, avg_loss = 1.5238
# Epoch 2457, 100.0%, avg_loss = 1.4720
# Epoch 2458, 100.0%, avg_loss = 1.4921
# Epoch 2459, 100.0%, avg_loss = 1.4613
# Epoch 2460, 100.0%, avg_loss = 1.5298
# Validation Loss: 1.5125
# Epoch 2461, 100.0%, avg_loss = 1.4665
# Epoch 2462, 100.0%, avg_loss = 1.4672
# Epoch 2463, 100.0%, avg_loss = 1.4793
# Epoch 2464, 100.0%, avg_loss = 1.4377
# Epoch 2465, 100.0%, avg_loss = 1.4994
# Validation Loss: 1.5192
# Epoch 2466, 100.0%, avg_loss = 1.5305
# Epoch 2467, 100.0%, avg_loss = 1.4783
# Epoch 2468, 100.0%, avg_loss = 1.5643
# Epoch 2469, 100.0%, avg_loss = 1.5231
# Epoch 2470, 100.0%, avg_loss = 1.5537
# Validation Loss: 1.5410
# Epoch 2471, 100.0%, avg_loss = 1.5425
# Epoch 2472, 100.0%, avg_loss = 1.5329
# Epoch 2473, 100.0%, avg_loss = 1.5012
# Epoch 2474, 100.0%, avg_loss = 1.5574
# Epoch 2475, 100.0%, avg_loss = 1.4770
# Validation Loss: 1.5721
# Epoch 2476, 100.0%, avg_loss = 1.5380
# Epoch 2477, 100.0%, avg_loss = 1.4910
# Epoch 2478, 100.0%, avg_loss = 1.4486
# Epoch 2479, 100.0%, avg_loss = 1.5453
# Epoch 2480, 100.0%, avg_loss = 1.5827
# Validation Loss: 1.5647
# Epoch 2481, 100.0%, avg_loss = 1.4726
# Epoch 2482, 100.0%, avg_loss = 1.4093
# Epoch 2483, 100.0%, avg_loss = 1.5314
# Epoch 2484, 100.0%, avg_loss = 1.5037
# Epoch 2485, 100.0%, avg_loss = 1.5031
# Validation Loss: 1.5308
# Epoch 2486, 100.0%, avg_loss = 1.5107
# Epoch 2487, 100.0%, avg_loss = 1.4890
# Epoch 2488, 100.0%, avg_loss = 1.4494
# Epoch 2489, 100.0%, avg_loss = 1.4139
# Epoch 2490, 100.0%, avg_loss = 1.5199
# Validation Loss: 1.5087
# Epoch 2491, 100.0%, avg_loss = 1.4665
# Epoch 2492, 100.0%, avg_loss = 1.4335
# Epoch 2493, 100.0%, avg_loss = 1.5302
# Epoch 2494, 100.0%, avg_loss = 1.5213
# Epoch 2495, 100.0%, avg_loss = 1.5407
# Validation Loss: 1.5213
# Epoch 2496, 100.0%, avg_loss = 1.4957
# Epoch 2497, 100.0%, avg_loss = 1.5495
# Epoch 2498, 100.0%, avg_loss = 1.5018
# Epoch 2499, 100.0%, avg_loss = 1.4967
# Epoch 2500, 100.0%, avg_loss = 1.5661
# Validation Loss: 1.5406
# Epoch 2501, 100.0%, avg_loss = 1.5399
# Epoch 2502, 100.0%, avg_loss = 1.4728
# Epoch 2503, 100.0%, avg_loss = 1.5554
# Epoch 2504, 100.0%, avg_loss = 1.4717
# Epoch 2505, 100.0%, avg_loss = 1.4974
# Validation Loss: 1.4865
# Epoch 2506, 100.0%, avg_loss = 1.5157
# Epoch 2507, 100.0%, avg_loss = 1.4868
# Epoch 2508, 100.0%, avg_loss = 1.5259
# Epoch 2509, 100.0%, avg_loss = 1.4225
# Epoch 2510, 100.0%, avg_loss = 1.5879
# Validation Loss: 1.5251
# Epoch 2511, 100.0%, avg_loss = 1.5684
# Epoch 2512, 100.0%, avg_loss = 1.5589
# Epoch 2513, 100.0%, avg_loss = 1.4630
# Epoch 2514, 100.0%, avg_loss = 1.4928
# Epoch 2515, 100.0%, avg_loss = 1.5085
# Validation Loss: 1.5634
# Epoch 2516, 100.0%, avg_loss = 1.5188
# Epoch 2517, 100.0%, avg_loss = 1.5085
# Epoch 2518, 100.0%, avg_loss = 1.4779
# Epoch 2519, 100.0%, avg_loss = 1.5088
# Epoch 2520, 100.0%, avg_loss = 1.5600
# Validation Loss: 1.4919
# Epoch 2521, 100.0%, avg_loss = 1.5090
# Epoch 2522, 100.0%, avg_loss = 1.5326
# Epoch 2523, 100.0%, avg_loss = 1.5043
# Epoch 2524, 100.0%, avg_loss = 1.4450
# Epoch 2525, 100.0%, avg_loss = 1.4666
# Validation Loss: 1.5194
# Epoch 2526, 100.0%, avg_loss = 1.5061
# Epoch 2527, 100.0%, avg_loss = 1.5204
# Epoch 2528, 100.0%, avg_loss = 1.5444
# Epoch 2529, 100.0%, avg_loss = 1.5537
# Epoch 2530, 100.0%, avg_loss = 1.5648
# Validation Loss: 1.5545
# Epoch 2531, 100.0%, avg_loss = 1.4881
# Epoch 2532, 100.0%, avg_loss = 1.5246
# Epoch 2533, 100.0%, avg_loss = 1.6009
# Epoch 2534, 100.0%, avg_loss = 1.5039
# Epoch 2535, 100.0%, avg_loss = 1.5474
# Validation Loss: 1.5439
# Epoch 2536, 100.0%, avg_loss = 1.5490
# Epoch 2537, 100.0%, avg_loss = 1.4624
# Epoch 2538, 100.0%, avg_loss = 1.5539
# Epoch 2539, 100.0%, avg_loss = 1.4753
# Epoch 2540, 100.0%, avg_loss = 1.4444
# Validation Loss: 1.5543
# Epoch 2541, 100.0%, avg_loss = 1.5280
# Epoch 2542, 100.0%, avg_loss = 1.4614
# Epoch 2543, 100.0%, avg_loss = 1.4898
# Epoch 2544, 100.0%, avg_loss = 1.5390
# Epoch 2545, 100.0%, avg_loss = 1.4890
# Validation Loss: 1.5234
# Epoch 2546, 100.0%, avg_loss = 1.4536
# Epoch 2547, 100.0%, avg_loss = 1.5020
# Epoch 2548, 100.0%, avg_loss = 1.4631
# Epoch 2549, 100.0%, avg_loss = 1.5328
# Epoch 2550, 100.0%, avg_loss = 1.5039
# Validation Loss: 1.5384
# Epoch 2551, 100.0%, avg_loss = 1.5064
# Epoch 2552, 100.0%, avg_loss = 1.5025
# Epoch 2553, 100.0%, avg_loss = 1.5047
# Epoch 2554, 100.0%, avg_loss = 1.4007
# Epoch 2555, 100.0%, avg_loss = 1.5601
# Validation Loss: 1.5317
# Epoch 2556, 100.0%, avg_loss = 1.4118
# Epoch 2557, 100.0%, avg_loss = 1.5160
# Epoch 2558, 100.0%, avg_loss = 1.4308
# Epoch 2559, 100.0%, avg_loss = 1.5496
# Epoch 2560, 100.0%, avg_loss = 1.4926
# Validation Loss: 1.5112
# Epoch 2561, 100.0%, avg_loss = 1.5700
# Epoch 2562, 100.0%, avg_loss = 1.5968
# Epoch 2563, 100.0%, avg_loss = 1.5083
# Epoch 2564, 100.0%, avg_loss = 1.5243
# Epoch 2565, 100.0%, avg_loss = 1.5253
# Validation Loss: 1.5528
# Epoch 2566, 100.0%, avg_loss = 1.5179
# Epoch 2567, 100.0%, avg_loss = 1.4832
# Epoch 2568, 100.0%, avg_loss = 1.5404
# Epoch 2569, 100.0%, avg_loss = 1.4864
# Epoch 2570, 100.0%, avg_loss = 1.5385
# Validation Loss: 1.5299
# Epoch 2571, 100.0%, avg_loss = 1.4987
# Epoch 2572, 100.0%, avg_loss = 1.5023
# Epoch 2573, 100.0%, avg_loss = 1.5254
# Epoch 2574, 100.0%, avg_loss = 1.5059
# Epoch 2575, 100.0%, avg_loss = 1.5373
# Validation Loss: 1.5194
# Epoch 2576, 100.0%, avg_loss = 1.5462
# Epoch 2577, 100.0%, avg_loss = 1.4745
# Epoch 2578, 100.0%, avg_loss = 1.4825
# Epoch 2579, 100.0%, avg_loss = 1.5020
# Epoch 2580, 100.0%, avg_loss = 1.4795
# Validation Loss: 1.5250
# Epoch 2581, 100.0%, avg_loss = 1.4803
# Epoch 2582, 100.0%, avg_loss = 1.4830
# Epoch 2583, 100.0%, avg_loss = 1.4970
# Epoch 2584, 100.0%, avg_loss = 1.4859
# Epoch 2585, 100.0%, avg_loss = 1.4893
# Validation Loss: 1.5091
# Epoch 2586, 100.0%, avg_loss = 1.4960
# Epoch 2587, 100.0%, avg_loss = 1.5538
# Epoch 2588, 100.0%, avg_loss = 1.5300
# Epoch 2589, 100.0%, avg_loss = 1.5089
# Epoch 2590, 100.0%, avg_loss = 1.5181
# Validation Loss: 1.5589
# Epoch 2591, 100.0%, avg_loss = 1.5604
# Epoch 2592, 100.0%, avg_loss = 1.5365
# Epoch 2593, 100.0%, avg_loss = 1.5087
# Epoch 2594, 100.0%, avg_loss = 1.4975
# Epoch 2595, 100.0%, avg_loss = 1.4632
# Validation Loss: 1.5426
# Epoch 2596, 100.0%, avg_loss = 1.4701
# Epoch 2597, 100.0%, avg_loss = 1.4635
# Epoch 2598, 100.0%, avg_loss = 1.4180
# Epoch 2599, 100.0%, avg_loss = 1.4719
# Epoch 2600, 100.0%, avg_loss = 1.4825
# Validation Loss: 1.5437
# Epoch 2601, 100.0%, avg_loss = 1.5353
# Epoch 2602, 100.0%, avg_loss = 1.5475
# Epoch 2603, 100.0%, avg_loss = 1.5313
# Epoch 2604, 100.0%, avg_loss = 1.5176
# Epoch 2605, 100.0%, avg_loss = 1.4821
# Validation Loss: 1.5292
# Epoch 2606, 100.0%, avg_loss = 1.4946
# Epoch 2607, 100.0%, avg_loss = 1.4408
# Epoch 2608, 100.0%, avg_loss = 1.5491
# Epoch 2609, 100.0%, avg_loss = 1.5973
# Epoch 2610, 100.0%, avg_loss = 1.4715
# Validation Loss: 1.5432
# Epoch 2611, 100.0%, avg_loss = 1.5009
# Epoch 2612, 100.0%, avg_loss = 1.4549
# Epoch 2613, 100.0%, avg_loss = 1.4821
# Epoch 2614, 100.0%, avg_loss = 1.4767
# Epoch 2615, 100.0%, avg_loss = 1.4462
# Validation Loss: 1.5294
# Epoch 2616, 100.0%, avg_loss = 1.5620
# Epoch 2617, 100.0%, avg_loss = 1.5085
# Epoch 2618, 100.0%, avg_loss = 1.4572
# Epoch 2619, 100.0%, avg_loss = 1.4393
# Epoch 2620, 100.0%, avg_loss = 1.5742
# Validation Loss: 1.5530
# Epoch 2621, 100.0%, avg_loss = 1.4816
# Epoch 2622, 100.0%, avg_loss = 1.5224
# Epoch 2623, 100.0%, avg_loss = 1.5754
# Epoch 2624, 100.0%, avg_loss = 1.4864
# Epoch 2625, 100.0%, avg_loss = 1.5131
# Validation Loss: 1.4867
# Epoch 2626, 100.0%, avg_loss = 1.5360
# Epoch 2627, 100.0%, avg_loss = 1.5435
# Epoch 2628, 100.0%, avg_loss = 1.5211
# Epoch 2629, 100.0%, avg_loss = 1.5522
# Epoch 2630, 100.0%, avg_loss = 1.4889
# Validation Loss: 1.5412
# Epoch 2631, 100.0%, avg_loss = 1.5640
# Epoch 2632, 100.0%, avg_loss = 1.5445
# Epoch 2633, 100.0%, avg_loss = 1.4965
# Epoch 2634, 100.0%, avg_loss = 1.4577
# Epoch 2635, 100.0%, avg_loss = 1.4434
# Validation Loss: 1.5254
# Epoch 2636, 100.0%, avg_loss = 1.4857
# Epoch 2637, 100.0%, avg_loss = 1.5116
# Epoch 2638, 100.0%, avg_loss = 1.4394
# Epoch 2639, 100.0%, avg_loss = 1.4764
# Epoch 2640, 100.0%, avg_loss = 1.5296
# Validation Loss: 1.5337
# Epoch 2641, 100.0%, avg_loss = 1.5080
# Epoch 2642, 100.0%, avg_loss = 1.5492
# Epoch 2643, 100.0%, avg_loss = 1.4827
# Epoch 2644, 100.0%, avg_loss = 1.5659
# Epoch 2645, 100.0%, avg_loss = 1.4044
# Validation Loss: 1.5657
# Epoch 2646, 100.0%, avg_loss = 1.5142
# Epoch 2647, 100.0%, avg_loss = 1.5350
# Epoch 2648, 100.0%, avg_loss = 1.4565
# Epoch 2649, 100.0%, avg_loss = 1.4945
# Epoch 2650, 100.0%, avg_loss = 1.5175
# Validation Loss: 1.5330
# Epoch 2651, 100.0%, avg_loss = 1.5595
# Epoch 2652, 100.0%, avg_loss = 1.5121
# Epoch 2653, 100.0%, avg_loss = 1.5595
# Epoch 2654, 100.0%, avg_loss = 1.5316
# Epoch 2655, 100.0%, avg_loss = 1.5101
# Validation Loss: 1.5060
# Epoch 2656, 100.0%, avg_loss = 1.4794
# Epoch 2657, 100.0%, avg_loss = 1.4598
# Epoch 2658, 100.0%, avg_loss = 1.5103
# Epoch 2659, 100.0%, avg_loss = 1.4614
# Epoch 2660, 100.0%, avg_loss = 1.5254
# Validation Loss: 1.5224
# Epoch 2661, 100.0%, avg_loss = 1.4764
# Epoch 2662, 100.0%, avg_loss = 1.4956
# Epoch 2663, 100.0%, avg_loss = 1.5013
# Epoch 2664, 100.0%, avg_loss = 1.5403
# Epoch 2665, 100.0%, avg_loss = 1.5208
# Validation Loss: 1.5417
# Epoch 2666, 100.0%, avg_loss = 1.5220
# Epoch 2667, 100.0%, avg_loss = 1.4639
# Epoch 2668, 100.0%, avg_loss = 1.5122
# Epoch 2669, 100.0%, avg_loss = 1.5220
# Epoch 2670, 100.0%, avg_loss = 1.5264
# Validation Loss: 1.5822
# Epoch 2671, 100.0%, avg_loss = 1.5520
# Epoch 2672, 100.0%, avg_loss = 1.5150
# Epoch 2673, 100.0%, avg_loss = 1.5446
# Epoch 2674, 100.0%, avg_loss = 1.6221
# Epoch 2675, 100.0%, avg_loss = 1.4668
# Validation Loss: 1.5570
# Epoch 2676, 100.0%, avg_loss = 1.5024
# Epoch 2677, 100.0%, avg_loss = 1.5223
# Epoch 2678, 100.0%, avg_loss = 1.5168
# Epoch 2679, 100.0%, avg_loss = 1.5404
# Epoch 2680, 100.0%, avg_loss = 1.4977
# Validation Loss: 1.5471
# Epoch 2681, 100.0%, avg_loss = 1.5456
# Epoch 2682, 100.0%, avg_loss = 1.4195
# Epoch 2683, 100.0%, avg_loss = 1.5796
# Epoch 2684, 100.0%, avg_loss = 1.5113
# Epoch 2685, 100.0%, avg_loss = 1.5026
# Validation Loss: 1.5381
# Epoch 2686, 100.0%, avg_loss = 1.5130
# Epoch 2687, 100.0%, avg_loss = 1.4758
# Epoch 2688, 100.0%, avg_loss = 1.4862
# Epoch 2689, 100.0%, avg_loss = 1.4421
# Epoch 2690, 100.0%, avg_loss = 1.5274
# Validation Loss: 1.5394
# Epoch 2691, 100.0%, avg_loss = 1.4988
# Epoch 2692, 100.0%, avg_loss = 1.5151
# Epoch 2693, 100.0%, avg_loss = 1.5484
# Epoch 2694, 100.0%, avg_loss = 1.4760
# Epoch 2695, 100.0%, avg_loss = 1.4875
# Validation Loss: 1.4965
# Epoch 2696, 100.0%, avg_loss = 1.4871
# Epoch 2697, 100.0%, avg_loss = 1.4414
# Epoch 2698, 100.0%, avg_loss = 1.5036
# Epoch 2699, 100.0%, avg_loss = 1.5168
# Epoch 2700, 100.0%, avg_loss = 1.5836
# Validation Loss: 1.5586
# Epoch 2701, 100.0%, avg_loss = 1.5096
# Epoch 2702, 100.0%, avg_loss = 1.5371
# Epoch 2703, 100.0%, avg_loss = 1.5112
# Epoch 2704, 100.0%, avg_loss = 1.5237
# Epoch 2705, 100.0%, avg_loss = 1.5197
# Validation Loss: 1.5272
# Epoch 2706, 100.0%, avg_loss = 1.5127
# Epoch 2707, 100.0%, avg_loss = 1.5094
# Epoch 2708, 100.0%, avg_loss = 1.5020
# Epoch 2709, 100.0%, avg_loss = 1.4893
# Epoch 2710, 100.0%, avg_loss = 1.5593
# Validation Loss: 1.5092
# Epoch 2711, 100.0%, avg_loss = 1.5402
# Epoch 2712, 100.0%, avg_loss = 1.5354
# Epoch 2713, 100.0%, avg_loss = 1.4929
# Epoch 2714, 100.0%, avg_loss = 1.4267
# Epoch 2715, 100.0%, avg_loss = 1.4895
# Validation Loss: 1.5443
# Epoch 2716, 100.0%, avg_loss = 1.6153
# Epoch 2717, 100.0%, avg_loss = 1.4205
# Epoch 2718, 100.0%, avg_loss = 1.5410
# Epoch 2719, 100.0%, avg_loss = 1.5034
# Epoch 2720, 100.0%, avg_loss = 1.5377
# Validation Loss: 1.5212
# Epoch 2721, 100.0%, avg_loss = 1.4489
# Epoch 2722, 100.0%, avg_loss = 1.4893
# Epoch 2723, 100.0%, avg_loss = 1.4995
# Epoch 2724, 100.0%, avg_loss = 1.5345
# Epoch 2725, 100.0%, avg_loss = 1.5218
# Validation Loss: 1.4917
# Epoch 2726, 100.0%, avg_loss = 1.4736
# Epoch 2727, 100.0%, avg_loss = 1.5165
# Epoch 2728, 100.0%, avg_loss = 1.4519
# Epoch 2729, 100.0%, avg_loss = 1.5367
# Epoch 2730, 100.0%, avg_loss = 1.5070
# Validation Loss: 1.5395
# Epoch 2731, 100.0%, avg_loss = 1.4956
# Epoch 2732, 100.0%, avg_loss = 1.4737
# Epoch 2733, 100.0%, avg_loss = 1.5386
# Epoch 2734, 100.0%, avg_loss = 1.4861
# Epoch 2735, 100.0%, avg_loss = 1.4376
# Validation Loss: 1.5175
# Epoch 2736, 100.0%, avg_loss = 1.5055
# Epoch 2737, 100.0%, avg_loss = 1.4804
# Epoch 2738, 100.0%, avg_loss = 1.4933
# Epoch 2739, 100.0%, avg_loss = 1.4796
# Epoch 2740, 100.0%, avg_loss = 1.4437
# Validation Loss: 1.5594
# Epoch 2741, 100.0%, avg_loss = 1.5336
# Epoch 2742, 100.0%, avg_loss = 1.4507
# Epoch 2743, 100.0%, avg_loss = 1.5505
# Epoch 2744, 100.0%, avg_loss = 1.4800
# Epoch 2745, 100.0%, avg_loss = 1.4946
# Validation Loss: 1.5499
# Epoch 2746, 100.0%, avg_loss = 1.5028
# Epoch 2747, 100.0%, avg_loss = 1.5077
# Epoch 2748, 100.0%, avg_loss = 1.5289
# Epoch 2749, 100.0%, avg_loss = 1.5155
# Epoch 2750, 100.0%, avg_loss = 1.5408
# Validation Loss: 1.5332
# Epoch 2751, 100.0%, avg_loss = 1.5040
# Epoch 2752, 100.0%, avg_loss = 1.5131
# Epoch 2753, 100.0%, avg_loss = 1.4764
# Epoch 2754, 100.0%, avg_loss = 1.5365
# Epoch 2755, 100.0%, avg_loss = 1.4566
# Validation Loss: 1.5292
# Epoch 2756, 100.0%, avg_loss = 1.5210
# Epoch 2757, 100.0%, avg_loss = 1.4874
# Epoch 2758, 100.0%, avg_loss = 1.4829
# Epoch 2759, 100.0%, avg_loss = 1.4982
# Epoch 2760, 100.0%, avg_loss = 1.5461
# Validation Loss: 1.5238
# Epoch 2761, 100.0%, avg_loss = 1.5099
# Epoch 2762, 100.0%, avg_loss = 1.5352
# Epoch 2763, 100.0%, avg_loss = 1.5454
# Epoch 2764, 100.0%, avg_loss = 1.5118
# Epoch 2765, 100.0%, avg_loss = 1.4892
# Validation Loss: 1.5621
# Epoch 2766, 100.0%, avg_loss = 1.5239
# Epoch 2767, 100.0%, avg_loss = 1.4712
# Epoch 2768, 100.0%, avg_loss = 1.4549
# Epoch 2769, 100.0%, avg_loss = 1.4902
# Epoch 2770, 100.0%, avg_loss = 1.4978
# Validation Loss: 1.5289
# Epoch 2771, 100.0%, avg_loss = 1.5615
# Epoch 2772, 100.0%, avg_loss = 1.5416
# Epoch 2773, 100.0%, avg_loss = 1.5027
# Epoch 2774, 100.0%, avg_loss = 1.4832
# Epoch 2775, 100.0%, avg_loss = 1.4487
# Validation Loss: 1.5001
# Epoch 2776, 100.0%, avg_loss = 1.4724
# Epoch 2777, 100.0%, avg_loss = 1.4824
# Epoch 2778, 100.0%, avg_loss = 1.4782
# Epoch 2779, 100.0%, avg_loss = 1.4808
# Epoch 2780, 100.0%, avg_loss = 1.4948
# Validation Loss: 1.5296
# Epoch 2781, 100.0%, avg_loss = 1.5006
# Epoch 2782, 100.0%, avg_loss = 1.4811
# Epoch 2783, 100.0%, avg_loss = 1.4763
# Epoch 2784, 100.0%, avg_loss = 1.5353
# Epoch 2785, 100.0%, avg_loss = 1.5001
# Validation Loss: 1.5062
# Epoch 2786, 100.0%, avg_loss = 1.4881
# Epoch 2787, 100.0%, avg_loss = 1.5211
# Epoch 2788, 100.0%, avg_loss = 1.5511
# Epoch 2789, 100.0%, avg_loss = 1.4229
# Epoch 2790, 100.0%, avg_loss = 1.5390
# Validation Loss: 1.5314
# Epoch 2791, 100.0%, avg_loss = 1.5676
# Epoch 2792, 100.0%, avg_loss = 1.4548
# Epoch 2793, 100.0%, avg_loss = 1.5485
# Epoch 2794, 100.0%, avg_loss = 1.5561
# Epoch 2795, 100.0%, avg_loss = 1.4738
# Validation Loss: 1.5018
# Epoch 2796, 100.0%, avg_loss = 1.5331
# Epoch 2797, 100.0%, avg_loss = 1.4582
# Epoch 2798, 100.0%, avg_loss = 1.5421
# Epoch 2799, 100.0%, avg_loss = 1.4449
# Epoch 2800, 100.0%, avg_loss = 1.5335
# Validation Loss: 1.5344
# Epoch 2801, 100.0%, avg_loss = 1.5549
# Epoch 2802, 100.0%, avg_loss = 1.4553
# Epoch 2803, 100.0%, avg_loss = 1.5122
# Epoch 2804, 100.0%, avg_loss = 1.5610
# Epoch 2805, 100.0%, avg_loss = 1.4729
# Validation Loss: 1.5032
# Epoch 2806, 100.0%, avg_loss = 1.4606
# Epoch 2807, 100.0%, avg_loss = 1.5420
# Epoch 2808, 100.0%, avg_loss = 1.4931
# Epoch 2809, 100.0%, avg_loss = 1.4698
# Epoch 2810, 100.0%, avg_loss = 1.5479
# Validation Loss: 1.5031
# Epoch 2811, 100.0%, avg_loss = 1.5008
# Epoch 2812, 100.0%, avg_loss = 1.5333
# Epoch 2813, 100.0%, avg_loss = 1.4731
# Epoch 2814, 100.0%, avg_loss = 1.4363
# Epoch 2815, 100.0%, avg_loss = 1.5089
# Validation Loss: 1.5390
# Epoch 2816, 100.0%, avg_loss = 1.5243
# Epoch 2817, 100.0%, avg_loss = 1.5731
# Epoch 2818, 100.0%, avg_loss = 1.4841
# Epoch 2819, 100.0%, avg_loss = 1.4879
# Epoch 2820, 100.0%, avg_loss = 1.5602
# Validation Loss: 1.5227
# Epoch 2821, 100.0%, avg_loss = 1.5137
# Epoch 2822, 100.0%, avg_loss = 1.5411
# Epoch 2823, 100.0%, avg_loss = 1.4123
# Epoch 2824, 100.0%, avg_loss = 1.5268
# Epoch 2825, 100.0%, avg_loss = 1.4818
# Validation Loss: 1.5236
# Epoch 2826, 100.0%, avg_loss = 1.4973
# Epoch 2827, 100.0%, avg_loss = 1.4890
# Epoch 2828, 100.0%, avg_loss = 1.5551
# Epoch 2829, 100.0%, avg_loss = 1.5124
# Epoch 2830, 100.0%, avg_loss = 1.5665
# Validation Loss: 1.5234
# Epoch 2831, 100.0%, avg_loss = 1.4969
# Epoch 2832, 100.0%, avg_loss = 1.4704
# Epoch 2833, 100.0%, avg_loss = 1.5114
# Epoch 2834, 100.0%, avg_loss = 1.5062
# Epoch 2835, 100.0%, avg_loss = 1.4933
# Validation Loss: 1.5283
# Epoch 2836, 100.0%, avg_loss = 1.4814
# Epoch 2837, 100.0%, avg_loss = 1.4767
# Epoch 2838, 100.0%, avg_loss = 1.5342
# Epoch 2839, 100.0%, avg_loss = 1.5245
# Epoch 2840, 100.0%, avg_loss = 1.5121
# Validation Loss: 1.5363
# Epoch 2841, 100.0%, avg_loss = 1.4775
# Epoch 2842, 100.0%, avg_loss = 1.5276
# Epoch 2843, 100.0%, avg_loss = 1.5541
# Epoch 2844, 100.0%, avg_loss = 1.5511
# Epoch 2845, 100.0%, avg_loss = 1.4938
# Validation Loss: 1.5446
# Epoch 2846, 100.0%, avg_loss = 1.5256
# Epoch 2847, 100.0%, avg_loss = 1.5203
# Epoch 2848, 100.0%, avg_loss = 1.4762
# Epoch 2849, 100.0%, avg_loss = 1.4145
# Epoch 2850, 100.0%, avg_loss = 1.4268
# Validation Loss: 1.5176
# Epoch 2851, 100.0%, avg_loss = 1.5101
# Epoch 2852, 100.0%, avg_loss = 1.4815
# Epoch 2853, 100.0%, avg_loss = 1.5185
# Epoch 2854, 100.0%, avg_loss = 1.4912
# Epoch 2855, 100.0%, avg_loss = 1.4863
# Validation Loss: 1.5218
# Epoch 2856, 100.0%, avg_loss = 1.5202
# Epoch 2857, 100.0%, avg_loss = 1.5427
# Epoch 2858, 100.0%, avg_loss = 1.6076
# Epoch 2859, 100.0%, avg_loss = 1.4364
# Epoch 2860, 100.0%, avg_loss = 1.4661
# Validation Loss: 1.5371
# Epoch 2861, 100.0%, avg_loss = 1.4937
# Epoch 2862, 100.0%, avg_loss = 1.5213
# Epoch 2863, 100.0%, avg_loss = 1.5038
# Epoch 2864, 100.0%, avg_loss = 1.4344
# Epoch 2865, 100.0%, avg_loss = 1.5345
# Validation Loss: 1.5394
# Epoch 2866, 100.0%, avg_loss = 1.4672
# Epoch 2867, 100.0%, avg_loss = 1.5358
# Epoch 2868, 100.0%, avg_loss = 1.5171
# Epoch 2869, 100.0%, avg_loss = 1.5151
# Epoch 2870, 100.0%, avg_loss = 1.5917
# Validation Loss: 1.5300
# Epoch 2871, 100.0%, avg_loss = 1.4611
# Epoch 2872, 100.0%, avg_loss = 1.5473
# Epoch 2873, 100.0%, avg_loss = 1.4544
# Epoch 2874, 100.0%, avg_loss = 1.5393
# Epoch 2875, 100.0%, avg_loss = 1.4882
# Validation Loss: 1.5032
# Epoch 2876, 100.0%, avg_loss = 1.5153
# Epoch 2877, 100.0%, avg_loss = 1.5238
# Epoch 2878, 100.0%, avg_loss = 1.5299
# Epoch 2879, 100.0%, avg_loss = 1.5569
# Epoch 2880, 100.0%, avg_loss = 1.5406
# Validation Loss: 1.4984
# Epoch 2881, 100.0%, avg_loss = 1.5326
# Epoch 2882, 100.0%, avg_loss = 1.4619
# Epoch 2883, 100.0%, avg_loss = 1.5318
# Epoch 2884, 100.0%, avg_loss = 1.5190
# Epoch 2885, 100.0%, avg_loss = 1.4843
# Validation Loss: 1.5350
# Epoch 2886, 100.0%, avg_loss = 1.4304
# Epoch 2887, 100.0%, avg_loss = 1.5320
# Epoch 2888, 100.0%, avg_loss = 1.4949
# Epoch 2889, 100.0%, avg_loss = 1.5104
# Epoch 2890, 100.0%, avg_loss = 1.5144
# Validation Loss: 1.5200
# Epoch 2891, 100.0%, avg_loss = 1.5663
# Epoch 2892, 100.0%, avg_loss = 1.4245
# Epoch 2893, 100.0%, avg_loss = 1.4905
# Epoch 2894, 100.0%, avg_loss = 1.5236
# Epoch 2895, 100.0%, avg_loss = 1.5552
# Validation Loss: 1.5143
# Epoch 2896, 100.0%, avg_loss = 1.5261
# Epoch 2897, 100.0%, avg_loss = 1.5393
# Epoch 2898, 100.0%, avg_loss = 1.4450
# Epoch 2899, 100.0%, avg_loss = 1.4462
# Epoch 2900, 100.0%, avg_loss = 1.5527
# Validation Loss: 1.5444
# Epoch 2901, 100.0%, avg_loss = 1.5451
# Epoch 2902, 100.0%, avg_loss = 1.5761
# Epoch 2903, 100.0%, avg_loss = 1.5293
# Epoch 2904, 100.0%, avg_loss = 1.5206
# Epoch 2905, 100.0%, avg_loss = 1.4972
# Validation Loss: 1.5321
# Epoch 2906, 100.0%, avg_loss = 1.5147
# Epoch 2907, 100.0%, avg_loss = 1.3988
# Epoch 2908, 100.0%, avg_loss = 1.5162
# Epoch 2909, 100.0%, avg_loss = 1.5819
# Epoch 2910, 100.0%, avg_loss = 1.6467
# Validation Loss: 1.4819
# Epoch 2911, 100.0%, avg_loss = 1.5136
# Epoch 2912, 100.0%, avg_loss = 1.4752
# Epoch 2913, 100.0%, avg_loss = 1.5033
# Epoch 2914, 100.0%, avg_loss = 1.5402
# Epoch 2915, 100.0%, avg_loss = 1.5323
# Validation Loss: 1.5132
# Epoch 2916, 100.0%, avg_loss = 1.4531
# Epoch 2917, 100.0%, avg_loss = 1.4258
# Epoch 2918, 100.0%, avg_loss = 1.5070
# Epoch 2919, 100.0%, avg_loss = 1.5305
# Epoch 2920, 100.0%, avg_loss = 1.5069
# Validation Loss: 1.5399
# Epoch 2921, 100.0%, avg_loss = 1.4707
# Epoch 2922, 100.0%, avg_loss = 1.5367
# Epoch 2923, 100.0%, avg_loss = 1.5011
# Epoch 2924, 100.0%, avg_loss = 1.4688
# Epoch 2925, 100.0%, avg_loss = 1.6037
# Validation Loss: 1.5074
# Epoch 2926, 100.0%, avg_loss = 1.4895
# Epoch 2927, 100.0%, avg_loss = 1.5603
# Epoch 2928, 100.0%, avg_loss = 1.4959
# Epoch 2929, 100.0%, avg_loss = 1.4564
# Epoch 2930, 100.0%, avg_loss = 1.5580
# Validation Loss: 1.5018
# Epoch 2931, 100.0%, avg_loss = 1.4888
# Epoch 2932, 100.0%, avg_loss = 1.5304
# Epoch 2933, 100.0%, avg_loss = 1.5054
# Epoch 2934, 100.0%, avg_loss = 1.5337
# Epoch 2935, 100.0%, avg_loss = 1.5032
# Validation Loss: 1.5037
# Epoch 2936, 100.0%, avg_loss = 1.4494
# Epoch 2937, 100.0%, avg_loss = 1.5032
# Epoch 2938, 100.0%, avg_loss = 1.5032
# Epoch 2939, 100.0%, avg_loss = 1.5305
# Epoch 2940, 100.0%, avg_loss = 1.5193
# Validation Loss: 1.5316
# Epoch 2941, 100.0%, avg_loss = 1.4508
# Epoch 2942, 100.0%, avg_loss = 1.4773
# Epoch 2943, 100.0%, avg_loss = 1.4610
# Epoch 2944, 100.0%, avg_loss = 1.5074
# Epoch 2945, 100.0%, avg_loss = 1.5362
# Validation Loss: 1.5167
# Epoch 2946, 100.0%, avg_loss = 1.5616
# Epoch 2947, 100.0%, avg_loss = 1.5150
# Epoch 2948, 100.0%, avg_loss = 1.5207
# Epoch 2949, 100.0%, avg_loss = 1.5180
# Epoch 2950, 100.0%, avg_loss = 1.4396
# Validation Loss: 1.5452
# Epoch 2951, 100.0%, avg_loss = 1.4647
# Epoch 2952, 100.0%, avg_loss = 1.5161
# Epoch 2953, 100.0%, avg_loss = 1.5065
# Epoch 2954, 100.0%, avg_loss = 1.5732
# Epoch 2955, 100.0%, avg_loss = 1.5176
# Validation Loss: 1.5231
# Epoch 2956, 100.0%, avg_loss = 1.4823
# Epoch 2957, 100.0%, avg_loss = 1.4888
# Epoch 2958, 100.0%, avg_loss = 1.4600
# Epoch 2959, 100.0%, avg_loss = 1.4996
# Epoch 2960, 100.0%, avg_loss = 1.5194
# Validation Loss: 1.5289
# Epoch 2961, 100.0%, avg_loss = 1.5841
# Epoch 2962, 100.0%, avg_loss = 1.5217
# Epoch 2963, 100.0%, avg_loss = 1.5260
# Epoch 2964, 100.0%, avg_loss = 1.5142
# Epoch 2965, 100.0%, avg_loss = 1.5325
# Validation Loss: 1.5758
# Epoch 2966, 100.0%, avg_loss = 1.4611
# Epoch 2967, 100.0%, avg_loss = 1.5117
# Epoch 2968, 100.0%, avg_loss = 1.4663
# Epoch 2969, 100.0%, avg_loss = 1.5219
# Epoch 2970, 100.0%, avg_loss = 1.4702
# Validation Loss: 1.5306
# Epoch 2971, 100.0%, avg_loss = 1.4924
# Epoch 2972, 100.0%, avg_loss = 1.3768
# Epoch 2973, 100.0%, avg_loss = 1.5291
# Epoch 2974, 100.0%, avg_loss = 1.5364
# Epoch 2975, 100.0%, avg_loss = 1.6037
# Validation Loss: 1.5082
# Epoch 2976, 100.0%, avg_loss = 1.4629
# Epoch 2977, 100.0%, avg_loss = 1.5760
# Epoch 2978, 100.0%, avg_loss = 1.4569
# Epoch 2979, 100.0%, avg_loss = 1.4961
# Epoch 2980, 100.0%, avg_loss = 1.4995
# Validation Loss: 1.5609
# Epoch 2981, 100.0%, avg_loss = 1.5207
# Epoch 2982, 100.0%, avg_loss = 1.4830
# Epoch 2983, 100.0%, avg_loss = 1.4854
# Epoch 2984, 100.0%, avg_loss = 1.4243
# Epoch 2985, 100.0%, avg_loss = 1.4816
# Validation Loss: 1.5399
# Epoch 2986, 100.0%, avg_loss = 1.5752
# Epoch 2987, 100.0%, avg_loss = 1.5173
# Epoch 2988, 100.0%, avg_loss = 1.4313
# Epoch 2989, 100.0%, avg_loss = 1.5030
# Epoch 2990, 100.0%, avg_loss = 1.5226
# Validation Loss: 1.4986
# Epoch 2991, 100.0%, avg_loss = 1.5044
# Epoch 2992, 100.0%, avg_loss = 1.5003
# Epoch 2993, 100.0%, avg_loss = 1.4650
# Epoch 2994, 100.0%, avg_loss = 1.4232
# Epoch 2995, 100.0%, avg_loss = 1.5344
# Validation Loss: 1.4971
# Epoch 2996, 100.0%, avg_loss = 1.5316
# Epoch 2997, 100.0%, avg_loss = 1.4792
# Epoch 2998, 100.0%, avg_loss = 1.5383
# Epoch 2999, 100.0%, avg_loss = 1.5743
# Epoch 3000, 100.0%, avg_loss = 1.5439
# Validation Loss: 1.4878

# %%
torch.save(local_predictor, './results_tokyo/local_predictor_fl_inc_open.pytorch')

# %%
with open('./results_tokyo/federated_pretrained_local_predictor_open_training_loss.pk', 'wb') as f:
    pk.dump(training_loss, f)
with open('./results_tokyo/federated_pretrained_local_predictor_open_validation_loss.pk', 'wb') as f:
    pk.dump(validation_loss, f)
