# %%
import torch
import torch.nn as nn
import pickle as pk
import numpy as np
from model import LocalPredictor
import random

# %%
import os

# %%
data = dict({})
for m in range(4, 13):
    for d in range(1, 32):
        filename = '../data/foursquare_interp_128/2012-{:02d}-{:02d}.pk'.format(m, d)
        if not os.path.isfile(filename):
            continue
        print(filename)
        with open(filename, 'rb') as f:
            data[(m, d)] = pk.load(f)
# Out:
# ../data/foursquare_interp_128/2012-04-04.pk
# ../data/foursquare_interp_128/2012-04-05.pk
# ../data/foursquare_interp_128/2012-04-08.pk
# ../data/foursquare_interp_128/2012-04-09.pk
# ../data/foursquare_interp_128/2012-04-10.pk
# ../data/foursquare_interp_128/2012-04-11.pk
# ../data/foursquare_interp_128/2012-04-12.pk
# ../data/foursquare_interp_128/2012-04-13.pk
# ../data/foursquare_interp_128/2012-04-14.pk
# ../data/foursquare_interp_128/2012-04-15.pk
# ../data/foursquare_interp_128/2012-04-16.pk
# ../data/foursquare_interp_128/2012-04-17.pk
# ../data/foursquare_interp_128/2012-04-18.pk
# ../data/foursquare_interp_128/2012-04-19.pk
# ../data/foursquare_interp_128/2012-04-20.pk
# ../data/foursquare_interp_128/2012-04-21.pk
# ../data/foursquare_interp_128/2012-04-22.pk
# ../data/foursquare_interp_128/2012-04-23.pk
# ../data/foursquare_interp_128/2012-04-24.pk
# ../data/foursquare_interp_128/2012-04-25.pk
# ../data/foursquare_interp_128/2012-04-26.pk
# ../data/foursquare_interp_128/2012-04-27.pk
# ../data/foursquare_interp_128/2012-04-28.pk
# ../data/foursquare_interp_128/2012-04-29.pk
# ../data/foursquare_interp_128/2012-05-02.pk
# ../data/foursquare_interp_128/2012-05-03.pk
# ../data/foursquare_interp_128/2012-05-04.pk
# ../data/foursquare_interp_128/2012-05-05.pk
# ../data/foursquare_interp_128/2012-05-07.pk
# ../data/foursquare_interp_128/2012-05-08.pk
# ../data/foursquare_interp_128/2012-05-09.pk
# ../data/foursquare_interp_128/2012-05-10.pk
# ../data/foursquare_interp_128/2012-05-11.pk
# ../data/foursquare_interp_128/2012-05-12.pk
# ../data/foursquare_interp_128/2012-05-13.pk
# ../data/foursquare_interp_128/2012-05-14.pk
# ../data/foursquare_interp_128/2012-05-15.pk
# ../data/foursquare_interp_128/2012-05-16.pk
# ../data/foursquare_interp_128/2012-05-17.pk
# ../data/foursquare_interp_128/2012-05-18.pk
# ../data/foursquare_interp_128/2012-05-19.pk
# ../data/foursquare_interp_128/2012-05-21.pk
# ../data/foursquare_interp_128/2012-05-22.pk
# ../data/foursquare_interp_128/2012-05-24.pk
# ../data/foursquare_interp_128/2012-05-25.pk
# ../data/foursquare_interp_128/2012-05-26.pk
# ../data/foursquare_interp_128/2012-05-27.pk
# ../data/foursquare_interp_128/2012-05-28.pk
# ../data/foursquare_interp_128/2012-05-29.pk
# ../data/foursquare_interp_128/2012-05-30.pk
# ../data/foursquare_interp_128/2012-06-01.pk
# ../data/foursquare_interp_128/2012-06-03.pk
# ../data/foursquare_interp_128/2012-06-04.pk
# ../data/foursquare_interp_128/2012-06-05.pk
# ../data/foursquare_interp_128/2012-06-06.pk
# ../data/foursquare_interp_128/2012-06-07.pk
# ../data/foursquare_interp_128/2012-06-08.pk
# ../data/foursquare_interp_128/2012-06-09.pk
# ../data/foursquare_interp_128/2012-06-10.pk
# ../data/foursquare_interp_128/2012-06-11.pk
# ../data/foursquare_interp_128/2012-06-12.pk
# ../data/foursquare_interp_128/2012-06-13.pk
# ../data/foursquare_interp_128/2012-06-14.pk
# ../data/foursquare_interp_128/2012-06-15.pk
# ../data/foursquare_interp_128/2012-06-17.pk
# ../data/foursquare_interp_128/2012-06-18.pk
# ../data/foursquare_interp_128/2012-06-19.pk
# ../data/foursquare_interp_128/2012-06-21.pk
# ../data/foursquare_interp_128/2012-06-25.pk
# ../data/foursquare_interp_128/2012-06-27.pk
# ../data/foursquare_interp_128/2012-07-01.pk
# ../data/foursquare_interp_128/2012-07-02.pk
# ../data/foursquare_interp_128/2012-07-03.pk
# ../data/foursquare_interp_128/2012-07-04.pk
# ../data/foursquare_interp_128/2012-07-05.pk
# ../data/foursquare_interp_128/2012-07-06.pk
# ../data/foursquare_interp_128/2012-07-07.pk
# ../data/foursquare_interp_128/2012-07-08.pk
# ../data/foursquare_interp_128/2012-07-09.pk
# ../data/foursquare_interp_128/2012-07-10.pk
# ../data/foursquare_interp_128/2012-07-11.pk
# ../data/foursquare_interp_128/2012-07-12.pk
# ../data/foursquare_interp_128/2012-07-13.pk
# ../data/foursquare_interp_128/2012-07-14.pk
# ../data/foursquare_interp_128/2012-07-15.pk
# ../data/foursquare_interp_128/2012-07-16.pk
# ../data/foursquare_interp_128/2012-07-17.pk
# ../data/foursquare_interp_128/2012-07-18.pk
# ../data/foursquare_interp_128/2012-07-19.pk
# ../data/foursquare_interp_128/2012-07-22.pk
# ../data/foursquare_interp_128/2012-07-24.pk
# ../data/foursquare_interp_128/2012-07-28.pk
# ../data/foursquare_interp_128/2012-07-29.pk
# ../data/foursquare_interp_128/2012-07-30.pk
# ../data/foursquare_interp_128/2012-08-05.pk
# ../data/foursquare_interp_128/2012-08-06.pk
# ../data/foursquare_interp_128/2012-08-09.pk
# ../data/foursquare_interp_128/2012-08-10.pk
# ../data/foursquare_interp_128/2012-08-11.pk
# ../data/foursquare_interp_128/2012-08-12.pk
# ../data/foursquare_interp_128/2012-08-13.pk
# ../data/foursquare_interp_128/2012-08-14.pk
# ../data/foursquare_interp_128/2012-08-17.pk
# ../data/foursquare_interp_128/2012-08-18.pk
# ../data/foursquare_interp_128/2012-08-19.pk
# ../data/foursquare_interp_128/2012-08-20.pk
# ../data/foursquare_interp_128/2012-09-05.pk
# ../data/foursquare_interp_128/2012-09-06.pk
# ../data/foursquare_interp_128/2012-09-10.pk
# ../data/foursquare_interp_128/2012-09-13.pk
# ../data/foursquare_interp_128/2012-09-14.pk
# ../data/foursquare_interp_128/2012-09-15.pk
# ../data/foursquare_interp_128/2012-09-16.pk
# ../data/foursquare_interp_128/2012-10-08.pk
# ../data/foursquare_interp_128/2012-10-12.pk
# ../data/foursquare_interp_128/2012-10-13.pk
# ../data/foursquare_interp_128/2012-10-16.pk
# ../data/foursquare_interp_128/2012-10-17.pk
# ../data/foursquare_interp_128/2012-10-19.pk
# ../data/foursquare_interp_128/2012-10-22.pk
# ../data/foursquare_interp_128/2012-10-23.pk
# ../data/foursquare_interp_128/2012-10-24.pk
# ../data/foursquare_interp_128/2012-10-25.pk
# ../data/foursquare_interp_128/2012-10-26.pk
# ../data/foursquare_interp_128/2012-10-27.pk
# ../data/foursquare_interp_128/2012-10-28.pk
# ../data/foursquare_interp_128/2012-10-29.pk
# ../data/foursquare_interp_128/2012-10-31.pk
# ../data/foursquare_interp_128/2012-11-01.pk
# ../data/foursquare_interp_128/2012-11-02.pk
# ../data/foursquare_interp_128/2012-11-05.pk
# ../data/foursquare_interp_128/2012-11-06.pk
# ../data/foursquare_interp_128/2012-11-07.pk
# ../data/foursquare_interp_128/2012-11-08.pk
# ../data/foursquare_interp_128/2012-11-09.pk
# ../data/foursquare_interp_128/2012-11-10.pk
# ../data/foursquare_interp_128/2012-11-11.pk
# ../data/foursquare_interp_128/2012-11-12.pk
# ../data/foursquare_interp_128/2012-11-13.pk
# ../data/foursquare_interp_128/2012-11-16.pk
# ../data/foursquare_interp_128/2012-11-17.pk
# ../data/foursquare_interp_128/2012-11-18.pk
# ../data/foursquare_interp_128/2012-11-20.pk
# ../data/foursquare_interp_128/2012-11-21.pk
# ../data/foursquare_interp_128/2012-11-22.pk
# ../data/foursquare_interp_128/2012-11-23.pk
# ../data/foursquare_interp_128/2012-11-24.pk
# ../data/foursquare_interp_128/2012-11-25.pk
# ../data/foursquare_interp_128/2012-11-26.pk
# ../data/foursquare_interp_128/2012-11-27.pk
# ../data/foursquare_interp_128/2012-11-28.pk
# ../data/foursquare_interp_128/2012-11-29.pk
# ../data/foursquare_interp_128/2012-12-01.pk
# ../data/foursquare_interp_128/2012-12-02.pk
# ../data/foursquare_interp_128/2012-12-03.pk
# ../data/foursquare_interp_128/2012-12-04.pk
# ../data/foursquare_interp_128/2012-12-05.pk
# ../data/foursquare_interp_128/2012-12-06.pk
# ../data/foursquare_interp_128/2012-12-07.pk
# ../data/foursquare_interp_128/2012-12-08.pk
# ../data/foursquare_interp_128/2012-12-09.pk
# ../data/foursquare_interp_128/2012-12-10.pk
# ../data/foursquare_interp_128/2012-12-11.pk
# ../data/foursquare_interp_128/2012-12-12.pk
# ../data/foursquare_interp_128/2012-12-13.pk
# ../data/foursquare_interp_128/2012-12-14.pk
# ../data/foursquare_interp_128/2012-12-15.pk
# ../data/foursquare_interp_128/2012-12-16.pk
# ../data/foursquare_interp_128/2012-12-17.pk
# ../data/foursquare_interp_128/2012-12-18.pk
# ../data/foursquare_interp_128/2012-12-19.pk
# ../data/foursquare_interp_128/2012-12-20.pk
# ../data/foursquare_interp_128/2012-12-21.pk
# ../data/foursquare_interp_128/2012-12-22.pk
# ../data/foursquare_interp_128/2012-12-23.pk
# ../data/foursquare_interp_128/2012-12-27.pk
# ../data/foursquare_interp_128/2012-12-28.pk
# ../data/foursquare_interp_128/2012-12-29.pk
# ../data/foursquare_interp_128/2012-12-30.pk
# ../data/foursquare_interp_128/2012-12-31.pk

# %%
uid_sets = dict({})
for d in data:
    uid_sets[d] = set(list(data[d].keys()))

# %%
num_locs = 128
loc_embedding_dim = 64
T = 96
num_time = T
time_embedding_dim = 32
hidden_dim = 128
latent_dim = 128
n_layers = 2

# %%
local_predictor = LocalPredictor(num_locs, loc_embedding_dim, num_time, time_embedding_dim, hidden_dim, latent_dim, n_layers).cuda(0)

# %%
optimizer = torch.optim.RMSprop(local_predictor.parameters(), lr=1e-3)
optimizer_scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=2, gamma=0.8)

# %%
dT = 4

# %%
training_loss = dict({})
validation_loss = dict({})

# %%
batch_size = 32

for epoch in range(1, 11):
    
    doc_date_set = set(random.sample(list(data.keys()), 100))
    qry_date_set = set(list(data.keys())) - doc_date_set

    uid_doc_set = set([])
    for d in doc_date_set:
        uid_doc_set = uid_doc_set | uid_sets[d]

    data_doc = dict({})
    data_qry = dict({})

    for d in doc_date_set:
        for uid in data[d]:
            if uid not in data_doc:
                data_doc[uid] = [data[d][uid]]
            else:
                data_doc[uid].append(data[d][uid])

    for d in qry_date_set:
        for uid in data[d]:
            if uid not in data_qry:
                data_qry[uid] = [data[d][uid]]
            else:
                data_qry[uid].append(data[d][uid])

    for uid in data_doc:
        data_doc[uid] = torch.LongTensor(data_doc[uid]).cuda(0)

    for uid in data_qry:
        data_qry[uid] = torch.LongTensor(data_qry[uid]).cuda(0)
    
    optimizer.zero_grad()
    #optimizer_scheduler.step()
    
    avg_loss = 0.0
    cnt = 0
    
    user_list_train = list(data_qry.keys())
    random.shuffle(user_list_train)
    
    for uid in user_list_train:
        t = np.random.randint(T - 2 * dT + 1)
        x_loc_qry = data_qry[uid][:, t: t + dT]
        x_t_qry = torch.zeros_like(x_loc_qry) + t
        y = data_qry[uid][:, t + 2 * dT - 1]
        
        if uid not in data_doc:
            loss = local_predictor(x_loc_qry, x_t_qry, None, None, y)
        else:
            x_loc_doc = data_doc[uid][:, t: t + 2 * dT]
            x_t_doc = torch.zeros_like(x_loc_doc) + t
            loss = local_predictor(x_loc_qry, x_t_qry, x_loc_doc, x_t_doc, y)
        
        loss.backward()
        cnt += data_qry[uid].shape[0]
        avg_loss += loss.item()

        if cnt % batch_size == 0:
            optimizer.step()
            optimizer.zero_grad()

            print('Epoch {:02d}, avg_loss = {:.4f}'.format(epoch, avg_loss / cnt), end='\r')
    training_loss[epoch] = avg_loss / cnt
    print('')
    
    # testing
        
    doc_date_set = set(random.sample(list(data.keys()), 100))
    qry_date_set = set(list(data.keys())) - doc_date_set

    uid_doc_set = set([])
    for d in doc_date_set:
        uid_doc_set = uid_doc_set | uid_sets[d]

    data_doc = dict({})
    data_qry = dict({})

    for d in doc_date_set:
        for uid in data[d]:
            if uid not in data_doc:
                data_doc[uid] = [data[d][uid]]
            else:
                data_doc[uid].append(data[d][uid])

    for d in qry_date_set:
        for uid in data[d]:
            if uid not in data_qry:
                data_qry[uid] = [data[d][uid]]
            else:
                data_qry[uid].append(data[d][uid])

    for uid in data_doc:
        data_doc[uid] = torch.LongTensor(data_doc[uid]).cuda(0)

    for uid in data_qry:
        data_qry[uid] = torch.LongTensor(data_qry[uid]).cuda(0)
    
    avg_loss = 0.0
    cnt = 0
    
    for uid in user_list_train:
        t = np.random.randint(T - 2 * dT + 1)
        x_loc_qry = data_qry[uid][:, t: t + dT]
        x_t_qry = torch.zeros_like(x_loc_qry) + t
        y = data_qry[uid][:, t + 2 * dT - 1]
        
        if uid not in data_doc:
            loss = local_predictor(x_loc_qry, x_t_qry, None, None, y)
        else:
            x_loc_doc = data_doc[uid][:, t: t + 2 * dT]
            x_t_doc = torch.zeros_like(x_loc_doc) + t
            loss = local_predictor(x_loc_qry, x_t_qry, x_loc_doc, x_t_doc, y)
        
        cnt += data_qry[uid].shape[0]
        avg_loss += loss.item()

        print('Epoch {:02d}, val_avg_loss = {:.4f}'.format(epoch, avg_loss / cnt), end='\r')
    validation_loss[epoch] = avg_loss / cnt
    print('')
# Out:
# Epoch 01, avg_loss = 0.2977
# Epoch 01, val_avg_loss = 0.2829
# Epoch 02, avg_loss = 0.2935
# Epoch 02, val_avg_loss = 0.2879
# Epoch 03, avg_loss = 0.2946
# Epoch 03, val_avg_loss = 0.2673
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-13-9176af1ee15c> in <module>
#     104     for uid in user_list_train:
#     105         t = np.random.randint(T - 2 * dT + 1)
# --> 106         x_loc_qry = data_qry[uid][:, t: t + dT]
#     107         x_t_qry = torch.zeros_like(x_loc_qry) + t
#     108         y = data_qry[uid][:, t + 2 * dT - 1]
#
# KeyError: 1229

# %%
torch.save(local_predictor, './results_tokyo/local_predictor_open_128.pytorch')
