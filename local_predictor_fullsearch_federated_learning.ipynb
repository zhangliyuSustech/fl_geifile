# %%
import torch
import torch.nn as nn
import pickle as pk
import numpy as np
from model import LocalPredictorFullSearch
import random

# %%
data = dict({})
for d in range(1, 29):
    filename = '../data/UsersInTokyo2012/201211{:02d}_interp.pk'.format(d)
    print(filename)
    with open(filename, 'rb') as f:
        data[d] = pk.load(f)
# Out:
# ../data/UsersInTokyo2012/20121101_interp.pk
# ../data/UsersInTokyo2012/20121102_interp.pk
# ../data/UsersInTokyo2012/20121103_interp.pk
# ../data/UsersInTokyo2012/20121104_interp.pk
# ../data/UsersInTokyo2012/20121105_interp.pk
# ../data/UsersInTokyo2012/20121106_interp.pk
# ../data/UsersInTokyo2012/20121107_interp.pk
# ../data/UsersInTokyo2012/20121108_interp.pk
# ../data/UsersInTokyo2012/20121109_interp.pk
# ../data/UsersInTokyo2012/20121110_interp.pk
# ../data/UsersInTokyo2012/20121111_interp.pk
# ../data/UsersInTokyo2012/20121112_interp.pk
# ../data/UsersInTokyo2012/20121113_interp.pk
# ../data/UsersInTokyo2012/20121114_interp.pk
# ../data/UsersInTokyo2012/20121115_interp.pk
# ../data/UsersInTokyo2012/20121116_interp.pk
# ../data/UsersInTokyo2012/20121117_interp.pk
# ../data/UsersInTokyo2012/20121118_interp.pk
# ../data/UsersInTokyo2012/20121119_interp.pk
# ../data/UsersInTokyo2012/20121120_interp.pk
# ../data/UsersInTokyo2012/20121121_interp.pk
# ../data/UsersInTokyo2012/20121122_interp.pk
# ../data/UsersInTokyo2012/20121123_interp.pk
# ../data/UsersInTokyo2012/20121124_interp.pk
# ../data/UsersInTokyo2012/20121125_interp.pk
# ../data/UsersInTokyo2012/20121126_interp.pk
# ../data/UsersInTokyo2012/20121127_interp.pk
# ../data/UsersInTokyo2012/20121128_interp.pk

# %%
uid_sets = dict({})
for d in data:
    uid_sets[d] = set(list(data[d].keys()))

# %%
uid_doc_set = set([])
for d in range(1, 15):
    uid_doc_set = uid_doc_set | uid_sets[d]

# %%
data_doc = dict({})
data_qry_train = dict({})
data_qry_test = dict({})

for d in range(1, 15):
    for uid in data[d]:
        if uid not in data_doc:
            data_doc[uid] = [data[d][uid]]
        else:
            data_doc[uid].append(data[d][uid])

for d in range(15, 22):
    for uid in data[d]:
        if uid not in data_qry_train:
            data_qry_train[uid] = [data[d][uid]]
        else:
            data_qry_train[uid].append(data[d][uid])
            
for d in range(22, 29):
    for uid in data[d]:
        if uid not in data_qry_test:
            data_qry_test[uid] = [data[d][uid]]
        else:
            data_qry_test[uid].append(data[d][uid])

# %%
for uid in data_doc:
    data_doc[uid] = torch.LongTensor(data_doc[uid]).cuda(1)

for uid in data_qry_train:
    data_qry_train[uid] = torch.LongTensor(data_qry_train[uid]).cuda(1)
    
for uid in data_qry_test:
    data_qry_test[uid] = torch.LongTensor(data_qry_test[uid]).cuda(1)

# %%
num_locs = 1600
loc_embedding_dim = 128
T = 96
num_time = T
time_embedding_dim = 32
hidden_dim = 256
latent_dim = 256

# %%
lr = 1e-3
momentum = 0.8

# %%
local_predictor = LocalPredictorFullSearch(num_locs, loc_embedding_dim, num_time, time_embedding_dim, hidden_dim, latent_dim).cuda(1)
local_predictor_server = LocalPredictorFullSearch(num_locs, loc_embedding_dim, num_time, time_embedding_dim, hidden_dim, latent_dim).cuda(1)
optimizer = torch.optim.SGD(local_predictor.parameters(), lr=lr)
optimizer.zero_grad()

# %%
dT = 4

# %%
training_loss = dict({})
validation_loss = dict({})

# %%
user_list_train = list(data_qry_train.keys())
time_list = list(range(T - 2 * dT + 1))

# Initialize global SGD
local_predictor_update = dict({})
        
for epoch in range(1, 4001):
    
    if epoch % 500 == 0:
        lr *= 0.5
    
    update_user_list = random.sample(user_list_train, 2048)
    random.shuffle(update_user_list)
    
    avg_loss = 0.0
    cnt = 0
    n = 0
    
    uidx = 0
    
    for uid in update_user_list:
        uidx += 1
        # loading server model to local
        local_predictor.load_state_dict(local_predictor_server.state_dict())

        nk = data_qry_train[uid].shape[0]
        n += data_qry_train[uid].shape[0]

        t = np.random.randint(T - 2 * dT + 1)
        x_loc_qry = data_qry_train[uid][:, t: t + dT]
        x_t_qry = torch.zeros_like(x_loc_qry) + t
        y = data_qry_train[uid][:, t + 2 * dT - 1]

        if uid not in data_doc:
            loss = local_predictor(x_loc_qry, x_t_qry, None, None, y)
        else:
            x_loc_doc = data_doc[uid][:, t: t + 2 * dT]
            x_t_doc = torch.zeros_like(x_loc_doc) + t
            loss = local_predictor(x_loc_qry, x_t_qry, x_loc_doc, x_t_doc, y)

        loss.backward()
        avg_loss += loss.item()
        cnt += nk
        
        with torch.no_grad():
            for name, para in local_predictor.named_parameters():
                if para.grad is None:
                    continue
                elif name not in local_predictor_update:
                    local_predictor_update[name] = (para.grad + torch.randn_like(para.grad) * 1e-2) * lr
                else:
                    local_predictor_update[name] += (para.grad + torch.randn_like(para.grad) * 1e-2) * lr
                
        optimizer.zero_grad()
        
        print('Epoch {:02d}, {:.1f}%, avg_loss = {:.4f}'.format(epoch, uidx * 100 / len(update_user_list), avg_loss / cnt), end='\r')

    # update
    with torch.no_grad():
        for name, para in local_predictor_server.named_parameters():
            para -= local_predictor_update[name]
            
        for name in local_predictor_update:
            local_predictor_update[name] *= momentum
    
    training_loss[epoch] = avg_loss / cnt
    print('')
    # testing
    
    if epoch % 5 == 0:
        with torch.no_grad():

            cnt = 0
            avg_loss = 0.0

            for uid in data_qry_test:

                if np.random.ranf() > 0.05:
                    continue

                nk = data_qry_test[uid].shape[0]

                t = np.random.randint(T - 2 * dT + 1)
                x_loc_qry = data_qry_test[uid][:, t: t + dT]
                x_t_qry = torch.zeros_like(x_loc_qry) + t
                y = data_qry_test[uid][:, t + 2 * dT - 1]

                if uid not in data_doc:
                    loss = local_predictor_server(x_loc_qry, x_t_qry, None, None, y)
                else:
                    x_loc_doc = data_doc[uid][:, t: t + 2 * dT]
                    x_t_doc = torch.zeros_like(x_loc_doc) + t
                    loss = local_predictor_server(x_loc_qry, x_t_qry, x_loc_doc, x_t_doc, y)

                avg_loss += loss.item()
                cnt += nk

            print('Validation Loss: {:.4f}'.format(avg_loss / cnt))
            validation_loss[epoch] = avg_loss / cnt
# Out:
# Epoch 01, 100.0%, avg_loss = 7.3783
# Epoch 02, 100.0%, avg_loss = 7.2986
# Epoch 03, 100.0%, avg_loss = 7.1357
# Epoch 04, 100.0%, avg_loss = 6.8730
# Epoch 05, 100.0%, avg_loss = 6.5930
# Validation Loss: 6.4149
# Epoch 06, 100.0%, avg_loss = 6.3554
# Epoch 07, 100.0%, avg_loss = 6.1058
# Epoch 08, 100.0%, avg_loss = 5.5671
# Epoch 09, 100.0%, avg_loss = 5.0436
# Epoch 10, 100.0%, avg_loss = 4.5968
# Validation Loss: 4.1795
# Epoch 11, 100.0%, avg_loss = 4.0858
# Epoch 12, 100.0%, avg_loss = 3.8204
# Epoch 13, 100.0%, avg_loss = 3.5401
# Epoch 14, 100.0%, avg_loss = 3.2754
# Epoch 15, 100.0%, avg_loss = 3.2098
# Validation Loss: 3.1315
# Epoch 16, 100.0%, avg_loss = 3.1756
# Epoch 17, 100.0%, avg_loss = 2.9148
# Epoch 18, 100.0%, avg_loss = 2.9282
# Epoch 19, 100.0%, avg_loss = 2.7448
# Epoch 20, 100.0%, avg_loss = 2.6724
# Validation Loss: 2.8416
# Epoch 21, 100.0%, avg_loss = 2.6849
# Epoch 22, 100.0%, avg_loss = 2.7125
# Epoch 23, 100.0%, avg_loss = 2.6452
# Epoch 24, 100.0%, avg_loss = 2.6694
# Epoch 25, 100.0%, avg_loss = 2.7241
# Validation Loss: 2.6771
# Epoch 26, 100.0%, avg_loss = 2.6799
# Epoch 27, 100.0%, avg_loss = 2.6001
# Epoch 28, 100.0%, avg_loss = 2.4497
# Epoch 29, 100.0%, avg_loss = 2.5784
# Epoch 30, 100.0%, avg_loss = 2.5099
# Validation Loss: 2.5068
# Epoch 31, 100.0%, avg_loss = 2.4822
# Epoch 32, 100.0%, avg_loss = 2.4965
# Epoch 33, 100.0%, avg_loss = 2.3930
# Epoch 34, 100.0%, avg_loss = 2.4527
# Epoch 35, 100.0%, avg_loss = 2.4108
# Validation Loss: 2.5171
# Epoch 36, 100.0%, avg_loss = 2.3747
# Epoch 37, 100.0%, avg_loss = 2.3800
# Epoch 38, 100.0%, avg_loss = 2.2953
# Epoch 39, 100.0%, avg_loss = 2.3209
# Epoch 40, 100.0%, avg_loss = 2.3606
# Validation Loss: 2.3274
# Epoch 41, 100.0%, avg_loss = 2.4013
# Epoch 42, 100.0%, avg_loss = 2.3112
# Epoch 43, 100.0%, avg_loss = 2.2502
# Epoch 44, 100.0%, avg_loss = 2.3096
# Epoch 45, 100.0%, avg_loss = 2.2610
# Validation Loss: 2.3194
# Epoch 46, 100.0%, avg_loss = 2.3258
# Epoch 47, 100.0%, avg_loss = 2.2409
# Epoch 48, 100.0%, avg_loss = 2.2616
# Epoch 49, 100.0%, avg_loss = 2.2618
# Epoch 50, 100.0%, avg_loss = 2.2098
# Validation Loss: 2.2642
# Epoch 51, 100.0%, avg_loss = 2.2253
# Epoch 52, 100.0%, avg_loss = 2.2020
# Epoch 53, 100.0%, avg_loss = 2.2667
# Epoch 54, 100.0%, avg_loss = 2.2159
# Epoch 55, 100.0%, avg_loss = 2.2533
# Validation Loss: 2.2241
# Epoch 56, 100.0%, avg_loss = 2.1874
# Epoch 57, 100.0%, avg_loss = 2.2635
# Epoch 58, 100.0%, avg_loss = 2.2953
# Epoch 59, 100.0%, avg_loss = 2.2135
# Epoch 60, 100.0%, avg_loss = 2.0106
# Validation Loss: 2.2282
# Epoch 61, 100.0%, avg_loss = 2.1980
# Epoch 62, 100.0%, avg_loss = 2.1402
# Epoch 63, 100.0%, avg_loss = 2.1282
# Epoch 64, 100.0%, avg_loss = 2.1695
# Epoch 65, 100.0%, avg_loss = 2.0315
# Validation Loss: 2.1613
# Epoch 66, 100.0%, avg_loss = 2.0099
# Epoch 67, 100.0%, avg_loss = 2.0749
# Epoch 68, 100.0%, avg_loss = 2.2074
# Epoch 69, 100.0%, avg_loss = 2.1021
# Epoch 70, 100.0%, avg_loss = 1.9740
# Validation Loss: 2.1589
# Epoch 71, 100.0%, avg_loss = 2.1659
# Epoch 72, 100.0%, avg_loss = 2.1420
# Epoch 73, 100.0%, avg_loss = 2.2117
# Epoch 74, 100.0%, avg_loss = 2.1316
# Epoch 75, 100.0%, avg_loss = 2.1109
# Validation Loss: 2.1179
# Epoch 76, 100.0%, avg_loss = 2.0649
# Epoch 77, 100.0%, avg_loss = 2.0910
# Epoch 78, 100.0%, avg_loss = 2.0295
# Epoch 79, 100.0%, avg_loss = 2.1495
# Epoch 80, 100.0%, avg_loss = 2.0844
# Validation Loss: 2.1230
# Epoch 81, 100.0%, avg_loss = 2.1325
# Epoch 82, 100.0%, avg_loss = 2.0345
# Epoch 83, 100.0%, avg_loss = 1.9995
# Epoch 84, 100.0%, avg_loss = 2.1378
# Epoch 85, 100.0%, avg_loss = 1.9148
# Validation Loss: 2.1039
# Epoch 86, 100.0%, avg_loss = 2.1059
# Epoch 87, 100.0%, avg_loss = 2.0954
# Epoch 88, 100.0%, avg_loss = 2.0713
# Epoch 89, 100.0%, avg_loss = 2.0675
# Epoch 90, 100.0%, avg_loss = 2.1028
# Validation Loss: 2.0642
# Epoch 91, 100.0%, avg_loss = 2.0508
# Epoch 92, 100.0%, avg_loss = 1.9888
# Epoch 93, 100.0%, avg_loss = 2.0867
# Epoch 94, 100.0%, avg_loss = 2.0966
# Epoch 95, 100.0%, avg_loss = 2.0619
# Validation Loss: 2.0218
# Epoch 96, 100.0%, avg_loss = 1.9613
# Epoch 97, 100.0%, avg_loss = 2.0908
# Epoch 98, 100.0%, avg_loss = 1.9692
# Epoch 99, 100.0%, avg_loss = 1.9413
# Epoch 100, 100.0%, avg_loss = 2.0108
# Validation Loss: 2.0363
# Epoch 101, 100.0%, avg_loss = 2.0944
# Epoch 102, 100.0%, avg_loss = 2.0063
# Epoch 103, 100.0%, avg_loss = 2.0839
# Epoch 104, 100.0%, avg_loss = 2.0300
# Epoch 105, 100.0%, avg_loss = 1.9903
# Validation Loss: 1.9817
# Epoch 106, 100.0%, avg_loss = 2.1206
# Epoch 107, 100.0%, avg_loss = 1.9623
# Epoch 108, 100.0%, avg_loss = 2.0023
# Epoch 109, 100.0%, avg_loss = 2.0320
# Epoch 110, 100.0%, avg_loss = 1.9939
# Validation Loss: 2.0171
# Epoch 111, 100.0%, avg_loss = 2.0125
# Epoch 112, 100.0%, avg_loss = 2.0201
# Epoch 113, 100.0%, avg_loss = 1.9328
# Epoch 114, 100.0%, avg_loss = 2.0014
# Epoch 115, 100.0%, avg_loss = 1.9981
# Validation Loss: 1.9674
# Epoch 116, 100.0%, avg_loss = 1.9952
# Epoch 117, 100.0%, avg_loss = 1.9806
# Epoch 118, 100.0%, avg_loss = 1.9924
# Epoch 119, 100.0%, avg_loss = 2.0098
# Epoch 120, 100.0%, avg_loss = 1.9615
# Validation Loss: 1.9667
# Epoch 121, 100.0%, avg_loss = 1.9658
# Epoch 122, 100.0%, avg_loss = 1.9522
# Epoch 123, 100.0%, avg_loss = 2.0404
# Epoch 124, 100.0%, avg_loss = 1.8912
# Epoch 125, 100.0%, avg_loss = 1.9683
# Validation Loss: 1.9828
# Epoch 126, 100.0%, avg_loss = 1.9702
# Epoch 127, 100.0%, avg_loss = 2.0236
# Epoch 128, 100.0%, avg_loss = 1.9388
# Epoch 129, 100.0%, avg_loss = 2.0395
# Epoch 130, 100.0%, avg_loss = 1.8911
# Validation Loss: 1.9279
# Epoch 131, 100.0%, avg_loss = 2.0771
# Epoch 132, 100.0%, avg_loss = 2.0845
# Epoch 133, 100.0%, avg_loss = 1.9023
# Epoch 134, 100.0%, avg_loss = 1.8808
# Epoch 135, 100.0%, avg_loss = 1.9746
# Validation Loss: 1.9967
# Epoch 136, 100.0%, avg_loss = 2.0030
# Epoch 137, 100.0%, avg_loss = 2.0225
# Epoch 138, 100.0%, avg_loss = 1.8239
# Epoch 139, 100.0%, avg_loss = 1.8996
# Epoch 140, 100.0%, avg_loss = 1.8438
# Validation Loss: 1.9587
# Epoch 141, 100.0%, avg_loss = 1.9303
# Epoch 142, 100.0%, avg_loss = 1.8297
# Epoch 143, 100.0%, avg_loss = 1.9553
# Epoch 144, 100.0%, avg_loss = 1.9745
# Epoch 145, 100.0%, avg_loss = 1.9455
# Validation Loss: 1.8968
# Epoch 146, 100.0%, avg_loss = 1.9023
# Epoch 147, 100.0%, avg_loss = 1.9884
# Epoch 148, 100.0%, avg_loss = 1.8481
# Epoch 149, 100.0%, avg_loss = 1.9331
# Epoch 150, 100.0%, avg_loss = 1.9063
# Validation Loss: 1.9607
# Epoch 151, 100.0%, avg_loss = 1.9275
# Epoch 152, 100.0%, avg_loss = 1.9802
# Epoch 153, 100.0%, avg_loss = 1.9053
# Epoch 154, 100.0%, avg_loss = 1.8796
# Epoch 155, 100.0%, avg_loss = 1.8321
# Validation Loss: 1.9341
# Epoch 156, 100.0%, avg_loss = 1.8741
# Epoch 157, 100.0%, avg_loss = 1.8145
# Epoch 158, 100.0%, avg_loss = 1.9245
# Epoch 159, 100.0%, avg_loss = 1.8410
# Epoch 160, 100.0%, avg_loss = 1.9177
# Validation Loss: 1.9355
# Epoch 161, 100.0%, avg_loss = 1.9171
# Epoch 162, 100.0%, avg_loss = 1.9104
# Epoch 163, 100.0%, avg_loss = 1.9925
# Epoch 164, 100.0%, avg_loss = 1.8425
# Epoch 165, 100.0%, avg_loss = 1.9776
# Validation Loss: 1.9096
# Epoch 166, 100.0%, avg_loss = 1.8623
# Epoch 167, 100.0%, avg_loss = 1.9385
# Epoch 168, 100.0%, avg_loss = 1.7941
# Epoch 169, 100.0%, avg_loss = 1.9296
# Epoch 170, 100.0%, avg_loss = 1.8327
# Validation Loss: 1.8374
# Epoch 171, 100.0%, avg_loss = 1.8724
# Epoch 172, 100.0%, avg_loss = 1.7888
# Epoch 173, 100.0%, avg_loss = 1.9228
# Epoch 174, 100.0%, avg_loss = 1.8305
# Epoch 175, 100.0%, avg_loss = 1.9023
# Validation Loss: 1.9262
# Epoch 176, 100.0%, avg_loss = 1.8455
# Epoch 177, 100.0%, avg_loss = 1.9083
# Epoch 178, 100.0%, avg_loss = 1.9003
# Epoch 179, 100.0%, avg_loss = 1.7945
# Epoch 180, 100.0%, avg_loss = 1.8788
# Validation Loss: 1.8769
# Epoch 181, 100.0%, avg_loss = 1.8706
# Epoch 182, 100.0%, avg_loss = 1.9087
# Epoch 183, 100.0%, avg_loss = 1.9495
# Epoch 184, 100.0%, avg_loss = 1.8493
# Epoch 185, 100.0%, avg_loss = 1.7875
# Validation Loss: 1.8535
# Epoch 186, 100.0%, avg_loss = 1.8284
# Epoch 187, 100.0%, avg_loss = 1.8230
# Epoch 188, 100.0%, avg_loss = 1.7797
# Epoch 189, 100.0%, avg_loss = 1.8341
# Epoch 190, 100.0%, avg_loss = 1.8357
# Validation Loss: 1.8204
# Epoch 191, 100.0%, avg_loss = 1.8962
# Epoch 192, 100.0%, avg_loss = 1.8206
# Epoch 193, 100.0%, avg_loss = 1.8330
# Epoch 194, 100.0%, avg_loss = 1.8425
# Epoch 195, 100.0%, avg_loss = 1.8521
# Validation Loss: 1.8574
# Epoch 196, 100.0%, avg_loss = 1.7880
# Epoch 197, 100.0%, avg_loss = 1.9016
# Epoch 198, 100.0%, avg_loss = 1.7627
# Epoch 199, 100.0%, avg_loss = 1.8512
# Epoch 200, 100.0%, avg_loss = 1.8478
# Validation Loss: 1.8419
# Epoch 201, 100.0%, avg_loss = 1.8917
# Epoch 202, 100.0%, avg_loss = 1.7780
# Epoch 203, 100.0%, avg_loss = 1.9045
# Epoch 204, 100.0%, avg_loss = 1.7961
# Epoch 205, 100.0%, avg_loss = 1.8659
# Validation Loss: 1.8424
# Epoch 206, 100.0%, avg_loss = 1.8297
# Epoch 207, 100.0%, avg_loss = 1.8113
# Epoch 208, 100.0%, avg_loss = 1.8466
# Epoch 209, 100.0%, avg_loss = 1.8451
# Epoch 210, 100.0%, avg_loss = 1.7873
# Validation Loss: 1.8711
# Epoch 211, 100.0%, avg_loss = 1.7392
# Epoch 212, 100.0%, avg_loss = 1.9183
# Epoch 213, 100.0%, avg_loss = 1.8788
# Epoch 214, 100.0%, avg_loss = 1.8319
# Epoch 215, 100.0%, avg_loss = 1.8559
# Validation Loss: 1.8251
# Epoch 216, 100.0%, avg_loss = 1.8646
# Epoch 217, 100.0%, avg_loss = 1.7497
# Epoch 218, 100.0%, avg_loss = 1.9005
# Epoch 219, 100.0%, avg_loss = 1.8728
# Epoch 220, 100.0%, avg_loss = 1.8578
# Validation Loss: 1.8100
# Epoch 221, 100.0%, avg_loss = 1.8106
# Epoch 222, 100.0%, avg_loss = 1.7913
# Epoch 223, 100.0%, avg_loss = 1.8021
# Epoch 224, 100.0%, avg_loss = 1.8060
# Epoch 225, 100.0%, avg_loss = 1.7541
# Validation Loss: 1.8776
# Epoch 226, 100.0%, avg_loss = 1.8607
# Epoch 227, 100.0%, avg_loss = 1.8390
# Epoch 228, 100.0%, avg_loss = 1.7586
# Epoch 229, 100.0%, avg_loss = 1.8367
# Epoch 230, 100.0%, avg_loss = 1.7615
# Validation Loss: 1.8446
# Epoch 231, 100.0%, avg_loss = 1.7034
# Epoch 232, 100.0%, avg_loss = 1.8573
# Epoch 233, 100.0%, avg_loss = 1.8231
# Epoch 234, 100.0%, avg_loss = 1.8742
# Epoch 235, 100.0%, avg_loss = 1.8049
# Validation Loss: 1.8260
# Epoch 236, 100.0%, avg_loss = 1.7906
# Epoch 237, 100.0%, avg_loss = 1.8249
# Epoch 238, 100.0%, avg_loss = 1.7712
# Epoch 239, 100.0%, avg_loss = 1.7844
# Epoch 240, 100.0%, avg_loss = 1.7569
# Validation Loss: 1.8012
# Epoch 241, 100.0%, avg_loss = 1.8274
# Epoch 242, 100.0%, avg_loss = 1.9207
# Epoch 243, 100.0%, avg_loss = 1.7658
# Epoch 244, 100.0%, avg_loss = 1.7866
# Epoch 245, 100.0%, avg_loss = 1.8606
# Validation Loss: 1.7889
# Epoch 246, 100.0%, avg_loss = 1.7721
# Epoch 247, 100.0%, avg_loss = 1.8542
# Epoch 248, 100.0%, avg_loss = 1.7347
# Epoch 249, 100.0%, avg_loss = 1.7206
# Epoch 250, 100.0%, avg_loss = 1.8849
# Validation Loss: 1.7958
# Epoch 251, 100.0%, avg_loss = 1.7771
# Epoch 252, 100.0%, avg_loss = 1.7835
# Epoch 253, 100.0%, avg_loss = 1.7701
# Epoch 254, 100.0%, avg_loss = 1.8395
# Epoch 255, 100.0%, avg_loss = 1.8155
# Validation Loss: 1.8379
# Epoch 256, 100.0%, avg_loss = 1.8368
# Epoch 257, 100.0%, avg_loss = 1.8938
# Epoch 258, 100.0%, avg_loss = 1.7932
# Epoch 259, 100.0%, avg_loss = 1.7390
# Epoch 260, 100.0%, avg_loss = 1.9146
# Validation Loss: 1.7988
# Epoch 261, 100.0%, avg_loss = 1.7819
# Epoch 262, 100.0%, avg_loss = 1.8102
# Epoch 263, 100.0%, avg_loss = 1.8098
# Epoch 264, 100.0%, avg_loss = 1.7485
# Epoch 265, 100.0%, avg_loss = 1.7946
# Validation Loss: 1.7768
# Epoch 266, 100.0%, avg_loss = 1.7681
# Epoch 267, 100.0%, avg_loss = 1.8309
# Epoch 268, 100.0%, avg_loss = 1.8235
# Epoch 269, 100.0%, avg_loss = 1.8135
# Epoch 270, 100.0%, avg_loss = 1.7511
# Validation Loss: 1.7574
# Epoch 271, 100.0%, avg_loss = 1.7651
# Epoch 272, 100.0%, avg_loss = 1.8267
# Epoch 273, 100.0%, avg_loss = 1.7614
# Epoch 274, 100.0%, avg_loss = 1.7784
# Epoch 275, 100.0%, avg_loss = 1.7935
# Validation Loss: 1.7992
# Epoch 276, 100.0%, avg_loss = 1.7320
# Epoch 277, 100.0%, avg_loss = 1.7777
# Epoch 278, 100.0%, avg_loss = 1.7940
# Epoch 279, 100.0%, avg_loss = 1.7434
# Epoch 280, 100.0%, avg_loss = 1.8183
# Validation Loss: 1.7941
# Epoch 281, 100.0%, avg_loss = 1.8202
# Epoch 282, 100.0%, avg_loss = 1.7452
# Epoch 283, 100.0%, avg_loss = 1.8932
# Epoch 284, 100.0%, avg_loss = 1.7976
# Epoch 285, 100.0%, avg_loss = 1.8305
# Validation Loss: 1.8124
# Epoch 286, 100.0%, avg_loss = 1.8031
# Epoch 287, 100.0%, avg_loss = 1.7363
# Epoch 288, 100.0%, avg_loss = 1.8143
# Epoch 289, 100.0%, avg_loss = 1.7616
# Epoch 290, 100.0%, avg_loss = 1.7995
# Validation Loss: 1.7928
# Epoch 291, 100.0%, avg_loss = 1.7441
# Epoch 292, 100.0%, avg_loss = 1.8203
# Epoch 293, 100.0%, avg_loss = 1.8341
# Epoch 294, 100.0%, avg_loss = 1.7394
# Epoch 295, 100.0%, avg_loss = 1.7606
# Validation Loss: 1.7951
# Epoch 296, 100.0%, avg_loss = 1.7807
# Epoch 297, 100.0%, avg_loss = 1.7570
# Epoch 298, 100.0%, avg_loss = 1.8531
# Epoch 299, 100.0%, avg_loss = 1.8080
# Epoch 300, 100.0%, avg_loss = 1.7673
# Validation Loss: 1.7510
# Epoch 301, 100.0%, avg_loss = 1.8244
# Epoch 302, 100.0%, avg_loss = 1.6743
# Epoch 303, 100.0%, avg_loss = 1.7677
# Epoch 304, 100.0%, avg_loss = 1.7948
# Epoch 305, 100.0%, avg_loss = 1.7195
# Validation Loss: 1.8190
# Epoch 306, 100.0%, avg_loss = 1.7055
# Epoch 307, 100.0%, avg_loss = 1.7561
# Epoch 308, 100.0%, avg_loss = 1.7582
# Epoch 309, 100.0%, avg_loss = 1.7676
# Epoch 310, 100.0%, avg_loss = 1.7638
# Validation Loss: 1.8108
# Epoch 311, 100.0%, avg_loss = 1.7054
# Epoch 312, 100.0%, avg_loss = 1.8115
# Epoch 313, 100.0%, avg_loss = 1.7947
# Epoch 314, 100.0%, avg_loss = 1.7647
# Epoch 315, 100.0%, avg_loss = 1.7321
# Validation Loss: 1.7581
# Epoch 316, 100.0%, avg_loss = 1.7189
# Epoch 317, 100.0%, avg_loss = 1.8877
# Epoch 318, 100.0%, avg_loss = 1.6774
# Epoch 319, 100.0%, avg_loss = 1.7985
# Epoch 320, 100.0%, avg_loss = 1.7941
# Validation Loss: 1.7691
# Epoch 321, 100.0%, avg_loss = 1.6760
# Epoch 322, 100.0%, avg_loss = 1.7376
# Epoch 323, 100.0%, avg_loss = 1.7537
# Epoch 324, 100.0%, avg_loss = 1.7287
# Epoch 325, 100.0%, avg_loss = 1.7135
# Validation Loss: 1.7387
# Epoch 326, 100.0%, avg_loss = 1.7385
# Epoch 327, 100.0%, avg_loss = 1.8104
# Epoch 328, 100.0%, avg_loss = 1.6355
# Epoch 329, 100.0%, avg_loss = 1.7657
# Epoch 330, 100.0%, avg_loss = 1.7290
# Validation Loss: 1.7462
# Epoch 331, 100.0%, avg_loss = 1.6818
# Epoch 332, 100.0%, avg_loss = 1.6775
# Epoch 333, 100.0%, avg_loss = 1.8043
# Epoch 334, 100.0%, avg_loss = 1.8124
# Epoch 335, 100.0%, avg_loss = 1.7344
# Validation Loss: 1.7640
# Epoch 336, 100.0%, avg_loss = 1.8068
# Epoch 337, 100.0%, avg_loss = 1.7335
# Epoch 338, 100.0%, avg_loss = 1.7402
# Epoch 339, 100.0%, avg_loss = 1.7567
# Epoch 340, 100.0%, avg_loss = 1.7148
# Validation Loss: 1.7371
# Epoch 341, 100.0%, avg_loss = 1.7252
# Epoch 342, 100.0%, avg_loss = 1.7111
# Epoch 343, 100.0%, avg_loss = 1.7145
# Epoch 344, 100.0%, avg_loss = 1.7969
# Epoch 345, 100.0%, avg_loss = 1.7366
# Validation Loss: 1.7542
# Epoch 346, 100.0%, avg_loss = 1.7992
# Epoch 347, 100.0%, avg_loss = 1.7320
# Epoch 348, 100.0%, avg_loss = 1.7199
# Epoch 349, 100.0%, avg_loss = 1.7923
# Epoch 350, 100.0%, avg_loss = 1.6730
# Validation Loss: 1.7498
# Epoch 351, 100.0%, avg_loss = 1.7448
# Epoch 352, 100.0%, avg_loss = 1.7789
# Epoch 353, 100.0%, avg_loss = 1.7544
# Epoch 354, 100.0%, avg_loss = 1.7938
# Epoch 355, 100.0%, avg_loss = 1.8350
# Validation Loss: 1.8040
# Epoch 356, 100.0%, avg_loss = 1.7672
# Epoch 357, 100.0%, avg_loss = 1.7323
# Epoch 358, 100.0%, avg_loss = 1.7395
# Epoch 359, 100.0%, avg_loss = 1.7366
# Epoch 360, 100.0%, avg_loss = 1.7429
# Validation Loss: 1.7578
# Epoch 361, 100.0%, avg_loss = 1.6653
# Epoch 362, 100.0%, avg_loss = 1.6633
# Epoch 363, 100.0%, avg_loss = 1.7671
# Epoch 364, 100.0%, avg_loss = 1.7417
# Epoch 365, 100.0%, avg_loss = 1.6796
# Validation Loss: 1.8023
# Epoch 366, 100.0%, avg_loss = 1.7800
# Epoch 367, 100.0%, avg_loss = 1.7588
# Epoch 368, 100.0%, avg_loss = 1.7768
# Epoch 369, 100.0%, avg_loss = 1.7158
# Epoch 370, 100.0%, avg_loss = 1.7299
# Validation Loss: 1.7326
# Epoch 371, 100.0%, avg_loss = 1.7754
# Epoch 372, 100.0%, avg_loss = 1.7281
# Epoch 373, 100.0%, avg_loss = 1.6768
# Epoch 374, 100.0%, avg_loss = 1.7728
# Epoch 375, 100.0%, avg_loss = 1.7609
# Validation Loss: 1.7406
# Epoch 376, 100.0%, avg_loss = 1.7652
# Epoch 377, 100.0%, avg_loss = 1.7874
# Epoch 378, 100.0%, avg_loss = 1.7688
# Epoch 379, 100.0%, avg_loss = 1.7418
# Epoch 380, 100.0%, avg_loss = 1.8010
# Validation Loss: 1.7546
# Epoch 381, 100.0%, avg_loss = 1.8050
# Epoch 382, 100.0%, avg_loss = 1.7372
# Epoch 383, 100.0%, avg_loss = 1.6746
# Epoch 384, 100.0%, avg_loss = 1.7280
# Epoch 385, 100.0%, avg_loss = 1.8091
# Validation Loss: 1.7521
# Epoch 386, 100.0%, avg_loss = 1.7007
# Epoch 387, 100.0%, avg_loss = 1.7105
# Epoch 388, 100.0%, avg_loss = 1.6745
# Epoch 389, 100.0%, avg_loss = 1.6698
# Epoch 390, 100.0%, avg_loss = 1.8006
# Validation Loss: 1.7816
# Epoch 391, 100.0%, avg_loss = 1.6974
# Epoch 392, 100.0%, avg_loss = 1.7470
# Epoch 393, 100.0%, avg_loss = 1.6751
# Epoch 394, 100.0%, avg_loss = 1.7850
# Epoch 395, 100.0%, avg_loss = 1.7724
# Validation Loss: 1.7583
# Epoch 396, 100.0%, avg_loss = 1.7392
# Epoch 397, 100.0%, avg_loss = 1.7399
# Epoch 398, 100.0%, avg_loss = 1.7238
# Epoch 399, 100.0%, avg_loss = 1.6896
# Epoch 400, 100.0%, avg_loss = 1.8216
# Validation Loss: 1.7579
# Epoch 401, 100.0%, avg_loss = 1.8548
# Epoch 402, 100.0%, avg_loss = 1.7383
# Epoch 403, 100.0%, avg_loss = 1.7208
# Epoch 404, 100.0%, avg_loss = 1.7308
# Epoch 405, 100.0%, avg_loss = 1.7438
# Validation Loss: 1.8287
# Epoch 406, 100.0%, avg_loss = 1.7026
# Epoch 407, 100.0%, avg_loss = 1.7673
# Epoch 408, 100.0%, avg_loss = 1.7610
# Epoch 409, 100.0%, avg_loss = 1.6938
# Epoch 410, 100.0%, avg_loss = 1.7889
# Validation Loss: 1.7189
# Epoch 411, 100.0%, avg_loss = 1.7921
# Epoch 412, 100.0%, avg_loss = 1.7654
# Epoch 413, 100.0%, avg_loss = 1.7461
# Epoch 414, 100.0%, avg_loss = 1.7293
# Epoch 415, 100.0%, avg_loss = 1.7399
# Validation Loss: 1.7577
# Epoch 416, 100.0%, avg_loss = 1.7353
# Epoch 417, 100.0%, avg_loss = 1.8305
# Epoch 418, 100.0%, avg_loss = 1.8291
# Epoch 419, 100.0%, avg_loss = 1.8187
# Epoch 420, 100.0%, avg_loss = 1.7594
# Validation Loss: 1.7204
# Epoch 421, 100.0%, avg_loss = 1.7099
# Epoch 422, 100.0%, avg_loss = 1.8330
# Epoch 423, 100.0%, avg_loss = 1.7358
# Epoch 424, 100.0%, avg_loss = 1.7455
# Epoch 425, 100.0%, avg_loss = 1.7376
# Validation Loss: 1.8206
# Epoch 426, 100.0%, avg_loss = 1.7940
# Epoch 427, 100.0%, avg_loss = 1.7988
# Epoch 428, 100.0%, avg_loss = 1.8780
# Epoch 429, 100.0%, avg_loss = 1.6999
# Epoch 430, 100.0%, avg_loss = 1.7399
# Validation Loss: 1.7615
# Epoch 431, 100.0%, avg_loss = 1.7063
# Epoch 432, 100.0%, avg_loss = 1.7719
# Epoch 433, 100.0%, avg_loss = 1.7440
# Epoch 434, 100.0%, avg_loss = 1.7960
# Epoch 435, 100.0%, avg_loss = 1.7210
# Validation Loss: 1.7197
# Epoch 436, 100.0%, avg_loss = 1.7795
# Epoch 437, 100.0%, avg_loss = 1.6354
# Epoch 438, 100.0%, avg_loss = 1.7284
# Epoch 439, 100.0%, avg_loss = 1.6619
# Epoch 440, 100.0%, avg_loss = 1.7401
# Validation Loss: 1.7531
# Epoch 441, 100.0%, avg_loss = 1.7424
# Epoch 442, 100.0%, avg_loss = 1.7309
# Epoch 443, 100.0%, avg_loss = 1.6848
# Epoch 444, 100.0%, avg_loss = 1.7421
# Epoch 445, 100.0%, avg_loss = 1.6881
# Validation Loss: 1.7305
# Epoch 446, 100.0%, avg_loss = 1.6818
# Epoch 447, 100.0%, avg_loss = 1.7436
# Epoch 448, 100.0%, avg_loss = 1.7319
# Epoch 449, 100.0%, avg_loss = 1.8004
# Epoch 450, 100.0%, avg_loss = 1.7102
# Validation Loss: 1.7646
# Epoch 451, 100.0%, avg_loss = 1.7752
# Epoch 452, 100.0%, avg_loss = 1.7996
# Epoch 453, 100.0%, avg_loss = 1.6819
# Epoch 454, 100.0%, avg_loss = 1.7596
# Epoch 455, 100.0%, avg_loss = 1.7438
# Validation Loss: 1.7372
# Epoch 456, 100.0%, avg_loss = 1.7872
# Epoch 457, 100.0%, avg_loss = 1.7949
# Epoch 458, 100.0%, avg_loss = 1.7188
# Epoch 459, 100.0%, avg_loss = 1.7096
# Epoch 460, 100.0%, avg_loss = 1.6922
# Validation Loss: 1.7531
# Epoch 461, 100.0%, avg_loss = 1.6324
# Epoch 462, 100.0%, avg_loss = 1.6504
# Epoch 463, 100.0%, avg_loss = 1.7736
# Epoch 464, 100.0%, avg_loss = 1.7047
# Epoch 465, 100.0%, avg_loss = 1.7661
# Validation Loss: 1.7649
# Epoch 466, 100.0%, avg_loss = 1.7707
# Epoch 467, 100.0%, avg_loss = 1.6760
# Epoch 468, 100.0%, avg_loss = 1.7621
# Epoch 469, 100.0%, avg_loss = 1.7299
# Epoch 470, 100.0%, avg_loss = 1.7504
# Validation Loss: 1.7652
# Epoch 471, 100.0%, avg_loss = 1.7318
# Epoch 472, 100.0%, avg_loss = 1.8224
# Epoch 473, 100.0%, avg_loss = 1.7239
# Epoch 474, 100.0%, avg_loss = 1.6660
# Epoch 475, 100.0%, avg_loss = 1.7152
# Validation Loss: 1.7038
# Epoch 476, 100.0%, avg_loss = 1.7403
# Epoch 477, 100.0%, avg_loss = 1.7357
# Epoch 478, 100.0%, avg_loss = 1.7487
# Epoch 479, 100.0%, avg_loss = 1.7250
# Epoch 480, 100.0%, avg_loss = 1.7588
# Validation Loss: 1.8114
# Epoch 481, 100.0%, avg_loss = 1.7503
# Epoch 482, 100.0%, avg_loss = 1.6657
# Epoch 483, 100.0%, avg_loss = 1.7900
# Epoch 484, 100.0%, avg_loss = 1.7173
# Epoch 485, 100.0%, avg_loss = 1.7667
# Validation Loss: 1.7593
# Epoch 486, 100.0%, avg_loss = 1.7177
# Epoch 487, 100.0%, avg_loss = 1.6713
# Epoch 488, 100.0%, avg_loss = 1.6449
# Epoch 489, 100.0%, avg_loss = 1.6552
# Epoch 490, 100.0%, avg_loss = 1.6882
# Validation Loss: 1.7882
# Epoch 491, 100.0%, avg_loss = 1.7010
# Epoch 492, 100.0%, avg_loss = 1.8553
# Epoch 493, 100.0%, avg_loss = 1.7360
# Epoch 494, 100.0%, avg_loss = 1.7747
# Epoch 495, 100.0%, avg_loss = 1.7893
# Validation Loss: 1.7795
# Epoch 496, 100.0%, avg_loss = 1.7590
# Epoch 497, 100.0%, avg_loss = 1.6821
# Epoch 498, 100.0%, avg_loss = 1.7393
# Epoch 499, 100.0%, avg_loss = 1.7063
# Epoch 500, 100.0%, avg_loss = 1.6720
# Validation Loss: 1.7451
# Epoch 501, 100.0%, avg_loss = 1.8235
# Epoch 502, 100.0%, avg_loss = 1.8593
# Epoch 503, 100.0%, avg_loss = 1.7193
# Epoch 504, 100.0%, avg_loss = 1.7304
# Epoch 505, 100.0%, avg_loss = 1.6985
# Validation Loss: 1.6902
# Epoch 506, 100.0%, avg_loss = 1.6998
# Epoch 507, 100.0%, avg_loss = 1.7192
# Epoch 508, 100.0%, avg_loss = 1.7270
# Epoch 509, 100.0%, avg_loss = 1.6758
# Epoch 510, 100.0%, avg_loss = 1.7734
# Validation Loss: 1.6733
# Epoch 511, 100.0%, avg_loss = 1.7442
# Epoch 512, 100.0%, avg_loss = 1.6739
# Epoch 513, 100.0%, avg_loss = 1.6160
# Epoch 514, 100.0%, avg_loss = 1.6617
# Epoch 515, 100.0%, avg_loss = 1.6131
# Validation Loss: 1.7157
# Epoch 516, 100.0%, avg_loss = 1.6717
# Epoch 517, 100.0%, avg_loss = 1.6520
# Epoch 518, 100.0%, avg_loss = 1.6722
# Epoch 519, 100.0%, avg_loss = 1.6897
# Epoch 520, 100.0%, avg_loss = 1.6498
# Validation Loss: 1.7053
# Epoch 521, 100.0%, avg_loss = 1.6819
# Epoch 522, 100.0%, avg_loss = 1.6157
# Epoch 523, 100.0%, avg_loss = 1.6785
# Epoch 524, 100.0%, avg_loss = 1.6592
# Epoch 525, 100.0%, avg_loss = 1.6329
# Validation Loss: 1.7160
# Epoch 526, 100.0%, avg_loss = 1.7042
# Epoch 527, 100.0%, avg_loss = 1.7728
# Epoch 528, 100.0%, avg_loss = 1.6761
# Epoch 529, 100.0%, avg_loss = 1.6317
# Epoch 530, 100.0%, avg_loss = 1.6058
# Validation Loss: 1.6034
# Epoch 531, 100.0%, avg_loss = 1.6224
# Epoch 532, 100.0%, avg_loss = 1.6159
# Epoch 533, 100.0%, avg_loss = 1.6550
# Epoch 534, 100.0%, avg_loss = 1.6122
# Epoch 535, 100.0%, avg_loss = 1.6509
# Validation Loss: 1.6629
# Epoch 536, 100.0%, avg_loss = 1.6873
# Epoch 537, 100.0%, avg_loss = 1.6839
# Epoch 538, 100.0%, avg_loss = 1.5835
# Epoch 539, 100.0%, avg_loss = 1.6959
# Epoch 540, 100.0%, avg_loss = 1.6738
# Validation Loss: 1.6698
# Epoch 541, 100.0%, avg_loss = 1.6821
# Epoch 542, 100.0%, avg_loss = 1.6494
# Epoch 543, 100.0%, avg_loss = 1.6435
# Epoch 544, 100.0%, avg_loss = 1.6698
# Epoch 545, 100.0%, avg_loss = 1.6563
# Validation Loss: 1.6656
# Epoch 546, 100.0%, avg_loss = 1.6479
# Epoch 547, 100.0%, avg_loss = 1.6913
# Epoch 548, 100.0%, avg_loss = 1.6319
# Epoch 549, 100.0%, avg_loss = 1.7206
# Epoch 550, 100.0%, avg_loss = 1.6547
# Validation Loss: 1.6604
# Epoch 551, 100.0%, avg_loss = 1.6687
# Epoch 552, 100.0%, avg_loss = 1.6771
# Epoch 553, 100.0%, avg_loss = 1.6956
# Epoch 554, 100.0%, avg_loss = 1.6162
# Epoch 555, 100.0%, avg_loss = 1.6610
# Validation Loss: 1.6755
# Epoch 556, 100.0%, avg_loss = 1.6020
# Epoch 557, 100.0%, avg_loss = 1.6104
# Epoch 558, 100.0%, avg_loss = 1.6067
# Epoch 559, 100.0%, avg_loss = 1.6334
# Epoch 560, 100.0%, avg_loss = 1.6722
# Validation Loss: 1.6770
# Epoch 561, 100.0%, avg_loss = 1.6339
# Epoch 562, 100.0%, avg_loss = 1.5756
# Epoch 563, 100.0%, avg_loss = 1.5937
# Epoch 564, 100.0%, avg_loss = 1.6666
# Epoch 565, 100.0%, avg_loss = 1.7602
# Validation Loss: 1.6595
# Epoch 566, 100.0%, avg_loss = 1.6842
# Epoch 567, 100.0%, avg_loss = 1.6410
# Epoch 568, 100.0%, avg_loss = 1.5834
# Epoch 569, 100.0%, avg_loss = 1.6650
# Epoch 570, 100.0%, avg_loss = 1.5670
# Validation Loss: 1.6458
# Epoch 571, 100.0%, avg_loss = 1.6175
# Epoch 572, 100.0%, avg_loss = 1.5892
# Epoch 573, 100.0%, avg_loss = 1.6417
# Epoch 574, 100.0%, avg_loss = 1.6816
# Epoch 575, 100.0%, avg_loss = 1.6765
# Validation Loss: 1.6513
# Epoch 576, 100.0%, avg_loss = 1.7162
# Epoch 577, 100.0%, avg_loss = 1.6464
# Epoch 578, 100.0%, avg_loss = 1.5352
# Epoch 579, 100.0%, avg_loss = 1.6635
# Epoch 580, 100.0%, avg_loss = 1.6299
# Validation Loss: 1.6350
# Epoch 581, 100.0%, avg_loss = 1.6487
# Epoch 582, 100.0%, avg_loss = 1.5778
# Epoch 583, 100.0%, avg_loss = 1.6554
# Epoch 584, 100.0%, avg_loss = 1.5514
# Epoch 585, 100.0%, avg_loss = 1.6156
# Validation Loss: 1.6290
# Epoch 586, 100.0%, avg_loss = 1.5953
# Epoch 587, 100.0%, avg_loss = 1.5414
# Epoch 588, 100.0%, avg_loss = 1.6053
# Epoch 589, 100.0%, avg_loss = 1.6086
# Epoch 590, 100.0%, avg_loss = 1.7136
# Validation Loss: 1.6250
# Epoch 591, 100.0%, avg_loss = 1.6308
# Epoch 592, 100.0%, avg_loss = 1.6644
# Epoch 593, 100.0%, avg_loss = 1.6521
# Epoch 594, 100.0%, avg_loss = 1.5943
# Epoch 595, 100.0%, avg_loss = 1.6481
# Validation Loss: 1.6353
# Epoch 596, 100.0%, avg_loss = 1.6854
# Epoch 597, 100.0%, avg_loss = 1.6387
# Epoch 598, 100.0%, avg_loss = 1.6251
# Epoch 599, 100.0%, avg_loss = 1.6798
# Epoch 600, 100.0%, avg_loss = 1.6114
# Validation Loss: 1.6804
# Epoch 601, 100.0%, avg_loss = 1.5494
# Epoch 602, 100.0%, avg_loss = 1.6795
# Epoch 603, 100.0%, avg_loss = 1.6820
# Epoch 604, 100.0%, avg_loss = 1.6893
# Epoch 605, 100.0%, avg_loss = 1.6840
# Validation Loss: 1.6250
# Epoch 606, 100.0%, avg_loss = 1.6258
# Epoch 607, 100.0%, avg_loss = 1.6409
# Epoch 608, 100.0%, avg_loss = 1.5855
# Epoch 609, 100.0%, avg_loss = 1.7391
# Epoch 610, 100.0%, avg_loss = 1.6698
# Validation Loss: 1.6130
# Epoch 611, 100.0%, avg_loss = 1.6557
# Epoch 612, 100.0%, avg_loss = 1.5881
# Epoch 613, 100.0%, avg_loss = 1.6084
# Epoch 614, 100.0%, avg_loss = 1.6956
# Epoch 615, 100.0%, avg_loss = 1.6422
# Validation Loss: 1.6437
# Epoch 616, 100.0%, avg_loss = 1.6234
# Epoch 617, 100.0%, avg_loss = 1.6304
# Epoch 618, 100.0%, avg_loss = 1.6903
# Epoch 619, 100.0%, avg_loss = 1.6622
# Epoch 620, 100.0%, avg_loss = 1.6063
# Validation Loss: 1.6793
# Epoch 621, 100.0%, avg_loss = 1.6428
# Epoch 622, 100.0%, avg_loss = 1.6784
# Epoch 623, 100.0%, avg_loss = 1.6042
# Epoch 624, 100.0%, avg_loss = 1.5864
# Epoch 625, 100.0%, avg_loss = 1.6584
# Validation Loss: 1.6680
# Epoch 626, 100.0%, avg_loss = 1.6227
# Epoch 627, 100.0%, avg_loss = 1.5989
# Epoch 628, 100.0%, avg_loss = 1.5440
# Epoch 629, 100.0%, avg_loss = 1.7706
# Epoch 630, 100.0%, avg_loss = 1.5750
# Validation Loss: 1.6531
# Epoch 631, 100.0%, avg_loss = 1.6541
# Epoch 632, 100.0%, avg_loss = 1.6120
# Epoch 633, 100.0%, avg_loss = 1.5808
# Epoch 634, 100.0%, avg_loss = 1.5794
# Epoch 635, 100.0%, avg_loss = 1.5703
# Validation Loss: 1.6468
# Epoch 636, 100.0%, avg_loss = 1.5912
# Epoch 637, 100.0%, avg_loss = 1.6038
# Epoch 638, 100.0%, avg_loss = 1.5947
# Epoch 639, 100.0%, avg_loss = 1.6330
# Epoch 640, 100.0%, avg_loss = 1.7192
# Validation Loss: 1.6515
# Epoch 641, 100.0%, avg_loss = 1.5830
# Epoch 642, 100.0%, avg_loss = 1.6808
# Epoch 643, 100.0%, avg_loss = 1.6725
# Epoch 644, 100.0%, avg_loss = 1.6381
# Epoch 645, 100.0%, avg_loss = 1.6536
# Validation Loss: 1.6430
# Epoch 646, 100.0%, avg_loss = 1.7189
# Epoch 647, 100.0%, avg_loss = 1.6743
# Epoch 648, 100.0%, avg_loss = 1.6565
# Epoch 649, 100.0%, avg_loss = 1.7025
# Epoch 650, 100.0%, avg_loss = 1.6202
# Validation Loss: 1.6812
# Epoch 651, 100.0%, avg_loss = 1.7043
# Epoch 652, 100.0%, avg_loss = 1.6799
# Epoch 653, 100.0%, avg_loss = 1.6062
# Epoch 654, 100.0%, avg_loss = 1.5856
# Epoch 655, 100.0%, avg_loss = 1.6942
# Validation Loss: 1.6373
# Epoch 656, 100.0%, avg_loss = 1.5885
# Epoch 657, 100.0%, avg_loss = 1.6039
# Epoch 658, 100.0%, avg_loss = 1.7063
# Epoch 659, 100.0%, avg_loss = 1.5831
# Epoch 660, 100.0%, avg_loss = 1.5756
# Validation Loss: 1.6588
# Epoch 661, 100.0%, avg_loss = 1.5902
# Epoch 662, 100.0%, avg_loss = 1.6472
# Epoch 663, 100.0%, avg_loss = 1.5978
# Epoch 664, 100.0%, avg_loss = 1.6551
# Epoch 665, 100.0%, avg_loss = 1.7302
# Validation Loss: 1.6415
# Epoch 666, 100.0%, avg_loss = 1.7008
# Epoch 667, 100.0%, avg_loss = 1.5972
# Epoch 668, 100.0%, avg_loss = 1.6828
# Epoch 669, 100.0%, avg_loss = 1.6442
# Epoch 670, 100.0%, avg_loss = 1.6368
# Validation Loss: 1.6351
# Epoch 671, 100.0%, avg_loss = 1.5742
# Epoch 672, 100.0%, avg_loss = 1.6571
# Epoch 673, 100.0%, avg_loss = 1.5706
# Epoch 674, 100.0%, avg_loss = 1.5522
# Epoch 675, 100.0%, avg_loss = 1.6541
# Validation Loss: 1.6257
# Epoch 676, 100.0%, avg_loss = 1.6449
# Epoch 677, 100.0%, avg_loss = 1.6067
# Epoch 678, 100.0%, avg_loss = 1.5665
# Epoch 679, 100.0%, avg_loss = 1.6447
# Epoch 680, 100.0%, avg_loss = 1.6511
# Validation Loss: 1.6275
# Epoch 681, 100.0%, avg_loss = 1.6153
# Epoch 682, 100.0%, avg_loss = 1.6078
# Epoch 683, 100.0%, avg_loss = 1.6211
# Epoch 684, 100.0%, avg_loss = 1.6347
# Epoch 685, 100.0%, avg_loss = 1.5876
# Validation Loss: 1.6356
# Epoch 686, 100.0%, avg_loss = 1.5904
# Epoch 687, 100.0%, avg_loss = 1.6831
# Epoch 688, 100.0%, avg_loss = 1.6584
# Epoch 689, 100.0%, avg_loss = 1.6197
# Epoch 690, 100.0%, avg_loss = 1.5371
# Validation Loss: 1.6785
# Epoch 691, 100.0%, avg_loss = 1.5869
# Epoch 692, 100.0%, avg_loss = 1.5858
# Epoch 693, 100.0%, avg_loss = 1.7266
# Epoch 694, 100.0%, avg_loss = 1.5808
# Epoch 695, 100.0%, avg_loss = 1.5412
# Validation Loss: 1.6492
# Epoch 696, 100.0%, avg_loss = 1.5795
# Epoch 697, 100.0%, avg_loss = 1.6169
# Epoch 698, 100.0%, avg_loss = 1.6472
# Epoch 699, 100.0%, avg_loss = 1.5830
# Epoch 700, 100.0%, avg_loss = 1.6060
# Validation Loss: 1.6691
# Epoch 701, 100.0%, avg_loss = 1.6772
# Epoch 702, 100.0%, avg_loss = 1.5701
# Epoch 703, 100.0%, avg_loss = 1.5438
# Epoch 704, 100.0%, avg_loss = 1.5361
# Epoch 705, 100.0%, avg_loss = 1.6161
# Validation Loss: 1.6345
# Epoch 706, 100.0%, avg_loss = 1.6276
# Epoch 707, 100.0%, avg_loss = 1.6234
# Epoch 708, 100.0%, avg_loss = 1.6467
# Epoch 709, 100.0%, avg_loss = 1.6112
# Epoch 710, 100.0%, avg_loss = 1.5308
# Validation Loss: 1.6570
# Epoch 711, 100.0%, avg_loss = 1.6078
# Epoch 712, 100.0%, avg_loss = 1.6483
# Epoch 713, 100.0%, avg_loss = 1.6132
# Epoch 714, 100.0%, avg_loss = 1.5908
# Epoch 715, 100.0%, avg_loss = 1.6676
# Validation Loss: 1.6199
# Epoch 716, 100.0%, avg_loss = 1.6333
# Epoch 717, 100.0%, avg_loss = 1.6750
# Epoch 718, 100.0%, avg_loss = 1.7032
# Epoch 719, 100.0%, avg_loss = 1.5878
# Epoch 720, 100.0%, avg_loss = 1.5932
# Validation Loss: 1.6483
# Epoch 721, 100.0%, avg_loss = 1.6897
# Epoch 722, 100.0%, avg_loss = 1.5976
# Epoch 723, 100.0%, avg_loss = 1.5768
# Epoch 724, 100.0%, avg_loss = 1.5766
# Epoch 725, 100.0%, avg_loss = 1.6632
# Validation Loss: 1.6361
# Epoch 726, 100.0%, avg_loss = 1.6376
# Epoch 727, 100.0%, avg_loss = 1.6699
# Epoch 728, 100.0%, avg_loss = 1.5988
# Epoch 729, 100.0%, avg_loss = 1.6895
# Epoch 730, 100.0%, avg_loss = 1.6233
# Validation Loss: 1.6774
# Epoch 731, 100.0%, avg_loss = 1.6255
# Epoch 732, 100.0%, avg_loss = 1.5488
# Epoch 733, 100.0%, avg_loss = 1.6223
# Epoch 734, 100.0%, avg_loss = 1.5703
# Epoch 735, 100.0%, avg_loss = 1.6814
# Validation Loss: 1.6180
# Epoch 736, 100.0%, avg_loss = 1.6291
# Epoch 737, 100.0%, avg_loss = 1.6086
# Epoch 738, 100.0%, avg_loss = 1.6414
# Epoch 739, 100.0%, avg_loss = 1.6845
# Epoch 740, 100.0%, avg_loss = 1.6256
# Validation Loss: 1.6127
# Epoch 741, 100.0%, avg_loss = 1.6644
# Epoch 742, 100.0%, avg_loss = 1.5703
# Epoch 743, 100.0%, avg_loss = 1.5519
# Epoch 744, 100.0%, avg_loss = 1.6050
# Epoch 745, 100.0%, avg_loss = 1.5534
# Validation Loss: 1.6338
# Epoch 746, 100.0%, avg_loss = 1.5592
# Epoch 747, 100.0%, avg_loss = 1.5701
# Epoch 748, 100.0%, avg_loss = 1.6288
# Epoch 749, 100.0%, avg_loss = 1.6435
# Epoch 750, 100.0%, avg_loss = 1.5871
# Validation Loss: 1.6329
# Epoch 751, 100.0%, avg_loss = 1.6008
# Epoch 752, 100.0%, avg_loss = 1.5924
# Epoch 753, 100.0%, avg_loss = 1.5195
# Epoch 754, 100.0%, avg_loss = 1.6751
# Epoch 755, 100.0%, avg_loss = 1.6181
# Validation Loss: 1.6433
# Epoch 756, 100.0%, avg_loss = 1.6890
# Epoch 757, 100.0%, avg_loss = 1.5215
# Epoch 758, 100.0%, avg_loss = 1.5630
# Epoch 759, 100.0%, avg_loss = 1.6417
# Epoch 760, 100.0%, avg_loss = 1.5379
# Validation Loss: 1.5873
# Epoch 761, 100.0%, avg_loss = 1.5788
# Epoch 762, 100.0%, avg_loss = 1.5483
# Epoch 763, 100.0%, avg_loss = 1.6498
# Epoch 764, 100.0%, avg_loss = 1.6230
# Epoch 765, 100.0%, avg_loss = 1.5799
# Validation Loss: 1.6061
# Epoch 766, 100.0%, avg_loss = 1.7324
# Epoch 767, 100.0%, avg_loss = 1.5839
# Epoch 768, 100.0%, avg_loss = 1.5823
# Epoch 769, 100.0%, avg_loss = 1.5807
# Epoch 770, 100.0%, avg_loss = 1.6019
# Validation Loss: 1.6412
# Epoch 771, 100.0%, avg_loss = 1.6434
# Epoch 772, 100.0%, avg_loss = 1.5997
# Epoch 773, 100.0%, avg_loss = 1.5686
# Epoch 774, 100.0%, avg_loss = 1.6333
# Epoch 775, 100.0%, avg_loss = 1.5732
# Validation Loss: 1.6507
# Epoch 776, 100.0%, avg_loss = 1.4828
# Epoch 777, 100.0%, avg_loss = 1.5482
# Epoch 778, 100.0%, avg_loss = 1.5478
# Epoch 779, 100.0%, avg_loss = 1.6372
# Epoch 780, 100.0%, avg_loss = 1.6264
# Validation Loss: 1.6134
# Epoch 781, 100.0%, avg_loss = 1.6724
# Epoch 782, 100.0%, avg_loss = 1.6437
# Epoch 783, 100.0%, avg_loss = 1.5374
# Epoch 784, 100.0%, avg_loss = 1.6408
# Epoch 785, 100.0%, avg_loss = 1.5192
# Validation Loss: 1.6389
# Epoch 786, 100.0%, avg_loss = 1.6490
# Epoch 787, 100.0%, avg_loss = 1.6221
# Epoch 788, 100.0%, avg_loss = 1.6521
# Epoch 789, 100.0%, avg_loss = 1.5819
# Epoch 790, 100.0%, avg_loss = 1.5320
# Validation Loss: 1.5937
# Epoch 791, 100.0%, avg_loss = 1.5966
# Epoch 792, 100.0%, avg_loss = 1.4986
# Epoch 793, 100.0%, avg_loss = 1.6227
# Epoch 794, 100.0%, avg_loss = 1.6686
# Epoch 795, 100.0%, avg_loss = 1.6122
# Validation Loss: 1.5988
# Epoch 796, 100.0%, avg_loss = 1.6338
# Epoch 797, 100.0%, avg_loss = 1.6054
# Epoch 798, 100.0%, avg_loss = 1.5753
# Epoch 799, 100.0%, avg_loss = 1.5119
# Epoch 800, 100.0%, avg_loss = 1.7005
# Validation Loss: 1.5636
# Epoch 801, 100.0%, avg_loss = 1.5358
# Epoch 802, 100.0%, avg_loss = 1.5947
# Epoch 803, 100.0%, avg_loss = 1.6060
# Epoch 804, 100.0%, avg_loss = 1.5805
# Epoch 805, 100.0%, avg_loss = 1.6137
# Validation Loss: 1.6420
# Epoch 806, 100.0%, avg_loss = 1.4885
# Epoch 807, 100.0%, avg_loss = 1.5774
# Epoch 808, 100.0%, avg_loss = 1.5637
# Epoch 809, 100.0%, avg_loss = 1.5724
# Epoch 810, 100.0%, avg_loss = 1.6414
# Validation Loss: 1.6227
# Epoch 811, 100.0%, avg_loss = 1.5822
# Epoch 812, 100.0%, avg_loss = 1.6371
# Epoch 813, 100.0%, avg_loss = 1.5664
# Epoch 814, 100.0%, avg_loss = 1.6423
# Epoch 815, 100.0%, avg_loss = 1.6283
# Validation Loss: 1.6036
# Epoch 816, 100.0%, avg_loss = 1.6174
# Epoch 817, 100.0%, avg_loss = 1.5882
# Epoch 818, 100.0%, avg_loss = 1.5609
# Epoch 819, 100.0%, avg_loss = 1.6237
# Epoch 820, 100.0%, avg_loss = 1.5951
# Validation Loss: 1.6487
# Epoch 821, 100.0%, avg_loss = 1.5389
# Epoch 822, 100.0%, avg_loss = 1.7307
# Epoch 823, 100.0%, avg_loss = 1.5866
# Epoch 824, 100.0%, avg_loss = 1.6115
# Epoch 825, 100.0%, avg_loss = 1.5927
# Validation Loss: 1.5904
# Epoch 826, 100.0%, avg_loss = 1.6034
# Epoch 827, 100.0%, avg_loss = 1.5472
# Epoch 828, 100.0%, avg_loss = 1.5808
# Epoch 829, 100.0%, avg_loss = 1.6079
# Epoch 830, 100.0%, avg_loss = 1.5700
# Validation Loss: 1.6410
# Epoch 831, 100.0%, avg_loss = 1.5395
# Epoch 832, 100.0%, avg_loss = 1.6606
# Epoch 833, 100.0%, avg_loss = 1.6038
# Epoch 834, 100.0%, avg_loss = 1.5852
# Epoch 835, 100.0%, avg_loss = 1.6320
# Validation Loss: 1.5964
# Epoch 836, 100.0%, avg_loss = 1.5898
# Epoch 837, 100.0%, avg_loss = 1.5851
# Epoch 838, 100.0%, avg_loss = 1.5657
# Epoch 839, 100.0%, avg_loss = 1.5512
# Epoch 840, 100.0%, avg_loss = 1.5383
# Validation Loss: 1.6083
# Epoch 841, 100.0%, avg_loss = 1.6418
# Epoch 842, 100.0%, avg_loss = 1.5835
# Epoch 843, 100.0%, avg_loss = 1.6771
# Epoch 844, 100.0%, avg_loss = 1.5419
# Epoch 845, 100.0%, avg_loss = 1.5934
# Validation Loss: 1.6086
# Epoch 846, 100.0%, avg_loss = 1.6590
# Epoch 847, 100.0%, avg_loss = 1.6061
# Epoch 848, 100.0%, avg_loss = 1.6642
# Epoch 849, 100.0%, avg_loss = 1.6318
# Epoch 850, 100.0%, avg_loss = 1.6206
# Validation Loss: 1.6231
# Epoch 851, 100.0%, avg_loss = 1.6078
# Epoch 852, 100.0%, avg_loss = 1.5844
# Epoch 853, 100.0%, avg_loss = 1.5612
# Epoch 854, 100.0%, avg_loss = 1.6051
# Epoch 855, 100.0%, avg_loss = 1.6221
# Validation Loss: 1.5980
# Epoch 856, 100.0%, avg_loss = 1.5350
# Epoch 857, 100.0%, avg_loss = 1.6355
# Epoch 858, 100.0%, avg_loss = 1.5772
# Epoch 859, 100.0%, avg_loss = 1.6099
# Epoch 860, 100.0%, avg_loss = 1.6049
# Validation Loss: 1.6331
# Epoch 861, 100.0%, avg_loss = 1.5670
# Epoch 862, 100.0%, avg_loss = 1.5897
# Epoch 863, 100.0%, avg_loss = 1.5999
# Epoch 864, 100.0%, avg_loss = 1.5136
# Epoch 865, 100.0%, avg_loss = 1.5521
# Validation Loss: 1.6151
# Epoch 866, 100.0%, avg_loss = 1.6244
# Epoch 867, 100.0%, avg_loss = 1.6077
# Epoch 868, 100.0%, avg_loss = 1.6367
# Epoch 869, 100.0%, avg_loss = 1.5624
# Epoch 870, 100.0%, avg_loss = 1.6340
# Validation Loss: 1.6461
# Epoch 871, 100.0%, avg_loss = 1.5346
# Epoch 872, 100.0%, avg_loss = 1.6347
# Epoch 873, 100.0%, avg_loss = 1.5945
# Epoch 874, 100.0%, avg_loss = 1.6105
# Epoch 875, 100.0%, avg_loss = 1.6062
# Validation Loss: 1.6170
# Epoch 876, 100.0%, avg_loss = 1.6458
# Epoch 877, 100.0%, avg_loss = 1.5598
# Epoch 878, 100.0%, avg_loss = 1.6200
# Epoch 879, 100.0%, avg_loss = 1.6370
# Epoch 880, 100.0%, avg_loss = 1.5708
# Validation Loss: 1.6150
# Epoch 881, 100.0%, avg_loss = 1.6132
# Epoch 882, 100.0%, avg_loss = 1.6245
# Epoch 883, 100.0%, avg_loss = 1.6255
# Epoch 884, 100.0%, avg_loss = 1.6228
# Epoch 885, 100.0%, avg_loss = 1.6486
# Validation Loss: 1.6212
# Epoch 886, 100.0%, avg_loss = 1.5975
# Epoch 887, 100.0%, avg_loss = 1.5354
# Epoch 888, 100.0%, avg_loss = 1.6105
# Epoch 889, 100.0%, avg_loss = 1.5989
# Epoch 890, 100.0%, avg_loss = 1.7152
# Validation Loss: 1.5861
# Epoch 891, 100.0%, avg_loss = 1.5971
# Epoch 892, 100.0%, avg_loss = 1.5395
# Epoch 893, 100.0%, avg_loss = 1.5727
# Epoch 894, 100.0%, avg_loss = 1.5673
# Epoch 895, 100.0%, avg_loss = 1.5792
# Validation Loss: 1.6524
# Epoch 896, 100.0%, avg_loss = 1.6423
# Epoch 897, 100.0%, avg_loss = 1.6135
# Epoch 898, 100.0%, avg_loss = 1.4651
# Epoch 899, 100.0%, avg_loss = 1.5064
# Epoch 900, 100.0%, avg_loss = 1.5604
# Validation Loss: 1.6195
# Epoch 901, 100.0%, avg_loss = 1.6883
# Epoch 902, 100.0%, avg_loss = 1.5458
# Epoch 903, 100.0%, avg_loss = 1.5816
# Epoch 904, 100.0%, avg_loss = 1.6068
# Epoch 905, 100.0%, avg_loss = 1.6253
# Validation Loss: 1.5823
# Epoch 906, 100.0%, avg_loss = 1.6006
# Epoch 907, 100.0%, avg_loss = 1.5583
# Epoch 908, 100.0%, avg_loss = 1.6312
# Epoch 909, 100.0%, avg_loss = 1.5528
# Epoch 910, 100.0%, avg_loss = 1.5409
# Validation Loss: 1.5582
# Epoch 911, 100.0%, avg_loss = 1.5929
# Epoch 912, 100.0%, avg_loss = 1.5487
# Epoch 913, 100.0%, avg_loss = 1.6104
# Epoch 914, 100.0%, avg_loss = 1.6054
# Epoch 915, 100.0%, avg_loss = 1.5985
# Validation Loss: 1.5901
# Epoch 916, 100.0%, avg_loss = 1.5512
# Epoch 917, 100.0%, avg_loss = 1.6594
# Epoch 918, 100.0%, avg_loss = 1.6688
# Epoch 919, 100.0%, avg_loss = 1.7031
# Epoch 920, 100.0%, avg_loss = 1.6590
# Validation Loss: 1.6240
# Epoch 921, 100.0%, avg_loss = 1.6500
# Epoch 922, 100.0%, avg_loss = 1.6655
# Epoch 923, 100.0%, avg_loss = 1.5371
# Epoch 924, 100.0%, avg_loss = 1.5069
# Epoch 925, 100.0%, avg_loss = 1.5232
# Validation Loss: 1.6161
# Epoch 926, 100.0%, avg_loss = 1.5686
# Epoch 927, 100.0%, avg_loss = 1.5428
# Epoch 928, 100.0%, avg_loss = 1.5998
# Epoch 929, 100.0%, avg_loss = 1.6527
# Epoch 930, 100.0%, avg_loss = 1.6197
# Validation Loss: 1.6439
# Epoch 931, 100.0%, avg_loss = 1.5884
# Epoch 932, 100.0%, avg_loss = 1.6123
# Epoch 933, 100.0%, avg_loss = 1.6324
# Epoch 934, 100.0%, avg_loss = 1.6704
# Epoch 935, 100.0%, avg_loss = 1.5940
# Validation Loss: 1.6053
# Epoch 936, 100.0%, avg_loss = 1.4983
# Epoch 937, 100.0%, avg_loss = 1.5892
# Epoch 938, 100.0%, avg_loss = 1.5759
# Epoch 939, 100.0%, avg_loss = 1.5946
# Epoch 940, 100.0%, avg_loss = 1.7311
# Validation Loss: 1.5940
# Epoch 941, 100.0%, avg_loss = 1.6219
# Epoch 942, 100.0%, avg_loss = 1.5892
# Epoch 943, 100.0%, avg_loss = 1.6341
# Epoch 944, 100.0%, avg_loss = 1.5717
# Epoch 945, 100.0%, avg_loss = 1.5890
# Validation Loss: 1.6144
# Epoch 946, 100.0%, avg_loss = 1.5320
# Epoch 947, 100.0%, avg_loss = 1.5994
# Epoch 948, 100.0%, avg_loss = 1.5736
# Epoch 949, 100.0%, avg_loss = 1.6066
# Epoch 950, 100.0%, avg_loss = 1.6595
# Validation Loss: 1.6319
# Epoch 951, 100.0%, avg_loss = 1.5465
# Epoch 952, 100.0%, avg_loss = 1.4997
# Epoch 953, 100.0%, avg_loss = 1.5395
# Epoch 954, 100.0%, avg_loss = 1.6843
# Epoch 955, 100.0%, avg_loss = 1.5700
# Validation Loss: 1.6152
# Epoch 956, 100.0%, avg_loss = 1.6744
# Epoch 957, 100.0%, avg_loss = 1.6646
# Epoch 958, 100.0%, avg_loss = 1.6535
# Epoch 959, 100.0%, avg_loss = 1.6273
# Epoch 960, 100.0%, avg_loss = 1.5647
# Validation Loss: 1.5798
# Epoch 961, 100.0%, avg_loss = 1.5968
# Epoch 962, 100.0%, avg_loss = 1.5567
# Epoch 963, 100.0%, avg_loss = 1.6382
# Epoch 964, 100.0%, avg_loss = 1.5389
# Epoch 965, 100.0%, avg_loss = 1.5095
# Validation Loss: 1.5888
# Epoch 966, 100.0%, avg_loss = 1.5319
# Epoch 967, 100.0%, avg_loss = 1.6124
# Epoch 968, 100.0%, avg_loss = 1.5778
# Epoch 969, 100.0%, avg_loss = 1.5574
# Epoch 970, 100.0%, avg_loss = 1.5549
# Validation Loss: 1.6152
# Epoch 971, 100.0%, avg_loss = 1.5666
# Epoch 972, 100.0%, avg_loss = 1.5477
# Epoch 973, 100.0%, avg_loss = 1.5534
# Epoch 974, 100.0%, avg_loss = 1.6173
# Epoch 975, 100.0%, avg_loss = 1.5895
# Validation Loss: 1.5669
# Epoch 976, 100.0%, avg_loss = 1.6168
# Epoch 977, 100.0%, avg_loss = 1.6004
# Epoch 978, 100.0%, avg_loss = 1.5787
# Epoch 979, 100.0%, avg_loss = 1.5547
# Epoch 980, 100.0%, avg_loss = 1.6393
# Validation Loss: 1.5973
# Epoch 981, 100.0%, avg_loss = 1.5518
# Epoch 982, 100.0%, avg_loss = 1.6059
# Epoch 983, 100.0%, avg_loss = 1.5568
# Epoch 984, 100.0%, avg_loss = 1.5692
# Epoch 985, 100.0%, avg_loss = 1.6043
# Validation Loss: 1.5966
# Epoch 986, 100.0%, avg_loss = 1.5783
# Epoch 987, 100.0%, avg_loss = 1.5744
# Epoch 988, 100.0%, avg_loss = 1.5817
# Epoch 989, 100.0%, avg_loss = 1.6466
# Epoch 990, 100.0%, avg_loss = 1.5154
# Validation Loss: 1.5933
# Epoch 991, 100.0%, avg_loss = 1.5126
# Epoch 992, 100.0%, avg_loss = 1.5475
# Epoch 993, 100.0%, avg_loss = 1.5859
# Epoch 994, 100.0%, avg_loss = 1.6360
# Epoch 995, 100.0%, avg_loss = 1.5686
# Validation Loss: 1.5993
# Epoch 996, 100.0%, avg_loss = 1.5661
# Epoch 997, 100.0%, avg_loss = 1.5768
# Epoch 998, 100.0%, avg_loss = 1.5700
# Epoch 999, 100.0%, avg_loss = 1.5968
# Epoch 1000, 100.0%, avg_loss = 1.5378
# Validation Loss: 1.6262
# Epoch 1001, 100.0%, avg_loss = 1.5481
# Epoch 1002, 100.0%, avg_loss = 1.5676
# Epoch 1003, 100.0%, avg_loss = 1.5633
# Epoch 1004, 100.0%, avg_loss = 1.5311
# Epoch 1005, 100.0%, avg_loss = 1.5991
# Validation Loss: 1.6076
# Epoch 1006, 100.0%, avg_loss = 1.5354
# Epoch 1007, 100.0%, avg_loss = 1.6565
# Epoch 1008, 100.0%, avg_loss = 1.5006
# Epoch 1009, 100.0%, avg_loss = 1.6109
# Epoch 1010, 100.0%, avg_loss = 1.5705
# Validation Loss: 1.5593
# Epoch 1011, 100.0%, avg_loss = 1.5824
# Epoch 1012, 100.0%, avg_loss = 1.5394
# Epoch 1013, 100.0%, avg_loss = 1.6034
# Epoch 1014, 100.0%, avg_loss = 1.6114
# Epoch 1015, 100.0%, avg_loss = 1.6172
# Validation Loss: 1.5812
# Epoch 1016, 100.0%, avg_loss = 1.5739
# Epoch 1017, 100.0%, avg_loss = 1.6040
# Epoch 1018, 100.0%, avg_loss = 1.5547
# Epoch 1019, 100.0%, avg_loss = 1.5278
# Epoch 1020, 100.0%, avg_loss = 1.4626
# Validation Loss: 1.6140
# Epoch 1021, 100.0%, avg_loss = 1.5317
# Epoch 1022, 100.0%, avg_loss = 1.6941
# Epoch 1023, 100.0%, avg_loss = 1.6021
# Epoch 1024, 100.0%, avg_loss = 1.5507
# Epoch 1025, 100.0%, avg_loss = 1.5811
# Validation Loss: 1.5657
# Epoch 1026, 100.0%, avg_loss = 1.5444
# Epoch 1027, 100.0%, avg_loss = 1.5780
# Epoch 1028, 100.0%, avg_loss = 1.5418
# Epoch 1029, 100.0%, avg_loss = 1.5886
# Epoch 1030, 100.0%, avg_loss = 1.5772
# Validation Loss: 1.5433
# Epoch 1031, 100.0%, avg_loss = 1.5286
# Epoch 1032, 100.0%, avg_loss = 1.5726
# Epoch 1033, 100.0%, avg_loss = 1.5091
# Epoch 1034, 100.0%, avg_loss = 1.5136
# Epoch 1035, 100.0%, avg_loss = 1.5966
# Validation Loss: 1.6149
# Epoch 1036, 100.0%, avg_loss = 1.5829
# Epoch 1037, 100.0%, avg_loss = 1.5530
# Epoch 1038, 100.0%, avg_loss = 1.6279
# Epoch 1039, 100.0%, avg_loss = 1.6274
# Epoch 1040, 100.0%, avg_loss = 1.5670
# Validation Loss: 1.5774
# Epoch 1041, 100.0%, avg_loss = 1.5523
# Epoch 1042, 100.0%, avg_loss = 1.5625
# Epoch 1043, 100.0%, avg_loss = 1.4878
# Epoch 1044, 100.0%, avg_loss = 1.5192
# Epoch 1045, 100.0%, avg_loss = 1.5585
# Validation Loss: 1.5535
# Epoch 1046, 100.0%, avg_loss = 1.5427
# Epoch 1047, 100.0%, avg_loss = 1.4722
# Epoch 1048, 100.0%, avg_loss = 1.6070
# Epoch 1049, 100.0%, avg_loss = 1.4944
# Epoch 1050, 100.0%, avg_loss = 1.5674
# Validation Loss: 1.6009
# Epoch 1051, 100.0%, avg_loss = 1.5460
# Epoch 1052, 100.0%, avg_loss = 1.5192
# Epoch 1053, 100.0%, avg_loss = 1.5476
# Epoch 1054, 100.0%, avg_loss = 1.4794
# Epoch 1055, 100.0%, avg_loss = 1.4815
# Validation Loss: 1.5812
# Epoch 1056, 100.0%, avg_loss = 1.6075
# Epoch 1057, 100.0%, avg_loss = 1.6199
# Epoch 1058, 100.0%, avg_loss = 1.5871
# Epoch 1059, 100.0%, avg_loss = 1.5968
# Epoch 1060, 100.0%, avg_loss = 1.5141
# Validation Loss: 1.5641
# Epoch 1061, 100.0%, avg_loss = 1.5939
# Epoch 1062, 100.0%, avg_loss = 1.5762
# Epoch 1063, 100.0%, avg_loss = 1.5092
# Epoch 1064, 100.0%, avg_loss = 1.5618
# Epoch 1065, 100.0%, avg_loss = 1.5906
# Validation Loss: 1.6019
# Epoch 1066, 100.0%, avg_loss = 1.5529
# Epoch 1067, 100.0%, avg_loss = 1.4901
# Epoch 1068, 100.0%, avg_loss = 1.5690
# Epoch 1069, 100.0%, avg_loss = 1.5634
# Epoch 1070, 100.0%, avg_loss = 1.5595
# Validation Loss: 1.5868
# Epoch 1071, 100.0%, avg_loss = 1.5554
# Epoch 1072, 100.0%, avg_loss = 1.6058
# Epoch 1073, 100.0%, avg_loss = 1.5260
# Epoch 1074, 100.0%, avg_loss = 1.5502
# Epoch 1075, 100.0%, avg_loss = 1.4690
# Validation Loss: 1.5671
# Epoch 1076, 100.0%, avg_loss = 1.5857
# Epoch 1077, 100.0%, avg_loss = 1.4995
# Epoch 1078, 100.0%, avg_loss = 1.5568
# Epoch 1079, 100.0%, avg_loss = 1.5338
# Epoch 1080, 100.0%, avg_loss = 1.5057
# Validation Loss: 1.5869
# Epoch 1081, 100.0%, avg_loss = 1.5172
# Epoch 1082, 100.0%, avg_loss = 1.5897
# Epoch 1083, 100.0%, avg_loss = 1.4873
# Epoch 1084, 100.0%, avg_loss = 1.5404
# Epoch 1085, 100.0%, avg_loss = 1.5359
# Validation Loss: 1.6281
# Epoch 1086, 100.0%, avg_loss = 1.6132
# Epoch 1087, 100.0%, avg_loss = 1.5046
# Epoch 1088, 100.0%, avg_loss = 1.5838
# Epoch 1089, 100.0%, avg_loss = 1.5150
# Epoch 1090, 100.0%, avg_loss = 1.5405
# Validation Loss: 1.5514
# Epoch 1091, 100.0%, avg_loss = 1.5054
# Epoch 1092, 100.0%, avg_loss = 1.5804
# Epoch 1093, 100.0%, avg_loss = 1.5206
# Epoch 1094, 100.0%, avg_loss = 1.5802
# Epoch 1095, 100.0%, avg_loss = 1.5293
# Validation Loss: 1.5604
# Epoch 1096, 100.0%, avg_loss = 1.6089
# Epoch 1097, 100.0%, avg_loss = 1.6549
# Epoch 1098, 100.0%, avg_loss = 1.5349
# Epoch 1099, 100.0%, avg_loss = 1.5143
# Epoch 1100, 100.0%, avg_loss = 1.5642
# Validation Loss: 1.5524
# Epoch 1101, 100.0%, avg_loss = 1.4922
# Epoch 1102, 100.0%, avg_loss = 1.6022
# Epoch 1103, 100.0%, avg_loss = 1.5473
# Epoch 1104, 100.0%, avg_loss = 1.4811
# Epoch 1105, 100.0%, avg_loss = 1.5227
# Validation Loss: 1.5426
# Epoch 1106, 100.0%, avg_loss = 1.5702
# Epoch 1107, 100.0%, avg_loss = 1.5893
# Epoch 1108, 100.0%, avg_loss = 1.4855
# Epoch 1109, 100.0%, avg_loss = 1.5155
# Epoch 1110, 100.0%, avg_loss = 1.4974
# Validation Loss: 1.5776
# Epoch 1111, 100.0%, avg_loss = 1.5347
# Epoch 1112, 100.0%, avg_loss = 1.5206
# Epoch 1113, 100.0%, avg_loss = 1.6194
# Epoch 1114, 100.0%, avg_loss = 1.5501
# Epoch 1115, 100.0%, avg_loss = 1.5709
# Validation Loss: 1.5293
# Epoch 1116, 100.0%, avg_loss = 1.5116
# Epoch 1117, 100.0%, avg_loss = 1.5381
# Epoch 1118, 100.0%, avg_loss = 1.5506
# Epoch 1119, 100.0%, avg_loss = 1.6344
# Epoch 1120, 100.0%, avg_loss = 1.6263
# Validation Loss: 1.5763
# Epoch 1121, 100.0%, avg_loss = 1.5807
# Epoch 1122, 100.0%, avg_loss = 1.6356
# Epoch 1123, 100.0%, avg_loss = 1.5034
# Epoch 1124, 100.0%, avg_loss = 1.6097
# Epoch 1125, 100.0%, avg_loss = 1.5932
# Validation Loss: 1.5542
# Epoch 1126, 100.0%, avg_loss = 1.5477
# Epoch 1127, 100.0%, avg_loss = 1.5829
# Epoch 1128, 100.0%, avg_loss = 1.5870
# Epoch 1129, 100.0%, avg_loss = 1.5822
# Epoch 1130, 100.0%, avg_loss = 1.5784
# Validation Loss: 1.5907
# Epoch 1131, 100.0%, avg_loss = 1.5721
# Epoch 1132, 100.0%, avg_loss = 1.5954
# Epoch 1133, 100.0%, avg_loss = 1.5503
# Epoch 1134, 100.0%, avg_loss = 1.5373
# Epoch 1135, 100.0%, avg_loss = 1.5408
# Validation Loss: 1.6002
# Epoch 1136, 100.0%, avg_loss = 1.6162
# Epoch 1137, 100.0%, avg_loss = 1.5098
# Epoch 1138, 100.0%, avg_loss = 1.5757
# Epoch 1139, 100.0%, avg_loss = 1.5343
# Epoch 1140, 100.0%, avg_loss = 1.5484
# Validation Loss: 1.5911
# Epoch 1141, 100.0%, avg_loss = 1.6032
# Epoch 1142, 100.0%, avg_loss = 1.5435
# Epoch 1143, 100.0%, avg_loss = 1.5905
# Epoch 1144, 100.0%, avg_loss = 1.4796
# Epoch 1145, 100.0%, avg_loss = 1.5017
# Validation Loss: 1.5442
# Epoch 1146, 100.0%, avg_loss = 1.5383
# Epoch 1147, 100.0%, avg_loss = 1.6107
# ...
# Epoch 3628, 100.0%, avg_loss = 1.5153
# Epoch 3629, 100.0%, avg_loss = 1.3836
# Epoch 3630, 100.0%, avg_loss = 1.3850
# Validation Loss: 1.4569
# Epoch 3631, 100.0%, avg_loss = 1.4612
# Epoch 3632, 100.0%, avg_loss = 1.4401
# Epoch 3633, 100.0%, avg_loss = 1.4070
# Epoch 3634, 100.0%, avg_loss = 1.4010
# Epoch 3635, 100.0%, avg_loss = 1.4616
# Validation Loss: 1.4544
# Epoch 3636, 100.0%, avg_loss = 1.4124
# Epoch 3637, 100.0%, avg_loss = 1.5034
# Epoch 3638, 100.0%, avg_loss = 1.4117
# Epoch 3639, 100.0%, avg_loss = 1.4275
# Epoch 3640, 100.0%, avg_loss = 1.4331
# Validation Loss: 1.4441
# Epoch 3641, 100.0%, avg_loss = 1.4451
# Epoch 3642, 100.0%, avg_loss = 1.4511
# Epoch 3643, 100.0%, avg_loss = 1.4284
# Epoch 3644, 100.0%, avg_loss = 1.4107
# Epoch 3645, 100.0%, avg_loss = 1.4638
# Validation Loss: 1.4235
# Epoch 3646, 100.0%, avg_loss = 1.4596
# Epoch 3647, 100.0%, avg_loss = 1.4672
# Epoch 3648, 100.0%, avg_loss = 1.4622
# Epoch 3649, 100.0%, avg_loss = 1.4867
# Epoch 3650, 100.0%, avg_loss = 1.4801
# Validation Loss: 1.4679
# Epoch 3651, 100.0%, avg_loss = 1.4634
# Epoch 3652, 100.0%, avg_loss = 1.4423
# Epoch 3653, 100.0%, avg_loss = 1.3881
# Epoch 3654, 100.0%, avg_loss = 1.4590
# Epoch 3655, 100.0%, avg_loss = 1.5567
# Validation Loss: 1.5133
# Epoch 3656, 100.0%, avg_loss = 1.4686
# Epoch 3657, 100.0%, avg_loss = 1.5194
# Epoch 3658, 100.0%, avg_loss = 1.4016
# Epoch 3659, 100.0%, avg_loss = 1.4906
# Epoch 3660, 100.0%, avg_loss = 1.4270
# Validation Loss: 1.4823
# Epoch 3661, 100.0%, avg_loss = 1.4255
# Epoch 3662, 100.0%, avg_loss = 1.5004
# Epoch 3663, 100.0%, avg_loss = 1.4183
# Epoch 3664, 100.0%, avg_loss = 1.4277
# Epoch 3665, 100.0%, avg_loss = 1.4699
# Validation Loss: 1.4579
# Epoch 3666, 100.0%, avg_loss = 1.3990
# Epoch 3667, 100.0%, avg_loss = 1.4608
# Epoch 3668, 100.0%, avg_loss = 1.4466
# Epoch 3669, 100.0%, avg_loss = 1.5053
# Epoch 3670, 100.0%, avg_loss = 1.3599
# Validation Loss: 1.4587
# Epoch 3671, 100.0%, avg_loss = 1.4455
# Epoch 3672, 100.0%, avg_loss = 1.4049
# Epoch 3673, 100.0%, avg_loss = 1.4475
# Epoch 3674, 100.0%, avg_loss = 1.4269
# Epoch 3675, 100.0%, avg_loss = 1.4229
# Validation Loss: 1.4979
# Epoch 3676, 100.0%, avg_loss = 1.4294
# Epoch 3677, 100.0%, avg_loss = 1.4264
# Epoch 3678, 100.0%, avg_loss = 1.4038
# Epoch 3679, 100.0%, avg_loss = 1.4406
# Epoch 3680, 100.0%, avg_loss = 1.5071
# Validation Loss: 1.4562
# Epoch 3681, 100.0%, avg_loss = 1.4199
# Epoch 3682, 100.0%, avg_loss = 1.4861
# Epoch 3683, 100.0%, avg_loss = 1.4679
# Epoch 3684, 100.0%, avg_loss = 1.4472
# Epoch 3685, 100.0%, avg_loss = 1.4159
# Validation Loss: 1.4852
# Epoch 3686, 100.0%, avg_loss = 1.3814
# Epoch 3687, 100.0%, avg_loss = 1.4851
# Epoch 3688, 100.0%, avg_loss = 1.4931
# Epoch 3689, 100.0%, avg_loss = 1.4350
# Epoch 3690, 100.0%, avg_loss = 1.4713
# Validation Loss: 1.4637
# Epoch 3691, 100.0%, avg_loss = 1.4842
# Epoch 3692, 100.0%, avg_loss = 1.4728
# Epoch 3693, 100.0%, avg_loss = 1.4353
# Epoch 3694, 100.0%, avg_loss = 1.4632
# Epoch 3695, 100.0%, avg_loss = 1.4819
# Validation Loss: 1.4591
# Epoch 3696, 100.0%, avg_loss = 1.4204
# Epoch 3697, 100.0%, avg_loss = 1.3577
# Epoch 3698, 100.0%, avg_loss = 1.5007
# Epoch 3699, 100.0%, avg_loss = 1.4500
# Epoch 3700, 100.0%, avg_loss = 1.4784
# Validation Loss: 1.4799
# Epoch 3701, 100.0%, avg_loss = 1.4475
# Epoch 3702, 100.0%, avg_loss = 1.4619
# Epoch 3703, 100.0%, avg_loss = 1.4809
# Epoch 3704, 100.0%, avg_loss = 1.3751
# Epoch 3705, 100.0%, avg_loss = 1.4078
# Validation Loss: 1.4897
# Epoch 3706, 100.0%, avg_loss = 1.4244
# Epoch 3707, 100.0%, avg_loss = 1.4422
# Epoch 3708, 100.0%, avg_loss = 1.4705
# Epoch 3709, 100.0%, avg_loss = 1.3858
# Epoch 3710, 100.0%, avg_loss = 1.4687
# Validation Loss: 1.4894
# Epoch 3711, 100.0%, avg_loss = 1.4490
# Epoch 3712, 100.0%, avg_loss = 1.4273
# Epoch 3713, 100.0%, avg_loss = 1.3893
# Epoch 3714, 100.0%, avg_loss = 1.4659
# Epoch 3715, 100.0%, avg_loss = 1.4690
# Validation Loss: 1.4874
# Epoch 3716, 100.0%, avg_loss = 1.4698
# Epoch 3717, 100.0%, avg_loss = 1.4002
# Epoch 3718, 100.0%, avg_loss = 1.4687
# Epoch 3719, 100.0%, avg_loss = 1.4924
# Epoch 3720, 100.0%, avg_loss = 1.4706
# Validation Loss: 1.4824
# Epoch 3721, 100.0%, avg_loss = 1.5005
# Epoch 3722, 100.0%, avg_loss = 1.4435
# Epoch 3723, 100.0%, avg_loss = 1.4971
# Epoch 3724, 100.0%, avg_loss = 1.5244
# Epoch 3725, 100.0%, avg_loss = 1.5031
# Validation Loss: 1.5009
# Epoch 3726, 100.0%, avg_loss = 1.4708
# Epoch 3727, 100.0%, avg_loss = 1.4577
# Epoch 3728, 100.0%, avg_loss = 1.5331
# Epoch 3729, 100.0%, avg_loss = 1.4215
# Epoch 3730, 100.0%, avg_loss = 1.4262
# Validation Loss: 1.4944
# Epoch 3731, 100.0%, avg_loss = 1.4319
# Epoch 3732, 100.0%, avg_loss = 1.4646
# Epoch 3733, 100.0%, avg_loss = 1.4859
# Epoch 3734, 100.0%, avg_loss = 1.4347
# Epoch 3735, 100.0%, avg_loss = 1.4473
# Validation Loss: 1.4994
# Epoch 3736, 100.0%, avg_loss = 1.4925
# Epoch 3737, 100.0%, avg_loss = 1.4169
# Epoch 3738, 100.0%, avg_loss = 1.4275
# Epoch 3739, 100.0%, avg_loss = 1.3843
# Epoch 3740, 100.0%, avg_loss = 1.5030
# Validation Loss: 1.4461
# Epoch 3741, 100.0%, avg_loss = 1.4459
# Epoch 3742, 100.0%, avg_loss = 1.4484
# Epoch 3743, 100.0%, avg_loss = 1.4104
# Epoch 3744, 100.0%, avg_loss = 1.4450
# Epoch 3745, 100.0%, avg_loss = 1.4142
# Validation Loss: 1.4870
# Epoch 3746, 100.0%, avg_loss = 1.4973
# Epoch 3747, 100.0%, avg_loss = 1.4462
# Epoch 3748, 100.0%, avg_loss = 1.4906
# Epoch 3749, 100.0%, avg_loss = 1.4367
# Epoch 3750, 100.0%, avg_loss = 1.4695
# Validation Loss: 1.4825
# Epoch 3751, 100.0%, avg_loss = 1.4826
# Epoch 3752, 100.0%, avg_loss = 1.4361
# Epoch 3753, 100.0%, avg_loss = 1.4736
# Epoch 3754, 100.0%, avg_loss = 1.5217
# Epoch 3755, 100.0%, avg_loss = 1.4318
# Validation Loss: 1.4657
# Epoch 3756, 100.0%, avg_loss = 1.4415
# Epoch 3757, 100.0%, avg_loss = 1.4365
# Epoch 3758, 100.0%, avg_loss = 1.4694
# Epoch 3759, 100.0%, avg_loss = 1.4329
# Epoch 3760, 100.0%, avg_loss = 1.5521
# Validation Loss: 1.4745
# Epoch 3761, 100.0%, avg_loss = 1.4323
# Epoch 3762, 100.0%, avg_loss = 1.4531
# Epoch 3763, 100.0%, avg_loss = 1.4045
# Epoch 3764, 100.0%, avg_loss = 1.4835
# Epoch 3765, 100.0%, avg_loss = 1.4172
# Validation Loss: 1.5086
# Epoch 3766, 100.0%, avg_loss = 1.4710
# Epoch 3767, 100.0%, avg_loss = 1.4957
# Epoch 3768, 100.0%, avg_loss = 1.4579
# Epoch 3769, 100.0%, avg_loss = 1.4346
# Epoch 3770, 100.0%, avg_loss = 1.3802
# Validation Loss: 1.4813
# Epoch 3771, 100.0%, avg_loss = 1.4371
# Epoch 3772, 100.0%, avg_loss = 1.4069
# Epoch 3773, 100.0%, avg_loss = 1.5053
# Epoch 3774, 100.0%, avg_loss = 1.3905
# Epoch 3775, 100.0%, avg_loss = 1.5525
# Validation Loss: 1.4774
# Epoch 3776, 100.0%, avg_loss = 1.5086
# Epoch 3777, 100.0%, avg_loss = 1.4409
# Epoch 3778, 100.0%, avg_loss = 1.4942
# Epoch 3779, 100.0%, avg_loss = 1.4863
# Epoch 3780, 100.0%, avg_loss = 1.4093
# Validation Loss: 1.4654
# Epoch 3781, 100.0%, avg_loss = 1.3849
# Epoch 3782, 100.0%, avg_loss = 1.5349
# Epoch 3783, 100.0%, avg_loss = 1.4891
# Epoch 3784, 100.0%, avg_loss = 1.4765
# Epoch 3785, 100.0%, avg_loss = 1.4947
# Validation Loss: 1.4746
# Epoch 3786, 100.0%, avg_loss = 1.5534
# Epoch 3787, 100.0%, avg_loss = 1.5137
# Epoch 3788, 100.0%, avg_loss = 1.4788
# Epoch 3789, 100.0%, avg_loss = 1.4048
# Epoch 3790, 100.0%, avg_loss = 1.4228
# Validation Loss: 1.4890
# Epoch 3791, 100.0%, avg_loss = 1.4294
# Epoch 3792, 100.0%, avg_loss = 1.3348
# Epoch 3793, 100.0%, avg_loss = 1.3860
# Epoch 3794, 100.0%, avg_loss = 1.4630
# Epoch 3795, 100.0%, avg_loss = 1.4264
# Validation Loss: 1.4839
# Epoch 3796, 100.0%, avg_loss = 1.4399
# Epoch 3797, 100.0%, avg_loss = 1.3681
# Epoch 3798, 100.0%, avg_loss = 1.4682
# Epoch 3799, 100.0%, avg_loss = 1.3955
# Epoch 3800, 100.0%, avg_loss = 1.4150
# Validation Loss: 1.5007
# Epoch 3801, 100.0%, avg_loss = 1.4796
# Epoch 3802, 100.0%, avg_loss = 1.4206
# Epoch 3803, 100.0%, avg_loss = 1.4463
# Epoch 3804, 100.0%, avg_loss = 1.4308
# Epoch 3805, 100.0%, avg_loss = 1.3932
# Validation Loss: 1.4748
# Epoch 3806, 100.0%, avg_loss = 1.5006
# Epoch 3807, 100.0%, avg_loss = 1.4357
# Epoch 3808, 100.0%, avg_loss = 1.4343
# Epoch 3809, 100.0%, avg_loss = 1.3962
# Epoch 3810, 100.0%, avg_loss = 1.4695
# Validation Loss: 1.4504
# Epoch 3811, 100.0%, avg_loss = 1.4218
# Epoch 3812, 100.0%, avg_loss = 1.4882
# Epoch 3813, 100.0%, avg_loss = 1.4038
# Epoch 3814, 100.0%, avg_loss = 1.3613
# Epoch 3815, 100.0%, avg_loss = 1.5322
# Validation Loss: 1.4422
# Epoch 3816, 100.0%, avg_loss = 1.4710
# Epoch 3817, 100.0%, avg_loss = 1.4876
# Epoch 3818, 100.0%, avg_loss = 1.4029
# Epoch 3819, 100.0%, avg_loss = 1.4545
# Epoch 3820, 100.0%, avg_loss = 1.4517
# Validation Loss: 1.5177
# Epoch 3821, 100.0%, avg_loss = 1.4128
# Epoch 3822, 100.0%, avg_loss = 1.4525
# Epoch 3823, 100.0%, avg_loss = 1.4592
# Epoch 3824, 100.0%, avg_loss = 1.4157
# Epoch 3825, 100.0%, avg_loss = 1.4480
# Validation Loss: 1.4940
# Epoch 3826, 100.0%, avg_loss = 1.4383
# Epoch 3827, 100.0%, avg_loss = 1.4451
# Epoch 3828, 100.0%, avg_loss = 1.4534
# Epoch 3829, 100.0%, avg_loss = 1.5304
# Epoch 3830, 100.0%, avg_loss = 1.4465
# Validation Loss: 1.4441
# Epoch 3831, 100.0%, avg_loss = 1.3966
# Epoch 3832, 100.0%, avg_loss = 1.4438
# Epoch 3833, 100.0%, avg_loss = 1.4281
# Epoch 3834, 100.0%, avg_loss = 1.4445
# Epoch 3835, 100.0%, avg_loss = 1.4937
# Validation Loss: 1.4819
# Epoch 3836, 100.0%, avg_loss = 1.4734
# Epoch 3837, 100.0%, avg_loss = 1.5147
# Epoch 3838, 100.0%, avg_loss = 1.4870
# Epoch 3839, 100.0%, avg_loss = 1.4560
# Epoch 3840, 100.0%, avg_loss = 1.3854
# Validation Loss: 1.4513
# Epoch 3841, 100.0%, avg_loss = 1.5420
# Epoch 3842, 100.0%, avg_loss = 1.4003
# Epoch 3843, 100.0%, avg_loss = 1.4271
# Epoch 3844, 100.0%, avg_loss = 1.3755
# Epoch 3845, 100.0%, avg_loss = 1.4220
# Validation Loss: 1.4679
# Epoch 3846, 100.0%, avg_loss = 1.4040
# Epoch 3847, 100.0%, avg_loss = 1.5165
# Epoch 3848, 100.0%, avg_loss = 1.4664
# Epoch 3849, 100.0%, avg_loss = 1.4357
# Epoch 3850, 100.0%, avg_loss = 1.4581
# Validation Loss: 1.4631
# Epoch 3851, 100.0%, avg_loss = 1.4784
# Epoch 3852, 100.0%, avg_loss = 1.4881
# Epoch 3853, 100.0%, avg_loss = 1.3773
# Epoch 3854, 100.0%, avg_loss = 1.4311
# Epoch 3855, 100.0%, avg_loss = 1.4714
# Validation Loss: 1.4698
# Epoch 3856, 100.0%, avg_loss = 1.4436
# Epoch 3857, 100.0%, avg_loss = 1.4968
# Epoch 3858, 100.0%, avg_loss = 1.4694
# Epoch 3859, 100.0%, avg_loss = 1.3975
# Epoch 3860, 100.0%, avg_loss = 1.4555
# Validation Loss: 1.5038
# Epoch 3861, 100.0%, avg_loss = 1.4310
# Epoch 3862, 100.0%, avg_loss = 1.4407
# Epoch 3863, 100.0%, avg_loss = 1.4466
# Epoch 3864, 100.0%, avg_loss = 1.4191
# Epoch 3865, 100.0%, avg_loss = 1.4030
# Validation Loss: 1.4570
# Epoch 3866, 100.0%, avg_loss = 1.4569
# Epoch 3867, 100.0%, avg_loss = 1.4905
# Epoch 3868, 100.0%, avg_loss = 1.4650
# Epoch 3869, 100.0%, avg_loss = 1.4070
# Epoch 3870, 100.0%, avg_loss = 1.4161
# Validation Loss: 1.5067
# Epoch 3871, 100.0%, avg_loss = 1.4148
# Epoch 3872, 100.0%, avg_loss = 1.4945
# Epoch 3873, 100.0%, avg_loss = 1.4400
# Epoch 3874, 100.0%, avg_loss = 1.4383
# Epoch 3875, 100.0%, avg_loss = 1.4417
# Validation Loss: 1.4522
# Epoch 3876, 100.0%, avg_loss = 1.4327
# Epoch 3877, 100.0%, avg_loss = 1.3963
# Epoch 3878, 100.0%, avg_loss = 1.4712
# Epoch 3879, 100.0%, avg_loss = 1.4521
# Epoch 3880, 100.0%, avg_loss = 1.4414
# Validation Loss: 1.4745
# Epoch 3881, 100.0%, avg_loss = 1.3984
# Epoch 3882, 100.0%, avg_loss = 1.4196
# Epoch 3883, 100.0%, avg_loss = 1.4888
# Epoch 3884, 100.0%, avg_loss = 1.4745
# Epoch 3885, 100.0%, avg_loss = 1.4900
# Validation Loss: 1.4603
# Epoch 3886, 100.0%, avg_loss = 1.4388
# Epoch 3887, 100.0%, avg_loss = 1.4789
# Epoch 3888, 100.0%, avg_loss = 1.4490
# Epoch 3889, 100.0%, avg_loss = 1.4738
# Epoch 3890, 100.0%, avg_loss = 1.4888
# Validation Loss: 1.4438
# Epoch 3891, 100.0%, avg_loss = 1.3942
# Epoch 3892, 100.0%, avg_loss = 1.4235
# Epoch 3893, 100.0%, avg_loss = 1.4690
# Epoch 3894, 100.0%, avg_loss = 1.4108
# Epoch 3895, 100.0%, avg_loss = 1.5064
# Validation Loss: 1.4655
# Epoch 3896, 100.0%, avg_loss = 1.4461
# Epoch 3897, 100.0%, avg_loss = 1.4025
# Epoch 3898, 100.0%, avg_loss = 1.4044
# Epoch 3899, 100.0%, avg_loss = 1.4632
# Epoch 3900, 100.0%, avg_loss = 1.4633
# Validation Loss: 1.5015
# Epoch 3901, 100.0%, avg_loss = 1.3486
# Epoch 3902, 100.0%, avg_loss = 1.4739
# Epoch 3903, 100.0%, avg_loss = 1.3995
# Epoch 3904, 100.0%, avg_loss = 1.4179
# Epoch 3905, 100.0%, avg_loss = 1.3670
# Validation Loss: 1.4833
# Epoch 3906, 100.0%, avg_loss = 1.4226
# Epoch 3907, 100.0%, avg_loss = 1.4597
# Epoch 3908, 100.0%, avg_loss = 1.4005
# Epoch 3909, 100.0%, avg_loss = 1.4337
# Epoch 3910, 100.0%, avg_loss = 1.4046
# Validation Loss: 1.4605
# Epoch 3911, 100.0%, avg_loss = 1.4686
# Epoch 3912, 100.0%, avg_loss = 1.4687
# Epoch 3913, 100.0%, avg_loss = 1.4941
# Epoch 3914, 100.0%, avg_loss = 1.4169
# Epoch 3915, 100.0%, avg_loss = 1.4373
# Validation Loss: 1.4760
# Epoch 3916, 100.0%, avg_loss = 1.4524
# Epoch 3917, 100.0%, avg_loss = 1.3932
# Epoch 3918, 100.0%, avg_loss = 1.4040
# Epoch 3919, 100.0%, avg_loss = 1.3995
# Epoch 3920, 100.0%, avg_loss = 1.4970
# Validation Loss: 1.4889
# Epoch 3921, 100.0%, avg_loss = 1.4019
# Epoch 3922, 100.0%, avg_loss = 1.4918
# Epoch 3923, 100.0%, avg_loss = 1.4311
# Epoch 3924, 100.0%, avg_loss = 1.5128
# Epoch 3925, 100.0%, avg_loss = 1.4013
# Validation Loss: 1.4794
# Epoch 3926, 100.0%, avg_loss = 1.3888
# Epoch 3927, 100.0%, avg_loss = 1.4744
# Epoch 3928, 100.0%, avg_loss = 1.4495
# Epoch 3929, 100.0%, avg_loss = 1.4788
# Epoch 3930, 100.0%, avg_loss = 1.4611
# Validation Loss: 1.4710
# Epoch 3931, 100.0%, avg_loss = 1.5032
# Epoch 3932, 100.0%, avg_loss = 1.5004
# Epoch 3933, 100.0%, avg_loss = 1.4970
# Epoch 3934, 100.0%, avg_loss = 1.4437
# Epoch 3935, 100.0%, avg_loss = 1.5083
# Validation Loss: 1.4739
# Epoch 3936, 100.0%, avg_loss = 1.4114
# Epoch 3937, 100.0%, avg_loss = 1.4904
# Epoch 3938, 100.0%, avg_loss = 1.4378
# Epoch 3939, 100.0%, avg_loss = 1.5007
# Epoch 3940, 100.0%, avg_loss = 1.4580
# Validation Loss: 1.4909
# Epoch 3941, 100.0%, avg_loss = 1.4510
# Epoch 3942, 100.0%, avg_loss = 1.4368
# Epoch 3943, 100.0%, avg_loss = 1.3282
# Epoch 3944, 100.0%, avg_loss = 1.4629
# Epoch 3945, 100.0%, avg_loss = 1.4125
# Validation Loss: 1.4942
# Epoch 3946, 100.0%, avg_loss = 1.4748
# Epoch 3947, 100.0%, avg_loss = 1.4467
# Epoch 3948, 100.0%, avg_loss = 1.4268
# Epoch 3949, 100.0%, avg_loss = 1.4044
# Epoch 3950, 100.0%, avg_loss = 1.4107
# Validation Loss: 1.4190
# Epoch 3951, 100.0%, avg_loss = 1.4562
# Epoch 3952, 100.0%, avg_loss = 1.3692
# Epoch 3953, 100.0%, avg_loss = 1.4600
# Epoch 3954, 100.0%, avg_loss = 1.5019
# Epoch 3955, 100.0%, avg_loss = 1.5228
# Validation Loss: 1.4500
# Epoch 3956, 100.0%, avg_loss = 1.5204
# Epoch 3957, 100.0%, avg_loss = 1.4113
# Epoch 3958, 100.0%, avg_loss = 1.5351
# Epoch 3959, 100.0%, avg_loss = 1.4392
# Epoch 3960, 100.0%, avg_loss = 1.4914
# Validation Loss: 1.4845
# Epoch 3961, 100.0%, avg_loss = 1.4431
# Epoch 3962, 100.0%, avg_loss = 1.4373
# Epoch 3963, 100.0%, avg_loss = 1.4419
# Epoch 3964, 100.0%, avg_loss = 1.4569
# Epoch 3965, 100.0%, avg_loss = 1.4434
# Validation Loss: 1.5056
# Epoch 3966, 100.0%, avg_loss = 1.4702
# Epoch 3967, 100.0%, avg_loss = 1.4472
# Epoch 3968, 100.0%, avg_loss = 1.4109
# Epoch 3969, 100.0%, avg_loss = 1.4538
# Epoch 3970, 100.0%, avg_loss = 1.4657
# Validation Loss: 1.4593
# Epoch 3971, 100.0%, avg_loss = 1.4876
# Epoch 3972, 100.0%, avg_loss = 1.4482
# Epoch 3973, 100.0%, avg_loss = 1.4501
# Epoch 3974, 100.0%, avg_loss = 1.4490
# Epoch 3975, 100.0%, avg_loss = 1.4816
# Validation Loss: 1.5158
# Epoch 3976, 100.0%, avg_loss = 1.5046
# Epoch 3977, 100.0%, avg_loss = 1.4657
# Epoch 3978, 100.0%, avg_loss = 1.4702
# Epoch 3979, 100.0%, avg_loss = 1.3127
# Epoch 3980, 100.0%, avg_loss = 1.4292
# Validation Loss: 1.4795
# Epoch 3981, 100.0%, avg_loss = 1.5316
# Epoch 3982, 100.0%, avg_loss = 1.4511
# Epoch 3983, 100.0%, avg_loss = 1.4408
# Epoch 3984, 100.0%, avg_loss = 1.4121
# Epoch 3985, 100.0%, avg_loss = 1.4659
# Validation Loss: 1.4656
# Epoch 3986, 100.0%, avg_loss = 1.4953
# Epoch 3987, 100.0%, avg_loss = 1.3775
# Epoch 3988, 100.0%, avg_loss = 1.5295
# Epoch 3989, 100.0%, avg_loss = 1.4712
# Epoch 3990, 100.0%, avg_loss = 1.4640
# Validation Loss: 1.4755
# Epoch 3991, 100.0%, avg_loss = 1.3784
# Epoch 3992, 100.0%, avg_loss = 1.4519
# Epoch 3993, 100.0%, avg_loss = 1.4325
# Epoch 3994, 100.0%, avg_loss = 1.4260
# Epoch 3995, 100.0%, avg_loss = 1.4402
# Validation Loss: 1.4833
# Epoch 3996, 100.0%, avg_loss = 1.4216
# Epoch 3997, 100.0%, avg_loss = 1.4612
# Epoch 3998, 100.0%, avg_loss = 1.4001
# Epoch 3999, 100.0%, avg_loss = 1.5433
# Epoch 4000, 100.0%, avg_loss = 1.3712
# Validation Loss: 1.4906

# %%
torch.save(local_predictor, 'local_predictor_fullsearch_fl_scratch.pytorch')

# %%
with open('./federated_local_predictor_fullsearch_training_loss.pk', 'wb') as f:
    pk.dump(training_loss, f)
with open('./federated_local_predictor_fullsearch_validation_loss.pk', 'wb') as f:
    pk.dump(validation_loss, f)
