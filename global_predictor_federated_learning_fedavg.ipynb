# %%
import torch
import torch.nn as nn
import pickle as pk
import numpy as np
from model import GlobalPredictor
import random

# %%
data = dict({})
for d in range(15, 29):
    filename = '/data/fan/UsersInTokyoProcessed/201211{:02d}_interp.pk'.format(d)
    print(filename)
    with open(filename, 'rb') as f:
        data[d] = pk.load(f)
# Out:
# /data/fan/UsersInTokyoProcessed/20121115_interp.pk
# /data/fan/UsersInTokyoProcessed/20121116_interp.pk
# /data/fan/UsersInTokyoProcessed/20121117_interp.pk
# /data/fan/UsersInTokyoProcessed/20121118_interp.pk
# /data/fan/UsersInTokyoProcessed/20121119_interp.pk
# /data/fan/UsersInTokyoProcessed/20121120_interp.pk
# /data/fan/UsersInTokyoProcessed/20121121_interp.pk
# /data/fan/UsersInTokyoProcessed/20121122_interp.pk
# /data/fan/UsersInTokyoProcessed/20121123_interp.pk
# /data/fan/UsersInTokyoProcessed/20121124_interp.pk
# /data/fan/UsersInTokyoProcessed/20121125_interp.pk
# /data/fan/UsersInTokyoProcessed/20121126_interp.pk
# /data/fan/UsersInTokyoProcessed/20121127_interp.pk
# /data/fan/UsersInTokyoProcessed/20121128_interp.pk

# %%
data_qry_train = dict({})
data_qry_test = dict({})

for d in range(15, 22):
    for uid in data[d]:
        if uid not in data_qry_train:
            data_qry_train[uid] = [data[d][uid]]
        else:
            data_qry_train[uid].append(data[d][uid])
            
for d in range(22, 29):
    for uid in data[d]:
        if uid not in data_qry_test:
            data_qry_test[uid] = [data[d][uid]]
        else:
            data_qry_test[uid].append(data[d][uid])

# %%
for uid in data_qry_train:
    data_qry_train[uid] = torch.LongTensor(data_qry_train[uid]).cuda(1)
    
for uid in data_qry_test:
    data_qry_test[uid] = torch.LongTensor(data_qry_test[uid]).cuda(1)

# %%
num_locs = 1600
loc_embedding_dim = 128
T = 96
num_time = T
time_embedding_dim = 32
hidden_dim = 256
latent_dim = 256

# %%
lr = 1e-2

# %%
global_predictor = GlobalPredictor(num_locs, loc_embedding_dim, num_time, time_embedding_dim, hidden_dim, latent_dim).cuda(1)
global_predictor_server = GlobalPredictor(num_locs, loc_embedding_dim, num_time, time_embedding_dim, hidden_dim, latent_dim).cuda(1)
optimizer = torch.optim.SGD(global_predictor.parameters(), lr=lr)
optimizer_scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=200, gamma=0.5)
optimizer.zero_grad()

# %%
dT = 4

# %%
training_loss = dict({})
validation_loss = dict({})

# %%
user_list_train = list(data_qry_train.keys())
time_list = list(range(T - 2 * dT + 1))

for epoch in range(1, 4001):
    
    optimizer_scheduler.step()
    
    update_user_list = random.sample(user_list_train, 512)
    
    update_weights_dict = global_predictor_server.state_dict()
    for para in update_weights_dict:
        update_weights_dict[para] = []
    
    avg_loss = 0.0
    cnt = 0
    n = 0
    
    uidx = 0
    
    for uid in update_user_list:
        uidx += 1
        # loading server model to local
        global_predictor.load_state_dict(global_predictor_server.state_dict())
        optimizer = torch.optim.SGD(global_predictor.parameters(), lr=lr)
        
        nk = data_qry_train[uid].shape[0]
        n += data_qry_train[uid].shape[0]
        
        for e in range(5):
        
            t = np.random.randint(T - 2 * dT + 1)
            x_loc_qry = data_qry_train[uid][:, t: t + dT]
            x_t_qry = torch.zeros_like(x_loc_qry) + t
            y = data_qry_train[uid][:, t + 2 * dT - 1]

            loss = global_predictor(x_loc_qry, x_t_qry, y)

            loss.backward()
            avg_loss += loss.item()
            cnt += nk

            optimizer.step()
            optimizer.zero_grad()
            
        cur_state_dict = global_predictor.state_dict()
        for para in cur_state_dict:
            update_weights_dict[para].append(cur_state_dict[para].cpu())
        
        print('Epoch {:02d}, {:.1f}%, avg_loss = {:.4f}'.format(epoch, uidx * 100 / len(update_user_list), avg_loss / cnt), end='\r')

    with torch.no_grad():
        
        for para in update_weights_dict:
            update_weights_dict[para] = torch.mean(torch.stack(update_weights_dict[para]), dim=0)
            
        global_predictor_server.load_state_dict(update_weights_dict)
    
    training_loss[epoch] = avg_loss / cnt
    print('')
    # testing
    
    if epoch % 5 == 0:
        with torch.no_grad():

            cnt = 0
            avg_loss = 0.0

            for uid in data_qry_test:

                if np.random.ranf() > 0.1:
                    continue

                nk = data_qry_test[uid].shape[0]

                t = np.random.randint(T - 2 * dT + 1)
                x_loc_qry = data_qry_test[uid][:, t: t + dT]
                x_t_qry = torch.zeros_like(x_loc_qry) + t
                y = data_qry_test[uid][:, t + 2 * dT - 1]

                loss = global_predictor_server(x_loc_qry, x_t_qry, y)

                avg_loss += loss.item()
                cnt += nk

            print('Validation Loss: {:.4f}'.format(avg_loss / cnt))
            validation_loss[epoch] = avg_loss / cnt
# Out:
# Epoch 01, 100.0%, avg_loss = 6.9236
# Epoch 02, 100.0%, avg_loss = 6.9713
# Epoch 03, 100.0%, avg_loss = 6.9360
# Epoch 04, 100.0%, avg_loss = 6.8872
# Epoch 05, 100.0%, avg_loss = 6.8709
# Validation Loss: 7.3761
# Epoch 06, 100.0%, avg_loss = 6.8852
# Epoch 07, 100.0%, avg_loss = 6.9495
# Epoch 08, 100.0%, avg_loss = 6.8814
# Epoch 09, 100.0%, avg_loss = 6.8974
# Epoch 10, 100.0%, avg_loss = 6.8656
# Validation Loss: 7.3648
# Epoch 11, 100.0%, avg_loss = 6.8461
# Epoch 12, 100.0%, avg_loss = 6.7761
# Epoch 13, 100.0%, avg_loss = 6.8053
# Epoch 14, 100.0%, avg_loss = 6.8174
# Epoch 15, 100.0%, avg_loss = 6.7880
# Validation Loss: 7.3531
# Epoch 16, 100.0%, avg_loss = 6.8332
# Epoch 17, 100.0%, avg_loss = 6.7856
# Epoch 18, 100.0%, avg_loss = 6.8112
# Epoch 19, 100.0%, avg_loss = 6.8567
# Epoch 20, 100.0%, avg_loss = 6.7561
# Validation Loss: 7.3420
# Epoch 21, 100.0%, avg_loss = 6.7449
# Epoch 22, 100.0%, avg_loss = 6.7073
# Epoch 23, 100.0%, avg_loss = 6.6906
# Epoch 24, 100.0%, avg_loss = 6.7121
# Epoch 25, 100.0%, avg_loss = 6.7049
# Validation Loss: 7.3245
# Epoch 26, 100.0%, avg_loss = 6.7232
# Epoch 27, 100.0%, avg_loss = 6.6862
# Epoch 28, 100.0%, avg_loss = 6.6393
# Epoch 29, 100.0%, avg_loss = 6.6373
# Epoch 30, 100.0%, avg_loss = 6.5938
# Validation Loss: 7.3090
# Epoch 31, 100.0%, avg_loss = 6.6194
# Epoch 32, 100.0%, avg_loss = 6.5226
# Epoch 33, 100.0%, avg_loss = 6.4957
# Epoch 34, 100.0%, avg_loss = 6.5114
# Epoch 35, 100.0%, avg_loss = 6.4874
# Validation Loss: 7.2906
# Epoch 36, 100.0%, avg_loss = 6.4127
# Epoch 37, 100.0%, avg_loss = 6.4220
# Epoch 38, 100.0%, avg_loss = 6.4003
# Epoch 39, 100.0%, avg_loss = 6.3984
# Epoch 40, 100.0%, avg_loss = 6.2657
# Validation Loss: 7.2626
# Epoch 41, 100.0%, avg_loss = 6.3500
# Epoch 42, 100.0%, avg_loss = 6.2973
# Epoch 43, 100.0%, avg_loss = 6.2763
# Epoch 44, 100.0%, avg_loss = 6.2863
# Epoch 45, 100.0%, avg_loss = 6.2476
# Validation Loss: 7.2330
# Epoch 46, 100.0%, avg_loss = 6.1694
# Epoch 47, 100.0%, avg_loss = 6.0430
# Epoch 48, 100.0%, avg_loss = 6.0865
# Epoch 49, 100.0%, avg_loss = 6.0828
# Epoch 50, 100.0%, avg_loss = 6.0131
# Validation Loss: 7.2002
# Epoch 51, 100.0%, avg_loss = 5.8488
# Epoch 52, 100.0%, avg_loss = 5.8819
# Epoch 53, 100.0%, avg_loss = 5.8413
# Epoch 54, 100.0%, avg_loss = 5.7149
# Epoch 55, 100.0%, avg_loss = 5.7998
# Validation Loss: 7.1513
# Epoch 56, 100.0%, avg_loss = 5.6564
# Epoch 57, 100.0%, avg_loss = 5.6476
# Epoch 58, 100.0%, avg_loss = 5.6815
# Epoch 59, 100.0%, avg_loss = 5.5293
# Epoch 60, 100.0%, avg_loss = 5.5997
# Validation Loss: 7.1027
# Epoch 61, 100.0%, avg_loss = 5.2943
# Epoch 62, 100.0%, avg_loss = 5.3972
# Epoch 63, 100.0%, avg_loss = 5.3966
# Epoch 64, 100.0%, avg_loss = 5.3146
# Epoch 65, 100.0%, avg_loss = 5.2332
# Validation Loss: 7.0561
# Epoch 66, 100.0%, avg_loss = 5.2073
# Epoch 67, 100.0%, avg_loss = 5.1612
# Epoch 68, 100.0%, avg_loss = 5.0843
# Epoch 69, 100.0%, avg_loss = 5.0879
# Epoch 70, 100.0%, avg_loss = 5.1086
# Validation Loss: 7.0117
# Epoch 71, 100.0%, avg_loss = 5.0752
# Epoch 72, 100.0%, avg_loss = 5.0060
# Epoch 73, 100.0%, avg_loss = 5.0843
# Epoch 74, 100.0%, avg_loss = 5.0265
# Epoch 75, 100.0%, avg_loss = 5.0610
# Validation Loss: 6.9645
# Epoch 76, 100.0%, avg_loss = 5.0190
# Epoch 77, 100.0%, avg_loss = 5.0076
# Epoch 78, 100.0%, avg_loss = 4.8372
# Epoch 79, 100.0%, avg_loss = 4.9371
# Epoch 80, 100.0%, avg_loss = 4.9926
# Validation Loss: 6.9320
# Epoch 81, 100.0%, avg_loss = 4.8776
# Epoch 82, 100.0%, avg_loss = 4.8966
# Epoch 83, 100.0%, avg_loss = 4.9297
# Epoch 84, 100.0%, avg_loss = 5.0224
# Epoch 85, 100.0%, avg_loss = 4.9045
# Validation Loss: 6.8911
# Epoch 86, 100.0%, avg_loss = 4.7884
# Epoch 87, 100.0%, avg_loss = 4.8458
# Epoch 88, 100.0%, avg_loss = 4.8907
# Epoch 89, 100.0%, avg_loss = 4.8487
# Epoch 90, 100.0%, avg_loss = 4.9138
# Validation Loss: 6.8577
# Epoch 91, 100.0%, avg_loss = 4.8056
# Epoch 92, 100.0%, avg_loss = 4.8418
# Epoch 93, 100.0%, avg_loss = 4.7524
# Epoch 94, 100.0%, avg_loss = 4.9643
# Epoch 95, 100.0%, avg_loss = 4.7494
# Validation Loss: 6.8281
# Epoch 96, 100.0%, avg_loss = 4.7462
# Epoch 97, 100.0%, avg_loss = 4.7402
# Epoch 98, 100.0%, avg_loss = 4.8436
# Epoch 99, 100.0%, avg_loss = 4.7130
# Epoch 100, 100.0%, avg_loss = 4.7746
# Validation Loss: 6.8069
# Epoch 101, 100.0%, avg_loss = 4.7693
# Epoch 102, 100.0%, avg_loss = 4.6551
# Epoch 103, 100.0%, avg_loss = 4.6944
# Epoch 104, 100.0%, avg_loss = 4.7573
# Epoch 105, 100.0%, avg_loss = 4.6540
# Validation Loss: 6.7898
# Epoch 106, 100.0%, avg_loss = 4.6462
# Epoch 107, 100.0%, avg_loss = 4.8353
# Epoch 108, 100.0%, avg_loss = 4.5602
# Epoch 109, 100.0%, avg_loss = 4.6859
# Epoch 110, 100.0%, avg_loss = 4.6668
# Validation Loss: 6.7561
# Epoch 111, 100.0%, avg_loss = 4.6257
# Epoch 112, 100.0%, avg_loss = 4.5765
# Epoch 113, 100.0%, avg_loss = 4.5587
# Epoch 114, 100.0%, avg_loss = 4.7269
# Epoch 115, 100.0%, avg_loss = 4.5819
# Validation Loss: 6.7161
# Epoch 116, 100.0%, avg_loss = 4.6322
# Epoch 117, 100.0%, avg_loss = 4.6049
# Epoch 118, 100.0%, avg_loss = 4.6853
# Epoch 119, 100.0%, avg_loss = 4.6551
# Epoch 120, 100.0%, avg_loss = 4.5298
# Validation Loss: 6.6951
# Epoch 121, 100.0%, avg_loss = 4.5145
# Epoch 122, 100.0%, avg_loss = 4.6405
# Epoch 123, 100.0%, avg_loss = 4.4581
# Epoch 124, 100.0%, avg_loss = 4.5214
# Epoch 125, 100.0%, avg_loss = 4.4744
# Validation Loss: 6.6703
# Epoch 126, 100.0%, avg_loss = 4.5240
# Epoch 127, 100.0%, avg_loss = 4.5366
# Epoch 128, 100.0%, avg_loss = 4.4728
# Epoch 129, 100.0%, avg_loss = 4.5310
# Epoch 130, 100.0%, avg_loss = 4.4983
# Validation Loss: 6.6500
# Epoch 131, 100.0%, avg_loss = 4.4306
# Epoch 132, 100.0%, avg_loss = 4.4888
# Epoch 133, 100.0%, avg_loss = 4.4883
# Epoch 134, 100.0%, avg_loss = 4.5013
# Epoch 135, 100.0%, avg_loss = 4.4331
# Validation Loss: 6.6167
# Epoch 136, 100.0%, avg_loss = 4.4595
# Epoch 137, 100.0%, avg_loss = 4.6148
# Epoch 138, 100.0%, avg_loss = 4.5459
# Epoch 139, 100.0%, avg_loss = 4.4876
# Epoch 140, 100.0%, avg_loss = 4.3714
# Validation Loss: 6.5785
# Epoch 141, 100.0%, avg_loss = 4.4688
# Epoch 142, 100.0%, avg_loss = 4.3563
# Epoch 143, 100.0%, avg_loss = 4.3933
# Epoch 144, 100.0%, avg_loss = 4.4656
# Epoch 145, 100.0%, avg_loss = 4.4331
# Validation Loss: 6.5434
# Epoch 146, 100.0%, avg_loss = 4.3933
# Epoch 147, 100.0%, avg_loss = 4.5561
# Epoch 148, 100.0%, avg_loss = 4.3629
# Epoch 149, 100.0%, avg_loss = 4.3600
# Epoch 150, 100.0%, avg_loss = 4.4151
# Validation Loss: 6.5259
# Epoch 151, 100.0%, avg_loss = 4.3278
# Epoch 152, 100.0%, avg_loss = 4.2944
# Epoch 153, 100.0%, avg_loss = 4.3377
# Epoch 154, 100.0%, avg_loss = 4.3762
# Epoch 155, 100.0%, avg_loss = 4.2922
# Validation Loss: 6.5051
# Epoch 156, 100.0%, avg_loss = 4.4145
# Epoch 157, 100.0%, avg_loss = 4.2606
# Epoch 158, 100.0%, avg_loss = 4.4329
# Epoch 159, 100.0%, avg_loss = 4.2770
# Epoch 160, 100.0%, avg_loss = 4.2952
# Validation Loss: 6.4764
# Epoch 161, 100.0%, avg_loss = 4.1986
# Epoch 162, 100.0%, avg_loss = 4.3837
# Epoch 163, 100.0%, avg_loss = 4.3558
# Epoch 164, 100.0%, avg_loss = 4.2885
# Epoch 165, 100.0%, avg_loss = 4.3600
# Validation Loss: 6.4448
# Epoch 166, 100.0%, avg_loss = 4.3100
# Epoch 167, 100.0%, avg_loss = 4.3365
# Epoch 168, 100.0%, avg_loss = 4.2049
# Epoch 169, 100.0%, avg_loss = 4.3134
# Epoch 170, 100.0%, avg_loss = 4.3250
# Validation Loss: 6.4146
# Epoch 171, 100.0%, avg_loss = 4.3277
# Epoch 172, 100.0%, avg_loss = 4.2674
# Epoch 173, 100.0%, avg_loss = 4.3034
# Epoch 174, 100.0%, avg_loss = 4.1745
# Epoch 175, 100.0%, avg_loss = 4.2644
# Validation Loss: 6.3865
# Epoch 176, 100.0%, avg_loss = 4.2698
# Epoch 177, 100.0%, avg_loss = 4.1614
# Epoch 178, 100.0%, avg_loss = 4.2276
# Epoch 179, 100.0%, avg_loss = 4.2606
# Epoch 180, 100.0%, avg_loss = 4.3994
# Validation Loss: 6.3738
# Epoch 181, 100.0%, avg_loss = 4.1832
# Epoch 182, 100.0%, avg_loss = 4.3972
# Epoch 183, 100.0%, avg_loss = 4.2545
# Epoch 184, 100.0%, avg_loss = 4.1773
# Epoch 185, 100.0%, avg_loss = 4.1359
# Validation Loss: 6.3508
# Epoch 186, 100.0%, avg_loss = 4.1330
# Epoch 187, 100.0%, avg_loss = 4.1260
# Epoch 188, 100.0%, avg_loss = 4.1448
# Epoch 189, 100.0%, avg_loss = 4.0750
# Epoch 190, 100.0%, avg_loss = 4.1534
# Validation Loss: 6.3101
# Epoch 191, 100.0%, avg_loss = 4.1617
# Epoch 192, 100.0%, avg_loss = 4.2098
# Epoch 193, 100.0%, avg_loss = 4.1241
# Epoch 194, 100.0%, avg_loss = 4.1075
# Epoch 195, 100.0%, avg_loss = 4.0881
# Validation Loss: 6.2810
# Epoch 196, 100.0%, avg_loss = 4.1096
# Epoch 197, 100.0%, avg_loss = 4.2032
# Epoch 198, 100.0%, avg_loss = 4.1330
# Epoch 199, 100.0%, avg_loss = 4.0718
# Epoch 200, 100.0%, avg_loss = 4.0405
# Validation Loss: 6.2585
# Epoch 201, 100.0%, avg_loss = 4.1546
# Epoch 202, 100.0%, avg_loss = 4.1788
# Epoch 203, 100.0%, avg_loss = 3.9525
# Epoch 204, 100.0%, avg_loss = 4.0722
# Epoch 205, 100.0%, avg_loss = 4.0708
# Validation Loss: 6.2476
# Epoch 206, 100.0%, avg_loss = 4.0035
# Epoch 207, 100.0%, avg_loss = 4.1138
# Epoch 208, 100.0%, avg_loss = 4.0623
# Epoch 209, 100.0%, avg_loss = 4.1398
# Epoch 210, 100.0%, avg_loss = 4.1013
# Validation Loss: 6.2313
# Epoch 211, 100.0%, avg_loss = 4.1120
# Epoch 212, 100.0%, avg_loss = 4.0012
# Epoch 213, 100.0%, avg_loss = 4.1990
# Epoch 214, 100.0%, avg_loss = 4.0622
# Epoch 215, 100.0%, avg_loss = 4.0379
# Validation Loss: 6.1919
# Epoch 216, 100.0%, avg_loss = 3.9818
# Epoch 217, 100.0%, avg_loss = 4.1102
# Epoch 218, 100.0%, avg_loss = 3.9375
# Epoch 219, 100.0%, avg_loss = 4.0717
# Epoch 220, 100.0%, avg_loss = 4.0347
# Validation Loss: 6.1469
# Epoch 221, 100.0%, avg_loss = 4.0851
# Epoch 222, 100.0%, avg_loss = 3.9825
# Epoch 223, 100.0%, avg_loss = 3.9515
# Epoch 224, 100.0%, avg_loss = 3.9997
# Epoch 225, 100.0%, avg_loss = 3.8765
# Validation Loss: 6.1084
# Epoch 226, 100.0%, avg_loss = 3.9472
# Epoch 227, 100.0%, avg_loss = 4.0098
# Epoch 228, 100.0%, avg_loss = 4.0122
# Epoch 229, 100.0%, avg_loss = 4.0561
# Epoch 230, 100.0%, avg_loss = 3.9110
# Validation Loss: 6.1170
# Epoch 231, 100.0%, avg_loss = 3.9495
# Epoch 232, 100.0%, avg_loss = 3.9339
# Epoch 233, 100.0%, avg_loss = 3.9643
# Epoch 234, 100.0%, avg_loss = 4.0360
# Epoch 235, 100.0%, avg_loss = 3.9245
# Validation Loss: 6.0664
# Epoch 236, 100.0%, avg_loss = 3.9812
# Epoch 237, 100.0%, avg_loss = 3.9636
# Epoch 238, 100.0%, avg_loss = 3.9717
# Epoch 239, 100.0%, avg_loss = 4.0051
# Epoch 240, 100.0%, avg_loss = 3.9898
# Validation Loss: 6.0595
# Epoch 241, 100.0%, avg_loss = 3.9410
# Epoch 242, 100.0%, avg_loss = 3.9838
# Epoch 243, 100.0%, avg_loss = 3.8866
# Epoch 244, 100.0%, avg_loss = 3.9633
# Epoch 245, 100.0%, avg_loss = 3.9334
# Validation Loss: 6.0247
# Epoch 246, 100.0%, avg_loss = 3.9103
# Epoch 247, 100.0%, avg_loss = 3.8260
# Epoch 248, 100.0%, avg_loss = 3.8331
# Epoch 249, 100.0%, avg_loss = 3.9627
# Epoch 250, 100.0%, avg_loss = 3.9542
# Validation Loss: 5.9915
# Epoch 251, 100.0%, avg_loss = 3.8826
# Epoch 252, 100.0%, avg_loss = 3.8985
# Epoch 253, 100.0%, avg_loss = 3.9349
# Epoch 254, 100.0%, avg_loss = 3.8772
# Epoch 255, 100.0%, avg_loss = 3.9561
# Validation Loss: 5.9797
# Epoch 256, 100.0%, avg_loss = 3.8868
# Epoch 257, 100.0%, avg_loss = 3.7946
# Epoch 258, 100.0%, avg_loss = 3.8403
# Epoch 259, 100.0%, avg_loss = 3.8747
# Epoch 260, 100.0%, avg_loss = 3.8403
# Validation Loss: 5.9462
# Epoch 261, 100.0%, avg_loss = 3.9670
# Epoch 262, 100.0%, avg_loss = 3.7583
# Epoch 263, 100.0%, avg_loss = 3.9453
# Epoch 264, 100.0%, avg_loss = 3.6756
# Epoch 265, 100.0%, avg_loss = 3.9071
# Validation Loss: 5.9456
# Epoch 266, 100.0%, avg_loss = 3.8722
# Epoch 267, 100.0%, avg_loss = 3.8120
# Epoch 268, 100.0%, avg_loss = 3.8756
# Epoch 269, 100.0%, avg_loss = 3.7341
# Epoch 270, 100.0%, avg_loss = 3.9139
# Validation Loss: 5.9054
# Epoch 271, 100.0%, avg_loss = 3.8120
# Epoch 272, 100.0%, avg_loss = 3.6994
# Epoch 273, 100.0%, avg_loss = 3.8988
# Epoch 274, 100.0%, avg_loss = 3.8298
# Epoch 275, 100.0%, avg_loss = 3.7064
# Validation Loss: 5.8817
# Epoch 276, 100.0%, avg_loss = 3.9418
# Epoch 277, 100.0%, avg_loss = 3.8191
# Epoch 278, 100.0%, avg_loss = 3.7834
# Epoch 279, 100.0%, avg_loss = 3.7645
# Epoch 280, 100.0%, avg_loss = 3.7499
# Validation Loss: 5.8659
# Epoch 281, 100.0%, avg_loss = 3.8032
# Epoch 282, 100.0%, avg_loss = 3.7918
# Epoch 283, 100.0%, avg_loss = 3.8139
# Epoch 284, 100.0%, avg_loss = 3.8163
# Epoch 285, 100.0%, avg_loss = 3.7323
# Validation Loss: 5.8027
# Epoch 286, 100.0%, avg_loss = 3.8046
# Epoch 287, 100.0%, avg_loss = 3.8185
# Epoch 288, 100.0%, avg_loss = 3.6490
# Epoch 289, 100.0%, avg_loss = 3.7466
# Epoch 290, 100.0%, avg_loss = 3.7772
# Validation Loss: 5.7803
# Epoch 291, 100.0%, avg_loss = 3.7941
# Epoch 292, 100.0%, avg_loss = 3.6841
# Epoch 293, 100.0%, avg_loss = 3.6339
# Epoch 294, 100.0%, avg_loss = 3.8075
# Epoch 295, 100.0%, avg_loss = 3.7267
# Validation Loss: 5.7787
# Epoch 296, 100.0%, avg_loss = 3.8175
# Epoch 297, 100.0%, avg_loss = 3.7502
# Epoch 298, 100.0%, avg_loss = 3.8058
# Epoch 299, 100.0%, avg_loss = 3.7497
# Epoch 300, 100.0%, avg_loss = 3.7502
# Validation Loss: 5.7358
# Epoch 301, 100.0%, avg_loss = 3.8203
# Epoch 302, 100.0%, avg_loss = 3.6437
# Epoch 303, 100.0%, avg_loss = 3.6324
# Epoch 304, 100.0%, avg_loss = 3.6279
# Epoch 305, 100.0%, avg_loss = 3.6510
# Validation Loss: 5.7374
# Epoch 306, 100.0%, avg_loss = 3.5664
# Epoch 307, 100.0%, avg_loss = 3.7277
# Epoch 308, 100.0%, avg_loss = 3.7629
# Epoch 309, 100.0%, avg_loss = 3.7907
# Epoch 310, 100.0%, avg_loss = 3.7132
# Validation Loss: 5.7052
# Epoch 311, 100.0%, avg_loss = 3.6646
# Epoch 312, 100.0%, avg_loss = 3.6149
# Epoch 313, 100.0%, avg_loss = 3.7922
# Epoch 314, 100.0%, avg_loss = 3.6824
# Epoch 315, 100.0%, avg_loss = 3.6062
# Validation Loss: 5.6739
# Epoch 316, 100.0%, avg_loss = 3.7278
# Epoch 317, 100.0%, avg_loss = 3.6976
# Epoch 318, 100.0%, avg_loss = 3.7235
# Epoch 319, 100.0%, avg_loss = 3.6313
# Epoch 320, 100.0%, avg_loss = 3.5470
# Validation Loss: 5.6403
# Epoch 321, 100.0%, avg_loss = 3.5656
# Epoch 322, 100.0%, avg_loss = 3.6990
# Epoch 323, 100.0%, avg_loss = 3.6233
# Epoch 324, 100.0%, avg_loss = 3.6387
# Epoch 325, 100.0%, avg_loss = 3.6803
# Validation Loss: 5.6301
# Epoch 326, 100.0%, avg_loss = 3.6044
# Epoch 327, 100.0%, avg_loss = 3.6569
# Epoch 328, 100.0%, avg_loss = 3.6264
# Epoch 329, 100.0%, avg_loss = 3.6305
# Epoch 330, 100.0%, avg_loss = 3.5453
# Validation Loss: 5.6165
# Epoch 331, 100.0%, avg_loss = 3.7812
# Epoch 332, 100.0%, avg_loss = 3.6871
# Epoch 333, 100.0%, avg_loss = 3.6534
# Epoch 334, 100.0%, avg_loss = 3.6475
# Epoch 335, 100.0%, avg_loss = 3.4890
# Validation Loss: 5.5828
# Epoch 336, 100.0%, avg_loss = 3.6263
# Epoch 337, 100.0%, avg_loss = 3.5261
# Epoch 338, 100.0%, avg_loss = 3.5609
# Epoch 339, 100.0%, avg_loss = 3.5851
# Epoch 340, 100.0%, avg_loss = 3.6090
# Validation Loss: 5.5658
# Epoch 341, 100.0%, avg_loss = 3.6177
# Epoch 342, 100.0%, avg_loss = 3.6755
# Epoch 343, 100.0%, avg_loss = 3.5857
# Epoch 344, 100.0%, avg_loss = 3.5332
# Epoch 345, 100.0%, avg_loss = 3.6346
# Validation Loss: 5.5442
# Epoch 346, 100.0%, avg_loss = 3.6411
# Epoch 347, 100.0%, avg_loss = 3.6436
# Epoch 348, 100.0%, avg_loss = 3.5821
# Epoch 349, 100.0%, avg_loss = 3.5711
# Epoch 350, 100.0%, avg_loss = 3.4919
# Validation Loss: 5.5020
# Epoch 351, 100.0%, avg_loss = 3.5839
# Epoch 352, 100.0%, avg_loss = 3.5413
# Epoch 353, 100.0%, avg_loss = 3.5774
# Epoch 354, 100.0%, avg_loss = 3.5831
# Epoch 355, 100.0%, avg_loss = 3.6124
# Validation Loss: 5.5039
# Epoch 356, 100.0%, avg_loss = 3.6265
# Epoch 357, 100.0%, avg_loss = 3.6874
# Epoch 358, 100.0%, avg_loss = 3.6155
# Epoch 359, 100.0%, avg_loss = 3.6079
# Epoch 360, 100.0%, avg_loss = 3.5069
# Validation Loss: 5.4468
# Epoch 361, 100.0%, avg_loss = 3.5503
# Epoch 362, 100.0%, avg_loss = 3.6309
# Epoch 363, 100.0%, avg_loss = 3.5287
# Epoch 364, 100.0%, avg_loss = 3.5561
# Epoch 365, 100.0%, avg_loss = 3.6602
# Validation Loss: 5.4507
# Epoch 366, 100.0%, avg_loss = 3.4907
# Epoch 367, 100.0%, avg_loss = 3.5173
# Epoch 368, 100.0%, avg_loss = 3.4536
# Epoch 369, 100.0%, avg_loss = 3.6415
# Epoch 370, 100.0%, avg_loss = 3.4880
# Validation Loss: 5.4155
# Epoch 371, 100.0%, avg_loss = 3.5691
# Epoch 372, 100.0%, avg_loss = 3.5296
# Epoch 373, 100.0%, avg_loss = 3.4585
# Epoch 374, 100.0%, avg_loss = 3.5899
# Epoch 375, 100.0%, avg_loss = 3.6356
# Validation Loss: 5.3986
# Epoch 376, 100.0%, avg_loss = 3.5841
# Epoch 377, 100.0%, avg_loss = 3.5210
# Epoch 378, 100.0%, avg_loss = 3.5190
# Epoch 379, 100.0%, avg_loss = 3.4782
# Epoch 380, 100.0%, avg_loss = 3.5647
# Validation Loss: 5.3810
# Epoch 381, 100.0%, avg_loss = 3.4927
# Epoch 382, 100.0%, avg_loss = 3.5321
# Epoch 383, 100.0%, avg_loss = 3.6065
# Epoch 384, 100.0%, avg_loss = 3.6646
# Epoch 385, 100.0%, avg_loss = 3.4078
# Validation Loss: 5.3475
# Epoch 386, 100.0%, avg_loss = 3.4631
# Epoch 387, 100.0%, avg_loss = 3.5686
# Epoch 388, 100.0%, avg_loss = 3.5698
# Epoch 389, 100.0%, avg_loss = 3.4979
# Epoch 390, 100.0%, avg_loss = 3.5968
# Validation Loss: 5.3352
# Epoch 391, 100.0%, avg_loss = 3.4233
# Epoch 392, 100.0%, avg_loss = 3.4834
# Epoch 393, 100.0%, avg_loss = 3.4519
# Epoch 394, 100.0%, avg_loss = 3.4833
# Epoch 395, 100.0%, avg_loss = 3.7007
# Validation Loss: 5.3192
# Epoch 396, 100.0%, avg_loss = 3.4739
# Epoch 397, 100.0%, avg_loss = 3.5046
# Epoch 398, 100.0%, avg_loss = 3.5119
# Epoch 399, 100.0%, avg_loss = 3.5741
# Epoch 400, 100.0%, avg_loss = 3.4946
# Validation Loss: 5.2972
# Epoch 401, 100.0%, avg_loss = 3.6060
# Epoch 402, 100.0%, avg_loss = 3.4839
# Epoch 403, 100.0%, avg_loss = 3.4766
# Epoch 404, 100.0%, avg_loss = 3.4271
# Epoch 405, 100.0%, avg_loss = 3.5366
# Validation Loss: 5.2616
# Epoch 406, 100.0%, avg_loss = 3.4598
# Epoch 407, 100.0%, avg_loss = 3.4127
# Epoch 408, 100.0%, avg_loss = 3.4651
# Epoch 409, 100.0%, avg_loss = 3.5024
# Epoch 410, 100.0%, avg_loss = 3.4750
# Validation Loss: 5.2573
# Epoch 411, 100.0%, avg_loss = 3.3149
# Epoch 412, 100.0%, avg_loss = 3.3909
# Epoch 413, 100.0%, avg_loss = 3.3265
# Epoch 414, 100.0%, avg_loss = 3.4759
# Epoch 415, 100.0%, avg_loss = 3.3348
# Validation Loss: 5.1996
# Epoch 416, 100.0%, avg_loss = 3.2976
# Epoch 417, 100.0%, avg_loss = 3.4550
# Epoch 418, 100.0%, avg_loss = 3.5884
# Epoch 419, 100.0%, avg_loss = 3.5088
# Epoch 420, 100.0%, avg_loss = 3.5184
# Validation Loss: 5.2259
# Epoch 421, 100.0%, avg_loss = 3.4536
# Epoch 422, 100.0%, avg_loss = 3.3741
# Epoch 423, 100.0%, avg_loss = 3.4374
# Epoch 424, 100.0%, avg_loss = 3.3520
# Epoch 425, 100.0%, avg_loss = 3.3687
# Validation Loss: 5.1692
# Epoch 426, 100.0%, avg_loss = 3.4174
# Epoch 427, 100.0%, avg_loss = 3.4583
# Epoch 428, 100.0%, avg_loss = 3.3652
# Epoch 429, 100.0%, avg_loss = 3.3682
# Epoch 430, 100.0%, avg_loss = 3.4211
# Validation Loss: 5.1596
# Epoch 431, 100.0%, avg_loss = 3.2809
# Epoch 432, 100.0%, avg_loss = 3.3731
# Epoch 433, 100.0%, avg_loss = 3.4666
# Epoch 434, 100.0%, avg_loss = 3.5478
# Epoch 435, 100.0%, avg_loss = 3.4141
# Validation Loss: 5.1536
# Epoch 436, 100.0%, avg_loss = 3.3891
# Epoch 437, 100.0%, avg_loss = 3.3502
# Epoch 438, 100.0%, avg_loss = 3.3424
# Epoch 439, 100.0%, avg_loss = 3.5511
# Epoch 440, 100.0%, avg_loss = 3.4068
# Validation Loss: 5.1160
# Epoch 441, 100.0%, avg_loss = 3.3328
# Epoch 442, 100.0%, avg_loss = 3.3279
# Epoch 443, 100.0%, avg_loss = 3.5602
# Epoch 444, 100.0%, avg_loss = 3.2504
# Epoch 445, 100.0%, avg_loss = 3.4018
# Validation Loss: 5.1014
# Epoch 446, 100.0%, avg_loss = 3.3574
# Epoch 447, 100.0%, avg_loss = 3.4684
# Epoch 448, 100.0%, avg_loss = 3.4035
# Epoch 449, 100.0%, avg_loss = 3.3859
# Epoch 450, 100.0%, avg_loss = 3.5393
# Validation Loss: 5.0909
# Epoch 451, 100.0%, avg_loss = 3.5718
# Epoch 452, 100.0%, avg_loss = 3.4152
# Epoch 453, 100.0%, avg_loss = 3.3444
# Epoch 454, 100.0%, avg_loss = 3.3920
# Epoch 455, 100.0%, avg_loss = 3.4488
# Validation Loss: 5.0550
# Epoch 456, 100.0%, avg_loss = 3.4331
# Epoch 457, 100.0%, avg_loss = 3.3634
# Epoch 458, 100.0%, avg_loss = 3.4346
# Epoch 459, 100.0%, avg_loss = 3.3317
# Epoch 460, 100.0%, avg_loss = 3.2996
# Validation Loss: 5.0495
# Epoch 461, 100.0%, avg_loss = 3.4523
# Epoch 462, 100.0%, avg_loss = 3.4064
# Epoch 463, 100.0%, avg_loss = 3.4106
# Epoch 464, 100.0%, avg_loss = 3.3567
# Epoch 465, 100.0%, avg_loss = 3.2638
# Validation Loss: 5.0102
# Epoch 466, 100.0%, avg_loss = 3.4628
# Epoch 467, 100.0%, avg_loss = 3.3107
# Epoch 468, 100.0%, avg_loss = 3.3812
# Epoch 469, 100.0%, avg_loss = 3.3402
# Epoch 470, 100.0%, avg_loss = 3.3184
# Validation Loss: 5.0019
# Epoch 471, 100.0%, avg_loss = 3.3893
# Epoch 472, 100.0%, avg_loss = 3.3887
# Epoch 473, 100.0%, avg_loss = 3.3644
# Epoch 474, 100.0%, avg_loss = 3.2998
# Epoch 475, 100.0%, avg_loss = 3.3582
# Validation Loss: 4.9738
# Epoch 476, 100.0%, avg_loss = 3.4099
# Epoch 477, 100.0%, avg_loss = 3.3357
# Epoch 478, 100.0%, avg_loss = 3.2769
# Epoch 479, 100.0%, avg_loss = 3.2980
# Epoch 480, 100.0%, avg_loss = 3.2702
# Validation Loss: 4.9778
# Epoch 481, 100.0%, avg_loss = 3.3213
# Epoch 482, 100.0%, avg_loss = 3.4449
# Epoch 483, 100.0%, avg_loss = 3.3541
# Epoch 484, 100.0%, avg_loss = 3.2654
# Epoch 485, 100.0%, avg_loss = 3.1860
# Validation Loss: 4.9318
# Epoch 486, 100.0%, avg_loss = 3.3094
# Epoch 487, 100.0%, avg_loss = 3.3631
# Epoch 488, 100.0%, avg_loss = 3.2780
# Epoch 489, 100.0%, avg_loss = 3.3031
# Epoch 490, 100.0%, avg_loss = 3.3038
# Validation Loss: 4.9490
# Epoch 491, 100.0%, avg_loss = 3.3745
# Epoch 492, 100.0%, avg_loss = 3.2952
# Epoch 493, 100.0%, avg_loss = 3.2946
# Epoch 494, 100.0%, avg_loss = 3.3059
# Epoch 495, 100.0%, avg_loss = 3.3797
# Validation Loss: 4.9087
# Epoch 496, 100.0%, avg_loss = 3.2295
# Epoch 497, 100.0%, avg_loss = 3.3429
# Epoch 498, 100.0%, avg_loss = 3.4223
# Epoch 499, 100.0%, avg_loss = 3.3182
# Epoch 500, 100.0%, avg_loss = 3.3013
# Validation Loss: 4.9014
# Epoch 501, 100.0%, avg_loss = 3.4287
# Epoch 502, 100.0%, avg_loss = 3.3434
# Epoch 503, 100.0%, avg_loss = 3.2419
# Epoch 504, 100.0%, avg_loss = 3.2137
# Epoch 505, 100.0%, avg_loss = 3.4726
# Validation Loss: 4.9300
# Epoch 506, 100.0%, avg_loss = 3.2551
# Epoch 507, 100.0%, avg_loss = 3.1851
# Epoch 508, 100.0%, avg_loss = 3.2434
# Epoch 509, 100.0%, avg_loss = 3.2639
# Epoch 510, 100.0%, avg_loss = 3.2786
# Validation Loss: 4.8582
# Epoch 511, 100.0%, avg_loss = 3.3261
# Epoch 512, 100.0%, avg_loss = 3.2936
# Epoch 513, 100.0%, avg_loss = 3.3442
# Epoch 514, 100.0%, avg_loss = 3.2634
# Epoch 515, 100.0%, avg_loss = 3.3243
# Validation Loss: 4.8285
# Epoch 516, 100.0%, avg_loss = 3.3506
# Epoch 517, 100.0%, avg_loss = 3.2555
# Epoch 518, 100.0%, avg_loss = 3.3258
# Epoch 519, 100.0%, avg_loss = 3.2900
# Epoch 520, 100.0%, avg_loss = 3.3866
# Validation Loss: 4.8206
# Epoch 521, 100.0%, avg_loss = 3.2412
# Epoch 522, 100.0%, avg_loss = 3.1942
# Epoch 523, 100.0%, avg_loss = 3.2525
# Epoch 524, 100.0%, avg_loss = 3.3797
# Epoch 525, 100.0%, avg_loss = 3.3761
# Validation Loss: 4.8232
# Epoch 526, 100.0%, avg_loss = 3.2942
# Epoch 527, 100.0%, avg_loss = 3.2252
# Epoch 528, 100.0%, avg_loss = 3.2319
# Epoch 529, 100.0%, avg_loss = 3.2862
# Epoch 530, 100.0%, avg_loss = 3.2762
# Validation Loss: 4.7866
# Epoch 531, 100.0%, avg_loss = 3.2429
# Epoch 532, 100.0%, avg_loss = 3.2877
# Epoch 533, 100.0%, avg_loss = 3.2284
# Epoch 534, 100.0%, avg_loss = 3.3142
# Epoch 535, 100.0%, avg_loss = 3.1600
# Validation Loss: 4.8006
# Epoch 536, 100.0%, avg_loss = 3.1935
# Epoch 537, 100.0%, avg_loss = 3.2111
# Epoch 538, 100.0%, avg_loss = 3.1664
# Epoch 539, 100.0%, avg_loss = 3.1791
# Epoch 540, 100.0%, avg_loss = 3.2697
# Validation Loss: 4.7393
# Epoch 541, 100.0%, avg_loss = 3.2175
# Epoch 542, 100.0%, avg_loss = 3.0978
# Epoch 543, 100.0%, avg_loss = 3.2638
# Epoch 544, 100.0%, avg_loss = 3.2576
# Epoch 545, 100.0%, avg_loss = 3.3254
# Validation Loss: 4.7458
# Epoch 546, 100.0%, avg_loss = 3.1510
# Epoch 547, 100.0%, avg_loss = 3.1771
# Epoch 548, 100.0%, avg_loss = 3.2650
# Epoch 549, 100.0%, avg_loss = 3.2450
# Epoch 550, 100.0%, avg_loss = 3.1956
# Validation Loss: 4.7214
# Epoch 551, 100.0%, avg_loss = 3.1030
# Epoch 552, 100.0%, avg_loss = 3.1372
# Epoch 553, 100.0%, avg_loss = 3.0947
# Epoch 554, 100.0%, avg_loss = 3.2315
# Epoch 555, 100.0%, avg_loss = 3.2675
# Validation Loss: 4.7094
# Epoch 556, 100.0%, avg_loss = 3.2443
# Epoch 557, 100.0%, avg_loss = 3.1509
# Epoch 558, 100.0%, avg_loss = 3.2104
# Epoch 559, 100.0%, avg_loss = 3.1544
# Epoch 560, 100.0%, avg_loss = 3.1719
# Validation Loss: 4.6915
# Epoch 561, 100.0%, avg_loss = 3.1336
# Epoch 562, 100.0%, avg_loss = 3.1908
# Epoch 563, 100.0%, avg_loss = 3.2360
# Epoch 564, 100.0%, avg_loss = 3.1821
# Epoch 565, 100.0%, avg_loss = 3.1807
# Validation Loss: 4.6465
# Epoch 566, 100.0%, avg_loss = 3.3772
# Epoch 567, 100.0%, avg_loss = 3.1955
# Epoch 568, 100.0%, avg_loss = 3.2983
# Epoch 569, 100.0%, avg_loss = 3.1788
# Epoch 570, 100.0%, avg_loss = 3.2522
# Validation Loss: 4.6326
# Epoch 571, 100.0%, avg_loss = 3.2482
# Epoch 572, 100.0%, avg_loss = 3.1669
# Epoch 573, 100.0%, avg_loss = 3.2094
# Epoch 574, 100.0%, avg_loss = 3.1709
# Epoch 575, 100.0%, avg_loss = 3.2607
# Validation Loss: 4.6588
# Epoch 576, 100.0%, avg_loss = 3.2300
# Epoch 577, 100.0%, avg_loss = 3.1118
# Epoch 578, 100.0%, avg_loss = 3.1371
# Epoch 579, 100.0%, avg_loss = 3.1645
# Epoch 580, 100.0%, avg_loss = 3.2545
# Validation Loss: 4.6341
# Epoch 581, 100.0%, avg_loss = 3.2019
# Epoch 582, 100.0%, avg_loss = 3.1868
# Epoch 583, 100.0%, avg_loss = 3.2324
# Epoch 584, 100.0%, avg_loss = 3.1937
# Epoch 585, 100.0%, avg_loss = 3.0568
# Validation Loss: 4.6093
# Epoch 586, 100.0%, avg_loss = 3.1774
# Epoch 587, 100.0%, avg_loss = 3.2621
# Epoch 588, 100.0%, avg_loss = 3.1304
# Epoch 589, 100.0%, avg_loss = 3.1449
# Epoch 590, 100.0%, avg_loss = 3.2246
# Validation Loss: 4.5865
# Epoch 591, 100.0%, avg_loss = 3.0640
# Epoch 592, 100.0%, avg_loss = 3.3152
# Epoch 593, 100.0%, avg_loss = 3.2198
# Epoch 594, 100.0%, avg_loss = 3.2150
# Epoch 595, 100.0%, avg_loss = 3.1369
# Validation Loss: 4.6015
# Epoch 596, 100.0%, avg_loss = 3.1289
# Epoch 597, 100.0%, avg_loss = 3.0756
# Epoch 598, 100.0%, avg_loss = 3.2007
# Epoch 599, 100.0%, avg_loss = 3.1399
# Epoch 600, 100.0%, avg_loss = 3.0217
# Validation Loss: 4.5765
# Epoch 601, 100.0%, avg_loss = 3.0871
# Epoch 602, 100.0%, avg_loss = 3.1963
# Epoch 603, 100.0%, avg_loss = 3.1423
# Epoch 604, 100.0%, avg_loss = 3.0877
# Epoch 605, 100.0%, avg_loss = 3.1652
# Validation Loss: 4.5540
# Epoch 606, 100.0%, avg_loss = 3.1714
# Epoch 607, 100.0%, avg_loss = 3.1942
# Epoch 608, 100.0%, avg_loss = 3.1461
# Epoch 609, 100.0%, avg_loss = 3.2107
# Epoch 610, 100.0%, avg_loss = 3.2281
# Validation Loss: 4.5295
# Epoch 611, 100.0%, avg_loss = 3.1208
# Epoch 612, 100.0%, avg_loss = 3.0411
# Epoch 613, 100.0%, avg_loss = 3.1689
# Epoch 614, 100.0%, avg_loss = 3.2039
# Epoch 615, 100.0%, avg_loss = 3.2027
# Validation Loss: 4.5105
# Epoch 616, 100.0%, avg_loss = 3.1890
# Epoch 617, 100.0%, avg_loss = 3.1932
# Epoch 618, 100.0%, avg_loss = 3.0956
# Epoch 619, 100.0%, avg_loss = 3.1293
# Epoch 620, 100.0%, avg_loss = 3.2411
# Validation Loss: 4.4721
# Epoch 621, 100.0%, avg_loss = 3.1471
# Epoch 622, 100.0%, avg_loss = 3.1048
# Epoch 623, 100.0%, avg_loss = 3.1126
# Epoch 624, 100.0%, avg_loss = 3.1444
# Epoch 625, 100.0%, avg_loss = 3.1030
# Validation Loss: 4.4780
# Epoch 626, 100.0%, avg_loss = 3.0138
# Epoch 627, 100.0%, avg_loss = 3.3017
# Epoch 628, 100.0%, avg_loss = 3.1720
# Epoch 629, 100.0%, avg_loss = 3.1295
# Epoch 630, 100.0%, avg_loss = 3.1888
# Validation Loss: 4.4645
# Epoch 631, 100.0%, avg_loss = 3.1616
# Epoch 632, 100.0%, avg_loss = 3.1168
# Epoch 633, 100.0%, avg_loss = 3.0495
# Epoch 634, 100.0%, avg_loss = 3.0500
# Epoch 635, 100.0%, avg_loss = 3.1658
# Validation Loss: 4.4766
# Epoch 636, 100.0%, avg_loss = 3.1166
# Epoch 637, 100.0%, avg_loss = 3.1317
# Epoch 638, 100.0%, avg_loss = 3.2190
# Epoch 639, 100.0%, avg_loss = 3.1630
# Epoch 640, 100.0%, avg_loss = 3.2229
# Validation Loss: 4.4166
# Epoch 641, 100.0%, avg_loss = 3.0545
# Epoch 642, 100.0%, avg_loss = 3.0750
# Epoch 643, 100.0%, avg_loss = 3.1708
# Epoch 644, 100.0%, avg_loss = 3.0596
# Epoch 645, 100.0%, avg_loss = 3.0896
# Validation Loss: 4.4216
# Epoch 646, 100.0%, avg_loss = 3.1539
# Epoch 647, 100.0%, avg_loss = 3.1923
# Epoch 648, 100.0%, avg_loss = 3.0367
# Epoch 649, 100.0%, avg_loss = 3.1339
# Epoch 650, 100.0%, avg_loss = 3.1756
# Validation Loss: 4.4172
# Epoch 651, 100.0%, avg_loss = 3.1502
# Epoch 652, 100.0%, avg_loss = 3.0328
# Epoch 653, 100.0%, avg_loss = 3.1499
# Epoch 654, 100.0%, avg_loss = 3.0091
# Epoch 655, 100.0%, avg_loss = 2.9730
# Validation Loss: 4.4416
# Epoch 656, 100.0%, avg_loss = 3.0925
# Epoch 657, 100.0%, avg_loss = 3.2172
# Epoch 658, 100.0%, avg_loss = 3.0543
# Epoch 659, 100.0%, avg_loss = 3.1361
# Epoch 660, 100.0%, avg_loss = 3.1320
# Validation Loss: 4.3502
# Epoch 661, 100.0%, avg_loss = 3.0510
# Epoch 662, 100.0%, avg_loss = 3.1209
# Epoch 663, 100.0%, avg_loss = 3.1982
# Epoch 664, 100.0%, avg_loss = 3.1462
# Epoch 665, 100.0%, avg_loss = 3.1057
# Validation Loss: 4.3685
# Epoch 666, 100.0%, avg_loss = 3.0925
# Epoch 667, 100.0%, avg_loss = 3.1207
# Epoch 668, 100.0%, avg_loss = 3.1394
# Epoch 669, 100.0%, avg_loss = 3.0817
# Epoch 670, 100.0%, avg_loss = 3.0395
# Validation Loss: 4.3587
# Epoch 671, 100.0%, avg_loss = 3.1884
# Epoch 672, 100.0%, avg_loss = 3.1141
# Epoch 673, 100.0%, avg_loss = 3.1526
# Epoch 674, 100.0%, avg_loss = 3.1264
# Epoch 675, 100.0%, avg_loss = 2.9573
# Validation Loss: 4.3215
# Epoch 676, 100.0%, avg_loss = 3.1254
# Epoch 677, 100.0%, avg_loss = 3.0666
# Epoch 678, 100.0%, avg_loss = 3.0680
# Epoch 679, 100.0%, avg_loss = 3.0016
# Epoch 680, 100.0%, avg_loss = 3.0254
# Validation Loss: 4.3462
# Epoch 681, 100.0%, avg_loss = 3.0777
# Epoch 682, 100.0%, avg_loss = 3.1918
# Epoch 683, 100.0%, avg_loss = 3.0050
# Epoch 684, 100.0%, avg_loss = 3.0277
# Epoch 685, 100.0%, avg_loss = 3.0093
# Validation Loss: 4.2832
# Epoch 686, 100.0%, avg_loss = 3.1342
# Epoch 687, 100.0%, avg_loss = 3.0512
# Epoch 688, 100.0%, avg_loss = 2.9710
# Epoch 689, 100.0%, avg_loss = 3.0470
# Epoch 690, 100.0%, avg_loss = 3.0117
# Validation Loss: 4.2922
# Epoch 691, 100.0%, avg_loss = 3.0224
# Epoch 692, 100.0%, avg_loss = 3.0884
# Epoch 693, 100.0%, avg_loss = 2.9684
# Epoch 694, 100.0%, avg_loss = 3.0925
# Epoch 695, 100.0%, avg_loss = 3.1546
# Validation Loss: 4.2746
# Epoch 696, 100.0%, avg_loss = 3.0517
# Epoch 697, 100.0%, avg_loss = 3.0472
# Epoch 698, 100.0%, avg_loss = 3.0964
# Epoch 699, 100.0%, avg_loss = 2.9706
# Epoch 700, 100.0%, avg_loss = 2.9996
# Validation Loss: 4.2832
# Epoch 701, 100.0%, avg_loss = 3.1142
# Epoch 702, 100.0%, avg_loss = 3.0456
# Epoch 703, 100.0%, avg_loss = 2.9774
# Epoch 704, 100.0%, avg_loss = 3.0514
# Epoch 705, 100.0%, avg_loss = 3.1121
# Validation Loss: 4.2385
# Epoch 706, 100.0%, avg_loss = 3.0453
# Epoch 707, 100.0%, avg_loss = 2.9949
# Epoch 708, 100.0%, avg_loss = 2.9304
# Epoch 709, 100.0%, avg_loss = 3.0192
# Epoch 710, 100.0%, avg_loss = 3.1048
# Validation Loss: 4.2522
# Epoch 711, 100.0%, avg_loss = 2.9329
# Epoch 712, 100.0%, avg_loss = 3.0343
# Epoch 713, 100.0%, avg_loss = 3.0252
# Epoch 714, 100.0%, avg_loss = 2.9487
# Epoch 715, 100.0%, avg_loss = 3.1028
# Validation Loss: 4.2197
# Epoch 716, 100.0%, avg_loss = 3.0075
# Epoch 717, 100.0%, avg_loss = 3.0612
# Epoch 718, 100.0%, avg_loss = 2.9885
# Epoch 719, 100.0%, avg_loss = 3.1334
# Epoch 720, 100.0%, avg_loss = 3.0486
# Validation Loss: 4.2172
# Epoch 721, 100.0%, avg_loss = 3.0997
# Epoch 722, 100.0%, avg_loss = 3.0530
# Epoch 723, 100.0%, avg_loss = 2.9849
# Epoch 724, 100.0%, avg_loss = 3.0341
# Epoch 725, 100.0%, avg_loss = 3.1188
# Validation Loss: 4.1774
# Epoch 726, 100.0%, avg_loss = 3.0050
# Epoch 727, 100.0%, avg_loss = 2.9335
# Epoch 728, 100.0%, avg_loss = 2.9682
# Epoch 729, 100.0%, avg_loss = 2.9252
# Epoch 730, 100.0%, avg_loss = 3.0710
# Validation Loss: 4.1675
# Epoch 731, 100.0%, avg_loss = 2.8674
# Epoch 732, 100.0%, avg_loss = 3.0887
# Epoch 733, 100.0%, avg_loss = 3.0111
# Epoch 734, 100.0%, avg_loss = 2.9705
# Epoch 735, 100.0%, avg_loss = 3.0125
# Validation Loss: 4.1548
# Epoch 736, 100.0%, avg_loss = 2.9227
# Epoch 737, 100.0%, avg_loss = 3.0093
# Epoch 738, 100.0%, avg_loss = 3.0415
# Epoch 739, 100.0%, avg_loss = 3.0743
# Epoch 740, 100.0%, avg_loss = 2.9706
# Validation Loss: 4.1605
# Epoch 741, 100.0%, avg_loss = 3.0912
# Epoch 742, 100.0%, avg_loss = 2.9261
# Epoch 743, 100.0%, avg_loss = 2.9680
# Epoch 744, 100.0%, avg_loss = 3.0268
# Epoch 745, 100.0%, avg_loss = 2.9212
# Validation Loss: 4.1611
# Epoch 746, 100.0%, avg_loss = 2.9697
# Epoch 747, 100.0%, avg_loss = 2.9903
# Epoch 748, 100.0%, avg_loss = 3.0467
# Epoch 749, 100.0%, avg_loss = 3.0212
# Epoch 750, 100.0%, avg_loss = 3.0065
# Validation Loss: 4.1241
# Epoch 751, 100.0%, avg_loss = 3.0482
# Epoch 752, 100.0%, avg_loss = 2.9805
# Epoch 753, 100.0%, avg_loss = 2.9126
# Epoch 754, 100.0%, avg_loss = 2.8831
# Epoch 755, 100.0%, avg_loss = 2.9483
# Validation Loss: 4.0705
# Epoch 756, 100.0%, avg_loss = 3.1350
# Epoch 757, 100.0%, avg_loss = 2.9445
# Epoch 758, 100.0%, avg_loss = 3.1043
# Epoch 759, 100.0%, avg_loss = 2.9568
# Epoch 760, 100.0%, avg_loss = 2.9515
# Validation Loss: 4.1121
# Epoch 761, 100.0%, avg_loss = 2.9995
# Epoch 762, 100.0%, avg_loss = 2.9837
# Epoch 763, 100.0%, avg_loss = 3.0565
# Epoch 764, 100.0%, avg_loss = 2.9779
# Epoch 765, 100.0%, avg_loss = 2.9802
# Validation Loss: 4.0854
# Epoch 766, 100.0%, avg_loss = 2.9999
# Epoch 767, 100.0%, avg_loss = 2.9325
# Epoch 768, 100.0%, avg_loss = 3.0856
# Epoch 769, 100.0%, avg_loss = 2.9841
# Epoch 770, 100.0%, avg_loss = 3.0102
# Validation Loss: 4.0683
# Epoch 771, 100.0%, avg_loss = 3.0193
# Epoch 772, 100.0%, avg_loss = 3.0220
# Epoch 773, 100.0%, avg_loss = 2.9645
# Epoch 774, 100.0%, avg_loss = 3.0203
# Epoch 775, 100.0%, avg_loss = 2.9803
# Validation Loss: 4.0802
# Epoch 776, 100.0%, avg_loss = 3.0759
# Epoch 777, 100.0%, avg_loss = 2.9215
# Epoch 778, 100.0%, avg_loss = 3.0431
# Epoch 779, 100.0%, avg_loss = 3.0831
# Epoch 780, 100.0%, avg_loss = 2.8988
# Validation Loss: 4.0758
# Epoch 781, 100.0%, avg_loss = 2.9298
# Epoch 782, 100.0%, avg_loss = 2.8301
# Epoch 783, 100.0%, avg_loss = 3.0269
# Epoch 784, 100.0%, avg_loss = 2.9956
# Epoch 785, 100.0%, avg_loss = 3.0741
# Validation Loss: 4.0604
# Epoch 786, 100.0%, avg_loss = 2.9158
# Epoch 787, 100.0%, avg_loss = 3.0433
# Epoch 788, 100.0%, avg_loss = 2.9413
# Epoch 789, 100.0%, avg_loss = 2.9396
# Epoch 790, 100.0%, avg_loss = 3.1223
# Validation Loss: 4.0302
# Epoch 791, 100.0%, avg_loss = 3.0294
# Epoch 792, 100.0%, avg_loss = 3.1241
# Epoch 793, 100.0%, avg_loss = 3.0594
# Epoch 794, 100.0%, avg_loss = 2.9482
# Epoch 795, 100.0%, avg_loss = 2.9181
# Validation Loss: 4.0086
# Epoch 796, 100.0%, avg_loss = 2.9231
# Epoch 797, 100.0%, avg_loss = 3.0291
# Epoch 798, 100.0%, avg_loss = 2.9400
# Epoch 799, 100.0%, avg_loss = 2.9901
# Epoch 800, 100.0%, avg_loss = 2.9018
# Validation Loss: 4.0196
# Epoch 801, 100.0%, avg_loss = 3.0153
# Epoch 802, 100.0%, avg_loss = 2.9483
# Epoch 803, 100.0%, avg_loss = 3.0697
# Epoch 804, 100.0%, avg_loss = 2.9355
# Epoch 805, 100.0%, avg_loss = 3.0229
# Validation Loss: 4.0100
# Epoch 806, 100.0%, avg_loss = 3.0848
# Epoch 807, 100.0%, avg_loss = 3.0075
# Epoch 808, 100.0%, avg_loss = 2.9228
# Epoch 809, 100.0%, avg_loss = 3.0329
# Epoch 810, 100.0%, avg_loss = 2.8251
# Validation Loss: 3.9969
# Epoch 811, 100.0%, avg_loss = 2.8570
# Epoch 812, 100.0%, avg_loss = 2.8590
# Epoch 813, 100.0%, avg_loss = 2.9312
# Epoch 814, 100.0%, avg_loss = 2.8952
# Epoch 815, 100.0%, avg_loss = 2.9167
# Validation Loss: 3.9743
# Epoch 816, 100.0%, avg_loss = 2.9634
# Epoch 817, 100.0%, avg_loss = 3.0108
# Epoch 818, 100.0%, avg_loss = 2.8905
# Epoch 819, 100.0%, avg_loss = 2.9007
# Epoch 820, 100.0%, avg_loss = 2.8761
# Validation Loss: 3.9585
# Epoch 821, 100.0%, avg_loss = 2.9140
# Epoch 822, 100.0%, avg_loss = 2.9795
# Epoch 823, 100.0%, avg_loss = 2.8754
# Epoch 824, 100.0%, avg_loss = 2.8313
# Epoch 825, 100.0%, avg_loss = 3.0437
# Validation Loss: 3.9842
# Epoch 826, 100.0%, avg_loss = 2.8524
# Epoch 827, 100.0%, avg_loss = 2.9110
# Epoch 828, 100.0%, avg_loss = 2.9044
# Epoch 829, 100.0%, avg_loss = 2.9634
# Epoch 830, 100.0%, avg_loss = 2.8938
# Validation Loss: 3.9142
# Epoch 831, 100.0%, avg_loss = 2.9481
# Epoch 832, 100.0%, avg_loss = 2.8490
# Epoch 833, 100.0%, avg_loss = 2.8305
# Epoch 834, 100.0%, avg_loss = 2.9043
# Epoch 835, 100.0%, avg_loss = 2.9437
# Validation Loss: 3.9158
# Epoch 836, 100.0%, avg_loss = 2.9591
# Epoch 837, 100.0%, avg_loss = 3.0029
# Epoch 838, 100.0%, avg_loss = 2.8344
# Epoch 839, 100.0%, avg_loss = 2.9613
# Epoch 840, 100.0%, avg_loss = 3.0149
# Validation Loss: 3.9322
# Epoch 841, 100.0%, avg_loss = 2.8539
# Epoch 842, 100.0%, avg_loss = 3.0068
# Epoch 843, 100.0%, avg_loss = 2.9958
# Epoch 844, 100.0%, avg_loss = 3.0142
# Epoch 845, 100.0%, avg_loss = 2.8253
# Validation Loss: 3.9111
# Epoch 846, 100.0%, avg_loss = 3.0045
# Epoch 847, 100.0%, avg_loss = 2.8886
# Epoch 848, 100.0%, avg_loss = 2.7842
# Epoch 849, 100.0%, avg_loss = 2.9554
# Epoch 850, 100.0%, avg_loss = 2.9709
# Validation Loss: 3.8827
# Epoch 851, 100.0%, avg_loss = 2.8101
# Epoch 852, 100.0%, avg_loss = 3.0583
# Epoch 853, 100.0%, avg_loss = 2.9406
# Epoch 854, 100.0%, avg_loss = 2.8237
# Epoch 855, 100.0%, avg_loss = 2.9583
# Validation Loss: 3.9078
# Epoch 856, 100.0%, avg_loss = 2.8783
# Epoch 857, 100.0%, avg_loss = 2.9859
# Epoch 858, 100.0%, avg_loss = 2.9886
# Epoch 859, 100.0%, avg_loss = 2.9663
# Epoch 860, 100.0%, avg_loss = 2.9231
# Validation Loss: 3.8599
# Epoch 861, 100.0%, avg_loss = 2.9458
# Epoch 862, 100.0%, avg_loss = 3.0030
# Epoch 863, 100.0%, avg_loss = 2.8265
# Epoch 864, 100.0%, avg_loss = 2.8235
# Epoch 865, 100.0%, avg_loss = 2.9146
# Validation Loss: 3.8635
# Epoch 866, 100.0%, avg_loss = 2.8580
# Epoch 867, 100.0%, avg_loss = 2.8483
# Epoch 868, 100.0%, avg_loss = 2.8701
# Epoch 869, 100.0%, avg_loss = 2.9874
# Epoch 870, 100.0%, avg_loss = 3.0049
# Validation Loss: 3.8827
# Epoch 871, 100.0%, avg_loss = 2.7728
# Epoch 872, 100.0%, avg_loss = 2.8440
# Epoch 873, 100.0%, avg_loss = 2.9234
# Epoch 874, 100.0%, avg_loss = 2.8514
# Epoch 875, 100.0%, avg_loss = 2.7895
# Validation Loss: 3.8494
# Epoch 876, 100.0%, avg_loss = 2.8488
# Epoch 877, 100.0%, avg_loss = 3.0388
# Epoch 878, 100.0%, avg_loss = 2.9376
# Epoch 879, 100.0%, avg_loss = 2.8968
# Epoch 880, 100.0%, avg_loss = 2.9195
# Validation Loss: 3.8326
# Epoch 881, 100.0%, avg_loss = 2.9377
# Epoch 882, 100.0%, avg_loss = 2.9140
# Epoch 883, 100.0%, avg_loss = 2.8984
# Epoch 884, 100.0%, avg_loss = 2.8568
# Epoch 885, 100.0%, avg_loss = 2.8286
# Validation Loss: 3.8083
# Epoch 886, 100.0%, avg_loss = 2.9094
# Epoch 887, 100.0%, avg_loss = 2.9508
# Epoch 888, 100.0%, avg_loss = 2.9450
# Epoch 889, 100.0%, avg_loss = 2.9371
# Epoch 890, 100.0%, avg_loss = 2.8436
# Validation Loss: 3.8240
# Epoch 891, 100.0%, avg_loss = 3.0718
# Epoch 892, 100.0%, avg_loss = 2.8357
# Epoch 893, 100.0%, avg_loss = 2.9879
# Epoch 894, 100.0%, avg_loss = 2.9302
# Epoch 895, 100.0%, avg_loss = 2.8849
# Validation Loss: 3.8112
# Epoch 896, 100.0%, avg_loss = 2.9081
# Epoch 897, 100.0%, avg_loss = 2.8985
# Epoch 898, 100.0%, avg_loss = 2.8008
# Epoch 899, 100.0%, avg_loss = 2.8460
# Epoch 900, 100.0%, avg_loss = 2.8962
# Validation Loss: 3.8046
# Epoch 901, 100.0%, avg_loss = 2.8703
# Epoch 902, 100.0%, avg_loss = 2.8470
# Epoch 903, 100.0%, avg_loss = 2.8234
# Epoch 904, 100.0%, avg_loss = 2.8918
# Epoch 905, 100.0%, avg_loss = 2.8978
# Validation Loss: 3.7775
# Epoch 906, 100.0%, avg_loss = 2.9331
# Epoch 907, 100.0%, avg_loss = 2.8911
# Epoch 908, 100.0%, avg_loss = 2.9216
# Epoch 909, 100.0%, avg_loss = 3.0124
# Epoch 910, 100.0%, avg_loss = 2.9331
# Validation Loss: 3.7934
# Epoch 911, 100.0%, avg_loss = 3.0324
# Epoch 912, 100.0%, avg_loss = 2.9412
# Epoch 913, 100.0%, avg_loss = 2.8599
# Epoch 914, 100.0%, avg_loss = 2.7321
# Epoch 915, 100.0%, avg_loss = 2.9050
# Validation Loss: 3.7355
# Epoch 916, 100.0%, avg_loss = 2.8250
# Epoch 917, 100.0%, avg_loss = 2.8669
# Epoch 918, 100.0%, avg_loss = 2.9228
# Epoch 919, 100.0%, avg_loss = 2.8881
# Epoch 920, 100.0%, avg_loss = 2.7205
# Validation Loss: 3.7859
# Epoch 921, 100.0%, avg_loss = 2.9464
# Epoch 922, 100.0%, avg_loss = 2.8399
# Epoch 923, 100.0%, avg_loss = 2.8205
# Epoch 924, 100.0%, avg_loss = 2.7961
# Epoch 925, 100.0%, avg_loss = 2.8093
# Validation Loss: 3.7403
# Epoch 926, 100.0%, avg_loss = 2.8586
# Epoch 927, 100.0%, avg_loss = 2.7928
# Epoch 928, 100.0%, avg_loss = 2.9368
# Epoch 929, 100.0%, avg_loss = 2.8889
# Epoch 930, 100.0%, avg_loss = 2.6979
# Validation Loss: 3.7040
# Epoch 931, 100.0%, avg_loss = 2.8923
# Epoch 932, 100.0%, avg_loss = 2.9425
# Epoch 933, 100.0%, avg_loss = 2.8185
# Epoch 934, 100.0%, avg_loss = 2.8735
# Epoch 935, 100.0%, avg_loss = 2.9302
# Validation Loss: 3.6940
# Epoch 936, 100.0%, avg_loss = 2.9354
# Epoch 937, 100.0%, avg_loss = 2.8658
# Epoch 938, 100.0%, avg_loss = 2.8087
# Epoch 939, 100.0%, avg_loss = 2.8342
# Epoch 940, 100.0%, avg_loss = 2.8564
# Validation Loss: 3.7092
# Epoch 941, 100.0%, avg_loss = 2.9568
# Epoch 942, 100.0%, avg_loss = 2.8071
# Epoch 943, 100.0%, avg_loss = 2.7581
# Epoch 944, 100.0%, avg_loss = 2.8274
# Epoch 945, 100.0%, avg_loss = 2.9024
# Validation Loss: 3.7113
# Epoch 946, 100.0%, avg_loss = 2.9130
# Epoch 947, 100.0%, avg_loss = 2.9103
# Epoch 948, 100.0%, avg_loss = 2.8352
# Epoch 949, 100.0%, avg_loss = 2.9096
# Epoch 950, 100.0%, avg_loss = 2.8165
# Validation Loss: 3.6819
# Epoch 951, 100.0%, avg_loss = 2.8091
# Epoch 952, 100.0%, avg_loss = 2.8641
# Epoch 953, 100.0%, avg_loss = 2.8798
# Epoch 954, 100.0%, avg_loss = 2.8153
# Epoch 955, 100.0%, avg_loss = 2.9369
# Validation Loss: 3.6955
# Epoch 956, 100.0%, avg_loss = 2.8125
# Epoch 957, 100.0%, avg_loss = 2.8377
# Epoch 958, 100.0%, avg_loss = 2.8011
# Epoch 959, 100.0%, avg_loss = 2.9489
# Epoch 960, 100.0%, avg_loss = 2.9681
# Validation Loss: 3.6725
# Epoch 961, 100.0%, avg_loss = 2.8630
# Epoch 962, 100.0%, avg_loss = 2.8353
# Epoch 963, 100.0%, avg_loss = 2.8195
# Epoch 964, 100.0%, avg_loss = 2.8070
# Epoch 965, 100.0%, avg_loss = 2.8666
# Validation Loss: 3.6528
# Epoch 966, 100.0%, avg_loss = 2.8206
# Epoch 967, 100.0%, avg_loss = 2.7822
# Epoch 968, 100.0%, avg_loss = 2.9381
# Epoch 969, 100.0%, avg_loss = 2.8920
# Epoch 970, 100.0%, avg_loss = 2.8919
# Validation Loss: 3.6519
# Epoch 971, 100.0%, avg_loss = 2.8065
# Epoch 972, 100.0%, avg_loss = 2.7287
# Epoch 973, 100.0%, avg_loss = 2.9379
# Epoch 974, 100.0%, avg_loss = 2.8344
# Epoch 975, 100.0%, avg_loss = 2.8737
# Validation Loss: 3.6375
# Epoch 976, 100.0%, avg_loss = 2.9626
# Epoch 977, 100.0%, avg_loss = 2.8387
# Epoch 978, 100.0%, avg_loss = 2.7758
# Epoch 979, 100.0%, avg_loss = 2.7334
# Epoch 980, 100.0%, avg_loss = 2.9643
# Validation Loss: 3.6306
# Epoch 981, 100.0%, avg_loss = 2.8298
# Epoch 982, 100.0%, avg_loss = 2.8024
# Epoch 983, 100.0%, avg_loss = 2.8703
# Epoch 984, 100.0%, avg_loss = 2.9064
# Epoch 985, 100.0%, avg_loss = 2.7599
# Validation Loss: 3.6219
# Epoch 986, 100.0%, avg_loss = 2.8437
# Epoch 987, 100.0%, avg_loss = 2.8627
# Epoch 988, 100.0%, avg_loss = 2.8877
# Epoch 989, 100.0%, avg_loss = 2.9078
# Epoch 990, 100.0%, avg_loss = 2.8461
# Validation Loss: 3.6062
# Epoch 991, 100.0%, avg_loss = 2.8667
# Epoch 992, 100.0%, avg_loss = 2.6930
# Epoch 993, 100.0%, avg_loss = 2.8959
# Epoch 994, 100.0%, avg_loss = 2.7066
# Epoch 995, 100.0%, avg_loss = 2.8576
# Validation Loss: 3.6085
# Epoch 996, 100.0%, avg_loss = 2.7692
# Epoch 997, 100.0%, avg_loss = 2.7145
# Epoch 998, 100.0%, avg_loss = 2.8472
# Epoch 999, 100.0%, avg_loss = 2.7870
# Epoch 1000, 100.0%, avg_loss = 2.8479
# Validation Loss: 3.5962
# Epoch 1001, 100.0%, avg_loss = 2.7517
# Epoch 1002, 100.0%, avg_loss = 2.8345
# Epoch 1003, 100.0%, avg_loss = 2.8378
# Epoch 1004, 100.0%, avg_loss = 2.8620
# Epoch 1005, 100.0%, avg_loss = 2.7365
# Validation Loss: 3.5840
# Epoch 1006, 100.0%, avg_loss = 2.7810
# Epoch 1007, 100.0%, avg_loss = 2.8891
# Epoch 1008, 100.0%, avg_loss = 2.7588
# Epoch 1009, 100.0%, avg_loss = 2.7812
# Epoch 1010, 100.0%, avg_loss = 2.7222
# Validation Loss: 3.5899
# Epoch 1011, 100.0%, avg_loss = 2.7845
# Epoch 1012, 100.0%, avg_loss = 2.8367
# Epoch 1013, 100.0%, avg_loss = 2.9119
# Epoch 1014, 100.0%, avg_loss = 2.7588
# Epoch 1015, 100.0%, avg_loss = 2.7891
# Validation Loss: 3.5417
# Epoch 1016, 100.0%, avg_loss = 2.7394
# Epoch 1017, 100.0%, avg_loss = 2.8291
# Epoch 1018, 100.0%, avg_loss = 2.8254
# Epoch 1019, 100.0%, avg_loss = 2.7008
# Epoch 1020, 100.0%, avg_loss = 2.7898
# Validation Loss: 3.5481
# Epoch 1021, 100.0%, avg_loss = 2.6768
# Epoch 1022, 100.0%, avg_loss = 2.9442
# Epoch 1023, 100.0%, avg_loss = 2.8142
# Epoch 1024, 100.0%, avg_loss = 2.8199
# Epoch 1025, 100.0%, avg_loss = 2.7850
# Validation Loss: 3.5403
# Epoch 1026, 100.0%, avg_loss = 2.7760
# Epoch 1027, 100.0%, avg_loss = 2.8525
# Epoch 1028, 100.0%, avg_loss = 2.8176
# Epoch 1029, 100.0%, avg_loss = 2.8639
# Epoch 1030, 100.0%, avg_loss = 2.7146
# Validation Loss: 3.5537
# Epoch 1031, 100.0%, avg_loss = 2.9019
# Epoch 1032, 100.0%, avg_loss = 2.6705
# Epoch 1033, 100.0%, avg_loss = 2.7284
# Epoch 1034, 100.0%, avg_loss = 2.8283
# Epoch 1035, 100.0%, avg_loss = 2.7868
# Validation Loss: 3.5313
# Epoch 1036, 100.0%, avg_loss = 2.7580
# Epoch 1037, 100.0%, avg_loss = 2.8014
# Epoch 1038, 100.0%, avg_loss = 2.8835
# Epoch 1039, 100.0%, avg_loss = 2.7371
# Epoch 1040, 100.0%, avg_loss = 2.7061
# Validation Loss: 3.4982
# Epoch 1041, 100.0%, avg_loss = 2.7010
# Epoch 1042, 100.0%, avg_loss = 2.8095
# Epoch 1043, 100.0%, avg_loss = 2.8231
# Epoch 1044, 100.0%, avg_loss = 2.9240
# Epoch 1045, 100.0%, avg_loss = 2.8388
# Validation Loss: 3.5117
# Epoch 1046, 100.0%, avg_loss = 2.7962
# Epoch 1047, 100.0%, avg_loss = 2.7313
# Epoch 1048, 100.0%, avg_loss = 2.7442
# Epoch 1049, 100.0%, avg_loss = 2.8731
# Epoch 1050, 100.0%, avg_loss = 2.7428
# Validation Loss: 3.5267
# Epoch 1051, 100.0%, avg_loss = 2.7839
# Epoch 1052, 100.0%, avg_loss = 2.7108
# Epoch 1053, 100.0%, avg_loss = 2.6956
# Epoch 1054, 100.0%, avg_loss = 2.7314
# Epoch 1055, 100.0%, avg_loss = 2.7650
# Validation Loss: 3.4881
# Epoch 1056, 100.0%, avg_loss = 2.8083
# Epoch 1057, 100.0%, avg_loss = 2.8449
# Epoch 1058, 100.0%, avg_loss = 2.7429
# Epoch 1059, 100.0%, avg_loss = 2.7796
# Epoch 1060, 100.0%, avg_loss = 2.8094
# Validation Loss: 3.5147
# Epoch 1061, 100.0%, avg_loss = 2.7695
# Epoch 1062, 100.0%, avg_loss = 2.7919
# Epoch 1063, 100.0%, avg_loss = 2.7639
# Epoch 1064, 100.0%, avg_loss = 2.8135
# Epoch 1065, 100.0%, avg_loss = 2.7795
# Validation Loss: 3.4619
# Epoch 1066, 100.0%, avg_loss = 2.6926
# Epoch 1067, 100.0%, avg_loss = 2.8690
# Epoch 1068, 100.0%, avg_loss = 2.7388
# Epoch 1069, 100.0%, avg_loss = 2.7766
# Epoch 1070, 100.0%, avg_loss = 2.7892
# Validation Loss: 3.4787
# Epoch 1071, 100.0%, avg_loss = 2.8655
# Epoch 1072, 100.0%, avg_loss = 2.7884
# Epoch 1073, 100.0%, avg_loss = 2.8515
# Epoch 1074, 100.0%, avg_loss = 2.8324
# Epoch 1075, 100.0%, avg_loss = 2.8384
# Validation Loss: 3.4533
# Epoch 1076, 100.0%, avg_loss = 2.7228
# Epoch 1077, 100.0%, avg_loss = 2.7855
# Epoch 1078, 100.0%, avg_loss = 2.8278
# Epoch 1079, 100.0%, avg_loss = 2.7863
# Epoch 1080, 100.0%, avg_loss = 2.6708
# Validation Loss: 3.4537
# Epoch 1081, 100.0%, avg_loss = 2.5994
# Epoch 1082, 100.0%, avg_loss = 2.8421
# Epoch 1083, 100.0%, avg_loss = 2.7546
# Epoch 1084, 100.0%, avg_loss = 2.9072
# Epoch 1085, 100.0%, avg_loss = 2.7328
# Validation Loss: 3.4214
# Epoch 1086, 100.0%, avg_loss = 2.7883
# Epoch 1087, 100.0%, avg_loss = 2.8136
# Epoch 1088, 100.0%, avg_loss = 2.7785
# Epoch 1089, 100.0%, avg_loss = 2.7318
# Epoch 1090, 100.0%, avg_loss = 2.8396
# Validation Loss: 3.3949
# Epoch 1091, 100.0%, avg_loss = 2.7140
# Epoch 1092, 100.0%, avg_loss = 2.7229
# Epoch 1093, 100.0%, avg_loss = 2.7462
# Epoch 1094, 100.0%, avg_loss = 2.7381
# Epoch 1095, 100.0%, avg_loss = 2.7478
# Validation Loss: 3.4399
# Epoch 1096, 100.0%, avg_loss = 2.7184
# Epoch 1097, 100.0%, avg_loss = 2.6162
# Epoch 1098, 100.0%, avg_loss = 2.8745
# Epoch 1099, 100.0%, avg_loss = 2.7770
# Epoch 1100, 100.0%, avg_loss = 2.7599
# Validation Loss: 3.4183
# Epoch 1101, 100.0%, avg_loss = 2.8534
# Epoch 1102, 100.0%, avg_loss = 2.7359
# Epoch 1103, 100.0%, avg_loss = 2.7451
# Epoch 1104, 100.0%, avg_loss = 2.7581
# Epoch 1105, 100.0%, avg_loss = 2.7720
# Validation Loss: 3.4178
# Epoch 1106, 100.0%, avg_loss = 2.8312
# Epoch 1107, 100.0%, avg_loss = 2.7209
# Epoch 1108, 100.0%, avg_loss = 2.7253
# Epoch 1109, 100.0%, avg_loss = 2.7899
# Epoch 1110, 100.0%, avg_loss = 2.6006
# Validation Loss: 3.4168
# Epoch 1111, 100.0%, avg_loss = 2.7235
# Epoch 1112, 100.0%, avg_loss = 2.7468
# Epoch 1113, 100.0%, avg_loss = 2.6722
# Epoch 1114, 100.0%, avg_loss = 2.7144
# Epoch 1115, 100.0%, avg_loss = 2.8873
# Validation Loss: 3.4012
# Epoch 1116, 100.0%, avg_loss = 2.7930
# Epoch 1117, 100.0%, avg_loss = 2.6517
# Epoch 1118, 100.0%, avg_loss = 2.8123
# Epoch 1119, 100.0%, avg_loss = 2.7152
# Epoch 1120, 100.0%, avg_loss = 2.6809
# Validation Loss: 3.3717
# Epoch 1121, 100.0%, avg_loss = 2.7402
# Epoch 1122, 100.0%, avg_loss = 2.6877
# Epoch 1123, 100.0%, avg_loss = 2.6946
# Epoch 1124, 100.0%, avg_loss = 2.5996
# Epoch 1125, 100.0%, avg_loss = 2.7253
# Validation Loss: 3.3791
# Epoch 1126, 100.0%, avg_loss = 2.6972
# Epoch 1127, 100.0%, avg_loss = 2.6803
# Epoch 1128, 100.0%, avg_loss = 2.7677
# Epoch 1129, 100.0%, avg_loss = 2.8552
# Epoch 1130, 100.0%, avg_loss = 2.7824
# Validation Loss: 3.3920
# Epoch 1131, 100.0%, avg_loss = 2.5872
# Epoch 1132, 100.0%, avg_loss = 2.8204
# Epoch 1133, 100.0%, avg_loss = 2.7820
# Epoch 1134, 100.0%, avg_loss = 2.6812
# Epoch 1135, 100.0%, avg_loss = 2.6057
# Validation Loss: 3.3633
# Epoch 1136, 100.0%, avg_loss = 2.7980
# Epoch 1137, 100.0%, avg_loss = 2.8146
# Epoch 1138, 100.0%, avg_loss = 2.6408
# Epoch 1139, 100.0%, avg_loss = 2.8211
# Epoch 1140, 100.0%, avg_loss = 2.6313
# Validation Loss: 3.3635
# Epoch 1141, 100.0%, avg_loss = 2.7133
# Epoch 1142, 100.0%, avg_loss = 2.7292
# Epoch 1143, 100.0%, avg_loss = 2.6592
# Epoch 1144, 100.0%, avg_loss = 2.7578
# Epoch 1145, 100.0%, avg_loss = 2.6744
# Validation Loss: 3.3623
# Epoch 1146, 100.0%, avg_loss = 2.6413
# Epoch 1147, 100.0%, avg_loss = 2.7508
# ...
# Epoch 3628, 100.0%, avg_loss = 2.2120
# Epoch 3629, 100.0%, avg_loss = 2.2194
# Epoch 3630, 100.0%, avg_loss = 2.1174
# Validation Loss: 2.2207
# Epoch 3631, 100.0%, avg_loss = 2.3307
# Epoch 3632, 100.0%, avg_loss = 2.2613
# Epoch 3633, 100.0%, avg_loss = 2.1780
# Epoch 3634, 100.0%, avg_loss = 2.2536
# Epoch 3635, 100.0%, avg_loss = 2.1886
# Validation Loss: 2.2072
# Epoch 3636, 100.0%, avg_loss = 2.1946
# Epoch 3637, 100.0%, avg_loss = 2.1522
# Epoch 3638, 100.0%, avg_loss = 2.0809
# Epoch 3639, 100.0%, avg_loss = 2.2656
# Epoch 3640, 100.0%, avg_loss = 2.2218
# Validation Loss: 2.1976
# Epoch 3641, 100.0%, avg_loss = 2.2519
# Epoch 3642, 100.0%, avg_loss = 2.2428
# Epoch 3643, 100.0%, avg_loss = 2.2577
# Epoch 3644, 100.0%, avg_loss = 2.1945
# Epoch 3645, 100.0%, avg_loss = 2.2275
# Validation Loss: 2.2291
# Epoch 3646, 100.0%, avg_loss = 2.2928
# Epoch 3647, 100.0%, avg_loss = 2.2409
# Epoch 3648, 100.0%, avg_loss = 2.1547
# Epoch 3649, 100.0%, avg_loss = 2.1909
# Epoch 3650, 100.0%, avg_loss = 2.2051
# Validation Loss: 2.2186
# Epoch 3651, 100.0%, avg_loss = 2.2563
# Epoch 3652, 100.0%, avg_loss = 2.2166
# Epoch 3653, 100.0%, avg_loss = 2.2245
# Epoch 3654, 100.0%, avg_loss = 2.3188
# Epoch 3655, 100.0%, avg_loss = 2.2514
# Validation Loss: 2.2122
# Epoch 3656, 100.0%, avg_loss = 2.2267
# Epoch 3657, 100.0%, avg_loss = 2.2535
# Epoch 3658, 100.0%, avg_loss = 2.3367
# Epoch 3659, 100.0%, avg_loss = 2.2860
# Epoch 3660, 100.0%, avg_loss = 2.2459
# Validation Loss: 2.2453
# Epoch 3661, 100.0%, avg_loss = 2.2195
# Epoch 3662, 100.0%, avg_loss = 2.3144
# Epoch 3663, 100.0%, avg_loss = 2.3434
# Epoch 3664, 100.0%, avg_loss = 2.1782
# Epoch 3665, 100.0%, avg_loss = 2.1515
# Validation Loss: 2.2580
# Epoch 3666, 100.0%, avg_loss = 2.2277
# Epoch 3667, 100.0%, avg_loss = 2.1730
# Epoch 3668, 100.0%, avg_loss = 2.2646
# Epoch 3669, 100.0%, avg_loss = 2.1669
# Epoch 3670, 100.0%, avg_loss = 2.3647
# Validation Loss: 2.2070
# Epoch 3671, 100.0%, avg_loss = 2.1847
# Epoch 3672, 100.0%, avg_loss = 2.2734
# Epoch 3673, 100.0%, avg_loss = 2.2999
# Epoch 3674, 100.0%, avg_loss = 2.2079
# Epoch 3675, 100.0%, avg_loss = 2.0325
# Validation Loss: 2.2207
# Epoch 3676, 100.0%, avg_loss = 2.1999
# Epoch 3677, 100.0%, avg_loss = 2.2475
# Epoch 3678, 100.0%, avg_loss = 2.1759
# Epoch 3679, 100.0%, avg_loss = 2.2018
# Epoch 3680, 100.0%, avg_loss = 2.1566
# Validation Loss: 2.2228
# Epoch 3681, 100.0%, avg_loss = 2.2478
# Epoch 3682, 100.0%, avg_loss = 2.2811
# Epoch 3683, 100.0%, avg_loss = 2.2441
# Epoch 3684, 100.0%, avg_loss = 2.1907
# Epoch 3685, 100.0%, avg_loss = 2.2135
# Validation Loss: 2.1936
# Epoch 3686, 100.0%, avg_loss = 2.1976
# Epoch 3687, 100.0%, avg_loss = 2.2485
# Epoch 3688, 100.0%, avg_loss = 2.2575
# Epoch 3689, 100.0%, avg_loss = 2.1382
# Epoch 3690, 100.0%, avg_loss = 2.3606
# Validation Loss: 2.1996
# Epoch 3691, 100.0%, avg_loss = 2.3074
# Epoch 3692, 100.0%, avg_loss = 2.2262
# Epoch 3693, 100.0%, avg_loss = 2.3462
# Epoch 3694, 100.0%, avg_loss = 2.3199
# Epoch 3695, 100.0%, avg_loss = 2.2199
# Validation Loss: 2.2044
# Epoch 3696, 100.0%, avg_loss = 2.2654
# Epoch 3697, 100.0%, avg_loss = 2.2844
# Epoch 3698, 100.0%, avg_loss = 2.2420
# Epoch 3699, 100.0%, avg_loss = 2.2609
# Epoch 3700, 100.0%, avg_loss = 2.2095
# Validation Loss: 2.2308
# Epoch 3701, 100.0%, avg_loss = 2.1566
# Epoch 3702, 100.0%, avg_loss = 2.2149
# Epoch 3703, 100.0%, avg_loss = 2.2125
# Epoch 3704, 100.0%, avg_loss = 2.1631
# Epoch 3705, 100.0%, avg_loss = 2.2834
# Validation Loss: 2.2035
# Epoch 3706, 100.0%, avg_loss = 2.2652
# Epoch 3707, 100.0%, avg_loss = 2.2667
# Epoch 3708, 100.0%, avg_loss = 2.2818
# Epoch 3709, 100.0%, avg_loss = 2.2120
# Epoch 3710, 100.0%, avg_loss = 2.2339
# Validation Loss: 2.1993
# Epoch 3711, 100.0%, avg_loss = 2.1742
# Epoch 3712, 100.0%, avg_loss = 2.3382
# Epoch 3713, 100.0%, avg_loss = 2.1817
# Epoch 3714, 100.0%, avg_loss = 2.1977
# Epoch 3715, 100.0%, avg_loss = 2.2466
# Validation Loss: 2.2121
# Epoch 3716, 100.0%, avg_loss = 2.1494
# Epoch 3717, 100.0%, avg_loss = 2.2582
# Epoch 3718, 100.0%, avg_loss = 2.1728
# Epoch 3719, 100.0%, avg_loss = 2.3246
# Epoch 3720, 100.0%, avg_loss = 2.1862
# Validation Loss: 2.1974
# Epoch 3721, 100.0%, avg_loss = 2.2959
# Epoch 3722, 100.0%, avg_loss = 2.2331
# Epoch 3723, 100.0%, avg_loss = 2.1478
# Epoch 3724, 100.0%, avg_loss = 2.2564
# Epoch 3725, 100.0%, avg_loss = 2.3267
# Validation Loss: 2.2387
# Epoch 3726, 100.0%, avg_loss = 2.1660
# Epoch 3727, 100.0%, avg_loss = 2.2837
# Epoch 3728, 100.0%, avg_loss = 2.1873
# Epoch 3729, 100.0%, avg_loss = 2.2519
# Epoch 3730, 100.0%, avg_loss = 2.3038
# Validation Loss: 2.2111
# Epoch 3731, 100.0%, avg_loss = 2.2367
# Epoch 3732, 100.0%, avg_loss = 2.2036
# Epoch 3733, 100.0%, avg_loss = 2.2676
# Epoch 3734, 100.0%, avg_loss = 2.1718
# Epoch 3735, 100.0%, avg_loss = 2.1575
# Validation Loss: 2.2056
# Epoch 3736, 100.0%, avg_loss = 2.2385
# Epoch 3737, 100.0%, avg_loss = 2.2572
# Epoch 3738, 100.0%, avg_loss = 2.2124
# Epoch 3739, 100.0%, avg_loss = 2.2152
# Epoch 3740, 100.0%, avg_loss = 2.1841
# Validation Loss: 2.1952
# Epoch 3741, 100.0%, avg_loss = 2.2754
# Epoch 3742, 100.0%, avg_loss = 2.2937
# Epoch 3743, 100.0%, avg_loss = 2.2531
# Epoch 3744, 100.0%, avg_loss = 2.2988
# Epoch 3745, 100.0%, avg_loss = 2.2221
# Validation Loss: 2.2133
# Epoch 3746, 100.0%, avg_loss = 2.1237
# Epoch 3747, 100.0%, avg_loss = 2.2732
# Epoch 3748, 100.0%, avg_loss = 2.2285
# Epoch 3749, 100.0%, avg_loss = 2.3167
# Epoch 3750, 100.0%, avg_loss = 2.2688
# Validation Loss: 2.1763
# Epoch 3751, 100.0%, avg_loss = 2.1488
# Epoch 3752, 100.0%, avg_loss = 2.1581
# Epoch 3753, 100.0%, avg_loss = 2.2688
# Epoch 3754, 100.0%, avg_loss = 2.2561
# Epoch 3755, 100.0%, avg_loss = 2.1383
# Validation Loss: 2.2028
# Epoch 3756, 100.0%, avg_loss = 2.1978
# Epoch 3757, 100.0%, avg_loss = 2.1976
# Epoch 3758, 100.0%, avg_loss = 2.2372
# Epoch 3759, 100.0%, avg_loss = 2.2963
# Epoch 3760, 100.0%, avg_loss = 2.2076
# Validation Loss: 2.1897
# Epoch 3761, 100.0%, avg_loss = 2.1614
# Epoch 3762, 100.0%, avg_loss = 2.0774
# Epoch 3763, 100.0%, avg_loss = 2.0869
# Epoch 3764, 100.0%, avg_loss = 2.2462
# Epoch 3765, 100.0%, avg_loss = 2.2679
# Validation Loss: 2.1993
# Epoch 3766, 100.0%, avg_loss = 2.1665
# Epoch 3767, 100.0%, avg_loss = 2.3057
# Epoch 3768, 100.0%, avg_loss = 2.3577
# Epoch 3769, 100.0%, avg_loss = 2.2831
# Epoch 3770, 100.0%, avg_loss = 2.2312
# Validation Loss: 2.2032
# Epoch 3771, 100.0%, avg_loss = 2.2794
# Epoch 3772, 100.0%, avg_loss = 2.2096
# Epoch 3773, 100.0%, avg_loss = 2.2511
# Epoch 3774, 100.0%, avg_loss = 2.2199
# Epoch 3775, 100.0%, avg_loss = 2.2414
# Validation Loss: 2.2147
# Epoch 3776, 100.0%, avg_loss = 2.1610
# Epoch 3777, 100.0%, avg_loss = 2.1745
# Epoch 3778, 100.0%, avg_loss = 2.1502
# Epoch 3779, 100.0%, avg_loss = 2.2425
# Epoch 3780, 100.0%, avg_loss = 2.1325
# Validation Loss: 2.1976
# Epoch 3781, 100.0%, avg_loss = 2.2620
# Epoch 3782, 100.0%, avg_loss = 2.1910
# Epoch 3783, 100.0%, avg_loss = 2.2941
# Epoch 3784, 100.0%, avg_loss = 2.2388
# Epoch 3785, 100.0%, avg_loss = 2.1826
# Validation Loss: 2.1688
# Epoch 3786, 100.0%, avg_loss = 2.2012
# Epoch 3787, 100.0%, avg_loss = 2.3669
# Epoch 3788, 100.0%, avg_loss = 2.3155
# Epoch 3789, 100.0%, avg_loss = 2.1331
# Epoch 3790, 100.0%, avg_loss = 2.2368
# Validation Loss: 2.1805
# Epoch 3791, 100.0%, avg_loss = 2.2619
# Epoch 3792, 100.0%, avg_loss = 2.2448
# Epoch 3793, 100.0%, avg_loss = 1.9908
# Epoch 3794, 100.0%, avg_loss = 2.1768
# Epoch 3795, 100.0%, avg_loss = 2.2668
# Validation Loss: 2.2035
# Epoch 3796, 100.0%, avg_loss = 2.2802
# Epoch 3797, 100.0%, avg_loss = 2.2257
# Epoch 3798, 100.0%, avg_loss = 2.1732
# Epoch 3799, 100.0%, avg_loss = 2.2672
# Epoch 3800, 100.0%, avg_loss = 2.2232
# Validation Loss: 2.2108
# Epoch 3801, 100.0%, avg_loss = 2.1990
# Epoch 3802, 100.0%, avg_loss = 2.1909
# Epoch 3803, 100.0%, avg_loss = 2.2482
# Epoch 3804, 100.0%, avg_loss = 2.1734
# Epoch 3805, 100.0%, avg_loss = 2.1318
# Validation Loss: 2.1975
# Epoch 3806, 100.0%, avg_loss = 2.1531
# Epoch 3807, 100.0%, avg_loss = 2.1657
# Epoch 3808, 100.0%, avg_loss = 2.2165
# Epoch 3809, 100.0%, avg_loss = 2.2001
# Epoch 3810, 100.0%, avg_loss = 2.2491
# Validation Loss: 2.1886
# Epoch 3811, 100.0%, avg_loss = 2.2957
# Epoch 3812, 100.0%, avg_loss = 2.2831
# Epoch 3813, 100.0%, avg_loss = 2.0886
# Epoch 3814, 100.0%, avg_loss = 2.2665
# Epoch 3815, 100.0%, avg_loss = 2.3822
# Validation Loss: 2.1960
# Epoch 3816, 100.0%, avg_loss = 2.1504
# Epoch 3817, 100.0%, avg_loss = 2.2781
# Epoch 3818, 100.0%, avg_loss = 2.2943
# Epoch 3819, 100.0%, avg_loss = 2.2205
# Epoch 3820, 100.0%, avg_loss = 2.2453
# Validation Loss: 2.2032
# Epoch 3821, 100.0%, avg_loss = 2.1345
# Epoch 3822, 100.0%, avg_loss = 2.1478
# Epoch 3823, 100.0%, avg_loss = 2.2437
# Epoch 3824, 100.0%, avg_loss = 2.3020
# Epoch 3825, 100.0%, avg_loss = 2.3182
# Validation Loss: 2.1740
# Epoch 3826, 100.0%, avg_loss = 2.3173
# Epoch 3827, 100.0%, avg_loss = 2.1705
# Epoch 3828, 100.0%, avg_loss = 2.1610
# Epoch 3829, 100.0%, avg_loss = 2.1886
# Epoch 3830, 100.0%, avg_loss = 2.1858
# Validation Loss: 2.2322
# Epoch 3831, 100.0%, avg_loss = 2.2250
# Epoch 3832, 100.0%, avg_loss = 2.2862
# Epoch 3833, 100.0%, avg_loss = 2.2620
# Epoch 3834, 100.0%, avg_loss = 2.1625
# Epoch 3835, 100.0%, avg_loss = 2.2832
# Validation Loss: 2.2192
# Epoch 3836, 100.0%, avg_loss = 2.2912
# Epoch 3837, 100.0%, avg_loss = 2.1397
# Epoch 3838, 100.0%, avg_loss = 2.1407
# Epoch 3839, 100.0%, avg_loss = 2.1208
# Epoch 3840, 100.0%, avg_loss = 2.1500
# Validation Loss: 2.2133
# Epoch 3841, 100.0%, avg_loss = 2.1454
# Epoch 3842, 100.0%, avg_loss = 2.1939
# Epoch 3843, 100.0%, avg_loss = 2.2574
# Epoch 3844, 100.0%, avg_loss = 2.1810
# Epoch 3845, 100.0%, avg_loss = 2.3200
# Validation Loss: 2.1918
# Epoch 3846, 100.0%, avg_loss = 2.2553
# Epoch 3847, 100.0%, avg_loss = 2.0442
# Epoch 3848, 100.0%, avg_loss = 2.1499
# Epoch 3849, 100.0%, avg_loss = 2.1547
# Epoch 3850, 100.0%, avg_loss = 2.1192
# Validation Loss: 2.1677
# Epoch 3851, 100.0%, avg_loss = 2.0809
# Epoch 3852, 100.0%, avg_loss = 2.2420
# Epoch 3853, 100.0%, avg_loss = 2.2519
# Epoch 3854, 100.0%, avg_loss = 2.0952
# Epoch 3855, 100.0%, avg_loss = 2.2272
# Validation Loss: 2.1837
# Epoch 3856, 100.0%, avg_loss = 2.2349
# Epoch 3857, 100.0%, avg_loss = 2.1729
# Epoch 3858, 100.0%, avg_loss = 2.0730
# Epoch 3859, 100.0%, avg_loss = 2.1432
# Epoch 3860, 100.0%, avg_loss = 2.1033
# Validation Loss: 2.1724
# Epoch 3861, 100.0%, avg_loss = 2.2835
# Epoch 3862, 100.0%, avg_loss = 2.2606
# Epoch 3863, 100.0%, avg_loss = 2.1391
# Epoch 3864, 100.0%, avg_loss = 2.2591
# Epoch 3865, 100.0%, avg_loss = 2.2730
# Validation Loss: 2.1792
# Epoch 3866, 100.0%, avg_loss = 2.1698
# Epoch 3867, 100.0%, avg_loss = 2.1615
# Epoch 3868, 100.0%, avg_loss = 2.2185
# Epoch 3869, 100.0%, avg_loss = 2.1407
# Epoch 3870, 100.0%, avg_loss = 2.3629
# Validation Loss: 2.1736
# Epoch 3871, 100.0%, avg_loss = 2.1708
# Epoch 3872, 100.0%, avg_loss = 2.2316
# Epoch 3873, 100.0%, avg_loss = 2.1873
# Epoch 3874, 100.0%, avg_loss = 2.2974
# Epoch 3875, 100.0%, avg_loss = 2.1052
# Validation Loss: 2.2049
# Epoch 3876, 100.0%, avg_loss = 2.2285
# Epoch 3877, 100.0%, avg_loss = 2.2866
# Epoch 3878, 100.0%, avg_loss = 2.1680
# Epoch 3879, 100.0%, avg_loss = 2.1015
# Epoch 3880, 100.0%, avg_loss = 2.2545
# Validation Loss: 2.2381
# Epoch 3881, 100.0%, avg_loss = 2.2086
# Epoch 3882, 100.0%, avg_loss = 2.3146
# Epoch 3883, 100.0%, avg_loss = 2.3043
# Epoch 3884, 100.0%, avg_loss = 2.0626
# Epoch 3885, 100.0%, avg_loss = 2.1473
# Validation Loss: 2.2004
# Epoch 3886, 100.0%, avg_loss = 2.0679
# Epoch 3887, 100.0%, avg_loss = 2.2328
# Epoch 3888, 100.0%, avg_loss = 2.1738
# Epoch 3889, 100.0%, avg_loss = 2.1749
# Epoch 3890, 100.0%, avg_loss = 2.2506
# Validation Loss: 2.1704
# Epoch 3891, 100.0%, avg_loss = 2.3467
# Epoch 3892, 100.0%, avg_loss = 2.2918
# Epoch 3893, 100.0%, avg_loss = 2.1188
# Epoch 3894, 100.0%, avg_loss = 2.2478
# Epoch 3895, 100.0%, avg_loss = 2.2665
# Validation Loss: 2.1977
# Epoch 3896, 100.0%, avg_loss = 2.2680
# Epoch 3897, 100.0%, avg_loss = 2.2724
# Epoch 3898, 100.0%, avg_loss = 2.2310
# Epoch 3899, 100.0%, avg_loss = 2.1514
# Epoch 3900, 100.0%, avg_loss = 2.3295
# Validation Loss: 2.1543
# Epoch 3901, 100.0%, avg_loss = 2.2649
# Epoch 3902, 100.0%, avg_loss = 2.1758
# Epoch 3903, 100.0%, avg_loss = 2.2025
# Epoch 3904, 100.0%, avg_loss = 2.1719
# Epoch 3905, 100.0%, avg_loss = 2.2602
# Validation Loss: 2.1756
# Epoch 3906, 100.0%, avg_loss = 2.1589
# Epoch 3907, 100.0%, avg_loss = 2.2168
# Epoch 3908, 100.0%, avg_loss = 2.2882
# Epoch 3909, 100.0%, avg_loss = 2.2123
# Epoch 3910, 100.0%, avg_loss = 2.2303
# Validation Loss: 2.1670
# Epoch 3911, 100.0%, avg_loss = 2.1533
# Epoch 3912, 100.0%, avg_loss = 2.1346
# Epoch 3913, 100.0%, avg_loss = 2.1889
# Epoch 3914, 100.0%, avg_loss = 2.1748
# Epoch 3915, 100.0%, avg_loss = 2.2263
# Validation Loss: 2.1452
# Epoch 3916, 100.0%, avg_loss = 2.2207
# Epoch 3917, 100.0%, avg_loss = 2.1041
# Epoch 3918, 100.0%, avg_loss = 2.0831
# Epoch 3919, 100.0%, avg_loss = 2.2403
# Epoch 3920, 100.0%, avg_loss = 2.2760
# Validation Loss: 2.1843
# Epoch 3921, 100.0%, avg_loss = 2.3169
# Epoch 3922, 100.0%, avg_loss = 2.2369
# Epoch 3923, 100.0%, avg_loss = 2.3509
# Epoch 3924, 100.0%, avg_loss = 2.1820
# Epoch 3925, 100.0%, avg_loss = 2.4468
# Validation Loss: 2.1827
# Epoch 3926, 100.0%, avg_loss = 2.3573
# Epoch 3927, 100.0%, avg_loss = 2.2285
# Epoch 3928, 100.0%, avg_loss = 2.2383
# Epoch 3929, 100.0%, avg_loss = 2.2568
# Epoch 3930, 100.0%, avg_loss = 2.1983
# Validation Loss: 2.1791
# Epoch 3931, 100.0%, avg_loss = 2.1777
# Epoch 3932, 100.0%, avg_loss = 2.0715
# Epoch 3933, 100.0%, avg_loss = 2.2445
# Epoch 3934, 100.0%, avg_loss = 2.2792
# Epoch 3935, 100.0%, avg_loss = 2.2617
# Validation Loss: 2.1541
# Epoch 3936, 100.0%, avg_loss = 2.1928
# Epoch 3937, 100.0%, avg_loss = 2.1714
# Epoch 3938, 100.0%, avg_loss = 2.1641
# Epoch 3939, 100.0%, avg_loss = 2.2038
# Epoch 3940, 100.0%, avg_loss = 2.1432
# Validation Loss: 2.1982
# Epoch 3941, 100.0%, avg_loss = 2.1326
# Epoch 3942, 100.0%, avg_loss = 2.2386
# Epoch 3943, 100.0%, avg_loss = 2.2499
# Epoch 3944, 100.0%, avg_loss = 2.1754
# Epoch 3945, 100.0%, avg_loss = 2.2532
# Validation Loss: 2.1964
# Epoch 3946, 100.0%, avg_loss = 2.1998
# Epoch 3947, 100.0%, avg_loss = 2.3340
# Epoch 3948, 100.0%, avg_loss = 2.1427
# Epoch 3949, 100.0%, avg_loss = 2.1644
# Epoch 3950, 100.0%, avg_loss = 2.2656
# Validation Loss: 2.1926
# Epoch 3951, 100.0%, avg_loss = 2.2963
# Epoch 3952, 100.0%, avg_loss = 2.1759
# Epoch 3953, 100.0%, avg_loss = 2.2669
# Epoch 3954, 100.0%, avg_loss = 2.2845
# Epoch 3955, 100.0%, avg_loss = 2.0990
# Validation Loss: 2.2097
# Epoch 3956, 100.0%, avg_loss = 2.1703
# Epoch 3957, 100.0%, avg_loss = 2.1119
# Epoch 3958, 100.0%, avg_loss = 2.1899
# Epoch 3959, 100.0%, avg_loss = 2.1515
# Epoch 3960, 100.0%, avg_loss = 2.1599
# Validation Loss: 2.1601
# Epoch 3961, 100.0%, avg_loss = 2.2803
# Epoch 3962, 100.0%, avg_loss = 2.2895
# Epoch 3963, 100.0%, avg_loss = 2.1622
# Epoch 3964, 100.0%, avg_loss = 2.2505
# Epoch 3965, 100.0%, avg_loss = 2.1606
# Validation Loss: 2.2096
# Epoch 3966, 100.0%, avg_loss = 2.2193
# Epoch 3967, 100.0%, avg_loss = 2.1629
# Epoch 3968, 100.0%, avg_loss = 2.2145
# Epoch 3969, 100.0%, avg_loss = 2.1904
# Epoch 3970, 100.0%, avg_loss = 2.1284
# Validation Loss: 2.1647
# Epoch 3971, 100.0%, avg_loss = 2.2879
# Epoch 3972, 100.0%, avg_loss = 2.2850
# Epoch 3973, 100.0%, avg_loss = 2.0498
# Epoch 3974, 100.0%, avg_loss = 2.2777
# Epoch 3975, 100.0%, avg_loss = 2.2772
# Validation Loss: 2.1678
# Epoch 3976, 100.0%, avg_loss = 2.2534
# Epoch 3977, 100.0%, avg_loss = 2.2836
# Epoch 3978, 100.0%, avg_loss = 2.2570
# Epoch 3979, 100.0%, avg_loss = 2.1441
# Epoch 3980, 100.0%, avg_loss = 2.1548
# Validation Loss: 2.1765
# Epoch 3981, 100.0%, avg_loss = 2.2965
# Epoch 3982, 100.0%, avg_loss = 2.2828
# Epoch 3983, 100.0%, avg_loss = 2.1919
# Epoch 3984, 100.0%, avg_loss = 2.2240
# Epoch 3985, 100.0%, avg_loss = 2.2639
# Validation Loss: 2.2059
# Epoch 3986, 100.0%, avg_loss = 2.1764
# Epoch 3987, 100.0%, avg_loss = 2.2590
# Epoch 3988, 100.0%, avg_loss = 2.1410
# Epoch 3989, 100.0%, avg_loss = 2.1676
# Epoch 3990, 100.0%, avg_loss = 2.2231
# Validation Loss: 2.1831
# Epoch 3991, 100.0%, avg_loss = 2.3061
# Epoch 3992, 100.0%, avg_loss = 2.2675
# Epoch 3993, 100.0%, avg_loss = 2.1570
# Epoch 3994, 100.0%, avg_loss = 2.1504
# Epoch 3995, 100.0%, avg_loss = 2.0871
# Validation Loss: 2.1774
# Epoch 3996, 100.0%, avg_loss = 2.2674
# Epoch 3997, 100.0%, avg_loss = 2.1767
# Epoch 3998, 100.0%, avg_loss = 2.2077
# Epoch 3999, 100.0%, avg_loss = 2.1461
# Epoch 4000, 100.0%, avg_loss = 2.2312
# Validation Loss: 2.1138

# %%
torch.save(global_predictor, './results_tokyo/global_predictor_fl_fedavg.pytorch')

# %%
with open('./results_tokyo/global_predictor_fl_fedavg_training_loss.pk', 'wb') as f:
    pk.dump(training_loss, f)
with open('./results_tokyo/global_predictor_fl_fedavg_validation_loss.pk', 'wb') as f:
    pk.dump(validation_loss, f)
