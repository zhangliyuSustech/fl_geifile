# %%
import torch
import torch.nn as nn
import pickle as pk
import numpy as np
from model import GlobalPredictor
import random

# %%
data = dict({})
for d in range(15, 29):
    filename = '/data/fan/UsersInOsakaProcessed/201210{:02d}_interp.pk'.format(d)
    print(filename)
    with open(filename, 'rb') as f:
        data[d] = pk.load(f)
# Out:
# /data/fan/UsersInOsakaProcessed/20121015_interp.pk
# /data/fan/UsersInOsakaProcessed/20121016_interp.pk
# /data/fan/UsersInOsakaProcessed/20121017_interp.pk
# /data/fan/UsersInOsakaProcessed/20121018_interp.pk
# /data/fan/UsersInOsakaProcessed/20121019_interp.pk
# /data/fan/UsersInOsakaProcessed/20121020_interp.pk
# /data/fan/UsersInOsakaProcessed/20121021_interp.pk
# /data/fan/UsersInOsakaProcessed/20121022_interp.pk
# /data/fan/UsersInOsakaProcessed/20121023_interp.pk
# /data/fan/UsersInOsakaProcessed/20121024_interp.pk
# /data/fan/UsersInOsakaProcessed/20121025_interp.pk
# /data/fan/UsersInOsakaProcessed/20121026_interp.pk
# /data/fan/UsersInOsakaProcessed/20121027_interp.pk
# /data/fan/UsersInOsakaProcessed/20121028_interp.pk

# %%
data_qry_train = dict({})
data_qry_test = dict({})

for d in range(15, 22):
    for uid in data[d]:
        if uid not in data_qry_train:
            data_qry_train[uid] = [data[d][uid]]
        else:
            data_qry_train[uid].append(data[d][uid])
            
for d in range(22, 29):
    for uid in data[d]:
        if uid not in data_qry_test:
            data_qry_test[uid] = [data[d][uid]]
        else:
            data_qry_test[uid].append(data[d][uid])

# %%
for uid in data_qry_train:
    data_qry_train[uid] = torch.LongTensor(data_qry_train[uid]).cuda(0)
    
for uid in data_qry_test:
    data_qry_test[uid] = torch.LongTensor(data_qry_test[uid]).cuda(0)

# %%
num_locs = 1600
loc_embedding_dim = 128
T = 96
num_time = T
time_embedding_dim = 32
hidden_dim = 256
latent_dim = 256

# %%
lr = 5e-4
momentum = 0.8

# %%
global_predictor = GlobalPredictor(num_locs, loc_embedding_dim, num_time, time_embedding_dim, hidden_dim, latent_dim).cuda(0)
global_predictor_server = GlobalPredictor(num_locs, loc_embedding_dim, num_time, time_embedding_dim, hidden_dim, latent_dim).cuda(0)
optimizer = torch.optim.SGD(global_predictor.parameters(), lr=lr)

# %%
dT = 4

# %%
training_loss = dict({})
validation_loss = dict({})

# %%
user_list_train = list(data_qry_train.keys())
time_list = list(range(T - 2 * dT + 1))

# Initialize global SGD
global_predictor_update = dict({})
        
for epoch in range(1, 2001):
    
    if epoch % 500 == 0:
        lr *= 0.5
    
    update_user_list = random.sample(user_list_train, 2048)
    random.shuffle(update_user_list)
    
    avg_loss = 0.0
    cnt = 0
    n = 0
    
    uidx = 0
    
    for uid in update_user_list:
        uidx += 1
        # loading server model to local
        global_predictor.load_state_dict(global_predictor_server.state_dict())

        nk = data_qry_train[uid].shape[0]
        n += data_qry_train[uid].shape[0]

        t = np.random.randint(T - 2 * dT + 1)
        x_loc_qry = data_qry_train[uid][:, t: t + dT]
        x_t_qry = torch.zeros_like(x_loc_qry) + t
        y = data_qry_train[uid][:, t + 2 * dT - 1]

        loss = global_predictor(x_loc_qry, x_t_qry, y)
        loss.backward()
        avg_loss += loss.item()
        cnt += nk
        
        with torch.no_grad():
            for name, para in global_predictor.named_parameters():
                if name not in global_predictor_update:
                    global_predictor_update[name] = para.grad * lr
                else:
                    global_predictor_update[name] += para.grad * lr
                
        optimizer.zero_grad()
        
        print('Epoch {:02d}, {:.1f}%, avg_loss = {:.4f}'.format(epoch, uidx * 100 / len(update_user_list), avg_loss / cnt), end='\r')

    # update
    with torch.no_grad():
        for name, para in global_predictor_server.named_parameters():
            para -= global_predictor_update[name]
            
        for name in global_predictor_update:
            global_predictor_update[name] *= momentum
    
    training_loss[epoch] = avg_loss / cnt
    print('')
    # testing
    
    if epoch % 5 == 0:
        with torch.no_grad():

            cnt = 0
            avg_loss = 0.0

            for uid in data_qry_test:

                if np.random.ranf() > 0.05:
                    continue

                nk = data_qry_test[uid].shape[0]

                t = np.random.randint(T - 2 * dT + 1)
                x_loc_qry = data_qry_test[uid][:, t: t + dT]
                x_t_qry = torch.zeros_like(x_loc_qry) + t
                y = data_qry_test[uid][:, t + 2 * dT - 1]

                loss = global_predictor_server(x_loc_qry, x_t_qry, y)

                avg_loss += loss.item()
                cnt += nk

            print('Validation Loss: {:.4f}'.format(avg_loss / cnt))
            validation_loss[epoch] = avg_loss / cnt
# Out:
# Epoch 01, 100.0%, avg_loss = 7.3859
# Epoch 02, 100.0%, avg_loss = 7.3340
# Epoch 03, 100.0%, avg_loss = 7.2415
# Epoch 04, 100.0%, avg_loss = 7.0446
# Epoch 05, 100.0%, avg_loss = 6.9063
# Validation Loss: 6.5875
# Epoch 06, 100.0%, avg_loss = 6.6321
# Epoch 07, 100.0%, avg_loss = 6.3155
# Epoch 08, 100.0%, avg_loss = 6.0075
# Epoch 09, 100.0%, avg_loss = 5.7423
# Epoch 10, 100.0%, avg_loss = 5.2845
# Validation Loss: 4.7598
# Epoch 11, 100.0%, avg_loss = 4.7604
# Epoch 12, 100.0%, avg_loss = 4.4010
# Epoch 13, 100.0%, avg_loss = 4.0416
# Epoch 14, 100.0%, avg_loss = 3.6594
# Epoch 15, 100.0%, avg_loss = 3.4762
# Validation Loss: 3.2698
# Epoch 16, 100.0%, avg_loss = 3.3236
# Epoch 17, 100.0%, avg_loss = 3.1460
# Epoch 18, 100.0%, avg_loss = 3.0412
# Epoch 19, 100.0%, avg_loss = 2.7512
# Epoch 20, 100.0%, avg_loss = 2.8803
# Validation Loss: 2.7592
# Epoch 21, 100.0%, avg_loss = 2.7525
# Epoch 22, 100.0%, avg_loss = 2.5330
# Epoch 23, 100.0%, avg_loss = 2.5063
# Epoch 24, 100.0%, avg_loss = 2.6269
# Epoch 25, 100.0%, avg_loss = 2.5235
# Validation Loss: 2.4415
# Epoch 26, 100.0%, avg_loss = 2.4543
# Epoch 27, 100.0%, avg_loss = 2.2435
# Epoch 28, 100.0%, avg_loss = 2.4312
# Epoch 29, 100.0%, avg_loss = 2.3635
# Epoch 30, 100.0%, avg_loss = 2.4119
# Validation Loss: 2.3325
# Epoch 31, 100.0%, avg_loss = 2.2911
# Epoch 32, 100.0%, avg_loss = 2.3331
# Epoch 33, 100.0%, avg_loss = 2.1397
# Epoch 34, 100.0%, avg_loss = 2.2186
# Epoch 35, 100.0%, avg_loss = 2.2270
# Validation Loss: 2.2492
# Epoch 36, 100.0%, avg_loss = 2.2080
# Epoch 37, 100.0%, avg_loss = 2.2281
# Epoch 38, 100.0%, avg_loss = 2.1997
# Epoch 39, 100.0%, avg_loss = 2.1446
# Epoch 40, 100.0%, avg_loss = 2.2233
# Validation Loss: 2.2867
# Epoch 41, 100.0%, avg_loss = 2.3236
# Epoch 42, 100.0%, avg_loss = 2.2925
# Epoch 43, 100.0%, avg_loss = 2.1709
# Epoch 44, 100.0%, avg_loss = 2.1098
# Epoch 45, 100.0%, avg_loss = 2.2495
# Validation Loss: 2.1615
# Epoch 46, 100.0%, avg_loss = 2.1189
# Epoch 47, 100.0%, avg_loss = 2.1678
# Epoch 48, 100.0%, avg_loss = 2.0752
# Epoch 49, 100.0%, avg_loss = 2.0421
# Epoch 50, 100.0%, avg_loss = 2.0570
# Validation Loss: 2.0787
# Epoch 51, 100.0%, avg_loss = 2.1649
# Epoch 52, 100.0%, avg_loss = 2.1169
# Epoch 53, 100.0%, avg_loss = 2.0455
# Epoch 54, 100.0%, avg_loss = 2.0483
# Epoch 55, 100.0%, avg_loss = 2.0447
# Validation Loss: 2.0640
# Epoch 56, 100.0%, avg_loss = 2.1151
# Epoch 57, 100.0%, avg_loss = 2.0520
# Epoch 58, 100.0%, avg_loss = 2.0044
# Epoch 59, 100.0%, avg_loss = 2.0484
# Epoch 60, 100.0%, avg_loss = 1.9211
# Validation Loss: 1.9938
# Epoch 61, 100.0%, avg_loss = 2.0515
# Epoch 62, 100.0%, avg_loss = 2.0000
# Epoch 63, 100.0%, avg_loss = 2.0412
# Epoch 64, 100.0%, avg_loss = 2.0464
# Epoch 65, 100.0%, avg_loss = 1.9646
# Validation Loss: 2.0672
# Epoch 66, 100.0%, avg_loss = 1.9196
# Epoch 67, 100.0%, avg_loss = 1.9824
# Epoch 68, 100.0%, avg_loss = 2.0391
# Epoch 69, 100.0%, avg_loss = 2.0148
# Epoch 70, 100.0%, avg_loss = 1.9630
# Validation Loss: 1.9147
# Epoch 71, 100.0%, avg_loss = 2.0534
# Epoch 72, 100.0%, avg_loss = 1.9728
# Epoch 73, 100.0%, avg_loss = 2.0021
# Epoch 74, 100.0%, avg_loss = 1.8884
# Epoch 75, 100.0%, avg_loss = 1.9887
# Validation Loss: 2.0317
# Epoch 76, 100.0%, avg_loss = 1.8791
# Epoch 77, 100.0%, avg_loss = 1.9888
# Epoch 78, 100.0%, avg_loss = 1.9059
# Epoch 79, 100.0%, avg_loss = 1.9538
# Epoch 80, 100.0%, avg_loss = 1.9631
# Validation Loss: 1.8697
# Epoch 81, 100.0%, avg_loss = 1.9879
# Epoch 82, 100.0%, avg_loss = 2.0361
# Epoch 83, 100.0%, avg_loss = 1.8862
# Epoch 84, 100.0%, avg_loss = 1.9154
# Epoch 85, 100.0%, avg_loss = 1.9425
# Validation Loss: 1.9416
# Epoch 86, 100.0%, avg_loss = 1.9273
# Epoch 87, 100.0%, avg_loss = 1.8867
# Epoch 88, 100.0%, avg_loss = 1.8945
# Epoch 89, 100.0%, avg_loss = 1.8810
# Epoch 90, 100.0%, avg_loss = 1.9314
# Validation Loss: 1.8990
# Epoch 91, 100.0%, avg_loss = 1.9168
# Epoch 92, 100.0%, avg_loss = 1.9552
# Epoch 93, 100.0%, avg_loss = 1.8863
# Epoch 94, 100.0%, avg_loss = 1.9235
# Epoch 95, 100.0%, avg_loss = 1.9296
# Validation Loss: 1.9694
# Epoch 96, 100.0%, avg_loss = 1.8656
# Epoch 97, 100.0%, avg_loss = 1.8757
# Epoch 98, 100.0%, avg_loss = 1.8497
# Epoch 99, 100.0%, avg_loss = 1.9009
# Epoch 100, 100.0%, avg_loss = 1.8535
# Validation Loss: 1.8378
# Epoch 101, 100.0%, avg_loss = 1.8937
# Epoch 102, 100.0%, avg_loss = 1.8151
# Epoch 103, 100.0%, avg_loss = 1.8785
# Epoch 104, 100.0%, avg_loss = 1.8851
# Epoch 105, 100.0%, avg_loss = 1.9043
# Validation Loss: 1.8909
# Epoch 106, 100.0%, avg_loss = 1.9540
# Epoch 107, 100.0%, avg_loss = 1.9196
# Epoch 108, 100.0%, avg_loss = 1.9107
# Epoch 109, 100.0%, avg_loss = 1.8683
# Epoch 110, 100.0%, avg_loss = 1.8303
# Validation Loss: 1.8844
# Epoch 111, 100.0%, avg_loss = 1.8213
# Epoch 112, 100.0%, avg_loss = 1.8626
# Epoch 113, 100.0%, avg_loss = 1.8747
# Epoch 114, 100.0%, avg_loss = 1.8581
# Epoch 115, 100.0%, avg_loss = 1.9032
# Validation Loss: 1.8092
# Epoch 116, 100.0%, avg_loss = 1.8394
# Epoch 117, 100.0%, avg_loss = 1.8340
# Epoch 118, 100.0%, avg_loss = 2.0143
# Epoch 119, 100.0%, avg_loss = 1.8879
# Epoch 120, 100.0%, avg_loss = 1.9017
# Validation Loss: 1.8035
# Epoch 121, 100.0%, avg_loss = 1.8363
# Epoch 122, 100.0%, avg_loss = 1.7781
# Epoch 123, 100.0%, avg_loss = 1.8409
# Epoch 124, 100.0%, avg_loss = 1.7793
# Epoch 125, 100.0%, avg_loss = 1.8280
# Validation Loss: 1.8007
# Epoch 126, 100.0%, avg_loss = 1.8765
# Epoch 127, 100.0%, avg_loss = 1.8515
# Epoch 128, 100.0%, avg_loss = 1.8575
# Epoch 129, 100.0%, avg_loss = 1.8152
# Epoch 130, 100.0%, avg_loss = 1.8956
# Validation Loss: 1.8737
# Epoch 131, 100.0%, avg_loss = 1.7694
# Epoch 132, 100.0%, avg_loss = 1.8311
# Epoch 133, 100.0%, avg_loss = 1.7267
# Epoch 134, 100.0%, avg_loss = 1.8493
# Epoch 135, 100.0%, avg_loss = 1.8274
# Validation Loss: 1.7836
# Epoch 136, 100.0%, avg_loss = 1.7389
# Epoch 137, 100.0%, avg_loss = 1.8721
# Epoch 138, 100.0%, avg_loss = 1.8395
# Epoch 139, 100.0%, avg_loss = 1.8183
# Epoch 140, 100.0%, avg_loss = 1.7333
# Validation Loss: 1.7930
# Epoch 141, 100.0%, avg_loss = 1.8627
# Epoch 142, 100.0%, avg_loss = 1.8597
# Epoch 143, 100.0%, avg_loss = 1.7396
# Epoch 144, 100.0%, avg_loss = 1.9005
# Epoch 145, 100.0%, avg_loss = 1.8256
# Validation Loss: 1.7770
# Epoch 146, 100.0%, avg_loss = 1.7498
# Epoch 147, 100.0%, avg_loss = 1.7938
# Epoch 148, 100.0%, avg_loss = 1.7634
# Epoch 149, 100.0%, avg_loss = 1.9184
# Epoch 150, 100.0%, avg_loss = 1.8144
# Validation Loss: 1.8762
# Epoch 151, 100.0%, avg_loss = 1.7831
# Epoch 152, 100.0%, avg_loss = 1.8175
# Epoch 153, 100.0%, avg_loss = 1.7979
# Epoch 154, 100.0%, avg_loss = 1.8406
# Epoch 155, 100.0%, avg_loss = 1.7404
# Validation Loss: 1.8210
# Epoch 156, 100.0%, avg_loss = 1.7379
# Epoch 157, 100.0%, avg_loss = 1.8213
# Epoch 158, 100.0%, avg_loss = 1.8239
# Epoch 159, 100.0%, avg_loss = 1.8077
# Epoch 160, 100.0%, avg_loss = 1.8115
# Validation Loss: 1.7939
# Epoch 161, 100.0%, avg_loss = 1.8469
# Epoch 162, 100.0%, avg_loss = 1.8294
# Epoch 163, 100.0%, avg_loss = 1.7926
# Epoch 164, 100.0%, avg_loss = 1.6972
# Epoch 165, 100.0%, avg_loss = 1.7289
# Validation Loss: 1.7518
# Epoch 166, 100.0%, avg_loss = 1.7319
# Epoch 167, 100.0%, avg_loss = 1.6972
# Epoch 168, 100.0%, avg_loss = 1.7930
# Epoch 169, 100.0%, avg_loss = 1.8163
# Epoch 170, 100.0%, avg_loss = 1.7847
# Validation Loss: 1.6961
# Epoch 171, 100.0%, avg_loss = 1.7537
# Epoch 172, 100.0%, avg_loss = 1.8032
# Epoch 173, 100.0%, avg_loss = 1.8417
# Epoch 174, 100.0%, avg_loss = 1.8795
# Epoch 175, 100.0%, avg_loss = 1.7640
# Validation Loss: 1.7785
# Epoch 176, 100.0%, avg_loss = 1.8245
# Epoch 177, 100.0%, avg_loss = 1.8007
# Epoch 178, 100.0%, avg_loss = 1.6210
# Epoch 179, 100.0%, avg_loss = 1.7914
# Epoch 180, 100.0%, avg_loss = 1.8124
# Validation Loss: 1.7238
# Epoch 181, 100.0%, avg_loss = 1.7104
# Epoch 182, 100.0%, avg_loss = 1.7241
# Epoch 183, 100.0%, avg_loss = 1.6837
# Epoch 184, 100.0%, avg_loss = 1.7768
# Epoch 185, 100.0%, avg_loss = 1.7543
# Validation Loss: 1.7524
# Epoch 186, 100.0%, avg_loss = 1.6798
# Epoch 187, 100.0%, avg_loss = 1.7648
# Epoch 188, 100.0%, avg_loss = 1.8166
# Epoch 189, 100.0%, avg_loss = 1.8219
# Epoch 190, 100.0%, avg_loss = 1.6626
# Validation Loss: 1.8276
# Epoch 191, 100.0%, avg_loss = 1.7778
# Epoch 192, 100.0%, avg_loss = 1.7858
# Epoch 193, 100.0%, avg_loss = 1.7152
# Epoch 194, 100.0%, avg_loss = 1.8437
# Epoch 195, 100.0%, avg_loss = 1.7324
# Validation Loss: 1.7302
# Epoch 196, 100.0%, avg_loss = 1.7710
# Epoch 197, 100.0%, avg_loss = 1.8028
# Epoch 198, 100.0%, avg_loss = 1.7113
# Epoch 199, 100.0%, avg_loss = 1.7383
# Epoch 200, 100.0%, avg_loss = 1.6626
# Validation Loss: 1.7252
# Epoch 201, 100.0%, avg_loss = 1.7375
# Epoch 202, 100.0%, avg_loss = 1.7359
# Epoch 203, 100.0%, avg_loss = 1.7739
# Epoch 204, 100.0%, avg_loss = 1.7102
# Epoch 205, 100.0%, avg_loss = 1.8066
# Validation Loss: 1.8054
# Epoch 206, 100.0%, avg_loss = 1.8077
# Epoch 207, 100.0%, avg_loss = 1.7584
# Epoch 208, 100.0%, avg_loss = 1.7747
# Epoch 209, 100.0%, avg_loss = 1.8580
# Epoch 210, 100.0%, avg_loss = 1.7180
# Validation Loss: 1.7272
# Epoch 211, 100.0%, avg_loss = 1.6851
# Epoch 212, 100.0%, avg_loss = 1.7097
# Epoch 213, 100.0%, avg_loss = 1.7331
# Epoch 214, 100.0%, avg_loss = 1.7457
# Epoch 215, 100.0%, avg_loss = 1.6773
# Validation Loss: 1.7608
# Epoch 216, 100.0%, avg_loss = 1.7558
# Epoch 217, 100.0%, avg_loss = 1.6896
# Epoch 218, 100.0%, avg_loss = 1.7389
# Epoch 219, 100.0%, avg_loss = 1.7680
# Epoch 220, 100.0%, avg_loss = 1.8155
# Validation Loss: 1.7942
# Epoch 221, 100.0%, avg_loss = 1.6893
# Epoch 222, 100.0%, avg_loss = 1.7182
# Epoch 223, 100.0%, avg_loss = 1.7012
# Epoch 224, 100.0%, avg_loss = 1.8114
# Epoch 225, 100.0%, avg_loss = 1.7850
# Validation Loss: 1.7331
# Epoch 226, 100.0%, avg_loss = 1.7736
# Epoch 227, 100.0%, avg_loss = 1.8632
# Epoch 228, 100.0%, avg_loss = 1.7506
# Epoch 229, 100.0%, avg_loss = 1.7338
# Epoch 230, 100.0%, avg_loss = 1.7790
# Validation Loss: 1.7467
# Epoch 231, 100.0%, avg_loss = 1.7587
# Epoch 232, 100.0%, avg_loss = 1.6367
# Epoch 233, 100.0%, avg_loss = 1.6664
# Epoch 234, 100.0%, avg_loss = 1.7304
# Epoch 235, 100.0%, avg_loss = 1.6770
# Validation Loss: 1.6930
# Epoch 236, 100.0%, avg_loss = 1.6744
# Epoch 237, 100.0%, avg_loss = 1.7048
# Epoch 238, 100.0%, avg_loss = 1.7302
# Epoch 239, 100.0%, avg_loss = 1.7413
# Epoch 240, 100.0%, avg_loss = 1.6917
# Validation Loss: 1.7378
# Epoch 241, 100.0%, avg_loss = 1.6283
# Epoch 242, 100.0%, avg_loss = 1.6970
# Epoch 243, 100.0%, avg_loss = 1.7185
# Epoch 244, 100.0%, avg_loss = 1.6200
# Epoch 245, 100.0%, avg_loss = 1.6680
# Validation Loss: 1.7303
# Epoch 246, 100.0%, avg_loss = 1.7207
# Epoch 247, 100.0%, avg_loss = 1.6958
# Epoch 248, 100.0%, avg_loss = 1.7175
# Epoch 249, 100.0%, avg_loss = 1.6274
# Epoch 250, 100.0%, avg_loss = 1.7483
# Validation Loss: 1.6962
# Epoch 251, 100.0%, avg_loss = 1.6823
# Epoch 252, 100.0%, avg_loss = 1.7390
# Epoch 253, 100.0%, avg_loss = 1.7966
# Epoch 254, 100.0%, avg_loss = 1.6174
# Epoch 255, 100.0%, avg_loss = 1.7824
# Validation Loss: 1.6960
# Epoch 256, 100.0%, avg_loss = 1.6930
# Epoch 257, 100.0%, avg_loss = 1.7581
# Epoch 258, 100.0%, avg_loss = 1.7488
# Epoch 259, 100.0%, avg_loss = 1.7371
# Epoch 260, 100.0%, avg_loss = 1.7961
# Validation Loss: 1.7282
# Epoch 261, 100.0%, avg_loss = 1.7730
# Epoch 262, 100.0%, avg_loss = 1.7176
# Epoch 263, 100.0%, avg_loss = 1.6567
# Epoch 264, 100.0%, avg_loss = 1.8287
# Epoch 265, 100.0%, avg_loss = 1.6954
# Validation Loss: 1.7507
# Epoch 266, 100.0%, avg_loss = 1.6907
# Epoch 267, 100.0%, avg_loss = 1.7170
# Epoch 268, 100.0%, avg_loss = 1.6967
# Epoch 269, 100.0%, avg_loss = 1.8346
# Epoch 270, 100.0%, avg_loss = 1.7181
# Validation Loss: 1.7022
# Epoch 271, 100.0%, avg_loss = 1.7361
# Epoch 272, 100.0%, avg_loss = 1.6500
# Epoch 273, 100.0%, avg_loss = 1.7164
# Epoch 274, 100.0%, avg_loss = 1.6407
# Epoch 275, 100.0%, avg_loss = 1.7414
# Validation Loss: 1.7082
# Epoch 276, 100.0%, avg_loss = 1.7381
# Epoch 277, 100.0%, avg_loss = 1.6638
# Epoch 278, 100.0%, avg_loss = 1.6919
# Epoch 279, 100.0%, avg_loss = 1.7291
# Epoch 280, 100.0%, avg_loss = 1.7202
# Validation Loss: 1.7461
# Epoch 281, 100.0%, avg_loss = 1.6698
# Epoch 282, 100.0%, avg_loss = 1.7360
# Epoch 283, 100.0%, avg_loss = 1.6720
# Epoch 284, 100.0%, avg_loss = 1.6410
# Epoch 285, 100.0%, avg_loss = 1.6575
# Validation Loss: 1.7694
# Epoch 286, 100.0%, avg_loss = 1.6907
# Epoch 287, 100.0%, avg_loss = 1.6653
# Epoch 288, 100.0%, avg_loss = 1.6992
# Epoch 289, 100.0%, avg_loss = 1.6910
# Epoch 290, 100.0%, avg_loss = 1.7912
# Validation Loss: 1.6757
# Epoch 291, 100.0%, avg_loss = 1.7582
# Epoch 292, 100.0%, avg_loss = 1.6931
# Epoch 293, 100.0%, avg_loss = 1.6117
# Epoch 294, 100.0%, avg_loss = 1.7581
# Epoch 295, 100.0%, avg_loss = 1.6817
# Validation Loss: 1.6704
# Epoch 296, 100.0%, avg_loss = 1.7421
# Epoch 297, 100.0%, avg_loss = 1.7299
# Epoch 298, 100.0%, avg_loss = 1.8054
# Epoch 299, 100.0%, avg_loss = 1.7245
# Epoch 300, 100.0%, avg_loss = 1.7539
# Validation Loss: 1.7731
# Epoch 301, 100.0%, avg_loss = 1.7744
# Epoch 302, 100.0%, avg_loss = 1.7118
# Epoch 303, 100.0%, avg_loss = 1.6567
# Epoch 304, 100.0%, avg_loss = 1.6156
# Epoch 305, 100.0%, avg_loss = 1.7465
# Validation Loss: 1.6863
# Epoch 306, 100.0%, avg_loss = 1.6898
# Epoch 307, 100.0%, avg_loss = 1.6472
# Epoch 308, 100.0%, avg_loss = 1.6478
# Epoch 309, 100.0%, avg_loss = 1.6786
# Epoch 310, 100.0%, avg_loss = 1.6778
# Validation Loss: 1.7342
# Epoch 311, 100.0%, avg_loss = 1.7441
# Epoch 312, 100.0%, avg_loss = 1.6864
# Epoch 313, 100.0%, avg_loss = 1.7383
# Epoch 314, 100.0%, avg_loss = 1.7102
# Epoch 315, 100.0%, avg_loss = 1.6376
# Validation Loss: 1.6019
# Epoch 316, 100.0%, avg_loss = 1.7148
# Epoch 317, 100.0%, avg_loss = 1.7150
# Epoch 318, 100.0%, avg_loss = 1.7400
# Epoch 319, 100.0%, avg_loss = 1.6815
# Epoch 320, 100.0%, avg_loss = 1.7299
# Validation Loss: 1.6405
# Epoch 321, 100.0%, avg_loss = 1.6467
# Epoch 322, 100.0%, avg_loss = 1.6772
# Epoch 323, 100.0%, avg_loss = 1.6809
# Epoch 324, 100.0%, avg_loss = 1.6144
# Epoch 325, 100.0%, avg_loss = 1.6316
# Validation Loss: 1.7229
# Epoch 326, 100.0%, avg_loss = 1.7136
# Epoch 327, 100.0%, avg_loss = 1.6463
# Epoch 328, 100.0%, avg_loss = 1.6993
# Epoch 329, 100.0%, avg_loss = 1.7570
# Epoch 330, 100.0%, avg_loss = 1.7560
# Validation Loss: 1.7010
# Epoch 331, 100.0%, avg_loss = 1.6941
# Epoch 332, 100.0%, avg_loss = 1.6525
# Epoch 333, 100.0%, avg_loss = 1.6607
# Epoch 334, 100.0%, avg_loss = 1.6051
# Epoch 335, 100.0%, avg_loss = 1.6839
# Validation Loss: 1.6545
# Epoch 336, 100.0%, avg_loss = 1.6758
# Epoch 337, 100.0%, avg_loss = 1.6399
# Epoch 338, 100.0%, avg_loss = 1.6752
# Epoch 339, 100.0%, avg_loss = 1.6883
# Epoch 340, 100.0%, avg_loss = 1.6853
# Validation Loss: 1.6633
# Epoch 341, 100.0%, avg_loss = 1.6444
# Epoch 342, 100.0%, avg_loss = 1.6751
# Epoch 343, 100.0%, avg_loss = 1.6538
# Epoch 344, 100.0%, avg_loss = 1.6602
# Epoch 345, 100.0%, avg_loss = 1.6507
# Validation Loss: 1.6805
# Epoch 346, 100.0%, avg_loss = 1.6647
# Epoch 347, 100.0%, avg_loss = 1.7214
# Epoch 348, 100.0%, avg_loss = 1.6582
# Epoch 349, 100.0%, avg_loss = 1.7081
# Epoch 350, 100.0%, avg_loss = 1.5928
# Validation Loss: 1.6468
# Epoch 351, 100.0%, avg_loss = 1.6900
# Epoch 352, 100.0%, avg_loss = 1.7514
# Epoch 353, 100.0%, avg_loss = 1.6960
# Epoch 354, 100.0%, avg_loss = 1.6402
# Epoch 355, 100.0%, avg_loss = 1.6644
# Validation Loss: 1.7040
# Epoch 356, 100.0%, avg_loss = 1.7277
# Epoch 357, 100.0%, avg_loss = 1.6874
# Epoch 358, 100.0%, avg_loss = 1.7249
# Epoch 359, 100.0%, avg_loss = 1.7060
# Epoch 360, 100.0%, avg_loss = 1.6965
# Validation Loss: 1.6705
# Epoch 361, 100.0%, avg_loss = 1.7623
# Epoch 362, 100.0%, avg_loss = 1.6694
# Epoch 363, 100.0%, avg_loss = 1.6342
# Epoch 364, 100.0%, avg_loss = 1.6765
# Epoch 365, 100.0%, avg_loss = 1.6318
# Validation Loss: 1.6353
# Epoch 366, 100.0%, avg_loss = 1.7152
# Epoch 367, 100.0%, avg_loss = 1.6154
# Epoch 368, 100.0%, avg_loss = 1.5915
# Epoch 369, 100.0%, avg_loss = 1.7557
# Epoch 370, 100.0%, avg_loss = 1.7357
# Validation Loss: 1.7294
# Epoch 371, 100.0%, avg_loss = 1.7599
# Epoch 372, 100.0%, avg_loss = 1.6632
# Epoch 373, 100.0%, avg_loss = 1.6656
# Epoch 374, 100.0%, avg_loss = 1.7290
# Epoch 375, 100.0%, avg_loss = 1.7140
# Validation Loss: 1.6817
# Epoch 376, 100.0%, avg_loss = 1.6132
# Epoch 377, 100.0%, avg_loss = 1.6497
# Epoch 378, 100.0%, avg_loss = 1.7157
# Epoch 379, 100.0%, avg_loss = 1.6585
# Epoch 380, 100.0%, avg_loss = 1.6631
# Validation Loss: 1.6640
# Epoch 381, 100.0%, avg_loss = 1.6428
# Epoch 382, 100.0%, avg_loss = 1.6229
# Epoch 383, 100.0%, avg_loss = 1.7128
# Epoch 384, 100.0%, avg_loss = 1.6490
# Epoch 385, 100.0%, avg_loss = 1.6415
# Validation Loss: 1.6937
# Epoch 386, 100.0%, avg_loss = 1.6691
# Epoch 387, 100.0%, avg_loss = 1.6347
# Epoch 388, 100.0%, avg_loss = 1.7964
# Epoch 389, 100.0%, avg_loss = 1.6338
# Epoch 390, 100.0%, avg_loss = 1.6695
# Validation Loss: 1.6900
# Epoch 391, 100.0%, avg_loss = 1.6610
# Epoch 392, 100.0%, avg_loss = 1.6429
# Epoch 393, 100.0%, avg_loss = 1.6813
# Epoch 394, 100.0%, avg_loss = 1.5975
# Epoch 395, 100.0%, avg_loss = 1.7169
# Validation Loss: 1.7054
# Epoch 396, 100.0%, avg_loss = 1.7533
# Epoch 397, 100.0%, avg_loss = 1.7315
# Epoch 398, 100.0%, avg_loss = 1.6334
# Epoch 399, 100.0%, avg_loss = 1.6061
# Epoch 400, 100.0%, avg_loss = 1.6769
# Validation Loss: 1.6884
# Epoch 401, 100.0%, avg_loss = 1.6639
# Epoch 402, 100.0%, avg_loss = 1.6962
# Epoch 403, 100.0%, avg_loss = 1.7475
# Epoch 404, 100.0%, avg_loss = 1.6862
# Epoch 405, 100.0%, avg_loss = 1.7671
# Validation Loss: 1.6419
# Epoch 406, 100.0%, avg_loss = 1.6428
# Epoch 407, 100.0%, avg_loss = 1.6905
# Epoch 408, 100.0%, avg_loss = 1.6720
# Epoch 409, 100.0%, avg_loss = 1.6676
# Epoch 410, 100.0%, avg_loss = 1.6309
# Validation Loss: 1.6595
# Epoch 411, 100.0%, avg_loss = 1.6667
# Epoch 412, 100.0%, avg_loss = 1.7026
# Epoch 413, 100.0%, avg_loss = 1.6789
# Epoch 414, 100.0%, avg_loss = 1.7096
# Epoch 415, 100.0%, avg_loss = 1.6771
# Validation Loss: 1.6827
# Epoch 416, 100.0%, avg_loss = 1.6718
# Epoch 417, 100.0%, avg_loss = 1.6336
# Epoch 418, 100.0%, avg_loss = 1.7179
# Epoch 419, 100.0%, avg_loss = 1.6227
# Epoch 420, 100.0%, avg_loss = 1.6492
# Validation Loss: 1.6751
# Epoch 421, 100.0%, avg_loss = 1.7016
# Epoch 422, 100.0%, avg_loss = 1.6867
# Epoch 423, 100.0%, avg_loss = 1.6791
# Epoch 424, 100.0%, avg_loss = 1.6954
# Epoch 425, 100.0%, avg_loss = 1.7419
# Validation Loss: 1.6593
# Epoch 426, 100.0%, avg_loss = 1.7027
# Epoch 427, 100.0%, avg_loss = 1.6398
# Epoch 428, 100.0%, avg_loss = 1.5619
# Epoch 429, 100.0%, avg_loss = 1.5687
# Epoch 430, 100.0%, avg_loss = 1.6685
# Validation Loss: 1.6366
# Epoch 431, 100.0%, avg_loss = 1.6438
# Epoch 432, 100.0%, avg_loss = 1.6807
# Epoch 433, 100.0%, avg_loss = 1.5759
# Epoch 434, 100.0%, avg_loss = 1.6222
# Epoch 435, 100.0%, avg_loss = 1.6827
# Validation Loss: 1.7519
# Epoch 436, 100.0%, avg_loss = 1.6861
# Epoch 437, 100.0%, avg_loss = 1.6595
# Epoch 438, 100.0%, avg_loss = 1.6828
# Epoch 439, 100.0%, avg_loss = 1.6682
# Epoch 440, 100.0%, avg_loss = 1.6482
# Validation Loss: 1.6825
# Epoch 441, 100.0%, avg_loss = 1.6738
# Epoch 442, 100.0%, avg_loss = 1.7303
# Epoch 443, 100.0%, avg_loss = 1.7246
# Epoch 444, 100.0%, avg_loss = 1.6358
# Epoch 445, 100.0%, avg_loss = 1.6737
# Validation Loss: 1.6227
# Epoch 446, 100.0%, avg_loss = 1.7283
# Epoch 447, 100.0%, avg_loss = 1.7105
# Epoch 448, 100.0%, avg_loss = 1.6169
# Epoch 449, 100.0%, avg_loss = 1.6746
# Epoch 450, 100.0%, avg_loss = 1.6879
# Validation Loss: 1.6668
# Epoch 451, 100.0%, avg_loss = 1.7115
# Epoch 452, 100.0%, avg_loss = 1.6324
# Epoch 453, 100.0%, avg_loss = 1.7611
# Epoch 454, 100.0%, avg_loss = 1.6485
# Epoch 455, 100.0%, avg_loss = 1.6713
# Validation Loss: 1.5850
# Epoch 456, 100.0%, avg_loss = 1.7273
# Epoch 457, 100.0%, avg_loss = 1.7601
# Epoch 458, 100.0%, avg_loss = 1.6871
# Epoch 459, 100.0%, avg_loss = 1.6607
# Epoch 460, 100.0%, avg_loss = 1.5989
# Validation Loss: 1.6903
# Epoch 461, 100.0%, avg_loss = 1.7037
# Epoch 462, 100.0%, avg_loss = 1.6315
# Epoch 463, 100.0%, avg_loss = 1.6712
# Epoch 464, 100.0%, avg_loss = 1.7007
# Epoch 465, 100.0%, avg_loss = 1.6038
# Validation Loss: 1.6703
# Epoch 466, 100.0%, avg_loss = 1.7050
# Epoch 467, 100.0%, avg_loss = 1.6644
# Epoch 468, 100.0%, avg_loss = 1.6484
# Epoch 469, 100.0%, avg_loss = 1.6562
# Epoch 470, 100.0%, avg_loss = 1.6636
# Validation Loss: 1.6590
# Epoch 471, 100.0%, avg_loss = 1.6346
# Epoch 472, 100.0%, avg_loss = 1.6232
# Epoch 473, 100.0%, avg_loss = 1.6382
# Epoch 474, 100.0%, avg_loss = 1.6854
# Epoch 475, 100.0%, avg_loss = 1.6082
# Validation Loss: 1.6915
# Epoch 476, 100.0%, avg_loss = 1.6581
# Epoch 477, 100.0%, avg_loss = 1.6386
# Epoch 478, 100.0%, avg_loss = 1.6317
# Epoch 479, 100.0%, avg_loss = 1.6504
# Epoch 480, 100.0%, avg_loss = 1.6689
# Validation Loss: 1.6951
# Epoch 481, 100.0%, avg_loss = 1.7390
# Epoch 482, 100.0%, avg_loss = 1.6826
# Epoch 483, 100.0%, avg_loss = 1.6856
# Epoch 484, 100.0%, avg_loss = 1.6636
# Epoch 485, 100.0%, avg_loss = 1.6150
# Validation Loss: 1.7029
# Epoch 486, 100.0%, avg_loss = 1.6172
# Epoch 487, 100.0%, avg_loss = 1.6570
# Epoch 488, 100.0%, avg_loss = 1.6582
# Epoch 489, 100.0%, avg_loss = 1.5951
# Epoch 490, 100.0%, avg_loss = 1.5811
# Validation Loss: 1.6427
# Epoch 491, 100.0%, avg_loss = 1.5367
# Epoch 492, 100.0%, avg_loss = 1.6158
# Epoch 493, 100.0%, avg_loss = 1.6302
# Epoch 494, 100.0%, avg_loss = 1.6512
# Epoch 495, 100.0%, avg_loss = 1.6958
# Validation Loss: 1.6590
# Epoch 496, 100.0%, avg_loss = 1.7126
# Epoch 497, 100.0%, avg_loss = 1.6161
# Epoch 498, 100.0%, avg_loss = 1.6709
# Epoch 499, 100.0%, avg_loss = 1.6282
# Epoch 500, 100.0%, avg_loss = 1.6849
# Validation Loss: 1.6552
# Epoch 501, 100.0%, avg_loss = 1.6167
# Epoch 502, 100.0%, avg_loss = 1.7165
# Epoch 503, 100.0%, avg_loss = 1.6733
# Epoch 504, 100.0%, avg_loss = 1.6524
# Epoch 505, 100.0%, avg_loss = 1.6170
# Validation Loss: 1.6858
# Epoch 506, 100.0%, avg_loss = 1.6775
# Epoch 507, 100.0%, avg_loss = 1.6861
# Epoch 508, 100.0%, avg_loss = 1.6979
# Epoch 509, 100.0%, avg_loss = 1.6442
# Epoch 510, 100.0%, avg_loss = 1.6447
# Validation Loss: 1.5756
# Epoch 511, 100.0%, avg_loss = 1.6947
# Epoch 512, 100.0%, avg_loss = 1.7854
# Epoch 513, 100.0%, avg_loss = 1.5287
# Epoch 514, 100.0%, avg_loss = 1.5812
# Epoch 515, 100.0%, avg_loss = 1.6702
# Validation Loss: 1.6779
# Epoch 516, 100.0%, avg_loss = 1.5919
# Epoch 517, 100.0%, avg_loss = 1.6389
# Epoch 518, 100.0%, avg_loss = 1.6257
# Epoch 519, 100.0%, avg_loss = 1.6390
# Epoch 520, 100.0%, avg_loss = 1.6649
# Validation Loss: 1.5440
# Epoch 521, 100.0%, avg_loss = 1.6490
# Epoch 522, 100.0%, avg_loss = 1.5555
# Epoch 523, 100.0%, avg_loss = 1.6973
# Epoch 524, 100.0%, avg_loss = 1.6304
# Epoch 525, 100.0%, avg_loss = 1.6375
# Validation Loss: 1.6395
# Epoch 526, 100.0%, avg_loss = 1.5704
# Epoch 527, 100.0%, avg_loss = 1.7162
# Epoch 528, 100.0%, avg_loss = 1.6344
# Epoch 529, 100.0%, avg_loss = 1.6389
# Epoch 530, 100.0%, avg_loss = 1.5720
# Validation Loss: 1.6340
# Epoch 531, 100.0%, avg_loss = 1.6484
# Epoch 532, 100.0%, avg_loss = 1.6262
# Epoch 533, 100.0%, avg_loss = 1.6313
# Epoch 534, 100.0%, avg_loss = 1.6488
# Epoch 535, 100.0%, avg_loss = 1.6906
# Validation Loss: 1.6489
# Epoch 536, 100.0%, avg_loss = 1.6280
# Epoch 537, 100.0%, avg_loss = 1.6302
# Epoch 538, 100.0%, avg_loss = 1.6183
# Epoch 539, 100.0%, avg_loss = 1.5903
# Epoch 540, 100.0%, avg_loss = 1.5574
# Validation Loss: 1.5221
# Epoch 541, 100.0%, avg_loss = 1.6338
# Epoch 542, 100.0%, avg_loss = 1.5773
# Epoch 543, 100.0%, avg_loss = 1.6498
# Epoch 544, 100.0%, avg_loss = 1.6845
# Epoch 545, 100.0%, avg_loss = 1.6283
# Validation Loss: 1.6901
# Epoch 546, 100.0%, avg_loss = 1.6157
# Epoch 547, 100.0%, avg_loss = 1.5886
# Epoch 548, 100.0%, avg_loss = 1.6360
# Epoch 549, 100.0%, avg_loss = 1.6947
# Epoch 550, 100.0%, avg_loss = 1.5754
# Validation Loss: 1.6336
# Epoch 551, 100.0%, avg_loss = 1.5813
# Epoch 552, 100.0%, avg_loss = 1.5679
# Epoch 553, 100.0%, avg_loss = 1.6240
# Epoch 554, 100.0%, avg_loss = 1.6080
# Epoch 555, 100.0%, avg_loss = 1.6184
# Validation Loss: 1.6501
# Epoch 556, 100.0%, avg_loss = 1.5968
# Epoch 557, 100.0%, avg_loss = 1.5476
# Epoch 558, 100.0%, avg_loss = 1.6221
# Epoch 559, 100.0%, avg_loss = 1.6123
# Epoch 560, 100.0%, avg_loss = 1.6052
# Validation Loss: 1.6115
# Epoch 561, 100.0%, avg_loss = 1.7060
# Epoch 562, 100.0%, avg_loss = 1.6453
# Epoch 563, 100.0%, avg_loss = 1.7107
# Epoch 564, 100.0%, avg_loss = 1.6069
# Epoch 565, 100.0%, avg_loss = 1.6061
# Validation Loss: 1.5753
# Epoch 566, 100.0%, avg_loss = 1.5721
# Epoch 567, 100.0%, avg_loss = 1.5800
# Epoch 568, 100.0%, avg_loss = 1.6043
# Epoch 569, 100.0%, avg_loss = 1.6376
# Epoch 570, 100.0%, avg_loss = 1.6692
# Validation Loss: 1.6486
# Epoch 571, 100.0%, avg_loss = 1.6330
# Epoch 572, 100.0%, avg_loss = 1.6001
# Epoch 573, 100.0%, avg_loss = 1.5904
# Epoch 574, 100.0%, avg_loss = 1.6087
# Epoch 575, 100.0%, avg_loss = 1.5533
# Validation Loss: 1.6121
# Epoch 576, 100.0%, avg_loss = 1.6157
# Epoch 577, 100.0%, avg_loss = 1.6519
# Epoch 578, 100.0%, avg_loss = 1.6421
# Epoch 579, 100.0%, avg_loss = 1.6969
# Epoch 580, 100.0%, avg_loss = 1.5149
# Validation Loss: 1.6098
# Epoch 581, 100.0%, avg_loss = 1.5628
# Epoch 582, 100.0%, avg_loss = 1.6528
# Epoch 583, 100.0%, avg_loss = 1.5820
# Epoch 584, 100.0%, avg_loss = 1.6386
# Epoch 585, 100.0%, avg_loss = 1.6456
# Validation Loss: 1.6164
# Epoch 586, 100.0%, avg_loss = 1.6036
# Epoch 587, 100.0%, avg_loss = 1.5944
# Epoch 588, 100.0%, avg_loss = 1.5908
# Epoch 589, 100.0%, avg_loss = 1.5808
# Epoch 590, 100.0%, avg_loss = 1.5768
# Validation Loss: 1.5790
# Epoch 591, 100.0%, avg_loss = 1.6698
# Epoch 592, 100.0%, avg_loss = 1.6015
# Epoch 593, 100.0%, avg_loss = 1.6658
# Epoch 594, 100.0%, avg_loss = 1.6147
# Epoch 595, 100.0%, avg_loss = 1.6270
# Validation Loss: 1.6312
# Epoch 596, 100.0%, avg_loss = 1.6030
# Epoch 597, 100.0%, avg_loss = 1.6792
# Epoch 598, 100.0%, avg_loss = 1.6091
# Epoch 599, 100.0%, avg_loss = 1.5619
# Epoch 600, 100.0%, avg_loss = 1.5967
# Validation Loss: 1.6423
# Epoch 601, 100.0%, avg_loss = 1.5816
# Epoch 602, 100.0%, avg_loss = 1.6085
# Epoch 603, 100.0%, avg_loss = 1.5842
# Epoch 604, 100.0%, avg_loss = 1.6302
# Epoch 605, 100.0%, avg_loss = 1.5935
# Validation Loss: 1.6444
# Epoch 606, 100.0%, avg_loss = 1.6190
# Epoch 607, 100.0%, avg_loss = 1.6055
# Epoch 608, 100.0%, avg_loss = 1.6021
# Epoch 609, 100.0%, avg_loss = 1.5263
# Epoch 610, 100.0%, avg_loss = 1.5930
# Validation Loss: 1.6277
# Epoch 611, 100.0%, avg_loss = 1.6940
# Epoch 612, 100.0%, avg_loss = 1.6538
# Epoch 613, 100.0%, avg_loss = 1.6212
# Epoch 614, 100.0%, avg_loss = 1.5867
# Epoch 615, 100.0%, avg_loss = 1.6478
# Validation Loss: 1.6043
# Epoch 616, 100.0%, avg_loss = 1.5881
# Epoch 617, 100.0%, avg_loss = 1.5760
# Epoch 618, 100.0%, avg_loss = 1.6395
# Epoch 619, 100.0%, avg_loss = 1.6375
# Epoch 620, 100.0%, avg_loss = 1.6144
# Validation Loss: 1.6654
# Epoch 621, 100.0%, avg_loss = 1.5901
# Epoch 622, 100.0%, avg_loss = 1.6048
# Epoch 623, 100.0%, avg_loss = 1.6456
# Epoch 624, 100.0%, avg_loss = 1.5548
# Epoch 625, 100.0%, avg_loss = 1.6259
# Validation Loss: 1.5752
# Epoch 626, 100.0%, avg_loss = 1.5350
# Epoch 627, 100.0%, avg_loss = 1.6111
# Epoch 628, 100.0%, avg_loss = 1.5651
# Epoch 629, 100.0%, avg_loss = 1.7069
# Epoch 630, 100.0%, avg_loss = 1.6331
# Validation Loss: 1.6936
# Epoch 631, 100.0%, avg_loss = 1.4863
# Epoch 632, 100.0%, avg_loss = 1.5971
# Epoch 633, 100.0%, avg_loss = 1.5836
# Epoch 634, 100.0%, avg_loss = 1.6007
# Epoch 635, 100.0%, avg_loss = 1.6044
# Validation Loss: 1.6193
# Epoch 636, 100.0%, avg_loss = 1.5992
# Epoch 637, 100.0%, avg_loss = 1.5526
# Epoch 638, 100.0%, avg_loss = 1.5766
# Epoch 639, 100.0%, avg_loss = 1.6146
# Epoch 640, 100.0%, avg_loss = 1.6919
# Validation Loss: 1.5707
# Epoch 641, 100.0%, avg_loss = 1.6163
# Epoch 642, 100.0%, avg_loss = 1.6447
# Epoch 643, 100.0%, avg_loss = 1.6476
# Epoch 644, 100.0%, avg_loss = 1.5736
# Epoch 645, 100.0%, avg_loss = 1.5897
# Validation Loss: 1.6107
# Epoch 646, 100.0%, avg_loss = 1.5657
# Epoch 647, 100.0%, avg_loss = 1.6173
# Epoch 648, 100.0%, avg_loss = 1.5992
# Epoch 649, 100.0%, avg_loss = 1.5562
# Epoch 650, 100.0%, avg_loss = 1.6390
# Validation Loss: 1.6010
# Epoch 651, 100.0%, avg_loss = 1.6254
# Epoch 652, 100.0%, avg_loss = 1.6308
# Epoch 653, 100.0%, avg_loss = 1.6965
# Epoch 654, 100.0%, avg_loss = 1.5828
# Epoch 655, 100.0%, avg_loss = 1.6787
# Validation Loss: 1.6489
# Epoch 656, 100.0%, avg_loss = 1.5748
# Epoch 657, 100.0%, avg_loss = 1.5771
# Epoch 658, 100.0%, avg_loss = 1.5892
# Epoch 659, 100.0%, avg_loss = 1.5941
# Epoch 660, 100.0%, avg_loss = 1.6393
# Validation Loss: 1.6854
# Epoch 661, 100.0%, avg_loss = 1.6134
# Epoch 662, 100.0%, avg_loss = 1.5769
# Epoch 663, 100.0%, avg_loss = 1.5724
# Epoch 664, 100.0%, avg_loss = 1.5338
# Epoch 665, 100.0%, avg_loss = 1.6260
# Validation Loss: 1.6656
# Epoch 666, 100.0%, avg_loss = 1.7303
# Epoch 667, 100.0%, avg_loss = 1.6180
# Epoch 668, 100.0%, avg_loss = 1.6157
# Epoch 669, 100.0%, avg_loss = 1.6678
# Epoch 670, 100.0%, avg_loss = 1.6288
# Validation Loss: 1.5769
# Epoch 671, 100.0%, avg_loss = 1.5155
# Epoch 672, 100.0%, avg_loss = 1.5272
# Epoch 673, 100.0%, avg_loss = 1.6099
# Epoch 674, 100.0%, avg_loss = 1.5945
# Epoch 675, 100.0%, avg_loss = 1.5533
# Validation Loss: 1.6350
# Epoch 676, 100.0%, avg_loss = 1.5530
# Epoch 677, 100.0%, avg_loss = 1.6177
# Epoch 678, 100.0%, avg_loss = 1.5465
# Epoch 679, 100.0%, avg_loss = 1.6486
# Epoch 680, 100.0%, avg_loss = 1.6225
# Validation Loss: 1.5873
# Epoch 681, 100.0%, avg_loss = 1.5740
# Epoch 682, 100.0%, avg_loss = 1.6107
# Epoch 683, 100.0%, avg_loss = 1.6242
# Epoch 684, 100.0%, avg_loss = 1.5724
# Epoch 685, 100.0%, avg_loss = 1.5823
# Validation Loss: 1.6011
# Epoch 686, 100.0%, avg_loss = 1.5740
# Epoch 687, 100.0%, avg_loss = 1.5946
# Epoch 688, 100.0%, avg_loss = 1.6647
# Epoch 689, 100.0%, avg_loss = 1.6090
# Epoch 690, 100.0%, avg_loss = 1.5921
# Validation Loss: 1.6089
# Epoch 691, 100.0%, avg_loss = 1.7041
# Epoch 692, 100.0%, avg_loss = 1.5435
# Epoch 693, 100.0%, avg_loss = 1.5872
# Epoch 694, 100.0%, avg_loss = 1.6960
# Epoch 695, 100.0%, avg_loss = 1.6550
# Validation Loss: 1.5887
# Epoch 696, 100.0%, avg_loss = 1.6833
# Epoch 697, 100.0%, avg_loss = 1.6321
# Epoch 698, 100.0%, avg_loss = 1.6205
# Epoch 699, 100.0%, avg_loss = 1.5690
# Epoch 700, 100.0%, avg_loss = 1.6152
# Validation Loss: 1.6079
# Epoch 701, 100.0%, avg_loss = 1.5550
# Epoch 702, 100.0%, avg_loss = 1.6352
# Epoch 703, 100.0%, avg_loss = 1.6085
# Epoch 704, 100.0%, avg_loss = 1.6972
# Epoch 705, 100.0%, avg_loss = 1.6182
# Validation Loss: 1.6098
# Epoch 706, 100.0%, avg_loss = 1.6597
# Epoch 707, 100.0%, avg_loss = 1.6415
# Epoch 708, 100.0%, avg_loss = 1.5990
# Epoch 709, 100.0%, avg_loss = 1.5829
# Epoch 710, 100.0%, avg_loss = 1.6026
# Validation Loss: 1.6117
# Epoch 711, 100.0%, avg_loss = 1.5675
# Epoch 712, 100.0%, avg_loss = 1.6860
# Epoch 713, 100.0%, avg_loss = 1.6094
# Epoch 714, 100.0%, avg_loss = 1.6260
# Epoch 715, 100.0%, avg_loss = 1.5537
# Validation Loss: 1.6332
# Epoch 716, 100.0%, avg_loss = 1.6129
# Epoch 717, 100.0%, avg_loss = 1.6589
# Epoch 718, 100.0%, avg_loss = 1.7320
# Epoch 719, 100.0%, avg_loss = 1.6460
# Epoch 720, 100.0%, avg_loss = 1.6186
# Validation Loss: 1.6111
# Epoch 721, 100.0%, avg_loss = 1.5266
# Epoch 722, 100.0%, avg_loss = 1.6245
# Epoch 723, 100.0%, avg_loss = 1.5883
# Epoch 724, 100.0%, avg_loss = 1.5723
# Epoch 725, 100.0%, avg_loss = 1.6245
# Validation Loss: 1.6212
# Epoch 726, 100.0%, avg_loss = 1.6488
# Epoch 727, 100.0%, avg_loss = 1.5809
# Epoch 728, 100.0%, avg_loss = 1.6113
# Epoch 729, 100.0%, avg_loss = 1.6115
# Epoch 730, 100.0%, avg_loss = 1.5842
# Validation Loss: 1.6404
# Epoch 731, 100.0%, avg_loss = 1.6807
# Epoch 732, 100.0%, avg_loss = 1.6868
# Epoch 733, 100.0%, avg_loss = 1.6138
# Epoch 734, 100.0%, avg_loss = 1.6047
# Epoch 735, 100.0%, avg_loss = 1.5748
# Validation Loss: 1.5912
# Epoch 736, 100.0%, avg_loss = 1.6899
# Epoch 737, 100.0%, avg_loss = 1.5562
# Epoch 738, 100.0%, avg_loss = 1.6339
# Epoch 739, 100.0%, avg_loss = 1.6578
# Epoch 740, 100.0%, avg_loss = 1.6233
# Validation Loss: 1.6102
# Epoch 741, 100.0%, avg_loss = 1.5679
# Epoch 742, 100.0%, avg_loss = 1.5292
# Epoch 743, 100.0%, avg_loss = 1.5181
# Epoch 744, 100.0%, avg_loss = 1.5880
# Epoch 745, 100.0%, avg_loss = 1.6057
# Validation Loss: 1.6248
# Epoch 746, 100.0%, avg_loss = 1.5856
# Epoch 747, 100.0%, avg_loss = 1.6286
# Epoch 748, 100.0%, avg_loss = 1.5615
# Epoch 749, 100.0%, avg_loss = 1.5556
# Epoch 750, 100.0%, avg_loss = 1.6120
# Validation Loss: 1.6097
# Epoch 751, 100.0%, avg_loss = 1.6255
# Epoch 752, 100.0%, avg_loss = 1.5090
# Epoch 753, 100.0%, avg_loss = 1.5478
# Epoch 754, 100.0%, avg_loss = 1.6375
# Epoch 755, 100.0%, avg_loss = 1.6128
# Validation Loss: 1.6651
# Epoch 756, 100.0%, avg_loss = 1.6392
# Epoch 757, 100.0%, avg_loss = 1.6261
# Epoch 758, 100.0%, avg_loss = 1.6178
# Epoch 759, 100.0%, avg_loss = 1.6826
# Epoch 760, 100.0%, avg_loss = 1.6465
# Validation Loss: 1.6328
# Epoch 761, 100.0%, avg_loss = 1.5483
# Epoch 762, 100.0%, avg_loss = 1.7011
# Epoch 763, 100.0%, avg_loss = 1.6727
# Epoch 764, 100.0%, avg_loss = 1.6145
# Epoch 765, 100.0%, avg_loss = 1.5093
# Validation Loss: 1.6352
# Epoch 766, 100.0%, avg_loss = 1.6555
# Epoch 767, 100.0%, avg_loss = 1.6031
# Epoch 768, 100.0%, avg_loss = 1.6040
# Epoch 769, 100.0%, avg_loss = 1.5856
# Epoch 770, 100.0%, avg_loss = 1.6231
# Validation Loss: 1.6016
# Epoch 771, 100.0%, avg_loss = 1.5486
# Epoch 772, 100.0%, avg_loss = 1.6270
# Epoch 773, 100.0%, avg_loss = 1.5719
# Epoch 774, 100.0%, avg_loss = 1.6177
# Epoch 775, 100.0%, avg_loss = 1.5466
# Validation Loss: 1.6279
# Epoch 776, 100.0%, avg_loss = 1.7068
# Epoch 777, 100.0%, avg_loss = 1.6576
# Epoch 778, 100.0%, avg_loss = 1.5965
# Epoch 779, 100.0%, avg_loss = 1.5941
# Epoch 780, 100.0%, avg_loss = 1.6717
# Validation Loss: 1.5985
# Epoch 781, 100.0%, avg_loss = 1.5495
# Epoch 782, 100.0%, avg_loss = 1.6700
# Epoch 783, 100.0%, avg_loss = 1.5934
# Epoch 784, 100.0%, avg_loss = 1.5585
# Epoch 785, 100.0%, avg_loss = 1.5922
# Validation Loss: 1.6059
# Epoch 786, 100.0%, avg_loss = 1.5795
# Epoch 787, 100.0%, avg_loss = 1.6043
# Epoch 788, 100.0%, avg_loss = 1.6115
# Epoch 789, 100.0%, avg_loss = 1.6400
# Epoch 790, 100.0%, avg_loss = 1.6040
# Validation Loss: 1.6440
# Epoch 791, 100.0%, avg_loss = 1.5762
# Epoch 792, 100.0%, avg_loss = 1.5691
# Epoch 793, 100.0%, avg_loss = 1.5778
# Epoch 794, 100.0%, avg_loss = 1.5624
# Epoch 795, 100.0%, avg_loss = 1.5952
# Validation Loss: 1.6421
# Epoch 796, 100.0%, avg_loss = 1.6130
# Epoch 797, 100.0%, avg_loss = 1.5330
# Epoch 798, 100.0%, avg_loss = 1.6128
# Epoch 799, 100.0%, avg_loss = 1.6655
# Epoch 800, 100.0%, avg_loss = 1.5880
# Validation Loss: 1.6708
# Epoch 801, 100.0%, avg_loss = 1.6158
# Epoch 802, 100.0%, avg_loss = 1.6161
# Epoch 803, 100.0%, avg_loss = 1.6473
# Epoch 804, 100.0%, avg_loss = 1.6268
# Epoch 805, 100.0%, avg_loss = 1.5099
# Validation Loss: 1.6271
# Epoch 806, 100.0%, avg_loss = 1.6448
# Epoch 807, 100.0%, avg_loss = 1.5644
# Epoch 808, 100.0%, avg_loss = 1.5821
# Epoch 809, 100.0%, avg_loss = 1.5683
# Epoch 810, 100.0%, avg_loss = 1.6097
# Validation Loss: 1.6598
# Epoch 811, 100.0%, avg_loss = 1.6107
# Epoch 812, 100.0%, avg_loss = 1.5680
# Epoch 813, 100.0%, avg_loss = 1.5395
# Epoch 814, 100.0%, avg_loss = 1.5883
# Epoch 815, 100.0%, avg_loss = 1.6219
# Validation Loss: 1.6175
# Epoch 816, 100.0%, avg_loss = 1.6269
# Epoch 817, 100.0%, avg_loss = 1.6349
# Epoch 818, 100.0%, avg_loss = 1.5580
# Epoch 819, 100.0%, avg_loss = 1.5587
# Epoch 820, 100.0%, avg_loss = 1.5882
# Validation Loss: 1.6534
# Epoch 821, 100.0%, avg_loss = 1.5390
# Epoch 822, 100.0%, avg_loss = 1.5784
# Epoch 823, 100.0%, avg_loss = 1.6447
# Epoch 824, 100.0%, avg_loss = 1.5547
# Epoch 825, 100.0%, avg_loss = 1.6221
# Validation Loss: 1.6127
# Epoch 826, 100.0%, avg_loss = 1.5767
# Epoch 827, 100.0%, avg_loss = 1.6144
# Epoch 828, 100.0%, avg_loss = 1.6831
# Epoch 829, 100.0%, avg_loss = 1.6700
# Epoch 830, 100.0%, avg_loss = 1.5415
# Validation Loss: 1.6325
# Epoch 831, 100.0%, avg_loss = 1.5521
# Epoch 832, 100.0%, avg_loss = 1.6761
# Epoch 833, 100.0%, avg_loss = 1.6038
# Epoch 834, 100.0%, avg_loss = 1.5581
# Epoch 835, 100.0%, avg_loss = 1.5535
# Validation Loss: 1.5500
# Epoch 836, 100.0%, avg_loss = 1.6115
# Epoch 837, 100.0%, avg_loss = 1.6028
# Epoch 838, 100.0%, avg_loss = 1.6316
# Epoch 839, 100.0%, avg_loss = 1.5689
# Epoch 840, 100.0%, avg_loss = 1.6163
# Validation Loss: 1.5974
# Epoch 841, 100.0%, avg_loss = 1.5888
# Epoch 842, 100.0%, avg_loss = 1.5828
# Epoch 843, 100.0%, avg_loss = 1.6899
# Epoch 844, 100.0%, avg_loss = 1.6019
# Epoch 845, 100.0%, avg_loss = 1.5923
# Validation Loss: 1.6365
# Epoch 846, 100.0%, avg_loss = 1.5756
# Epoch 847, 100.0%, avg_loss = 1.6032
# Epoch 848, 100.0%, avg_loss = 1.5844
# Epoch 849, 100.0%, avg_loss = 1.5889
# Epoch 850, 100.0%, avg_loss = 1.6242
# Validation Loss: 1.6281
# Epoch 851, 100.0%, avg_loss = 1.6251
# Epoch 852, 100.0%, avg_loss = 1.5930
# Epoch 853, 100.0%, avg_loss = 1.6332
# Epoch 854, 100.0%, avg_loss = 1.5282
# Epoch 855, 100.0%, avg_loss = 1.5698
# Validation Loss: 1.6065
# Epoch 856, 100.0%, avg_loss = 1.6811
# Epoch 857, 100.0%, avg_loss = 1.6040
# Epoch 858, 100.0%, avg_loss = 1.6284
# Epoch 859, 100.0%, avg_loss = 1.5869
# Epoch 860, 100.0%, avg_loss = 1.6199
# Validation Loss: 1.6372
# Epoch 861, 100.0%, avg_loss = 1.5869
# Epoch 862, 100.0%, avg_loss = 1.5468
# Epoch 863, 100.0%, avg_loss = 1.6167
# Epoch 864, 100.0%, avg_loss = 1.6208
# Epoch 865, 100.0%, avg_loss = 1.5927
# Validation Loss: 1.5925
# Epoch 866, 100.0%, avg_loss = 1.5813
# Epoch 867, 100.0%, avg_loss = 1.5523
# Epoch 868, 100.0%, avg_loss = 1.5383
# Epoch 869, 100.0%, avg_loss = 1.5919
# Epoch 870, 100.0%, avg_loss = 1.5679
# Validation Loss: 1.6841
# Epoch 871, 100.0%, avg_loss = 1.6298
# Epoch 872, 100.0%, avg_loss = 1.5598
# Epoch 873, 100.0%, avg_loss = 1.4908
# Epoch 874, 100.0%, avg_loss = 1.5923
# Epoch 875, 100.0%, avg_loss = 1.6368
# Validation Loss: 1.5652
# Epoch 876, 100.0%, avg_loss = 1.5458
# Epoch 877, 100.0%, avg_loss = 1.5763
# Epoch 878, 100.0%, avg_loss = 1.5866
# Epoch 879, 100.0%, avg_loss = 1.6040
# Epoch 880, 100.0%, avg_loss = 1.5632
# Validation Loss: 1.6177
# Epoch 881, 100.0%, avg_loss = 1.6244
# Epoch 882, 100.0%, avg_loss = 1.6455
# Epoch 883, 100.0%, avg_loss = 1.6027
# Epoch 884, 100.0%, avg_loss = 1.6088
# Epoch 885, 100.0%, avg_loss = 1.5948
# Validation Loss: 1.6253
# Epoch 886, 100.0%, avg_loss = 1.6530
# Epoch 887, 100.0%, avg_loss = 1.5529
# Epoch 888, 100.0%, avg_loss = 1.6570
# Epoch 889, 100.0%, avg_loss = 1.6039
# Epoch 890, 100.0%, avg_loss = 1.5654
# Validation Loss: 1.6328
# Epoch 891, 100.0%, avg_loss = 1.5062
# Epoch 892, 100.0%, avg_loss = 1.5472
# Epoch 893, 100.0%, avg_loss = 1.6968
# Epoch 894, 100.0%, avg_loss = 1.6278
# Epoch 895, 100.0%, avg_loss = 1.5061
# Validation Loss: 1.5615
# Epoch 896, 100.0%, avg_loss = 1.6388
# Epoch 897, 100.0%, avg_loss = 1.6324
# Epoch 898, 100.0%, avg_loss = 1.5463
# Epoch 899, 100.0%, avg_loss = 1.5897
# Epoch 900, 100.0%, avg_loss = 1.6144
# Validation Loss: 1.5885
# Epoch 901, 100.0%, avg_loss = 1.5999
# Epoch 902, 100.0%, avg_loss = 1.5541
# Epoch 903, 100.0%, avg_loss = 1.6394
# Epoch 904, 100.0%, avg_loss = 1.5841
# Epoch 905, 100.0%, avg_loss = 1.6372
# Validation Loss: 1.5859
# Epoch 906, 100.0%, avg_loss = 1.6558
# Epoch 907, 100.0%, avg_loss = 1.5428
# Epoch 908, 100.0%, avg_loss = 1.6205
# Epoch 909, 100.0%, avg_loss = 1.5916
# Epoch 910, 100.0%, avg_loss = 1.6196
# Validation Loss: 1.6384
# Epoch 911, 100.0%, avg_loss = 1.6092
# Epoch 912, 100.0%, avg_loss = 1.6032
# Epoch 913, 100.0%, avg_loss = 1.6674
# Epoch 914, 100.0%, avg_loss = 1.5596
# Epoch 915, 100.0%, avg_loss = 1.5614
# Validation Loss: 1.6213
# Epoch 916, 100.0%, avg_loss = 1.5534
# Epoch 917, 100.0%, avg_loss = 1.5934
# Epoch 918, 100.0%, avg_loss = 1.6005
# Epoch 919, 100.0%, avg_loss = 1.5868
# Epoch 920, 100.0%, avg_loss = 1.5899
# Validation Loss: 1.6732
# Epoch 921, 100.0%, avg_loss = 1.4898
# Epoch 922, 100.0%, avg_loss = 1.5757
# Epoch 923, 100.0%, avg_loss = 1.6171
# Epoch 924, 100.0%, avg_loss = 1.5606
# Epoch 925, 100.0%, avg_loss = 1.5607
# Validation Loss: 1.5957
# Epoch 926, 100.0%, avg_loss = 1.6139
# Epoch 927, 100.0%, avg_loss = 1.5863
# Epoch 928, 100.0%, avg_loss = 1.6382
# Epoch 929, 100.0%, avg_loss = 1.5355
# Epoch 930, 100.0%, avg_loss = 1.5609
# Validation Loss: 1.6483
# Epoch 931, 100.0%, avg_loss = 1.6530
# Epoch 932, 100.0%, avg_loss = 1.7270
# Epoch 933, 100.0%, avg_loss = 1.5931
# Epoch 934, 100.0%, avg_loss = 1.6080
# Epoch 935, 100.0%, avg_loss = 1.5676
# Validation Loss: 1.5918
# Epoch 936, 100.0%, avg_loss = 1.5905
# Epoch 937, 100.0%, avg_loss = 1.5612
# Epoch 938, 100.0%, avg_loss = 1.5740
# Epoch 939, 100.0%, avg_loss = 1.5239
# Epoch 940, 100.0%, avg_loss = 1.6205
# Validation Loss: 1.6399
# Epoch 941, 100.0%, avg_loss = 1.6165
# Epoch 942, 100.0%, avg_loss = 1.7263
# Epoch 943, 100.0%, avg_loss = 1.6024
# Epoch 944, 100.0%, avg_loss = 1.6448
# Epoch 945, 100.0%, avg_loss = 1.6267
# Validation Loss: 1.6135
# Epoch 946, 100.0%, avg_loss = 1.5894
# Epoch 947, 100.0%, avg_loss = 1.5972
# Epoch 948, 100.0%, avg_loss = 1.5795
# Epoch 949, 100.0%, avg_loss = 1.6134
# Epoch 950, 100.0%, avg_loss = 1.5628
# Validation Loss: 1.6304
# Epoch 951, 100.0%, avg_loss = 1.5988
# Epoch 952, 100.0%, avg_loss = 1.6126
# Epoch 953, 100.0%, avg_loss = 1.5887
# Epoch 954, 100.0%, avg_loss = 1.5924
# Epoch 955, 100.0%, avg_loss = 1.5706
# Validation Loss: 1.6163
# Epoch 956, 100.0%, avg_loss = 1.6028
# Epoch 957, 100.0%, avg_loss = 1.5461
# Epoch 958, 100.0%, avg_loss = 1.5526
# Epoch 959, 100.0%, avg_loss = 1.5570
# Epoch 960, 100.0%, avg_loss = 1.6482
# Validation Loss: 1.6525
# Epoch 961, 100.0%, avg_loss = 1.6499
# Epoch 962, 100.0%, avg_loss = 1.5777
# Epoch 963, 100.0%, avg_loss = 1.6060
# Epoch 964, 100.0%, avg_loss = 1.6459
# Epoch 965, 100.0%, avg_loss = 1.6126
# Validation Loss: 1.5703
# Epoch 966, 100.0%, avg_loss = 1.5836
# Epoch 967, 100.0%, avg_loss = 1.5641
# Epoch 968, 100.0%, avg_loss = 1.5517
# Epoch 969, 100.0%, avg_loss = 1.5550
# Epoch 970, 100.0%, avg_loss = 1.5694
# Validation Loss: 1.6080
# Epoch 971, 100.0%, avg_loss = 1.6558
# Epoch 972, 100.0%, avg_loss = 1.5873
# Epoch 973, 100.0%, avg_loss = 1.5604
# Epoch 974, 100.0%, avg_loss = 1.5430
# Epoch 975, 100.0%, avg_loss = 1.6160
# Validation Loss: 1.6009
# Epoch 976, 100.0%, avg_loss = 1.6065
# Epoch 977, 100.0%, avg_loss = 1.6178
# Epoch 978, 100.0%, avg_loss = 1.5977
# Epoch 979, 100.0%, avg_loss = 1.7094
# Epoch 980, 100.0%, avg_loss = 1.6645
# Validation Loss: 1.5697
# Epoch 981, 100.0%, avg_loss = 1.5414
# Epoch 982, 100.0%, avg_loss = 1.5513
# Epoch 983, 100.0%, avg_loss = 1.7373
# Epoch 984, 100.0%, avg_loss = 1.6728
# Epoch 985, 100.0%, avg_loss = 1.5644
# Validation Loss: 1.6457
# Epoch 986, 100.0%, avg_loss = 1.6015
# Epoch 987, 100.0%, avg_loss = 1.6684
# Epoch 988, 100.0%, avg_loss = 1.5317
# Epoch 989, 100.0%, avg_loss = 1.6519
# Epoch 990, 100.0%, avg_loss = 1.5378
# Validation Loss: 1.5369
# Epoch 991, 100.0%, avg_loss = 1.6094
# Epoch 992, 100.0%, avg_loss = 1.5793
# Epoch 993, 100.0%, avg_loss = 1.5896
# Epoch 994, 100.0%, avg_loss = 1.5328
# Epoch 995, 100.0%, avg_loss = 1.6157
# Validation Loss: 1.6883
# Epoch 996, 100.0%, avg_loss = 1.5945
# Epoch 997, 100.0%, avg_loss = 1.6118
# Epoch 998, 100.0%, avg_loss = 1.6356
# Epoch 999, 100.0%, avg_loss = 1.5561
# Epoch 1000, 100.0%, avg_loss = 1.5695
# Validation Loss: 1.5949
# Epoch 1001, 100.0%, avg_loss = 1.6518
# Epoch 1002, 100.0%, avg_loss = 1.6329
# Epoch 1003, 100.0%, avg_loss = 1.6231
# Epoch 1004, 100.0%, avg_loss = 1.6125
# Epoch 1005, 100.0%, avg_loss = 1.6508
# Validation Loss: 1.5390
# Epoch 1006, 100.0%, avg_loss = 1.6301
# Epoch 1007, 100.0%, avg_loss = 1.5043
# Epoch 1008, 100.0%, avg_loss = 1.5751
# Epoch 1009, 100.0%, avg_loss = 1.6640
# Epoch 1010, 100.0%, avg_loss = 1.5063
# Validation Loss: 1.5614
# Epoch 1011, 100.0%, avg_loss = 1.5233
# Epoch 1012, 100.0%, avg_loss = 1.6110
# Epoch 1013, 100.0%, avg_loss = 1.6228
# Epoch 1014, 100.0%, avg_loss = 1.6023
# Epoch 1015, 100.0%, avg_loss = 1.6246
# Validation Loss: 1.6292
# Epoch 1016, 100.0%, avg_loss = 1.5504
# Epoch 1017, 100.0%, avg_loss = 1.4883
# Epoch 1018, 100.0%, avg_loss = 1.5096
# Epoch 1019, 100.0%, avg_loss = 1.6047
# Epoch 1020, 100.0%, avg_loss = 1.5691
# Validation Loss: 1.6752
# Epoch 1021, 100.0%, avg_loss = 1.6312
# Epoch 1022, 100.0%, avg_loss = 1.6007
# Epoch 1023, 100.0%, avg_loss = 1.5925
# Epoch 1024, 100.0%, avg_loss = 1.5556
# Epoch 1025, 100.0%, avg_loss = 1.6488
# Validation Loss: 1.5866
# Epoch 1026, 100.0%, avg_loss = 1.6016
# Epoch 1027, 100.0%, avg_loss = 1.5640
# Epoch 1028, 100.0%, avg_loss = 1.5942
# Epoch 1029, 100.0%, avg_loss = 1.5903
# Epoch 1030, 100.0%, avg_loss = 1.5150
# Validation Loss: 1.6091
# Epoch 1031, 100.0%, avg_loss = 1.5628
# Epoch 1032, 100.0%, avg_loss = 1.6224
# Epoch 1033, 100.0%, avg_loss = 1.6574
# Epoch 1034, 100.0%, avg_loss = 1.5608
# Epoch 1035, 100.0%, avg_loss = 1.5449
# Validation Loss: 1.5814
# Epoch 1036, 100.0%, avg_loss = 1.6470
# Epoch 1037, 100.0%, avg_loss = 1.5961
# Epoch 1038, 100.0%, avg_loss = 1.5787
# Epoch 1039, 100.0%, avg_loss = 1.5218
# Epoch 1040, 100.0%, avg_loss = 1.5635
# Validation Loss: 1.5537
# Epoch 1041, 100.0%, avg_loss = 1.5555
# Epoch 1042, 100.0%, avg_loss = 1.5839
# Epoch 1043, 100.0%, avg_loss = 1.4785
# Epoch 1044, 100.0%, avg_loss = 1.6029
# Epoch 1045, 100.0%, avg_loss = 1.5713
# Validation Loss: 1.6049
# Epoch 1046, 100.0%, avg_loss = 1.5536
# Epoch 1047, 100.0%, avg_loss = 1.5962
# Epoch 1048, 100.0%, avg_loss = 1.5903
# Epoch 1049, 100.0%, avg_loss = 1.6300
# Epoch 1050, 100.0%, avg_loss = 1.5882
# Validation Loss: 1.5863
# Epoch 1051, 100.0%, avg_loss = 1.5068
# Epoch 1052, 100.0%, avg_loss = 1.5437
# Epoch 1053, 100.0%, avg_loss = 1.6347
# Epoch 1054, 100.0%, avg_loss = 1.5800
# Epoch 1055, 100.0%, avg_loss = 1.6507
# Validation Loss: 1.5850
# Epoch 1056, 100.0%, avg_loss = 1.6071
# Epoch 1057, 100.0%, avg_loss = 1.5910
# Epoch 1058, 100.0%, avg_loss = 1.5668
# Epoch 1059, 100.0%, avg_loss = 1.6031
# Epoch 1060, 100.0%, avg_loss = 1.6107
# Validation Loss: 1.5562
# Epoch 1061, 100.0%, avg_loss = 1.5494
# Epoch 1062, 100.0%, avg_loss = 1.4977
# Epoch 1063, 100.0%, avg_loss = 1.6003
# Epoch 1064, 100.0%, avg_loss = 1.6055
# Epoch 1065, 100.0%, avg_loss = 1.6010
# Validation Loss: 1.5709
# Epoch 1066, 100.0%, avg_loss = 1.5207
# Epoch 1067, 100.0%, avg_loss = 1.6795
# Epoch 1068, 100.0%, avg_loss = 1.5906
# Epoch 1069, 100.0%, avg_loss = 1.5572
# Epoch 1070, 100.0%, avg_loss = 1.5456
# Validation Loss: 1.6469
# Epoch 1071, 100.0%, avg_loss = 1.5605
# Epoch 1072, 100.0%, avg_loss = 1.5772
# Epoch 1073, 100.0%, avg_loss = 1.5825
# Epoch 1074, 100.0%, avg_loss = 1.6180
# Epoch 1075, 100.0%, avg_loss = 1.6120
# Validation Loss: 1.6206
# Epoch 1076, 100.0%, avg_loss = 1.6203
# Epoch 1077, 100.0%, avg_loss = 1.5463
# Epoch 1078, 100.0%, avg_loss = 1.5518
# Epoch 1079, 100.0%, avg_loss = 1.5861
# Epoch 1080, 100.0%, avg_loss = 1.6165
# Validation Loss: 1.6015
# Epoch 1081, 100.0%, avg_loss = 1.6054
# Epoch 1082, 100.0%, avg_loss = 1.5704
# Epoch 1083, 100.0%, avg_loss = 1.6394
# Epoch 1084, 100.0%, avg_loss = 1.6119
# Epoch 1085, 100.0%, avg_loss = 1.6545
# Validation Loss: 1.6097
# Epoch 1086, 100.0%, avg_loss = 1.6537
# Epoch 1087, 100.0%, avg_loss = 1.5209
# Epoch 1088, 100.0%, avg_loss = 1.6162
# Epoch 1089, 100.0%, avg_loss = 1.5883
# Epoch 1090, 100.0%, avg_loss = 1.5869
# Validation Loss: 1.6352
# Epoch 1091, 100.0%, avg_loss = 1.5956
# Epoch 1092, 100.0%, avg_loss = 1.6234
# Epoch 1093, 100.0%, avg_loss = 1.6259
# Epoch 1094, 100.0%, avg_loss = 1.6304
# Epoch 1095, 100.0%, avg_loss = 1.5450
# Validation Loss: 1.6041
# Epoch 1096, 100.0%, avg_loss = 1.5714
# Epoch 1097, 100.0%, avg_loss = 1.6197
# Epoch 1098, 100.0%, avg_loss = 1.6615
# Epoch 1099, 100.0%, avg_loss = 1.5590
# Epoch 1100, 100.0%, avg_loss = 1.5547
# Validation Loss: 1.5113
# Epoch 1101, 100.0%, avg_loss = 1.6858
# Epoch 1102, 100.0%, avg_loss = 1.6088
# Epoch 1103, 100.0%, avg_loss = 1.5481
# Epoch 1104, 100.0%, avg_loss = 1.5856
# Epoch 1105, 100.0%, avg_loss = 1.5485
# Validation Loss: 1.5701
# Epoch 1106, 100.0%, avg_loss = 1.6492
# Epoch 1107, 100.0%, avg_loss = 1.6561
# Epoch 1108, 100.0%, avg_loss = 1.5227
# Epoch 1109, 100.0%, avg_loss = 1.5049
# Epoch 1110, 100.0%, avg_loss = 1.6061
# Validation Loss: 1.5556
# Epoch 1111, 100.0%, avg_loss = 1.6222
# Epoch 1112, 100.0%, avg_loss = 1.6059
# Epoch 1113, 100.0%, avg_loss = 1.5427
# Epoch 1114, 100.0%, avg_loss = 1.5693
# Epoch 1115, 100.0%, avg_loss = 1.5792
# Validation Loss: 1.5534
# Epoch 1116, 100.0%, avg_loss = 1.5597
# Epoch 1117, 100.0%, avg_loss = 1.6428
# Epoch 1118, 100.0%, avg_loss = 1.5663
# Epoch 1119, 100.0%, avg_loss = 1.5432
# Epoch 1120, 100.0%, avg_loss = 1.5758
# Validation Loss: 1.6107
# Epoch 1121, 100.0%, avg_loss = 1.6552
# Epoch 1122, 100.0%, avg_loss = 1.5107
# Epoch 1123, 100.0%, avg_loss = 1.5749
# Epoch 1124, 100.0%, avg_loss = 1.5078
# Epoch 1125, 100.0%, avg_loss = 1.4934
# Validation Loss: 1.5511
# Epoch 1126, 100.0%, avg_loss = 1.5044
# Epoch 1127, 100.0%, avg_loss = 1.5282
# Epoch 1128, 100.0%, avg_loss = 1.5607
# Epoch 1129, 100.0%, avg_loss = 1.5810
# Epoch 1130, 100.0%, avg_loss = 1.5688
# Validation Loss: 1.5581
# Epoch 1131, 100.0%, avg_loss = 1.4996
# Epoch 1132, 100.0%, avg_loss = 1.6085
# Epoch 1133, 100.0%, avg_loss = 1.5947
# Epoch 1134, 100.0%, avg_loss = 1.5585
# Epoch 1135, 100.0%, avg_loss = 1.4601
# Validation Loss: 1.5625
# Epoch 1136, 100.0%, avg_loss = 1.5276
# Epoch 1137, 100.0%, avg_loss = 1.6104
# Epoch 1138, 100.0%, avg_loss = 1.5787
# Epoch 1139, 100.0%, avg_loss = 1.6012
# Epoch 1140, 100.0%, avg_loss = 1.5800
# Validation Loss: 1.5866
# Epoch 1141, 100.0%, avg_loss = 1.6596
# Epoch 1142, 100.0%, avg_loss = 1.5263
# Epoch 1143, 100.0%, avg_loss = 1.6034
# Epoch 1144, 100.0%, avg_loss = 1.5588
# Epoch 1145, 100.0%, avg_loss = 1.5869
# Validation Loss: 1.5839
# Epoch 1146, 100.0%, avg_loss = 1.5067
# Epoch 1147, 100.0%, avg_loss = 1.6312
# ...
# Epoch 1628, 100.0%, avg_loss = 1.5773
# Epoch 1629, 100.0%, avg_loss = 1.6108
# Epoch 1630, 100.0%, avg_loss = 1.4941
# Validation Loss: 1.5230
# Epoch 1631, 100.0%, avg_loss = 1.5587
# Epoch 1632, 100.0%, avg_loss = 1.6175
# Epoch 1633, 100.0%, avg_loss = 1.5134
# Epoch 1634, 100.0%, avg_loss = 1.5866
# Epoch 1635, 100.0%, avg_loss = 1.5902
# Validation Loss: 1.5345
# Epoch 1636, 100.0%, avg_loss = 1.5007
# Epoch 1637, 100.0%, avg_loss = 1.5669
# Epoch 1638, 100.0%, avg_loss = 1.5174
# Epoch 1639, 100.0%, avg_loss = 1.4944
# Epoch 1640, 100.0%, avg_loss = 1.5891
# Validation Loss: 1.5195
# Epoch 1641, 100.0%, avg_loss = 1.5347
# Epoch 1642, 100.0%, avg_loss = 1.5471
# Epoch 1643, 100.0%, avg_loss = 1.5616
# Epoch 1644, 100.0%, avg_loss = 1.5420
# Epoch 1645, 100.0%, avg_loss = 1.5331
# Validation Loss: 1.5557
# Epoch 1646, 100.0%, avg_loss = 1.6015
# Epoch 1647, 100.0%, avg_loss = 1.5380
# Epoch 1648, 100.0%, avg_loss = 1.5344
# Epoch 1649, 100.0%, avg_loss = 1.5458
# Epoch 1650, 100.0%, avg_loss = 1.5216
# Validation Loss: 1.5852
# Epoch 1651, 100.0%, avg_loss = 1.5695
# Epoch 1652, 100.0%, avg_loss = 1.5164
# Epoch 1653, 100.0%, avg_loss = 1.4945
# Epoch 1654, 100.0%, avg_loss = 1.5883
# Epoch 1655, 100.0%, avg_loss = 1.5849
# Validation Loss: 1.5230
# Epoch 1656, 100.0%, avg_loss = 1.5705
# Epoch 1657, 100.0%, avg_loss = 1.4700
# Epoch 1658, 100.0%, avg_loss = 1.6175
# Epoch 1659, 100.0%, avg_loss = 1.6347
# Epoch 1660, 100.0%, avg_loss = 1.5709
# Validation Loss: 1.5473
# Epoch 1661, 100.0%, avg_loss = 1.6020
# Epoch 1662, 100.0%, avg_loss = 1.5418
# Epoch 1663, 100.0%, avg_loss = 1.6128
# Epoch 1664, 100.0%, avg_loss = 1.5780
# Epoch 1665, 100.0%, avg_loss = 1.5244
# Validation Loss: 1.4901
# Epoch 1666, 100.0%, avg_loss = 1.5854
# Epoch 1667, 100.0%, avg_loss = 1.5613
# Epoch 1668, 100.0%, avg_loss = 1.5945
# Epoch 1669, 100.0%, avg_loss = 1.5844
# Epoch 1670, 100.0%, avg_loss = 1.5433
# Validation Loss: 1.5692
# Epoch 1671, 100.0%, avg_loss = 1.4740
# Epoch 1672, 100.0%, avg_loss = 1.5895
# Epoch 1673, 100.0%, avg_loss = 1.5939
# Epoch 1674, 100.0%, avg_loss = 1.5039
# Epoch 1675, 100.0%, avg_loss = 1.5249
# Validation Loss: 1.5658
# Epoch 1676, 100.0%, avg_loss = 1.5574
# Epoch 1677, 100.0%, avg_loss = 1.6422
# Epoch 1678, 100.0%, avg_loss = 1.5784
# Epoch 1679, 100.0%, avg_loss = 1.5681
# Epoch 1680, 100.0%, avg_loss = 1.5884
# Validation Loss: 1.5377
# Epoch 1681, 100.0%, avg_loss = 1.5391
# Epoch 1682, 100.0%, avg_loss = 1.5543
# Epoch 1683, 100.0%, avg_loss = 1.5277
# Epoch 1684, 100.0%, avg_loss = 1.5567
# Epoch 1685, 100.0%, avg_loss = 1.5001
# Validation Loss: 1.5805
# Epoch 1686, 100.0%, avg_loss = 1.6154
# Epoch 1687, 100.0%, avg_loss = 1.5327
# Epoch 1688, 100.0%, avg_loss = 1.5580
# Epoch 1689, 100.0%, avg_loss = 1.6402
# Epoch 1690, 100.0%, avg_loss = 1.4410
# Validation Loss: 1.5143
# Epoch 1691, 100.0%, avg_loss = 1.6102
# Epoch 1692, 100.0%, avg_loss = 1.5380
# Epoch 1693, 100.0%, avg_loss = 1.5695
# Epoch 1694, 100.0%, avg_loss = 1.5818
# Epoch 1695, 100.0%, avg_loss = 1.5473
# Validation Loss: 1.5811
# Epoch 1696, 100.0%, avg_loss = 1.5596
# Epoch 1697, 100.0%, avg_loss = 1.5764
# Epoch 1698, 100.0%, avg_loss = 1.5221
# Epoch 1699, 100.0%, avg_loss = 1.5819
# Epoch 1700, 100.0%, avg_loss = 1.5470
# Validation Loss: 1.5784
# Epoch 1701, 100.0%, avg_loss = 1.6473
# Epoch 1702, 100.0%, avg_loss = 1.5757
# Epoch 1703, 100.0%, avg_loss = 1.5203
# Epoch 1704, 100.0%, avg_loss = 1.4728
# Epoch 1705, 100.0%, avg_loss = 1.5078
# Validation Loss: 1.6053
# Epoch 1706, 100.0%, avg_loss = 1.5108
# Epoch 1707, 100.0%, avg_loss = 1.5599
# Epoch 1708, 100.0%, avg_loss = 1.5343
# Epoch 1709, 100.0%, avg_loss = 1.5978
# Epoch 1710, 100.0%, avg_loss = 1.5732
# Validation Loss: 1.5732
# Epoch 1711, 100.0%, avg_loss = 1.5385
# Epoch 1712, 100.0%, avg_loss = 1.5312
# Epoch 1713, 100.0%, avg_loss = 1.5781
# Epoch 1714, 100.0%, avg_loss = 1.5666
# Epoch 1715, 100.0%, avg_loss = 1.5610
# Validation Loss: 1.5400
# Epoch 1716, 100.0%, avg_loss = 1.5498
# Epoch 1717, 100.0%, avg_loss = 1.5763
# Epoch 1718, 100.0%, avg_loss = 1.5130
# Epoch 1719, 100.0%, avg_loss = 1.6094
# Epoch 1720, 100.0%, avg_loss = 1.5923
# Validation Loss: 1.5873
# Epoch 1721, 100.0%, avg_loss = 1.6739
# Epoch 1722, 100.0%, avg_loss = 1.5844
# Epoch 1723, 100.0%, avg_loss = 1.5262
# Epoch 1724, 100.0%, avg_loss = 1.6028
# Epoch 1725, 100.0%, avg_loss = 1.5227
# Validation Loss: 1.5894
# Epoch 1726, 100.0%, avg_loss = 1.5312
# Epoch 1727, 100.0%, avg_loss = 1.5356
# Epoch 1728, 100.0%, avg_loss = 1.6141
# Epoch 1729, 100.0%, avg_loss = 1.5378
# Epoch 1730, 100.0%, avg_loss = 1.5492
# Validation Loss: 1.5383
# Epoch 1731, 100.0%, avg_loss = 1.6176
# Epoch 1732, 100.0%, avg_loss = 1.5573
# Epoch 1733, 100.0%, avg_loss = 1.5672
# Epoch 1734, 100.0%, avg_loss = 1.5702
# Epoch 1735, 100.0%, avg_loss = 1.5517
# Validation Loss: 1.5217
# Epoch 1736, 100.0%, avg_loss = 1.5792
# Epoch 1737, 100.0%, avg_loss = 1.5439
# Epoch 1738, 100.0%, avg_loss = 1.5586
# Epoch 1739, 100.0%, avg_loss = 1.6028
# Epoch 1740, 100.0%, avg_loss = 1.5267
# Validation Loss: 1.5542
# Epoch 1741, 100.0%, avg_loss = 1.5277
# Epoch 1742, 100.0%, avg_loss = 1.6331
# Epoch 1743, 100.0%, avg_loss = 1.5255
# Epoch 1744, 100.0%, avg_loss = 1.5506
# Epoch 1745, 100.0%, avg_loss = 1.5549
# Validation Loss: 1.5798
# Epoch 1746, 100.0%, avg_loss = 1.5577
# Epoch 1747, 100.0%, avg_loss = 1.5994
# Epoch 1748, 100.0%, avg_loss = 1.4857
# Epoch 1749, 100.0%, avg_loss = 1.5429
# Epoch 1750, 100.0%, avg_loss = 1.5323
# Validation Loss: 1.5302
# Epoch 1751, 100.0%, avg_loss = 1.6034
# Epoch 1752, 100.0%, avg_loss = 1.5106
# Epoch 1753, 100.0%, avg_loss = 1.5367
# Epoch 1754, 100.0%, avg_loss = 1.5912
# Epoch 1755, 100.0%, avg_loss = 1.5764
# Validation Loss: 1.5525
# Epoch 1756, 100.0%, avg_loss = 1.5257
# Epoch 1757, 100.0%, avg_loss = 1.4937
# Epoch 1758, 100.0%, avg_loss = 1.5487
# Epoch 1759, 100.0%, avg_loss = 1.4975
# Epoch 1760, 100.0%, avg_loss = 1.5148
# Validation Loss: 1.5293
# Epoch 1761, 100.0%, avg_loss = 1.5595
# Epoch 1762, 100.0%, avg_loss = 1.6006
# Epoch 1763, 100.0%, avg_loss = 1.5545
# Epoch 1764, 100.0%, avg_loss = 1.5450
# Epoch 1765, 100.0%, avg_loss = 1.5054
# Validation Loss: 1.5358
# Epoch 1766, 100.0%, avg_loss = 1.6367
# Epoch 1767, 100.0%, avg_loss = 1.4957
# Epoch 1768, 100.0%, avg_loss = 1.5905
# Epoch 1769, 100.0%, avg_loss = 1.5647
# Epoch 1770, 100.0%, avg_loss = 1.5460
# Validation Loss: 1.5853
# Epoch 1771, 100.0%, avg_loss = 1.5206
# Epoch 1772, 100.0%, avg_loss = 1.6370
# Epoch 1773, 100.0%, avg_loss = 1.5946
# Epoch 1774, 100.0%, avg_loss = 1.5855
# Epoch 1775, 100.0%, avg_loss = 1.4862
# Validation Loss: 1.5798
# Epoch 1776, 100.0%, avg_loss = 1.4604
# Epoch 1777, 100.0%, avg_loss = 1.5644
# Epoch 1778, 100.0%, avg_loss = 1.5855
# Epoch 1779, 100.0%, avg_loss = 1.5367
# Epoch 1780, 100.0%, avg_loss = 1.4978
# Validation Loss: 1.6087
# Epoch 1781, 100.0%, avg_loss = 1.5923
# Epoch 1782, 100.0%, avg_loss = 1.5179
# Epoch 1783, 100.0%, avg_loss = 1.6253
# Epoch 1784, 100.0%, avg_loss = 1.6190
# Epoch 1785, 100.0%, avg_loss = 1.5845
# Validation Loss: 1.5464
# Epoch 1786, 100.0%, avg_loss = 1.5293
# Epoch 1787, 100.0%, avg_loss = 1.4839
# Epoch 1788, 100.0%, avg_loss = 1.5077
# Epoch 1789, 100.0%, avg_loss = 1.5464
# Epoch 1790, 100.0%, avg_loss = 1.5720
# Validation Loss: 1.6103
# Epoch 1791, 100.0%, avg_loss = 1.5206
# Epoch 1792, 100.0%, avg_loss = 1.5073
# Epoch 1793, 100.0%, avg_loss = 1.6167
# Epoch 1794, 100.0%, avg_loss = 1.5170
# Epoch 1795, 100.0%, avg_loss = 1.5714
# Validation Loss: 1.5769
# Epoch 1796, 100.0%, avg_loss = 1.5745
# Epoch 1797, 100.0%, avg_loss = 1.5296
# Epoch 1798, 100.0%, avg_loss = 1.5952
# Epoch 1799, 100.0%, avg_loss = 1.6166
# Epoch 1800, 100.0%, avg_loss = 1.5574
# Validation Loss: 1.5435
# Epoch 1801, 100.0%, avg_loss = 1.5777
# Epoch 1802, 100.0%, avg_loss = 1.5485
# Epoch 1803, 100.0%, avg_loss = 1.5640
# Epoch 1804, 100.0%, avg_loss = 1.6298
# Epoch 1805, 100.0%, avg_loss = 1.5897
# Validation Loss: 1.5796
# Epoch 1806, 100.0%, avg_loss = 1.5673
# Epoch 1807, 100.0%, avg_loss = 1.5906
# Epoch 1808, 100.0%, avg_loss = 1.6016
# Epoch 1809, 100.0%, avg_loss = 1.5445
# Epoch 1810, 100.0%, avg_loss = 1.5233
# Validation Loss: 1.5262
# Epoch 1811, 100.0%, avg_loss = 1.6090
# Epoch 1812, 100.0%, avg_loss = 1.5213
# Epoch 1813, 100.0%, avg_loss = 1.5363
# Epoch 1814, 100.0%, avg_loss = 1.5688
# Epoch 1815, 100.0%, avg_loss = 1.5249
# Validation Loss: 1.5981
# Epoch 1816, 100.0%, avg_loss = 1.5093
# Epoch 1817, 100.0%, avg_loss = 1.6179
# Epoch 1818, 100.0%, avg_loss = 1.4884
# Epoch 1819, 100.0%, avg_loss = 1.5499
# Epoch 1820, 100.0%, avg_loss = 1.5614
# Validation Loss: 1.6054
# Epoch 1821, 100.0%, avg_loss = 1.6290
# Epoch 1822, 100.0%, avg_loss = 1.5457
# Epoch 1823, 100.0%, avg_loss = 1.4997
# Epoch 1824, 100.0%, avg_loss = 1.5134
# Epoch 1825, 100.0%, avg_loss = 1.5241
# Validation Loss: 1.5209
# Epoch 1826, 100.0%, avg_loss = 1.6082
# Epoch 1827, 100.0%, avg_loss = 1.5828
# Epoch 1828, 100.0%, avg_loss = 1.6210
# Epoch 1829, 100.0%, avg_loss = 1.4949
# Epoch 1830, 100.0%, avg_loss = 1.5494
# Validation Loss: 1.5550
# Epoch 1831, 100.0%, avg_loss = 1.5562
# Epoch 1832, 100.0%, avg_loss = 1.5755
# Epoch 1833, 100.0%, avg_loss = 1.5116
# Epoch 1834, 100.0%, avg_loss = 1.5921
# Epoch 1835, 100.0%, avg_loss = 1.5520
# Validation Loss: 1.6156
# Epoch 1836, 100.0%, avg_loss = 1.5693
# Epoch 1837, 100.0%, avg_loss = 1.5132
# Epoch 1838, 100.0%, avg_loss = 1.6046
# Epoch 1839, 100.0%, avg_loss = 1.4959
# Epoch 1840, 100.0%, avg_loss = 1.5278
# Validation Loss: 1.4753
# Epoch 1841, 100.0%, avg_loss = 1.5048
# Epoch 1842, 100.0%, avg_loss = 1.5400
# Epoch 1843, 100.0%, avg_loss = 1.5792
# Epoch 1844, 100.0%, avg_loss = 1.5902
# Epoch 1845, 100.0%, avg_loss = 1.5392
# Validation Loss: 1.5363
# Epoch 1846, 100.0%, avg_loss = 1.5782
# Epoch 1847, 100.0%, avg_loss = 1.6043
# Epoch 1848, 100.0%, avg_loss = 1.5471
# Epoch 1849, 100.0%, avg_loss = 1.5111
# Epoch 1850, 100.0%, avg_loss = 1.5683
# Validation Loss: 1.5531
# Epoch 1851, 100.0%, avg_loss = 1.5473
# Epoch 1852, 100.0%, avg_loss = 1.5879
# Epoch 1853, 100.0%, avg_loss = 1.5691
# Epoch 1854, 100.0%, avg_loss = 1.5903
# Epoch 1855, 100.0%, avg_loss = 1.5311
# Validation Loss: 1.5979
# Epoch 1856, 100.0%, avg_loss = 1.5799
# Epoch 1857, 100.0%, avg_loss = 1.5564
# Epoch 1858, 100.0%, avg_loss = 1.5496
# Epoch 1859, 100.0%, avg_loss = 1.6145
# Epoch 1860, 100.0%, avg_loss = 1.5865
# Validation Loss: 1.5636
# Epoch 1861, 100.0%, avg_loss = 1.4980
# Epoch 1862, 100.0%, avg_loss = 1.5752
# Epoch 1863, 100.0%, avg_loss = 1.4921
# Epoch 1864, 100.0%, avg_loss = 1.5697
# Epoch 1865, 100.0%, avg_loss = 1.4987
# Validation Loss: 1.6006
# Epoch 1866, 100.0%, avg_loss = 1.5533
# Epoch 1867, 100.0%, avg_loss = 1.5237
# Epoch 1868, 100.0%, avg_loss = 1.5234
# Epoch 1869, 100.0%, avg_loss = 1.5452
# Epoch 1870, 100.0%, avg_loss = 1.5110
# Validation Loss: 1.5779
# Epoch 1871, 100.0%, avg_loss = 1.5731
# Epoch 1872, 100.0%, avg_loss = 1.5566
# Epoch 1873, 100.0%, avg_loss = 1.5521
# Epoch 1874, 100.0%, avg_loss = 1.5230
# Epoch 1875, 100.0%, avg_loss = 1.5128
# Validation Loss: 1.5219
# Epoch 1876, 100.0%, avg_loss = 1.6406
# Epoch 1877, 100.0%, avg_loss = 1.5690
# Epoch 1878, 100.0%, avg_loss = 1.5368
# Epoch 1879, 100.0%, avg_loss = 1.5853
# Epoch 1880, 100.0%, avg_loss = 1.6128
# Validation Loss: 1.6234
# Epoch 1881, 100.0%, avg_loss = 1.6696
# Epoch 1882, 100.0%, avg_loss = 1.6725
# Epoch 1883, 100.0%, avg_loss = 1.5622
# Epoch 1884, 100.0%, avg_loss = 1.5606
# Epoch 1885, 100.0%, avg_loss = 1.6598
# Validation Loss: 1.6059
# Epoch 1886, 100.0%, avg_loss = 1.5752
# Epoch 1887, 100.0%, avg_loss = 1.5006
# Epoch 1888, 100.0%, avg_loss = 1.6267
# Epoch 1889, 100.0%, avg_loss = 1.5333
# Epoch 1890, 100.0%, avg_loss = 1.5947
# Validation Loss: 1.5938
# Epoch 1891, 100.0%, avg_loss = 1.5650
# Epoch 1892, 100.0%, avg_loss = 1.5833
# Epoch 1893, 100.0%, avg_loss = 1.5773
# Epoch 1894, 100.0%, avg_loss = 1.5767
# Epoch 1895, 100.0%, avg_loss = 1.6026
# Validation Loss: 1.5476
# Epoch 1896, 100.0%, avg_loss = 1.5408
# Epoch 1897, 100.0%, avg_loss = 1.5169
# Epoch 1898, 100.0%, avg_loss = 1.5690
# Epoch 1899, 100.0%, avg_loss = 1.6189
# Epoch 1900, 100.0%, avg_loss = 1.5150
# Validation Loss: 1.5352
# Epoch 1901, 100.0%, avg_loss = 1.5629
# Epoch 1902, 100.0%, avg_loss = 1.5480
# Epoch 1903, 100.0%, avg_loss = 1.5296
# Epoch 1904, 100.0%, avg_loss = 1.5907
# Epoch 1905, 100.0%, avg_loss = 1.5059
# Validation Loss: 1.5374
# Epoch 1906, 100.0%, avg_loss = 1.5132
# Epoch 1907, 100.0%, avg_loss = 1.5192
# Epoch 1908, 100.0%, avg_loss = 1.5589
# Epoch 1909, 100.0%, avg_loss = 1.6047
# Epoch 1910, 100.0%, avg_loss = 1.4668
# Validation Loss: 1.5963
# Epoch 1911, 100.0%, avg_loss = 1.5369
# Epoch 1912, 100.0%, avg_loss = 1.5430
# Epoch 1913, 100.0%, avg_loss = 1.5336
# Epoch 1914, 100.0%, avg_loss = 1.5990
# Epoch 1915, 100.0%, avg_loss = 1.5491
# Validation Loss: 1.5289
# Epoch 1916, 100.0%, avg_loss = 1.6003
# Epoch 1917, 100.0%, avg_loss = 1.4056
# Epoch 1918, 100.0%, avg_loss = 1.5137
# Epoch 1919, 100.0%, avg_loss = 1.4770
# Epoch 1920, 100.0%, avg_loss = 1.5357
# Validation Loss: 1.5809
# Epoch 1921, 100.0%, avg_loss = 1.5248
# Epoch 1922, 100.0%, avg_loss = 1.5040
# Epoch 1923, 100.0%, avg_loss = 1.5854
# Epoch 1924, 100.0%, avg_loss = 1.5842
# Epoch 1925, 100.0%, avg_loss = 1.6108
# Validation Loss: 1.5853
# Epoch 1926, 100.0%, avg_loss = 1.5628
# Epoch 1927, 100.0%, avg_loss = 1.5812
# Epoch 1928, 100.0%, avg_loss = 1.5624
# Epoch 1929, 100.0%, avg_loss = 1.5122
# Epoch 1930, 100.0%, avg_loss = 1.5241
# Validation Loss: 1.5975
# Epoch 1931, 100.0%, avg_loss = 1.5215
# Epoch 1932, 100.0%, avg_loss = 1.4893
# Epoch 1933, 100.0%, avg_loss = 1.5905
# Epoch 1934, 100.0%, avg_loss = 1.5028
# Epoch 1935, 100.0%, avg_loss = 1.4924
# Validation Loss: 1.4897
# Epoch 1936, 100.0%, avg_loss = 1.5642
# Epoch 1937, 100.0%, avg_loss = 1.5661
# Epoch 1938, 100.0%, avg_loss = 1.5570
# Epoch 1939, 100.0%, avg_loss = 1.5770
# Epoch 1940, 100.0%, avg_loss = 1.5506
# Validation Loss: 1.5802
# Epoch 1941, 100.0%, avg_loss = 1.5658
# Epoch 1942, 100.0%, avg_loss = 1.5899
# Epoch 1943, 100.0%, avg_loss = 1.5634
# Epoch 1944, 100.0%, avg_loss = 1.5257
# Epoch 1945, 100.0%, avg_loss = 1.5652
# Validation Loss: 1.5645
# Epoch 1946, 100.0%, avg_loss = 1.5085
# Epoch 1947, 100.0%, avg_loss = 1.5559
# Epoch 1948, 100.0%, avg_loss = 1.5261
# Epoch 1949, 100.0%, avg_loss = 1.5919
# Epoch 1950, 100.0%, avg_loss = 1.5535
# Validation Loss: 1.6310
# Epoch 1951, 100.0%, avg_loss = 1.4843
# Epoch 1952, 100.0%, avg_loss = 1.5485
# Epoch 1953, 100.0%, avg_loss = 1.5428
# Epoch 1954, 100.0%, avg_loss = 1.5741
# Epoch 1955, 100.0%, avg_loss = 1.5668
# Validation Loss: 1.5949
# Epoch 1956, 100.0%, avg_loss = 1.5890
# Epoch 1957, 100.0%, avg_loss = 1.5946
# Epoch 1958, 100.0%, avg_loss = 1.5666
# Epoch 1959, 100.0%, avg_loss = 1.5442
# Epoch 1960, 100.0%, avg_loss = 1.5023
# Validation Loss: 1.6199
# Epoch 1961, 100.0%, avg_loss = 1.4947
# Epoch 1962, 100.0%, avg_loss = 1.5603
# Epoch 1963, 100.0%, avg_loss = 1.5520
# Epoch 1964, 100.0%, avg_loss = 1.5963
# Epoch 1965, 100.0%, avg_loss = 1.5785
# Validation Loss: 1.5603
# Epoch 1966, 100.0%, avg_loss = 1.5942
# Epoch 1967, 100.0%, avg_loss = 1.4876
# Epoch 1968, 100.0%, avg_loss = 1.5833
# Epoch 1969, 100.0%, avg_loss = 1.5235
# Epoch 1970, 100.0%, avg_loss = 1.5562
# Validation Loss: 1.5789
# Epoch 1971, 100.0%, avg_loss = 1.5568
# Epoch 1972, 100.0%, avg_loss = 1.5598
# Epoch 1973, 100.0%, avg_loss = 1.5754
# Epoch 1974, 100.0%, avg_loss = 1.5755
# Epoch 1975, 100.0%, avg_loss = 1.5469
# Validation Loss: 1.5696
# Epoch 1976, 100.0%, avg_loss = 1.5514
# Epoch 1977, 100.0%, avg_loss = 1.5645
# Epoch 1978, 100.0%, avg_loss = 1.5882
# Epoch 1979, 100.0%, avg_loss = 1.5373
# Epoch 1980, 100.0%, avg_loss = 1.6489
# Validation Loss: 1.5185
# Epoch 1981, 100.0%, avg_loss = 1.6429
# Epoch 1982, 100.0%, avg_loss = 1.5270
# Epoch 1983, 100.0%, avg_loss = 1.5858
# Epoch 1984, 100.0%, avg_loss = 1.5294
# Epoch 1985, 100.0%, avg_loss = 1.5587
# Validation Loss: 1.5541
# Epoch 1986, 100.0%, avg_loss = 1.5618
# Epoch 1987, 100.0%, avg_loss = 1.5944
# Epoch 1988, 100.0%, avg_loss = 1.6097
# Epoch 1989, 100.0%, avg_loss = 1.5011
# Epoch 1990, 100.0%, avg_loss = 1.6054
# Validation Loss: 1.5595
# Epoch 1991, 100.0%, avg_loss = 1.5837
# Epoch 1992, 100.0%, avg_loss = 1.4813
# Epoch 1993, 100.0%, avg_loss = 1.5372
# Epoch 1994, 100.0%, avg_loss = 1.5569
# Epoch 1995, 100.0%, avg_loss = 1.5390
# Validation Loss: 1.4987
# Epoch 1996, 100.0%, avg_loss = 1.5585
# Epoch 1997, 100.0%, avg_loss = 1.5086
# Epoch 1998, 100.0%, avg_loss = 1.6115
# Epoch 1999, 100.0%, avg_loss = 1.6431
# Epoch 2000, 100.0%, avg_loss = 1.5301
# Validation Loss: 1.5621

# %%
torch.save(global_predictor, './results_osaka/global_predictor_fl.pytorch')

# %%
with open('./results_osaka/federated_global_predictor_training_loss.pk', 'wb') as f:
    pk.dump(training_loss, f)
with open('./results_osaka/federated_global_predictor_validation_loss.pk', 'wb') as f:
    pk.dump(validation_loss, f)

# %%
with torch.no_grad():

    cnt = 0
    avg_loss = 0.0

    for uid in data_qry_test:

        nk = data_qry_test[uid].shape[0]

        t = np.random.randint(T - 2 * dT + 1)
        x_loc_qry = data_qry_test[uid][:, t: t + dT]
        x_t_qry = torch.zeros_like(x_loc_qry) + t
        y = data_qry_test[uid][:, t + 2 * dT - 1]

        loss = global_predictor_server(x_loc_qry, x_t_qry, y)

        avg_loss += loss.item()
        cnt += nk

    print('Validation Loss: {:.4f}'.format(avg_loss / cnt))
